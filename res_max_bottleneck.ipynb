# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

batch_size = 4

std_transforms = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

std_trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=std_transforms)
trainloader = torch.utils.data.DataLoader(std_trainset, batch_size=batch_size,
                                          shuffle=True, num_workers=2)

validset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=std_transforms)
validloader = torch.utils.data.DataLoader(validset, batch_size=batch_size,
                                         shuffle=False, num_workers=2)

# If there are GPUs, choose the first one for computing. Otherwise use CPU.
device = torch.device("cuda:0" if torch.cuda.is_available() else ("mps" if torch.backends.mps.is_available() else "cpu"))

# the order for cifar10 10 classes
classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

print(device)
print(len(std_trainset))
print(len(trainloader))  
# If 'mps or cuda:0' is printed, it means GPU is available.
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# mps
# 50000
# 12500

# %% [markdown]
# #### Optional: Apply data augmentation

# %%
from custom_nn.datasets import CustomCIFAR10

# Additional focused augmentations
focused_augmentations = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
])

# using custom dataset class to add focused augmentations capability
aug_trainset = CustomCIFAR10(
    root='./data',
    train=True,
    download=True,
    transform=std_transforms,
    focused_transform=focused_augmentations
)

# the class we want the augmentation for birds, cats, deer, and dogs
desired_classes = [1, 2, 3, 4]

# Filter the dataset
filtered_indices = [i for i, (_, label) in enumerate(aug_trainset) if label in desired_classes]

filtered_dataset = torch.utils.data.Subset(aug_trainset, filtered_indices)

# Combine the two datasets
combined_trainset = torch.utils.data.ConcatDataset([std_trainset, filtered_dataset])
trainloader = torch.utils.data.DataLoader(combined_trainset, batch_size=batch_size,
                                          shuffle=True, num_workers=2)
print(len(combined_trainset))
print(len(trainloader))
# Out:
# Files already downloaded and verified
# 70000
# 17500

# %%
from custom_nn.blocks import BottleneckResBlock, ResBlock
class ResBottleneck(nn.Module):
    def __init__(self):
        super().__init__()
        
         ### RES 1
         
        # 3x32x32 to 20x32x32
        self.br1 = BottleneckResBlock(3, 10, 20)
        self.act1 = nn.ReLU()

        # 20x32x32 to 20x16x16
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        
        ### RES 2
        
        # 20x16x16 to 20x16x16
        self.br2 = BottleneckResBlock(20, 8, 20)
        self.act2 = nn.ReLU()
        # 20x16x16 to 20x8x8
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        
        ### RES 3
        
        # 20x8x8 to 20x8x8
        self.br3 = BottleneckResBlock(20, 8, 20)
        self.act3 = nn.ReLU()
        
        ### RES 4
        
        # 20x8x8 to 20x8x8
        self.br4 = BottleneckResBlock(20, 8, 20)
        self.act4 = nn.ReLU()
        
        ### RES 5
        
        # 20x8x8 to 20x8x8
        self.br5 = BottleneckResBlock(20, 8, 20)
        self.act5 = nn.ReLU()
        
                
        self.flatten = nn.Flatten(1)
        # 20x8x8 affine operation to hidden layer with 100 neurons
        self.fc1 = nn.Linear(20 * 8 * 8, 100)
        self.bn1 = nn.BatchNorm1d(100)
        self.act4 = nn.ReLU()
        
        # affine operation to output layer with 10 neurons
        self.fc2 = nn.Linear(100, 10)
        
    def forward(self, x):
        
        x = self.br1(x)
        x = self.act1(x)
        x = self.pool1(x)
    
        x = self.br2(x)
        x = self.act2(x)
        x = self.pool2(x)
        
        x = self.br3(x)
        x = self.act3(x)
        
        x = self.br4(x)
        x = self.act4(x)
        
        x = self.br5(x)
        x = self.act5(x)
                
        # flatten and pass through fully connected layers
        x = self.flatten(x)
        x = self.fc1(x)
        x = self.bn1(x)
        x = self.act4(x)
        x = self.fc2(x)
        return x
test = ResBottleneck()
test.to(device)
test(torch.randn(4, 3, 32, 32).to(device))
# Out:
# tensor([[ 0.0374,  0.3974, -0.2201, -0.3572, -0.8411,  0.5982,  0.5916, -0.4979,
#          -0.2669, -0.0617],
#         [-0.2219, -0.7491, -0.0133, -0.4631, -0.3678,  0.1656, -0.3359, -0.0752,
#          -0.1694,  0.4346],
#         [ 0.5927,  0.2553, -0.3928,  0.1637, -0.0761,  0.1033,  0.7636,  0.1770,
#          -0.1402, -0.4405],
#         [ 0.2855,  0.5875, -0.6148,  0.3858,  0.2037,  0.7654, -0.4870,  0.2119,
#          -0.3903,  0.3362]], device='mps:0', grad_fn=<LinearBackward0>)

# %%
from pathlib import Path
import time
from custom_nn.utils.model_utils import count_parameters, get_model_size

epoch_start = 0     # Start from epoch 0 or last checkpoint epoch
iter_n = len(trainloader)  # number of iteration per epoch
record_freq = 100 # how many times to record the loss and accuracy per epoch
print_freq = 100 # how many times to print the loss and accuracy per epoch
iter_n_per_record = iter_n // record_freq  # Record frequency.
iter_n_per_print = iter_n // print_freq # Print frequency, need to be multiple of record_freq.

# a number for computing running validation loss in each iteration.
train_per_valid = len(trainloader) / len(validloader)  

avg_train_losses, avg_valid_losses = [], []   # Avg. losses.
train_accuracies, valid_accuracies = [], []  # Train and test accuracies.
time_per_epoch = []  # Time per epoch.

model = ResBottleneck()     # Create the network instance.
# Move the network parameters to the specified device
# need to be done before passing to optimizer.
model.to(device)  

assert model(torch.randn(4, 3, 32, 32).to(device)).shape == torch.Size([4, 10])

# We use Adam as optimizer.
opt = optim.Adam(model.parameters(), lr=5e-4, betas=(0.9, 0.999), eps=1e-08, weight_decay=1e-4)
# We use cross-entropy as loss function.
loss_func = nn.CrossEntropyLoss() 

# add scheduling
# scheduler = optim.lr_scheduler.ExponentialLR(opt, gamma=0.8)
# scheduler = optim.lr_scheduler.StepLR(opt, step_size=5, gamma=0.8)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(opt, mode='max', factor=0.1, patience=4, threshold=1e-4)

# directory to save the model
directory_path = Path("./checkpoints/res_max_bottleneck" + "_batch" + str(batch_size))
# Make the directory if it doesn't exist
directory_path.mkdir(parents=True, exist_ok=True)

print("train_per_valid:", train_per_valid)

print("number of parameters:", count_parameters(model))
print('model size: {:.4f}MB'.format(get_model_size(model)))
# Out:
# train_per_valid: 7.0
# number of parameters: 136536
# model size: 0.5239MB

# %%
import re

# Pattern to match the files and extract epoch numbers
pattern = r'epoch_(\d+).pth'

# Use Path.glob to list all files matching the pattern
files = list(directory_path.glob('epoch_*.pth'))

# Extract epochs and files into a list of tuples
epoch_files = []
for file_path in files:
    match = re.search(pattern, file_path.name)
    if match:
        epoch_num = int(match.group(1))
        epoch_files.append((epoch_num, file_path))

# Sort the list by epoch number in descending order
epoch_files.sort(key=lambda x: x[0], reverse=False)

if epoch_files:
    # populating history for loss and accuracy for plotting
    for file in epoch_files:
        checkpoint = torch.load(file[1])
        avg_train_losses += checkpoint['avg_train_losses']
        avg_valid_losses += checkpoint['avg_valid_losses']
        train_accuracies.append(checkpoint['train_accuracy'])
        valid_accuracies.append(checkpoint['valid_accuracy'])
        time_per_epoch.append(checkpoint['time_per_epoch'])
    
    # load the model from the latest checkpoint file
    latest_file_path = epoch_files[-1][1]
    print(f"The latest checkpoint file is: {latest_file_path}")
    checkpoint = torch.load(latest_file_path)
    model.load_state_dict(checkpoint['model_state_dict'])
    opt.load_state_dict(checkpoint['optimizer_state_dict'])
    scheduler.load_state_dict(checkpoint['scheduler_state_dict'])
    
    # start training from the next epoch
    epoch_start = checkpoint['epoch'] + 1
else:
    print("No checkpoint files found.")
# Out:
# No checkpoint files found.

# %%
epochs = 10  # Total epochs.

for epoch in range(epoch_start, epoch_start + epochs):  # Loop over the dataset multiple times.
    running_train_loss = 0.0       # Initialize running train_loss for training set.
    running_val_loss = 0.0     # Initialize running train_loss for validation set.
    
    # Initialize running total and correct for computing train accuracy.
    train_correct = 0 
    train_total = 0
    # Initialize running total and correct for computing test accuracy.
    valid_total = 0   
    valid_correct = 0
    
    
    
    print('--> [Start of epoch {}]'.format(epoch) +
          '  lr: {:.6f}'.format(opt.param_groups[0]['lr']))
    
    # print('--> [Start of epoch {}]'.format(epoch))
    
    epoch_start_time = time.time()
    
    validiter = iter(validloader)
    for i, data in enumerate(iterable=trainloader, start=0):
        
        # Set the model to training mode.
        model.train()
        
        # Get the inputs.
        inputs, labels = data
        
        # Move the inputs to the specified device.
        inputs, labels = inputs.to(device), labels.to(device)
        
        # Zero the parameter gradients.
        opt.zero_grad()

        # Forward step
        train_output = model(inputs)
        train_loss = loss_func(train_output, labels)
        
        # Backward step.
        train_loss.backward()
        
        # Optimization step (update the parameters).
        opt.step()
        
        model.eval()
        
        # record statistics.
        running_train_loss += train_loss.item()
        
        # this is for recording training accuracy
        _, train_predicted = torch.max(train_output.data, 1)
        train_total += labels.size(0)
        train_correct += (train_predicted == labels).sum().item()
        
        # only iterate through validation set according to train_per_valid ratio
        if i % train_per_valid == train_per_valid - 1:
            # Set the model to evaluation mode.
            with torch.no_grad():
                valid_inputs, valid_labels = next(validiter)
                valid_inputs, valid_labels = valid_inputs.to(device), valid_labels.to(device)
                valid_output = model(valid_inputs)
                valid_loss = loss_func(valid_output, valid_labels)
                running_val_loss += valid_loss.item()
                
                _, valid_predicted = torch.max(valid_output.data, 1)
                valid_total += valid_labels.size(0)
                valid_correct += (valid_predicted == valid_labels).sum().item()
            
        # Record training/validation loss every several mini-batches.
        if i % iter_n_per_record == iter_n_per_record - 1: 
            avg_train_loss = running_train_loss / iter_n_per_record
            avg_train_losses.append(avg_train_loss)
            avg_valid_loss = train_per_valid * running_val_loss / iter_n_per_record
            avg_valid_losses.append(avg_valid_loss)
            running_train_loss, running_val_loss = 0.0, 0.0
            
            # only print traing training loss once in a while to avoid cluster output
            if i % iter_n_per_print == iter_n_per_print - 1:
                print('[epoch: {}, i: {:5d}]'.format(epoch, i) +
                      '  train_loss: {:.3f}'.format(avg_train_loss) + 
                      '  |  valid_loss: {:.3f}'.format(avg_valid_loss))
                            
    epoch_end_time = time.time()
    time_per_epoch.append(epoch_end_time - epoch_start_time)
    
    # calculating train accuracy
    train_accuracy = 100 * train_correct / train_total
    train_accuracies.append(train_accuracy)
    
    valid_accuracy = 100 * valid_correct / valid_total
    valid_accuracies.append(valid_accuracy)     
    
    # reduce on plateau scheduling
    scheduler.step(valid_accuracy)
    
    # Store the networks after each epochs.
    # in case we want to do simple average or weighted average
    file_name = f'epoch_{epoch:04d}.pth'
    save_path = directory_path / file_name
    
    torch.save({
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': opt.state_dict(),
            'scheduler_state_dict': scheduler.state_dict(),
            'avg_train_losses': avg_train_losses[epoch * iter_n_per_record : (epoch + 1) * iter_n_per_record],
            'avg_valid_losses': avg_valid_losses[epoch * iter_n_per_record : (epoch + 1) * iter_n_per_record],
            'train_accuracy': train_accuracies[epoch],
            'valid_accuracy': valid_accuracies[epoch],
            'time_per_epoch': time_per_epoch[epoch],
            }, save_path)
    
    print('--> [End of epoch {}]'.format(epoch) +
                      ' train_accuracy: {:.2f}%'.format(train_accuracy) + 
                      '  |  valid_accuracy: {:.2f}%'.format(valid_accuracy))

print('Finished Training.')
# Out:
# --> [Start of epoch 0]  lr: 0.000500
# [epoch: 0, i:   174]  train_loss: 2.184  |  valid_loss: 2.384
# [epoch: 0, i:   349]  train_loss: 2.087  |  valid_loss: 2.213
# [epoch: 0, i:   524]  train_loss: 1.959  |  valid_loss: 2.059
# [epoch: 0, i:   699]  train_loss: 1.916  |  valid_loss: 2.032
# [epoch: 0, i:   874]  train_loss: 1.878  |  valid_loss: 1.938
# [epoch: 0, i:  1049]  train_loss: 1.852  |  valid_loss: 1.914
# [epoch: 0, i:  1224]  train_loss: 1.854  |  valid_loss: 1.927
# [epoch: 0, i:  1399]  train_loss: 1.839  |  valid_loss: 1.794
# [epoch: 0, i:  1574]  train_loss: 1.890  |  valid_loss: 1.673
# [epoch: 0, i:  1749]  train_loss: 1.792  |  valid_loss: 1.669
# [epoch: 0, i:  1924]  train_loss: 1.758  |  valid_loss: 1.673
# [epoch: 0, i:  2099]  train_loss: 1.769  |  valid_loss: 1.700
# [epoch: 0, i:  2274]  train_loss: 1.760  |  valid_loss: 1.785
# [epoch: 0, i:  2449]  train_loss: 1.721  |  valid_loss: 1.796
# [epoch: 0, i:  2624]  train_loss: 1.731  |  valid_loss: 1.458
# [epoch: 0, i:  2799]  train_loss: 1.714  |  valid_loss: 1.609
# [epoch: 0, i:  2974]  train_loss: 1.782  |  valid_loss: 1.682
# [epoch: 0, i:  3149]  train_loss: 1.702  |  valid_loss: 1.645
# [epoch: 0, i:  3324]  train_loss: 1.726  |  valid_loss: 1.619
# [epoch: 0, i:  3499]  train_loss: 1.681  |  valid_loss: 1.566
# [epoch: 0, i:  3674]  train_loss: 1.698  |  valid_loss: 1.421
# [epoch: 0, i:  3849]  train_loss: 1.743  |  valid_loss: 1.594
# [epoch: 0, i:  4024]  train_loss: 1.701  |  valid_loss: 1.565
# [epoch: 0, i:  4199]  train_loss: 1.748  |  valid_loss: 1.652
# [epoch: 0, i:  4374]  train_loss: 1.693  |  valid_loss: 1.525
# [epoch: 0, i:  4549]  train_loss: 1.679  |  valid_loss: 1.844
# [epoch: 0, i:  4724]  train_loss: 1.694  |  valid_loss: 1.547
# [epoch: 0, i:  4899]  train_loss: 1.703  |  valid_loss: 1.552
# [epoch: 0, i:  5074]  train_loss: 1.642  |  valid_loss: 1.587
# [epoch: 0, i:  5249]  train_loss: 1.646  |  valid_loss: 1.475
# [epoch: 0, i:  5424]  train_loss: 1.672  |  valid_loss: 1.447
# [epoch: 0, i:  5599]  train_loss: 1.690  |  valid_loss: 1.519
# [epoch: 0, i:  5774]  train_loss: 1.610  |  valid_loss: 1.514
# [epoch: 0, i:  5949]  train_loss: 1.581  |  valid_loss: 1.578
# [epoch: 0, i:  6124]  train_loss: 1.594  |  valid_loss: 1.603
# [epoch: 0, i:  6299]  train_loss: 1.613  |  valid_loss: 1.391
# [epoch: 0, i:  6474]  train_loss: 1.630  |  valid_loss: 1.454
# [epoch: 0, i:  6649]  train_loss: 1.530  |  valid_loss: 1.536
# [epoch: 0, i:  6824]  train_loss: 1.607  |  valid_loss: 1.456
# [epoch: 0, i:  6999]  train_loss: 1.687  |  valid_loss: 1.537
# [epoch: 0, i:  7174]  train_loss: 1.559  |  valid_loss: 1.562
# [epoch: 0, i:  7349]  train_loss: 1.571  |  valid_loss: 1.444
# [epoch: 0, i:  7524]  train_loss: 1.533  |  valid_loss: 1.336
# [epoch: 0, i:  7699]  train_loss: 1.550  |  valid_loss: 1.515
# [epoch: 0, i:  7874]  train_loss: 1.612  |  valid_loss: 1.466
# [epoch: 0, i:  8049]  train_loss: 1.559  |  valid_loss: 1.384
# [epoch: 0, i:  8224]  train_loss: 1.513  |  valid_loss: 1.352
# [epoch: 0, i:  8399]  train_loss: 1.544  |  valid_loss: 1.479
# [epoch: 0, i:  8574]  train_loss: 1.499  |  valid_loss: 1.288
# [epoch: 0, i:  8749]  train_loss: 1.534  |  valid_loss: 1.394
# [epoch: 0, i:  8924]  train_loss: 1.522  |  valid_loss: 1.372
# [epoch: 0, i:  9099]  train_loss: 1.553  |  valid_loss: 1.465
# [epoch: 0, i:  9274]  train_loss: 1.506  |  valid_loss: 1.443
# [epoch: 0, i:  9449]  train_loss: 1.538  |  valid_loss: 1.566
# [epoch: 0, i:  9624]  train_loss: 1.542  |  valid_loss: 1.512
# [epoch: 0, i:  9799]  train_loss: 1.525  |  valid_loss: 1.431
# [epoch: 0, i:  9974]  train_loss: 1.510  |  valid_loss: 1.412
# [epoch: 0, i: 10149]  train_loss: 1.560  |  valid_loss: 1.265
# [epoch: 0, i: 10324]  train_loss: 1.522  |  valid_loss: 1.512
# [epoch: 0, i: 10499]  train_loss: 1.521  |  valid_loss: 1.294
# [epoch: 0, i: 10674]  train_loss: 1.488  |  valid_loss: 1.481
# [epoch: 0, i: 10849]  train_loss: 1.597  |  valid_loss: 1.299
# [epoch: 0, i: 11024]  train_loss: 1.489  |  valid_loss: 1.354
# [epoch: 0, i: 11199]  train_loss: 1.474  |  valid_loss: 1.470
# [epoch: 0, i: 11374]  train_loss: 1.556  |  valid_loss: 1.418
# [epoch: 0, i: 11549]  train_loss: 1.534  |  valid_loss: 1.339
# [epoch: 0, i: 11724]  train_loss: 1.515  |  valid_loss: 1.430
# [epoch: 0, i: 11899]  train_loss: 1.540  |  valid_loss: 1.413
# [epoch: 0, i: 12074]  train_loss: 1.420  |  valid_loss: 1.437
# [epoch: 0, i: 12249]  train_loss: 1.506  |  valid_loss: 1.550
# [epoch: 0, i: 12424]  train_loss: 1.564  |  valid_loss: 1.335
# [epoch: 0, i: 12599]  train_loss: 1.481  |  valid_loss: 1.325
# [epoch: 0, i: 12774]  train_loss: 1.458  |  valid_loss: 1.208
# [epoch: 0, i: 12949]  train_loss: 1.452  |  valid_loss: 1.153
# [epoch: 0, i: 13124]  train_loss: 1.427  |  valid_loss: 1.265
# [epoch: 0, i: 13299]  train_loss: 1.496  |  valid_loss: 1.462
# [epoch: 0, i: 13474]  train_loss: 1.599  |  valid_loss: 1.287
# [epoch: 0, i: 13649]  train_loss: 1.376  |  valid_loss: 1.287
# [epoch: 0, i: 13824]  train_loss: 1.538  |  valid_loss: 1.420
# [epoch: 0, i: 13999]  train_loss: 1.429  |  valid_loss: 1.348
# [epoch: 0, i: 14174]  train_loss: 1.371  |  valid_loss: 1.304
# [epoch: 0, i: 14349]  train_loss: 1.510  |  valid_loss: 1.366
# [epoch: 0, i: 14524]  train_loss: 1.426  |  valid_loss: 1.485
# [epoch: 0, i: 14699]  train_loss: 1.460  |  valid_loss: 1.476
# [epoch: 0, i: 14874]  train_loss: 1.481  |  valid_loss: 1.458
# [epoch: 0, i: 15049]  train_loss: 1.512  |  valid_loss: 1.234
# [epoch: 0, i: 15224]  train_loss: 1.444  |  valid_loss: 1.341
# [epoch: 0, i: 15399]  train_loss: 1.420  |  valid_loss: 1.312
# [epoch: 0, i: 15574]  train_loss: 1.379  |  valid_loss: 1.307
# [epoch: 0, i: 15749]  train_loss: 1.422  |  valid_loss: 1.245
# [epoch: 0, i: 15924]  train_loss: 1.380  |  valid_loss: 1.314
# [epoch: 0, i: 16099]  train_loss: 1.423  |  valid_loss: 1.296
# [epoch: 0, i: 16274]  train_loss: 1.491  |  valid_loss: 1.230
# [epoch: 0, i: 16449]  train_loss: 1.438  |  valid_loss: 1.286
# [epoch: 0, i: 16624]  train_loss: 1.455  |  valid_loss: 1.139
# [epoch: 0, i: 16799]  train_loss: 1.354  |  valid_loss: 1.256
# [epoch: 0, i: 16974]  train_loss: 1.474  |  valid_loss: 1.248
# [epoch: 0, i: 17149]  train_loss: 1.439  |  valid_loss: 1.296
# [epoch: 0, i: 17324]  train_loss: 1.405  |  valid_loss: 1.386
# [epoch: 0, i: 17499]  train_loss: 1.460  |  valid_loss: 1.348
# --> [End of epoch 0] train_accuracy: 42.56%  |  valid_accuracy: 46.09%
# --> [Start of epoch 1]  lr: 0.000500
# [epoch: 1, i:   174]  train_loss: 1.357  |  valid_loss: 1.141
# [epoch: 1, i:   349]  train_loss: 1.375  |  valid_loss: 1.294
# [epoch: 1, i:   524]  train_loss: 1.421  |  valid_loss: 1.299
# [epoch: 1, i:   699]  train_loss: 1.322  |  valid_loss: 1.204
# [epoch: 1, i:   874]  train_loss: 1.405  |  valid_loss: 1.281
# [epoch: 1, i:  1049]  train_loss: 1.308  |  valid_loss: 1.086
# [epoch: 1, i:  1224]  train_loss: 1.395  |  valid_loss: 1.143
# [epoch: 1, i:  1399]  train_loss: 1.343  |  valid_loss: 1.332
# [epoch: 1, i:  1574]  train_loss: 1.307  |  valid_loss: 1.183
# [epoch: 1, i:  1749]  train_loss: 1.435  |  valid_loss: 1.100
# [epoch: 1, i:  1924]  train_loss: 1.432  |  valid_loss: 1.175
# [epoch: 1, i:  2099]  train_loss: 1.409  |  valid_loss: 1.256
# [epoch: 1, i:  2274]  train_loss: 1.386  |  valid_loss: 1.451
# [epoch: 1, i:  2449]  train_loss: 1.379  |  valid_loss: 1.204
# [epoch: 1, i:  2624]  train_loss: 1.364  |  valid_loss: 1.051
# [epoch: 1, i:  2799]  train_loss: 1.420  |  valid_loss: 1.275
# [epoch: 1, i:  2974]  train_loss: 1.395  |  valid_loss: 1.183
# [epoch: 1, i:  3149]  train_loss: 1.343  |  valid_loss: 1.257
# [epoch: 1, i:  3324]  train_loss: 1.394  |  valid_loss: 1.117
# [epoch: 1, i:  3499]  train_loss: 1.341  |  valid_loss: 1.262
# [epoch: 1, i:  3674]  train_loss: 1.373  |  valid_loss: 1.125
# [epoch: 1, i:  3849]  train_loss: 1.376  |  valid_loss: 1.285
# [epoch: 1, i:  4024]  train_loss: 1.438  |  valid_loss: 1.095
# [epoch: 1, i:  4199]  train_loss: 1.395  |  valid_loss: 1.228
# [epoch: 1, i:  4374]  train_loss: 1.343  |  valid_loss: 1.177
# [epoch: 1, i:  4549]  train_loss: 1.320  |  valid_loss: 1.492
# [epoch: 1, i:  4724]  train_loss: 1.417  |  valid_loss: 1.173
# [epoch: 1, i:  4899]  train_loss: 1.348  |  valid_loss: 1.226
# [epoch: 1, i:  5074]  train_loss: 1.354  |  valid_loss: 1.251
# [epoch: 1, i:  5249]  train_loss: 1.413  |  valid_loss: 1.191
# [epoch: 1, i:  5424]  train_loss: 1.344  |  valid_loss: 1.103
# [epoch: 1, i:  5599]  train_loss: 1.349  |  valid_loss: 1.178
# [epoch: 1, i:  5774]  train_loss: 1.427  |  valid_loss: 1.176
# [epoch: 1, i:  5949]  train_loss: 1.398  |  valid_loss: 1.284
# [epoch: 1, i:  6124]  train_loss: 1.305  |  valid_loss: 1.362
# [epoch: 1, i:  6299]  train_loss: 1.293  |  valid_loss: 1.145
# [epoch: 1, i:  6474]  train_loss: 1.404  |  valid_loss: 1.362
# [epoch: 1, i:  6649]  train_loss: 1.312  |  valid_loss: 1.368
# [epoch: 1, i:  6824]  train_loss: 1.348  |  valid_loss: 1.095
# [epoch: 1, i:  6999]  train_loss: 1.420  |  valid_loss: 1.189
# [epoch: 1, i:  7174]  train_loss: 1.440  |  valid_loss: 1.287
# [epoch: 1, i:  7349]  train_loss: 1.341  |  valid_loss: 1.144
# [epoch: 1, i:  7524]  train_loss: 1.388  |  valid_loss: 1.124
# [epoch: 1, i:  7699]  train_loss: 1.372  |  valid_loss: 1.285
# [epoch: 1, i:  7874]  train_loss: 1.346  |  valid_loss: 1.292
# [epoch: 1, i:  8049]  train_loss: 1.365  |  valid_loss: 1.123
# [epoch: 1, i:  8224]  train_loss: 1.361  |  valid_loss: 1.121
# [epoch: 1, i:  8399]  train_loss: 1.298  |  valid_loss: 1.150
# [epoch: 1, i:  8574]  train_loss: 1.387  |  valid_loss: 1.116
# [epoch: 1, i:  8749]  train_loss: 1.321  |  valid_loss: 1.249
# [epoch: 1, i:  8924]  train_loss: 1.368  |  valid_loss: 1.213
# [epoch: 1, i:  9099]  train_loss: 1.310  |  valid_loss: 1.190
# [epoch: 1, i:  9274]  train_loss: 1.360  |  valid_loss: 1.106
# [epoch: 1, i:  9449]  train_loss: 1.373  |  valid_loss: 1.339
# [epoch: 1, i:  9624]  train_loss: 1.272  |  valid_loss: 1.156
# [epoch: 1, i:  9799]  train_loss: 1.307  |  valid_loss: 1.274
# [epoch: 1, i:  9974]  train_loss: 1.324  |  valid_loss: 1.157
# [epoch: 1, i: 10149]  train_loss: 1.356  |  valid_loss: 1.085
# [epoch: 1, i: 10324]  train_loss: 1.308  |  valid_loss: 1.404
# [epoch: 1, i: 10499]  train_loss: 1.399  |  valid_loss: 1.158
# [epoch: 1, i: 10674]  train_loss: 1.310  |  valid_loss: 1.348
# [epoch: 1, i: 10849]  train_loss: 1.354  |  valid_loss: 1.194
# [epoch: 1, i: 11024]  train_loss: 1.338  |  valid_loss: 1.202
# [epoch: 1, i: 11199]  train_loss: 1.272  |  valid_loss: 1.152
# [epoch: 1, i: 11374]  train_loss: 1.344  |  valid_loss: 1.158
# [epoch: 1, i: 11549]  train_loss: 1.315  |  valid_loss: 1.146
# [epoch: 1, i: 11724]  train_loss: 1.359  |  valid_loss: 1.265
# [epoch: 1, i: 11899]  train_loss: 1.374  |  valid_loss: 1.240
# [epoch: 1, i: 12074]  train_loss: 1.289  |  valid_loss: 1.264
# [epoch: 1, i: 12249]  train_loss: 1.355  |  valid_loss: 1.301
# [epoch: 1, i: 12424]  train_loss: 1.205  |  valid_loss: 1.100
# [epoch: 1, i: 12599]  train_loss: 1.267  |  valid_loss: 1.083
# [epoch: 1, i: 12774]  train_loss: 1.261  |  valid_loss: 1.028
# [epoch: 1, i: 12949]  train_loss: 1.451  |  valid_loss: 0.926
# [epoch: 1, i: 13124]  train_loss: 1.313  |  valid_loss: 1.131
# [epoch: 1, i: 13299]  train_loss: 1.280  |  valid_loss: 1.119
# [epoch: 1, i: 13474]  train_loss: 1.265  |  valid_loss: 1.224
# [epoch: 1, i: 13649]  train_loss: 1.378  |  valid_loss: 1.065
# [epoch: 1, i: 13824]  train_loss: 1.336  |  valid_loss: 1.261
# [epoch: 1, i: 13999]  train_loss: 1.297  |  valid_loss: 1.146
# [epoch: 1, i: 14174]  train_loss: 1.321  |  valid_loss: 1.044
# [epoch: 1, i: 14349]  train_loss: 1.335  |  valid_loss: 1.183
# [epoch: 1, i: 14524]  train_loss: 1.311  |  valid_loss: 1.173
# [epoch: 1, i: 14699]  train_loss: 1.249  |  valid_loss: 1.258
# [epoch: 1, i: 14874]  train_loss: 1.337  |  valid_loss: 1.217
# [epoch: 1, i: 15049]  train_loss: 1.356  |  valid_loss: 1.157
# [epoch: 1, i: 15224]  train_loss: 1.363  |  valid_loss: 1.132
# [epoch: 1, i: 15399]  train_loss: 1.291  |  valid_loss: 1.241
# [epoch: 1, i: 15574]  train_loss: 1.306  |  valid_loss: 1.209
# [epoch: 1, i: 15749]  train_loss: 1.345  |  valid_loss: 1.112
# [epoch: 1, i: 15924]  train_loss: 1.327  |  valid_loss: 1.109
# [epoch: 1, i: 16099]  train_loss: 1.358  |  valid_loss: 1.065
# [epoch: 1, i: 16274]  train_loss: 1.246  |  valid_loss: 1.092
# [epoch: 1, i: 16449]  train_loss: 1.320  |  valid_loss: 1.232
# [epoch: 1, i: 16624]  train_loss: 1.257  |  valid_loss: 1.028
# [epoch: 1, i: 16799]  train_loss: 1.311  |  valid_loss: 0.976
# [epoch: 1, i: 16974]  train_loss: 1.299  |  valid_loss: 1.039
# [epoch: 1, i: 17149]  train_loss: 1.312  |  valid_loss: 1.205
# [epoch: 1, i: 17324]  train_loss: 1.329  |  valid_loss: 1.164
# [epoch: 1, i: 17499]  train_loss: 1.350  |  valid_loss: 1.201
# --> [End of epoch 1] train_accuracy: 52.61%  |  valid_accuracy: 57.77%
# --> [Start of epoch 2]  lr: 0.000500
# [epoch: 2, i:   174]  train_loss: 1.254  |  valid_loss: 1.060
# [epoch: 2, i:   349]  train_loss: 1.170  |  valid_loss: 1.287
# [epoch: 2, i:   524]  train_loss: 1.316  |  valid_loss: 1.194
# [epoch: 2, i:   699]  train_loss: 1.270  |  valid_loss: 1.077
# [epoch: 2, i:   874]  train_loss: 1.317  |  valid_loss: 1.157
# [epoch: 2, i:  1049]  train_loss: 1.359  |  valid_loss: 0.878
# [epoch: 2, i:  1224]  train_loss: 1.268  |  valid_loss: 1.102
# [epoch: 2, i:  1399]  train_loss: 1.327  |  valid_loss: 1.189
# [epoch: 2, i:  1574]  train_loss: 1.302  |  valid_loss: 1.062
# [epoch: 2, i:  1749]  train_loss: 1.215  |  valid_loss: 0.972
# [epoch: 2, i:  1924]  train_loss: 1.305  |  valid_loss: 0.971
# [epoch: 2, i:  2099]  train_loss: 1.271  |  valid_loss: 1.124
# [epoch: 2, i:  2274]  train_loss: 1.278  |  valid_loss: 1.118
# [epoch: 2, i:  2449]  train_loss: 1.167  |  valid_loss: 1.069
# [epoch: 2, i:  2624]  train_loss: 1.258  |  valid_loss: 0.961
# [epoch: 2, i:  2799]  train_loss: 1.283  |  valid_loss: 1.204
# [epoch: 2, i:  2974]  train_loss: 1.319  |  valid_loss: 1.142
# [epoch: 2, i:  3149]  train_loss: 1.227  |  valid_loss: 1.127
# [epoch: 2, i:  3324]  train_loss: 1.271  |  valid_loss: 0.928
# [epoch: 2, i:  3499]  train_loss: 1.296  |  valid_loss: 1.348
# [epoch: 2, i:  3674]  train_loss: 1.263  |  valid_loss: 1.075
# [epoch: 2, i:  3849]  train_loss: 1.311  |  valid_loss: 1.214
# [epoch: 2, i:  4024]  train_loss: 1.255  |  valid_loss: 1.098
# [epoch: 2, i:  4199]  train_loss: 1.232  |  valid_loss: 1.114
# [epoch: 2, i:  4374]  train_loss: 1.285  |  valid_loss: 1.090
# [epoch: 2, i:  4549]  train_loss: 1.247  |  valid_loss: 1.384
# [epoch: 2, i:  4724]  train_loss: 1.181  |  valid_loss: 1.037
# [epoch: 2, i:  4899]  train_loss: 1.280  |  valid_loss: 1.153
# [epoch: 2, i:  5074]  train_loss: 1.272  |  valid_loss: 1.127
# [epoch: 2, i:  5249]  train_loss: 1.247  |  valid_loss: 1.133
# [epoch: 2, i:  5424]  train_loss: 1.238  |  valid_loss: 0.967
# [epoch: 2, i:  5599]  train_loss: 1.289  |  valid_loss: 1.073
# [epoch: 2, i:  5774]  train_loss: 1.249  |  valid_loss: 1.073
# [epoch: 2, i:  5949]  train_loss: 1.204  |  valid_loss: 1.184
# [epoch: 2, i:  6124]  train_loss: 1.294  |  valid_loss: 1.228
# [epoch: 2, i:  6299]  train_loss: 1.205  |  valid_loss: 1.012
# [epoch: 2, i:  6474]  train_loss: 1.236  |  valid_loss: 1.277
# [epoch: 2, i:  6649]  train_loss: 1.326  |  valid_loss: 1.063
# [epoch: 2, i:  6824]  train_loss: 1.237  |  valid_loss: 0.973
# [epoch: 2, i:  6999]  train_loss: 1.234  |  valid_loss: 1.089
# [epoch: 2, i:  7174]  train_loss: 1.291  |  valid_loss: 1.033
# [epoch: 2, i:  7349]  train_loss: 1.246  |  valid_loss: 1.062
# [epoch: 2, i:  7524]  train_loss: 1.366  |  valid_loss: 0.976
# [epoch: 2, i:  7699]  train_loss: 1.221  |  valid_loss: 0.995
# [epoch: 2, i:  7874]  train_loss: 1.297  |  valid_loss: 1.123
# [epoch: 2, i:  8049]  train_loss: 1.201  |  valid_loss: 1.132
# [epoch: 2, i:  8224]  train_loss: 1.234  |  valid_loss: 0.967
# [epoch: 2, i:  8399]  train_loss: 1.267  |  valid_loss: 0.986
# [epoch: 2, i:  8574]  train_loss: 1.190  |  valid_loss: 0.981
# [epoch: 2, i:  8749]  train_loss: 1.233  |  valid_loss: 1.215
# [epoch: 2, i:  8924]  train_loss: 1.236  |  valid_loss: 1.141
# [epoch: 2, i:  9099]  train_loss: 1.233  |  valid_loss: 1.031
# [epoch: 2, i:  9274]  train_loss: 1.267  |  valid_loss: 1.076
# [epoch: 2, i:  9449]  train_loss: 1.322  |  valid_loss: 1.215
# [epoch: 2, i:  9624]  train_loss: 1.226  |  valid_loss: 1.030
# [epoch: 2, i:  9799]  train_loss: 1.197  |  valid_loss: 1.210
# [epoch: 2, i:  9974]  train_loss: 1.223  |  valid_loss: 1.063
# [epoch: 2, i: 10149]  train_loss: 1.196  |  valid_loss: 0.967
# [epoch: 2, i: 10324]  train_loss: 1.197  |  valid_loss: 1.260
# [epoch: 2, i: 10499]  train_loss: 1.229  |  valid_loss: 1.056
# [epoch: 2, i: 10674]  train_loss: 1.177  |  valid_loss: 1.201
# [epoch: 2, i: 10849]  train_loss: 1.321  |  valid_loss: 1.027
# [epoch: 2, i: 11024]  train_loss: 1.223  |  valid_loss: 1.104
# [epoch: 2, i: 11199]  train_loss: 1.198  |  valid_loss: 1.139
# [epoch: 2, i: 11374]  train_loss: 1.247  |  valid_loss: 1.053
# [epoch: 2, i: 11549]  train_loss: 1.162  |  valid_loss: 1.117
# [epoch: 2, i: 11724]  train_loss: 1.272  |  valid_loss: 1.106
# [epoch: 2, i: 11899]  train_loss: 1.230  |  valid_loss: 1.173
# [epoch: 2, i: 12074]  train_loss: 1.191  |  valid_loss: 1.073
# [epoch: 2, i: 12249]  train_loss: 1.199  |  valid_loss: 1.240
# [epoch: 2, i: 12424]  train_loss: 1.248  |  valid_loss: 0.999
# [epoch: 2, i: 12599]  train_loss: 1.232  |  valid_loss: 1.013
# [epoch: 2, i: 12774]  train_loss: 1.214  |  valid_loss: 0.981
# [epoch: 2, i: 12949]  train_loss: 1.291  |  valid_loss: 0.901
# [epoch: 2, i: 13124]  train_loss: 1.280  |  valid_loss: 1.024
# [epoch: 2, i: 13299]  train_loss: 1.303  |  valid_loss: 1.071
# [epoch: 2, i: 13474]  train_loss: 1.204  |  valid_loss: 1.040
# [epoch: 2, i: 13649]  train_loss: 1.254  |  valid_loss: 1.006
# [epoch: 2, i: 13824]  train_loss: 1.228  |  valid_loss: 1.141
# [epoch: 2, i: 13999]  train_loss: 1.203  |  valid_loss: 1.125
# [epoch: 2, i: 14174]  train_loss: 1.254  |  valid_loss: 1.042
# [epoch: 2, i: 14349]  train_loss: 1.141  |  valid_loss: 1.089
# [epoch: 2, i: 14524]  train_loss: 1.248  |  valid_loss: 1.034
# [epoch: 2, i: 14699]  train_loss: 1.244  |  valid_loss: 1.175
# [epoch: 2, i: 14874]  train_loss: 1.285  |  valid_loss: 1.185
# [epoch: 2, i: 15049]  train_loss: 1.301  |  valid_loss: 0.939
# [epoch: 2, i: 15224]  train_loss: 1.193  |  valid_loss: 1.177
# [epoch: 2, i: 15399]  train_loss: 1.183  |  valid_loss: 1.186
# [epoch: 2, i: 15574]  train_loss: 1.250  |  valid_loss: 1.135
# [epoch: 2, i: 15749]  train_loss: 1.192  |  valid_loss: 1.035
# [epoch: 2, i: 15924]  train_loss: 1.144  |  valid_loss: 1.023
# [epoch: 2, i: 16099]  train_loss: 1.205  |  valid_loss: 0.899
# [epoch: 2, i: 16274]  train_loss: 1.199  |  valid_loss: 0.927
# [epoch: 2, i: 16449]  train_loss: 1.230  |  valid_loss: 1.137
# [epoch: 2, i: 16624]  train_loss: 1.212  |  valid_loss: 0.966
# [epoch: 2, i: 16799]  train_loss: 1.206  |  valid_loss: 0.829
# [epoch: 2, i: 16974]  train_loss: 1.267  |  valid_loss: 1.021
# [epoch: 2, i: 17149]  train_loss: 1.118  |  valid_loss: 1.128
# [epoch: 2, i: 17324]  train_loss: 1.221  |  valid_loss: 1.113
# [epoch: 2, i: 17499]  train_loss: 1.288  |  valid_loss: 1.090
# --> [End of epoch 2] train_accuracy: 56.58%  |  valid_accuracy: 61.72%
# --> [Start of epoch 3]  lr: 0.000500
# [epoch: 3, i:   174]  train_loss: 1.246  |  valid_loss: 0.994
# [epoch: 3, i:   349]  train_loss: 1.251  |  valid_loss: 1.142
# [epoch: 3, i:   524]  train_loss: 1.239  |  valid_loss: 1.060
# [epoch: 3, i:   699]  train_loss: 1.200  |  valid_loss: 1.063
# [epoch: 3, i:   874]  train_loss: 1.208  |  valid_loss: 1.122
# [epoch: 3, i:  1049]  train_loss: 1.242  |  valid_loss: 0.918
# [epoch: 3, i:  1224]  train_loss: 1.144  |  valid_loss: 0.960
# [epoch: 3, i:  1399]  train_loss: 1.288  |  valid_loss: 1.127
# [epoch: 3, i:  1574]  train_loss: 1.187  |  valid_loss: 1.014
# [epoch: 3, i:  1749]  train_loss: 1.196  |  valid_loss: 0.891
# [epoch: 3, i:  1924]  train_loss: 1.150  |  valid_loss: 0.860
# [epoch: 3, i:  2099]  train_loss: 1.230  |  valid_loss: 1.030
# [epoch: 3, i:  2274]  train_loss: 1.190  |  valid_loss: 1.018
# [epoch: 3, i:  2449]  train_loss: 1.223  |  valid_loss: 1.017
# [epoch: 3, i:  2624]  train_loss: 1.154  |  valid_loss: 0.985
# [epoch: 3, i:  2799]  train_loss: 1.140  |  valid_loss: 1.139
# [epoch: 3, i:  2974]  train_loss: 1.171  |  valid_loss: 0.931
# [epoch: 3, i:  3149]  train_loss: 1.130  |  valid_loss: 1.035
# [epoch: 3, i:  3324]  train_loss: 1.206  |  valid_loss: 0.953
# [epoch: 3, i:  3499]  train_loss: 1.174  |  valid_loss: 1.136
# [epoch: 3, i:  3674]  train_loss: 1.185  |  valid_loss: 1.048
# [epoch: 3, i:  3849]  train_loss: 1.212  |  valid_loss: 1.183
# [epoch: 3, i:  4024]  train_loss: 1.199  |  valid_loss: 1.009
# [epoch: 3, i:  4199]  train_loss: 1.155  |  valid_loss: 1.035
# [epoch: 3, i:  4374]  train_loss: 1.270  |  valid_loss: 1.033
# [epoch: 3, i:  4549]  train_loss: 1.206  |  valid_loss: 1.297
# [epoch: 3, i:  4724]  train_loss: 1.235  |  valid_loss: 0.911
# [epoch: 3, i:  4899]  train_loss: 1.262  |  valid_loss: 1.016
# [epoch: 3, i:  5074]  train_loss: 1.204  |  valid_loss: 1.051
# [epoch: 3, i:  5249]  train_loss: 1.177  |  valid_loss: 0.923
# [epoch: 3, i:  5424]  train_loss: 1.186  |  valid_loss: 0.968
# [epoch: 3, i:  5599]  train_loss: 1.184  |  valid_loss: 0.993
# [epoch: 3, i:  5774]  train_loss: 1.176  |  valid_loss: 1.000
# [epoch: 3, i:  5949]  train_loss: 1.157  |  valid_loss: 1.140
# [epoch: 3, i:  6124]  train_loss: 1.187  |  valid_loss: 1.252
# [epoch: 3, i:  6299]  train_loss: 1.231  |  valid_loss: 1.077
# [epoch: 3, i:  6474]  train_loss: 1.190  |  valid_loss: 1.134
# [epoch: 3, i:  6649]  train_loss: 1.185  |  valid_loss: 1.119
# [epoch: 3, i:  6824]  train_loss: 1.163  |  valid_loss: 0.988
# [epoch: 3, i:  6999]  train_loss: 1.225  |  valid_loss: 0.958
# [epoch: 3, i:  7174]  train_loss: 1.173  |  valid_loss: 0.896
# [epoch: 3, i:  7349]  train_loss: 1.212  |  valid_loss: 0.934
# [epoch: 3, i:  7524]  train_loss: 1.237  |  valid_loss: 0.849
# [epoch: 3, i:  7699]  train_loss: 1.174  |  valid_loss: 0.960
# [epoch: 3, i:  7874]  train_loss: 1.217  |  valid_loss: 0.997
# [epoch: 3, i:  8049]  train_loss: 1.197  |  valid_loss: 1.096
# [epoch: 3, i:  8224]  train_loss: 1.160  |  valid_loss: 0.869
# [epoch: 3, i:  8399]  train_loss: 1.208  |  valid_loss: 0.930
# [epoch: 3, i:  8574]  train_loss: 1.201  |  valid_loss: 1.003
# [epoch: 3, i:  8749]  train_loss: 1.241  |  valid_loss: 1.118
# [epoch: 3, i:  8924]  train_loss: 1.212  |  valid_loss: 0.975
# [epoch: 3, i:  9099]  train_loss: 1.101  |  valid_loss: 1.024
# [epoch: 3, i:  9274]  train_loss: 1.134  |  valid_loss: 0.859
# [epoch: 3, i:  9449]  train_loss: 1.167  |  valid_loss: 1.215
# [epoch: 3, i:  9624]  train_loss: 1.129  |  valid_loss: 0.920
# [epoch: 3, i:  9799]  train_loss: 1.170  |  valid_loss: 1.166
# [epoch: 3, i:  9974]  train_loss: 1.125  |  valid_loss: 1.103
# [epoch: 3, i: 10149]  train_loss: 1.252  |  valid_loss: 0.829
# [epoch: 3, i: 10324]  train_loss: 1.213  |  valid_loss: 1.210
# [epoch: 3, i: 10499]  train_loss: 1.192  |  valid_loss: 0.955
# [epoch: 3, i: 10674]  train_loss: 1.149  |  valid_loss: 1.154
# [epoch: 3, i: 10849]  train_loss: 1.163  |  valid_loss: 0.922
# [epoch: 3, i: 11024]  train_loss: 1.180  |  valid_loss: 0.978
# [epoch: 3, i: 11199]  train_loss: 1.251  |  valid_loss: 0.994
# [epoch: 3, i: 11374]  train_loss: 1.163  |  valid_loss: 1.027
# [epoch: 3, i: 11549]  train_loss: 1.135  |  valid_loss: 1.039
# [epoch: 3, i: 11724]  train_loss: 1.183  |  valid_loss: 1.037
# [epoch: 3, i: 11899]  train_loss: 1.162  |  valid_loss: 1.087
# [epoch: 3, i: 12074]  train_loss: 1.141  |  valid_loss: 0.992
# [epoch: 3, i: 12249]  train_loss: 1.209  |  valid_loss: 1.172
# [epoch: 3, i: 12424]  train_loss: 1.202  |  valid_loss: 0.978
# [epoch: 3, i: 12599]  train_loss: 1.219  |  valid_loss: 0.936
# [epoch: 3, i: 12774]  train_loss: 1.137  |  valid_loss: 0.925
# [epoch: 3, i: 12949]  train_loss: 1.183  |  valid_loss: 0.891
# [epoch: 3, i: 13124]  train_loss: 1.181  |  valid_loss: 1.007
# [epoch: 3, i: 13299]  train_loss: 1.061  |  valid_loss: 0.905
# [epoch: 3, i: 13474]  train_loss: 1.147  |  valid_loss: 1.023
# [epoch: 3, i: 13649]  train_loss: 1.188  |  valid_loss: 0.949
# [epoch: 3, i: 13824]  train_loss: 1.224  |  valid_loss: 1.043
# [epoch: 3, i: 13999]  train_loss: 1.232  |  valid_loss: 1.048
# [epoch: 3, i: 14174]  train_loss: 1.111  |  valid_loss: 0.932
# [epoch: 3, i: 14349]  train_loss: 1.207  |  valid_loss: 0.989
# [epoch: 3, i: 14524]  train_loss: 1.190  |  valid_loss: 0.960
# [epoch: 3, i: 14699]  train_loss: 1.278  |  valid_loss: 1.117
# [epoch: 3, i: 14874]  train_loss: 1.238  |  valid_loss: 1.093
# [epoch: 3, i: 15049]  train_loss: 1.173  |  valid_loss: 0.992
# [epoch: 3, i: 15224]  train_loss: 1.203  |  valid_loss: 1.009
# [epoch: 3, i: 15399]  train_loss: 1.224  |  valid_loss: 1.011
# [epoch: 3, i: 15574]  train_loss: 1.152  |  valid_loss: 1.008
# [epoch: 3, i: 15749]  train_loss: 1.108  |  valid_loss: 1.081
# [epoch: 3, i: 15924]  train_loss: 1.197  |  valid_loss: 0.901
# [epoch: 3, i: 16099]  train_loss: 1.172  |  valid_loss: 0.860
# [epoch: 3, i: 16274]  train_loss: 1.235  |  valid_loss: 0.976
# [epoch: 3, i: 16449]  train_loss: 1.225  |  valid_loss: 1.119
# [epoch: 3, i: 16624]  train_loss: 1.188  |  valid_loss: 1.008
# [epoch: 3, i: 16799]  train_loss: 1.155  |  valid_loss: 0.962
# [epoch: 3, i: 16974]  train_loss: 1.208  |  valid_loss: 0.836
# [epoch: 3, i: 17149]  train_loss: 1.195  |  valid_loss: 1.124
# [epoch: 3, i: 17324]  train_loss: 1.209  |  valid_loss: 1.040
# [epoch: 3, i: 17499]  train_loss: 1.216  |  valid_loss: 1.006
# --> [End of epoch 3] train_accuracy: 58.73%  |  valid_accuracy: 64.63%
# --> [Start of epoch 4]  lr: 0.000500
# [epoch: 4, i:   174]  train_loss: 1.195  |  valid_loss: 0.967
# [epoch: 4, i:   349]  train_loss: 1.097  |  valid_loss: 1.009
# [epoch: 4, i:   524]  train_loss: 1.206  |  valid_loss: 1.035
# [epoch: 4, i:   699]  train_loss: 1.140  |  valid_loss: 0.953
# [epoch: 4, i:   874]  train_loss: 1.151  |  valid_loss: 1.025
# [epoch: 4, i:  1049]  train_loss: 1.105  |  valid_loss: 0.836
# [epoch: 4, i:  1224]  train_loss: 1.196  |  valid_loss: 0.905
# [epoch: 4, i:  1399]  train_loss: 1.055  |  valid_loss: 1.004
# [epoch: 4, i:  1574]  train_loss: 1.114  |  valid_loss: 0.976
# [epoch: 4, i:  1749]  train_loss: 1.183  |  valid_loss: 0.885
# [epoch: 4, i:  1924]  train_loss: 1.176  |  valid_loss: 0.837
# [epoch: 4, i:  2099]  train_loss: 1.162  |  valid_loss: 0.998
# [epoch: 4, i:  2274]  train_loss: 1.145  |  valid_loss: 0.941
# [epoch: 4, i:  2449]  train_loss: 1.209  |  valid_loss: 1.016
# [epoch: 4, i:  2624]  train_loss: 1.125  |  valid_loss: 0.887
# [epoch: 4, i:  2799]  train_loss: 1.104  |  valid_loss: 1.044
# [epoch: 4, i:  2974]  train_loss: 1.170  |  valid_loss: 0.922
# [epoch: 4, i:  3149]  train_loss: 1.107  |  valid_loss: 1.023
# [epoch: 4, i:  3324]  train_loss: 1.121  |  valid_loss: 0.971
# [epoch: 4, i:  3499]  train_loss: 1.050  |  valid_loss: 1.092
# [epoch: 4, i:  3674]  train_loss: 1.179  |  valid_loss: 0.956
# [epoch: 4, i:  3849]  train_loss: 1.120  |  valid_loss: 1.102
# [epoch: 4, i:  4024]  train_loss: 1.166  |  valid_loss: 0.989
# [epoch: 4, i:  4199]  train_loss: 1.151  |  valid_loss: 0.993
# [epoch: 4, i:  4374]  train_loss: 1.207  |  valid_loss: 1.043
# [epoch: 4, i:  4549]  train_loss: 1.236  |  valid_loss: 1.218
# [epoch: 4, i:  4724]  train_loss: 1.141  |  valid_loss: 0.894
# [epoch: 4, i:  4899]  train_loss: 1.138  |  valid_loss: 0.950
# [epoch: 4, i:  5074]  train_loss: 1.143  |  valid_loss: 1.031
# [epoch: 4, i:  5249]  train_loss: 1.185  |  valid_loss: 0.822
# [epoch: 4, i:  5424]  train_loss: 1.170  |  valid_loss: 0.956
# [epoch: 4, i:  5599]  train_loss: 1.172  |  valid_loss: 0.951
# [epoch: 4, i:  5774]  train_loss: 1.111  |  valid_loss: 1.034
# [epoch: 4, i:  5949]  train_loss: 1.226  |  valid_loss: 1.086
# [epoch: 4, i:  6124]  train_loss: 1.196  |  valid_loss: 1.072
# [epoch: 4, i:  6299]  train_loss: 1.187  |  valid_loss: 0.992
# [epoch: 4, i:  6474]  train_loss: 1.083  |  valid_loss: 1.037
# [epoch: 4, i:  6649]  train_loss: 1.141  |  valid_loss: 1.095
# [epoch: 4, i:  6824]  train_loss: 1.130  |  valid_loss: 0.776
# [epoch: 4, i:  6999]  train_loss: 1.121  |  valid_loss: 0.909
# [epoch: 4, i:  7174]  train_loss: 1.184  |  valid_loss: 0.877
# [epoch: 4, i:  7349]  train_loss: 1.110  |  valid_loss: 0.910
# [epoch: 4, i:  7524]  train_loss: 1.138  |  valid_loss: 0.828
# [epoch: 4, i:  7699]  train_loss: 1.091  |  valid_loss: 0.972
# [epoch: 4, i:  7874]  train_loss: 1.103  |  valid_loss: 0.912
# [epoch: 4, i:  8049]  train_loss: 1.171  |  valid_loss: 1.038
# [epoch: 4, i:  8224]  train_loss: 1.054  |  valid_loss: 0.900
# [epoch: 4, i:  8399]  train_loss: 1.082  |  valid_loss: 0.955
# [epoch: 4, i:  8574]  train_loss: 1.075  |  valid_loss: 0.810
# [epoch: 4, i:  8749]  train_loss: 1.104  |  valid_loss: 0.989
# [epoch: 4, i:  8924]  train_loss: 1.150  |  valid_loss: 0.961
# [epoch: 4, i:  9099]  train_loss: 1.144  |  valid_loss: 0.973
# [epoch: 4, i:  9274]  train_loss: 1.118  |  valid_loss: 0.786
# [epoch: 4, i:  9449]  train_loss: 1.104  |  valid_loss: 1.161
# [epoch: 4, i:  9624]  train_loss: 1.144  |  valid_loss: 0.892
# [epoch: 4, i:  9799]  train_loss: 1.113  |  valid_loss: 1.097
# [epoch: 4, i:  9974]  train_loss: 1.156  |  valid_loss: 1.118
# [epoch: 4, i: 10149]  train_loss: 1.184  |  valid_loss: 0.841
# [epoch: 4, i: 10324]  train_loss: 1.119  |  valid_loss: 1.156
# [epoch: 4, i: 10499]  train_loss: 1.091  |  valid_loss: 0.913
# [epoch: 4, i: 10674]  train_loss: 1.152  |  valid_loss: 1.152
# [epoch: 4, i: 10849]  train_loss: 1.132  |  valid_loss: 1.000
# [epoch: 4, i: 11024]  train_loss: 1.135  |  valid_loss: 0.966
# [epoch: 4, i: 11199]  train_loss: 1.209  |  valid_loss: 0.940
# [epoch: 4, i: 11374]  train_loss: 1.186  |  valid_loss: 1.011
# [epoch: 4, i: 11549]  train_loss: 1.137  |  valid_loss: 0.988
# [epoch: 4, i: 11724]  train_loss: 1.121  |  valid_loss: 0.969
# [epoch: 4, i: 11899]  train_loss: 1.120  |  valid_loss: 1.000
# [epoch: 4, i: 12074]  train_loss: 1.161  |  valid_loss: 0.932
# [epoch: 4, i: 12249]  train_loss: 1.186  |  valid_loss: 1.128
# [epoch: 4, i: 12424]  train_loss: 1.187  |  valid_loss: 0.905
# [epoch: 4, i: 12599]  train_loss: 1.189  |  valid_loss: 1.024
# [epoch: 4, i: 12774]  train_loss: 1.138  |  valid_loss: 0.982
# [epoch: 4, i: 12949]  train_loss: 1.168  |  valid_loss: 0.882
# [epoch: 4, i: 13124]  train_loss: 1.151  |  valid_loss: 0.948
# [epoch: 4, i: 13299]  train_loss: 1.108  |  valid_loss: 0.890
# [epoch: 4, i: 13474]  train_loss: 1.076  |  valid_loss: 1.010
# [epoch: 4, i: 13649]  train_loss: 1.103  |  valid_loss: 0.922
# [epoch: 4, i: 13824]  train_loss: 1.142  |  valid_loss: 0.988
# [epoch: 4, i: 13999]  train_loss: 1.197  |  valid_loss: 1.024
# [epoch: 4, i: 14174]  train_loss: 1.075  |  valid_loss: 0.841
# [epoch: 4, i: 14349]  train_loss: 1.130  |  valid_loss: 1.009
# [epoch: 4, i: 14524]  train_loss: 1.124  |  valid_loss: 1.005
# [epoch: 4, i: 14699]  train_loss: 1.051  |  valid_loss: 1.015
# [epoch: 4, i: 14874]  train_loss: 1.136  |  valid_loss: 1.017
# [epoch: 4, i: 15049]  train_loss: 1.015  |  valid_loss: 0.942
# [epoch: 4, i: 15224]  train_loss: 1.196  |  valid_loss: 1.057
# [epoch: 4, i: 15399]  train_loss: 1.126  |  valid_loss: 1.123
# [epoch: 4, i: 15574]  train_loss: 1.182  |  valid_loss: 1.082
# [epoch: 4, i: 15749]  train_loss: 1.065  |  valid_loss: 1.023
# [epoch: 4, i: 15924]  train_loss: 1.191  |  valid_loss: 0.882
# [epoch: 4, i: 16099]  train_loss: 1.043  |  valid_loss: 0.803
# [epoch: 4, i: 16274]  train_loss: 1.014  |  valid_loss: 0.918
# [epoch: 4, i: 16449]  train_loss: 1.127  |  valid_loss: 1.019
# [epoch: 4, i: 16624]  train_loss: 1.127  |  valid_loss: 0.862
# [epoch: 4, i: 16799]  train_loss: 1.128  |  valid_loss: 0.961
# [epoch: 4, i: 16974]  train_loss: 1.108  |  valid_loss: 0.837
# [epoch: 4, i: 17149]  train_loss: 1.042  |  valid_loss: 1.090
# [epoch: 4, i: 17324]  train_loss: 1.091  |  valid_loss: 1.066
# [epoch: 4, i: 17499]  train_loss: 1.110  |  valid_loss: 1.055
# --> [End of epoch 4] train_accuracy: 60.64%  |  valid_accuracy: 66.06%
# --> [Start of epoch 5]  lr: 0.000500
# [epoch: 5, i:   174]  train_loss: 1.093  |  valid_loss: 0.917
# [epoch: 5, i:   349]  train_loss: 1.124  |  valid_loss: 0.978
# [epoch: 5, i:   524]  train_loss: 1.088  |  valid_loss: 1.025
# [epoch: 5, i:   699]  train_loss: 1.095  |  valid_loss: 0.904
# [epoch: 5, i:   874]  train_loss: 1.135  |  valid_loss: 0.977
# [epoch: 5, i:  1049]  train_loss: 1.066  |  valid_loss: 0.813
# [epoch: 5, i:  1224]  train_loss: 1.022  |  valid_loss: 0.949
# [epoch: 5, i:  1399]  train_loss: 1.093  |  valid_loss: 1.048
# [epoch: 5, i:  1574]  train_loss: 1.067  |  valid_loss: 0.994
# [epoch: 5, i:  1749]  train_loss: 1.126  |  valid_loss: 0.787
# [epoch: 5, i:  1924]  train_loss: 1.133  |  valid_loss: 0.755
# [epoch: 5, i:  2099]  train_loss: 1.081  |  valid_loss: 0.921
# [epoch: 5, i:  2274]  train_loss: 1.155  |  valid_loss: 0.993
# [epoch: 5, i:  2449]  train_loss: 1.072  |  valid_loss: 0.828
# [epoch: 5, i:  2624]  train_loss: 1.185  |  valid_loss: 0.808
# [epoch: 5, i:  2799]  train_loss: 1.059  |  valid_loss: 0.979
# [epoch: 5, i:  2974]  train_loss: 1.118  |  valid_loss: 0.911
# [epoch: 5, i:  3149]  train_loss: 1.096  |  valid_loss: 0.946
# [epoch: 5, i:  3324]  train_loss: 1.109  |  valid_loss: 0.903
# [epoch: 5, i:  3499]  train_loss: 1.085  |  valid_loss: 1.115
# [epoch: 5, i:  3674]  train_loss: 1.095  |  valid_loss: 1.023
# [epoch: 5, i:  3849]  train_loss: 1.035  |  valid_loss: 1.058
# [epoch: 5, i:  4024]  train_loss: 1.105  |  valid_loss: 0.906
# [epoch: 5, i:  4199]  train_loss: 1.089  |  valid_loss: 0.907
# [epoch: 5, i:  4374]  train_loss: 1.135  |  valid_loss: 0.973
# [epoch: 5, i:  4549]  train_loss: 1.118  |  valid_loss: 1.209
# [epoch: 5, i:  4724]  train_loss: 1.109  |  valid_loss: 0.874
# [epoch: 5, i:  4899]  train_loss: 1.080  |  valid_loss: 1.031
# [epoch: 5, i:  5074]  train_loss: 1.126  |  valid_loss: 0.905
# [epoch: 5, i:  5249]  train_loss: 1.182  |  valid_loss: 0.887
# [epoch: 5, i:  5424]  train_loss: 1.158  |  valid_loss: 0.895
# [epoch: 5, i:  5599]  train_loss: 1.093  |  valid_loss: 0.876
# [epoch: 5, i:  5774]  train_loss: 1.107  |  valid_loss: 0.942
# [epoch: 5, i:  5949]  train_loss: 1.146  |  valid_loss: 1.060
# [epoch: 5, i:  6124]  train_loss: 1.127  |  valid_loss: 1.126
# [epoch: 5, i:  6299]  train_loss: 1.074  |  valid_loss: 1.049
# [epoch: 5, i:  6474]  train_loss: 1.098  |  valid_loss: 1.069
# [epoch: 5, i:  6649]  train_loss: 1.088  |  valid_loss: 1.057
# [epoch: 5, i:  6824]  train_loss: 1.142  |  valid_loss: 0.787
# [epoch: 5, i:  6999]  train_loss: 1.184  |  valid_loss: 0.827
# [epoch: 5, i:  7174]  train_loss: 1.096  |  valid_loss: 0.800
# [epoch: 5, i:  7349]  train_loss: 1.031  |  valid_loss: 0.947
# [epoch: 5, i:  7524]  train_loss: 1.143  |  valid_loss: 0.805
# [epoch: 5, i:  7699]  train_loss: 1.215  |  valid_loss: 0.960
# [epoch: 5, i:  7874]  train_loss: 1.126  |  valid_loss: 0.917
# [epoch: 5, i:  8049]  train_loss: 1.075  |  valid_loss: 0.967
# [epoch: 5, i:  8224]  train_loss: 1.119  |  valid_loss: 0.787
# [epoch: 5, i:  8399]  train_loss: 1.146  |  valid_loss: 0.907
# [epoch: 5, i:  8574]  train_loss: 1.113  |  valid_loss: 0.855
# [epoch: 5, i:  8749]  train_loss: 1.091  |  valid_loss: 0.921
# [epoch: 5, i:  8924]  train_loss: 1.081  |  valid_loss: 0.889
# [epoch: 5, i:  9099]  train_loss: 1.074  |  valid_loss: 0.928
# [epoch: 5, i:  9274]  train_loss: 1.151  |  valid_loss: 0.743
# [epoch: 5, i:  9449]  train_loss: 1.089  |  valid_loss: 1.168
# [epoch: 5, i:  9624]  train_loss: 1.214  |  valid_loss: 0.874
# [epoch: 5, i:  9799]  train_loss: 1.153  |  valid_loss: 1.056
# [epoch: 5, i:  9974]  train_loss: 1.153  |  valid_loss: 1.005
# [epoch: 5, i: 10149]  train_loss: 1.077  |  valid_loss: 0.791
# [epoch: 5, i: 10324]  train_loss: 1.217  |  valid_loss: 1.147
# [epoch: 5, i: 10499]  train_loss: 1.120  |  valid_loss: 0.861
# [epoch: 5, i: 10674]  train_loss: 1.079  |  valid_loss: 1.044
# [epoch: 5, i: 10849]  train_loss: 1.115  |  valid_loss: 0.935
# [epoch: 5, i: 11024]  train_loss: 1.127  |  valid_loss: 0.954
# [epoch: 5, i: 11199]  train_loss: 1.086  |  valid_loss: 0.903
# [epoch: 5, i: 11374]  train_loss: 1.032  |  valid_loss: 1.014
# [epoch: 5, i: 11549]  train_loss: 1.108  |  valid_loss: 1.026
# [epoch: 5, i: 11724]  train_loss: 1.067  |  valid_loss: 0.911
# [epoch: 5, i: 11899]  train_loss: 1.125  |  valid_loss: 0.948
# [epoch: 5, i: 12074]  train_loss: 1.157  |  valid_loss: 0.922
# [epoch: 5, i: 12249]  train_loss: 1.037  |  valid_loss: 1.113
# [epoch: 5, i: 12424]  train_loss: 1.157  |  valid_loss: 0.843
# [epoch: 5, i: 12599]  train_loss: 1.050  |  valid_loss: 0.936
# [epoch: 5, i: 12774]  train_loss: 1.055  |  valid_loss: 0.896
# [epoch: 5, i: 12949]  train_loss: 1.144  |  valid_loss: 0.855
# [epoch: 5, i: 13124]  train_loss: 1.083  |  valid_loss: 0.819
# [epoch: 5, i: 13299]  train_loss: 1.133  |  valid_loss: 0.908
# [epoch: 5, i: 13474]  train_loss: 1.065  |  valid_loss: 1.049
# [epoch: 5, i: 13649]  train_loss: 1.100  |  valid_loss: 0.830
# [epoch: 5, i: 13824]  train_loss: 1.060  |  valid_loss: 1.009
# [epoch: 5, i: 13999]  train_loss: 1.111  |  valid_loss: 1.044
# [epoch: 5, i: 14174]  train_loss: 1.134  |  valid_loss: 0.882
# [epoch: 5, i: 14349]  train_loss: 1.146  |  valid_loss: 0.967
# [epoch: 5, i: 14524]  train_loss: 1.102  |  valid_loss: 0.974
# [epoch: 5, i: 14699]  train_loss: 1.141  |  valid_loss: 1.073
# [epoch: 5, i: 14874]  train_loss: 1.078  |  valid_loss: 0.939
# [epoch: 5, i: 15049]  train_loss: 1.164  |  valid_loss: 0.921
# [epoch: 5, i: 15224]  train_loss: 1.059  |  valid_loss: 0.965
# [epoch: 5, i: 15399]  train_loss: 1.060  |  valid_loss: 1.023
# [epoch: 5, i: 15574]  train_loss: 1.114  |  valid_loss: 0.952
# [epoch: 5, i: 15749]  train_loss: 1.104  |  valid_loss: 0.926
# [epoch: 5, i: 15924]  train_loss: 1.165  |  valid_loss: 0.863
# [epoch: 5, i: 16099]  train_loss: 1.131  |  valid_loss: 0.753
# [epoch: 5, i: 16274]  train_loss: 1.085  |  valid_loss: 0.851
# [epoch: 5, i: 16449]  train_loss: 1.057  |  valid_loss: 0.950
# [epoch: 5, i: 16624]  train_loss: 1.087  |  valid_loss: 0.872
# [epoch: 5, i: 16799]  train_loss: 1.080  |  valid_loss: 0.774
# [epoch: 5, i: 16974]  train_loss: 1.076  |  valid_loss: 0.891
# [epoch: 5, i: 17149]  train_loss: 1.099  |  valid_loss: 1.018
# [epoch: 5, i: 17324]  train_loss: 1.143  |  valid_loss: 1.021
# [epoch: 5, i: 17499]  train_loss: 1.060  |  valid_loss: 0.999
# --> [End of epoch 5] train_accuracy: 62.07%  |  valid_accuracy: 67.48%
# --> [Start of epoch 6]  lr: 0.000500
# [epoch: 6, i:   174]  train_loss: 1.117  |  valid_loss: 0.903
# [epoch: 6, i:   349]  train_loss: 1.095  |  valid_loss: 0.976
# [epoch: 6, i:   524]  train_loss: 1.045  |  valid_loss: 0.979
# [epoch: 6, i:   699]  train_loss: 1.060  |  valid_loss: 0.900
# [epoch: 6, i:   874]  train_loss: 1.144  |  valid_loss: 0.907
# [epoch: 6, i:  1049]  train_loss: 1.093  |  valid_loss: 0.729
# [epoch: 6, i:  1224]  train_loss: 1.051  |  valid_loss: 0.840
# [epoch: 6, i:  1399]  train_loss: 1.088  |  valid_loss: 1.016
# [epoch: 6, i:  1574]  train_loss: 1.149  |  valid_loss: 0.986
# [epoch: 6, i:  1749]  train_loss: 1.023  |  valid_loss: 0.823
# [epoch: 6, i:  1924]  train_loss: 1.051  |  valid_loss: 0.769
# [epoch: 6, i:  2099]  train_loss: 1.130  |  valid_loss: 0.908
# [epoch: 6, i:  2274]  train_loss: 1.065  |  valid_loss: 0.948
# [epoch: 6, i:  2449]  train_loss: 1.087  |  valid_loss: 0.859
# [epoch: 6, i:  2624]  train_loss: 1.045  |  valid_loss: 0.819
# [epoch: 6, i:  2799]  train_loss: 1.098  |  valid_loss: 0.897
# [epoch: 6, i:  2974]  train_loss: 1.026  |  valid_loss: 0.848
# [epoch: 6, i:  3149]  train_loss: 1.099  |  valid_loss: 0.921
# [epoch: 6, i:  3324]  train_loss: 1.030  |  valid_loss: 0.908
# [epoch: 6, i:  3499]  train_loss: 1.105  |  valid_loss: 1.117
# [epoch: 6, i:  3674]  train_loss: 1.127  |  valid_loss: 0.961
# [epoch: 6, i:  3849]  train_loss: 1.066  |  valid_loss: 1.081
# [epoch: 6, i:  4024]  train_loss: 0.986  |  valid_loss: 0.919
# [epoch: 6, i:  4199]  train_loss: 1.105  |  valid_loss: 0.902
# [epoch: 6, i:  4374]  train_loss: 0.993  |  valid_loss: 0.950
# [epoch: 6, i:  4549]  train_loss: 1.042  |  valid_loss: 1.206
# [epoch: 6, i:  4724]  train_loss: 1.085  |  valid_loss: 0.796
# [epoch: 6, i:  4899]  train_loss: 1.134  |  valid_loss: 0.932
# [epoch: 6, i:  5074]  train_loss: 1.071  |  valid_loss: 0.866
# [epoch: 6, i:  5249]  train_loss: 1.040  |  valid_loss: 0.788
# [epoch: 6, i:  5424]  train_loss: 1.112  |  valid_loss: 0.835
# [epoch: 6, i:  5599]  train_loss: 1.086  |  valid_loss: 0.950
# [epoch: 6, i:  5774]  train_loss: 1.117  |  valid_loss: 0.935
# [epoch: 6, i:  5949]  train_loss: 0.976  |  valid_loss: 0.962
# [epoch: 6, i:  6124]  train_loss: 1.071  |  valid_loss: 1.053
# [epoch: 6, i:  6299]  train_loss: 1.076  |  valid_loss: 0.946
# [epoch: 6, i:  6474]  train_loss: 1.048  |  valid_loss: 1.086
# [epoch: 6, i:  6649]  train_loss: 1.078  |  valid_loss: 0.990
# [epoch: 6, i:  6824]  train_loss: 1.139  |  valid_loss: 0.877
# [epoch: 6, i:  6999]  train_loss: 1.085  |  valid_loss: 0.877
# [epoch: 6, i:  7174]  train_loss: 1.113  |  valid_loss: 0.825
# [epoch: 6, i:  7349]  train_loss: 1.051  |  valid_loss: 0.860
# [epoch: 6, i:  7524]  train_loss: 1.048  |  valid_loss: 0.742
# [epoch: 6, i:  7699]  train_loss: 1.162  |  valid_loss: 0.910
# [epoch: 6, i:  7874]  train_loss: 1.141  |  valid_loss: 0.888
# [epoch: 6, i:  8049]  train_loss: 1.152  |  valid_loss: 0.921
# [epoch: 6, i:  8224]  train_loss: 0.990  |  valid_loss: 0.856
# [epoch: 6, i:  8399]  train_loss: 1.046  |  valid_loss: 0.846
# [epoch: 6, i:  8574]  train_loss: 1.064  |  valid_loss: 0.835
# [epoch: 6, i:  8749]  train_loss: 1.122  |  valid_loss: 1.069
# [epoch: 6, i:  8924]  train_loss: 1.103  |  valid_loss: 0.898
# [epoch: 6, i:  9099]  train_loss: 1.102  |  valid_loss: 0.975
# [epoch: 6, i:  9274]  train_loss: 1.109  |  valid_loss: 0.793
# [epoch: 6, i:  9449]  train_loss: 1.029  |  valid_loss: 0.975
# [epoch: 6, i:  9624]  train_loss: 1.051  |  valid_loss: 0.942
# [epoch: 6, i:  9799]  train_loss: 1.092  |  valid_loss: 0.983
# [epoch: 6, i:  9974]  train_loss: 1.067  |  valid_loss: 1.040
# [epoch: 6, i: 10149]  train_loss: 1.053  |  valid_loss: 0.828
# [epoch: 6, i: 10324]  train_loss: 1.017  |  valid_loss: 1.109
# [epoch: 6, i: 10499]  train_loss: 0.996  |  valid_loss: 0.807
# [epoch: 6, i: 10674]  train_loss: 1.064  |  valid_loss: 1.091
# [epoch: 6, i: 10849]  train_loss: 0.974  |  valid_loss: 0.883
# [epoch: 6, i: 11024]  train_loss: 1.074  |  valid_loss: 0.966
# [epoch: 6, i: 11199]  train_loss: 1.049  |  valid_loss: 0.870
# [epoch: 6, i: 11374]  train_loss: 1.141  |  valid_loss: 1.062
# [epoch: 6, i: 11549]  train_loss: 1.122  |  valid_loss: 0.961
# [epoch: 6, i: 11724]  train_loss: 1.070  |  valid_loss: 0.918
# [epoch: 6, i: 11899]  train_loss: 1.061  |  valid_loss: 0.942
# [epoch: 6, i: 12074]  train_loss: 1.148  |  valid_loss: 0.869
# [epoch: 6, i: 12249]  train_loss: 1.033  |  valid_loss: 1.071
# [epoch: 6, i: 12424]  train_loss: 1.134  |  valid_loss: 0.773
# [epoch: 6, i: 12599]  train_loss: 1.087  |  valid_loss: 0.925
# [epoch: 6, i: 12774]  train_loss: 1.121  |  valid_loss: 0.910
# [epoch: 6, i: 12949]  train_loss: 1.063  |  valid_loss: 0.652
# [epoch: 6, i: 13124]  train_loss: 1.096  |  valid_loss: 0.901
# [epoch: 6, i: 13299]  train_loss: 1.100  |  valid_loss: 0.824
# [epoch: 6, i: 13474]  train_loss: 1.069  |  valid_loss: 0.993
# [epoch: 6, i: 13649]  train_loss: 1.071  |  valid_loss: 0.891
# [epoch: 6, i: 13824]  train_loss: 1.050  |  valid_loss: 1.024
# [epoch: 6, i: 13999]  train_loss: 0.989  |  valid_loss: 0.980
# [epoch: 6, i: 14174]  train_loss: 1.089  |  valid_loss: 0.841
# [epoch: 6, i: 14349]  train_loss: 1.105  |  valid_loss: 0.922
# [epoch: 6, i: 14524]  train_loss: 1.119  |  valid_loss: 0.857
# [epoch: 6, i: 14699]  train_loss: 1.120  |  valid_loss: 0.984
# [epoch: 6, i: 14874]  train_loss: 1.156  |  valid_loss: 0.997
# [epoch: 6, i: 15049]  train_loss: 1.021  |  valid_loss: 0.847
# [epoch: 6, i: 15224]  train_loss: 1.100  |  valid_loss: 0.845
# [epoch: 6, i: 15399]  train_loss: 1.137  |  valid_loss: 0.906
# [epoch: 6, i: 15574]  train_loss: 1.024  |  valid_loss: 1.001
# [epoch: 6, i: 15749]  train_loss: 1.018  |  valid_loss: 1.006
# [epoch: 6, i: 15924]  train_loss: 1.102  |  valid_loss: 0.860
# [epoch: 6, i: 16099]  train_loss: 1.150  |  valid_loss: 0.756
# [epoch: 6, i: 16274]  train_loss: 1.079  |  valid_loss: 0.943
# [epoch: 6, i: 16449]  train_loss: 1.043  |  valid_loss: 0.956
# [epoch: 6, i: 16624]  train_loss: 1.035  |  valid_loss: 0.935
# [epoch: 6, i: 16799]  train_loss: 1.062  |  valid_loss: 0.750
# [epoch: 6, i: 16974]  train_loss: 1.028  |  valid_loss: 0.842
# [epoch: 6, i: 17149]  train_loss: 1.087  |  valid_loss: 1.122
# [epoch: 6, i: 17324]  train_loss: 1.043  |  valid_loss: 0.960
# [epoch: 6, i: 17499]  train_loss: 1.125  |  valid_loss: 0.927
# --> [End of epoch 6] train_accuracy: 63.25%  |  valid_accuracy: 68.51%
# --> [Start of epoch 7]  lr: 0.000500
# [epoch: 7, i:   174]  train_loss: 1.065  |  valid_loss: 0.826
# [epoch: 7, i:   349]  train_loss: 1.031  |  valid_loss: 0.895
# [epoch: 7, i:   524]  train_loss: 1.094  |  valid_loss: 0.931
# [epoch: 7, i:   699]  train_loss: 1.070  |  valid_loss: 0.911
# [epoch: 7, i:   874]  train_loss: 1.038  |  valid_loss: 0.872
# [epoch: 7, i:  1049]  train_loss: 1.033  |  valid_loss: 0.774
# [epoch: 7, i:  1224]  train_loss: 1.092  |  valid_loss: 0.841
# [epoch: 7, i:  1399]  train_loss: 1.096  |  valid_loss: 0.960
# [epoch: 7, i:  1574]  train_loss: 1.112  |  valid_loss: 0.958
# [epoch: 7, i:  1749]  train_loss: 0.970  |  valid_loss: 0.815
# [epoch: 7, i:  1924]  train_loss: 1.058  |  valid_loss: 0.730
# [epoch: 7, i:  2099]  train_loss: 1.072  |  valid_loss: 0.860
# [epoch: 7, i:  2274]  train_loss: 0.914  |  valid_loss: 0.919
# [epoch: 7, i:  2449]  train_loss: 1.083  |  valid_loss: 0.830
# [epoch: 7, i:  2624]  train_loss: 1.010  |  valid_loss: 0.752
# [epoch: 7, i:  2799]  train_loss: 1.070  |  valid_loss: 1.004
# [epoch: 7, i:  2974]  train_loss: 1.077  |  valid_loss: 0.830
# [epoch: 7, i:  3149]  train_loss: 1.044  |  valid_loss: 0.929
# [epoch: 7, i:  3324]  train_loss: 1.034  |  valid_loss: 0.888
# [epoch: 7, i:  3499]  train_loss: 1.102  |  valid_loss: 1.047
# [epoch: 7, i:  3674]  train_loss: 1.035  |  valid_loss: 0.898
# [epoch: 7, i:  3849]  train_loss: 0.980  |  valid_loss: 0.998
# [epoch: 7, i:  4024]  train_loss: 1.019  |  valid_loss: 0.854
# [epoch: 7, i:  4199]  train_loss: 1.077  |  valid_loss: 0.907
# [epoch: 7, i:  4374]  train_loss: 1.073  |  valid_loss: 0.942
# [epoch: 7, i:  4549]  train_loss: 1.036  |  valid_loss: 1.121
# [epoch: 7, i:  4724]  train_loss: 1.069  |  valid_loss: 0.746
# [epoch: 7, i:  4899]  train_loss: 1.018  |  valid_loss: 0.922
# [epoch: 7, i:  5074]  train_loss: 1.021  |  valid_loss: 0.906
# [epoch: 7, i:  5249]  train_loss: 1.017  |  valid_loss: 0.802
# [epoch: 7, i:  5424]  train_loss: 1.013  |  valid_loss: 0.809
# [epoch: 7, i:  5599]  train_loss: 1.042  |  valid_loss: 0.909
# [epoch: 7, i:  5774]  train_loss: 1.062  |  valid_loss: 0.957
# [epoch: 7, i:  5949]  train_loss: 1.067  |  valid_loss: 0.967
# [epoch: 7, i:  6124]  train_loss: 1.052  |  valid_loss: 1.025
# [epoch: 7, i:  6299]  train_loss: 1.036  |  valid_loss: 0.896
# [epoch: 7, i:  6474]  train_loss: 1.060  |  valid_loss: 0.961
# [epoch: 7, i:  6649]  train_loss: 1.026  |  valid_loss: 1.000
# [epoch: 7, i:  6824]  train_loss: 1.091  |  valid_loss: 0.813
# [epoch: 7, i:  6999]  train_loss: 1.058  |  valid_loss: 0.874
# [epoch: 7, i:  7174]  train_loss: 1.095  |  valid_loss: 0.794
# [epoch: 7, i:  7349]  train_loss: 1.065  |  valid_loss: 0.949
# [epoch: 7, i:  7524]  train_loss: 1.045  |  valid_loss: 0.762
# [epoch: 7, i:  7699]  train_loss: 1.038  |  valid_loss: 0.899
# [epoch: 7, i:  7874]  train_loss: 1.114  |  valid_loss: 0.884
# [epoch: 7, i:  8049]  train_loss: 1.072  |  valid_loss: 0.982
# [epoch: 7, i:  8224]  train_loss: 1.147  |  valid_loss: 0.770
# [epoch: 7, i:  8399]  train_loss: 0.987  |  valid_loss: 0.886
# [epoch: 7, i:  8574]  train_loss: 1.038  |  valid_loss: 0.805
# [epoch: 7, i:  8749]  train_loss: 1.059  |  valid_loss: 1.007
# [epoch: 7, i:  8924]  train_loss: 1.057  |  valid_loss: 0.845
# [epoch: 7, i:  9099]  train_loss: 1.001  |  valid_loss: 0.946
# [epoch: 7, i:  9274]  train_loss: 1.013  |  valid_loss: 0.735
# [epoch: 7, i:  9449]  train_loss: 1.022  |  valid_loss: 0.964
# [epoch: 7, i:  9624]  train_loss: 1.019  |  valid_loss: 0.879
# [epoch: 7, i:  9799]  train_loss: 1.068  |  valid_loss: 0.985
# [epoch: 7, i:  9974]  train_loss: 1.056  |  valid_loss: 1.004
# [epoch: 7, i: 10149]  train_loss: 0.976  |  valid_loss: 0.727
# [epoch: 7, i: 10324]  train_loss: 1.012  |  valid_loss: 1.054
# [epoch: 7, i: 10499]  train_loss: 1.030  |  valid_loss: 0.916
# [epoch: 7, i: 10674]  train_loss: 1.103  |  valid_loss: 0.981
# [epoch: 7, i: 10849]  train_loss: 0.993  |  valid_loss: 0.902
# [epoch: 7, i: 11024]  train_loss: 1.077  |  valid_loss: 0.846
# [epoch: 7, i: 11199]  train_loss: 1.010  |  valid_loss: 0.785
# [epoch: 7, i: 11374]  train_loss: 1.024  |  valid_loss: 1.033
# [epoch: 7, i: 11549]  train_loss: 1.025  |  valid_loss: 0.957
# [epoch: 7, i: 11724]  train_loss: 1.002  |  valid_loss: 0.843
# [epoch: 7, i: 11899]  train_loss: 1.041  |  valid_loss: 1.004
# [epoch: 7, i: 12074]  train_loss: 1.045  |  valid_loss: 0.834
# [epoch: 7, i: 12249]  train_loss: 1.078  |  valid_loss: 1.054
# [epoch: 7, i: 12424]  train_loss: 1.109  |  valid_loss: 0.796
# [epoch: 7, i: 12599]  train_loss: 1.092  |  valid_loss: 0.928
# [epoch: 7, i: 12774]  train_loss: 1.075  |  valid_loss: 0.935
# [epoch: 7, i: 12949]  train_loss: 1.112  |  valid_loss: 0.696
# [epoch: 7, i: 13124]  train_loss: 1.128  |  valid_loss: 0.850
# [epoch: 7, i: 13299]  train_loss: 1.133  |  valid_loss: 0.829
# [epoch: 7, i: 13474]  train_loss: 1.127  |  valid_loss: 0.903
# [epoch: 7, i: 13649]  train_loss: 1.122  |  valid_loss: 0.839
# [epoch: 7, i: 13824]  train_loss: 1.001  |  valid_loss: 0.882
# [epoch: 7, i: 13999]  train_loss: 1.092  |  valid_loss: 0.977
# [epoch: 7, i: 14174]  train_loss: 1.097  |  valid_loss: 0.768
# [epoch: 7, i: 14349]  train_loss: 0.997  |  valid_loss: 0.870
# [epoch: 7, i: 14524]  train_loss: 1.063  |  valid_loss: 0.844
# [epoch: 7, i: 14699]  train_loss: 1.067  |  valid_loss: 1.011
# [epoch: 7, i: 14874]  train_loss: 1.022  |  valid_loss: 0.923
# [epoch: 7, i: 15049]  train_loss: 1.133  |  valid_loss: 0.872
# [epoch: 7, i: 15224]  train_loss: 0.985  |  valid_loss: 0.983
# [epoch: 7, i: 15399]  train_loss: 1.095  |  valid_loss: 1.003
# [epoch: 7, i: 15574]  train_loss: 1.045  |  valid_loss: 0.954
# [epoch: 7, i: 15749]  train_loss: 1.133  |  valid_loss: 0.874
# [epoch: 7, i: 15924]  train_loss: 0.978  |  valid_loss: 0.885
# [epoch: 7, i: 16099]  train_loss: 1.028  |  valid_loss: 0.691
# [epoch: 7, i: 16274]  train_loss: 1.037  |  valid_loss: 0.855
# [epoch: 7, i: 16449]  train_loss: 1.030  |  valid_loss: 0.925
# [epoch: 7, i: 16624]  train_loss: 1.060  |  valid_loss: 0.809
# [epoch: 7, i: 16799]  train_loss: 1.128  |  valid_loss: 0.749
# [epoch: 7, i: 16974]  train_loss: 0.973  |  valid_loss: 0.916
# [epoch: 7, i: 17149]  train_loss: 1.003  |  valid_loss: 1.112
# [epoch: 7, i: 17324]  train_loss: 1.108  |  valid_loss: 0.975
# [epoch: 7, i: 17499]  train_loss: 1.088  |  valid_loss: 0.870
# --> [End of epoch 7] train_accuracy: 64.06%  |  valid_accuracy: 69.37%
# --> [Start of epoch 8]  lr: 0.000500
# [epoch: 8, i:   174]  train_loss: 0.972  |  valid_loss: 0.784
# [epoch: 8, i:   349]  train_loss: 0.982  |  valid_loss: 0.956
# [epoch: 8, i:   524]  train_loss: 1.118  |  valid_loss: 0.907
# [epoch: 8, i:   699]  train_loss: 1.028  |  valid_loss: 0.869
# [epoch: 8, i:   874]  train_loss: 1.049  |  valid_loss: 0.897
# [epoch: 8, i:  1049]  train_loss: 1.019  |  valid_loss: 0.707
# [epoch: 8, i:  1224]  train_loss: 1.023  |  valid_loss: 0.913
# [epoch: 8, i:  1399]  train_loss: 0.996  |  valid_loss: 0.964
# [epoch: 8, i:  1574]  train_loss: 1.081  |  valid_loss: 0.966
# [epoch: 8, i:  1749]  train_loss: 1.050  |  valid_loss: 0.850
# [epoch: 8, i:  1924]  train_loss: 1.009  |  valid_loss: 0.840
# [epoch: 8, i:  2099]  train_loss: 1.052  |  valid_loss: 0.839
# [epoch: 8, i:  2274]  train_loss: 1.035  |  valid_loss: 0.913
# [epoch: 8, i:  2449]  train_loss: 1.009  |  valid_loss: 0.809
# [epoch: 8, i:  2624]  train_loss: 1.022  |  valid_loss: 0.739
# [epoch: 8, i:  2799]  train_loss: 0.961  |  valid_loss: 0.883
# [epoch: 8, i:  2974]  train_loss: 0.934  |  valid_loss: 0.902
# [epoch: 8, i:  3149]  train_loss: 1.019  |  valid_loss: 0.906
# [epoch: 8, i:  3324]  train_loss: 0.966  |  valid_loss: 0.862
# [epoch: 8, i:  3499]  train_loss: 0.974  |  valid_loss: 1.135
# [epoch: 8, i:  3674]  train_loss: 0.992  |  valid_loss: 0.930
# [epoch: 8, i:  3849]  train_loss: 0.968  |  valid_loss: 0.962
# [epoch: 8, i:  4024]  train_loss: 1.134  |  valid_loss: 0.947
# [epoch: 8, i:  4199]  train_loss: 1.045  |  valid_loss: 0.893
# [epoch: 8, i:  4374]  train_loss: 0.978  |  valid_loss: 0.878
# [epoch: 8, i:  4549]  train_loss: 1.010  |  valid_loss: 1.063
# [epoch: 8, i:  4724]  train_loss: 1.029  |  valid_loss: 0.781
# [epoch: 8, i:  4899]  train_loss: 1.024  |  valid_loss: 0.914
# [epoch: 8, i:  5074]  train_loss: 0.983  |  valid_loss: 0.750
# [epoch: 8, i:  5249]  train_loss: 1.028  |  valid_loss: 0.767
# [epoch: 8, i:  5424]  train_loss: 1.045  |  valid_loss: 0.874
# [epoch: 8, i:  5599]  train_loss: 1.009  |  valid_loss: 0.912
# [epoch: 8, i:  5774]  train_loss: 1.080  |  valid_loss: 0.845
# [epoch: 8, i:  5949]  train_loss: 1.167  |  valid_loss: 0.961
# [epoch: 8, i:  6124]  train_loss: 0.995  |  valid_loss: 1.026
# [epoch: 8, i:  6299]  train_loss: 1.105  |  valid_loss: 0.874
# [epoch: 8, i:  6474]  train_loss: 1.069  |  valid_loss: 1.019
# [epoch: 8, i:  6649]  train_loss: 1.011  |  valid_loss: 0.954
# [epoch: 8, i:  6824]  train_loss: 1.026  |  valid_loss: 0.775
# [epoch: 8, i:  6999]  train_loss: 1.095  |  valid_loss: 0.778
# [epoch: 8, i:  7174]  train_loss: 1.006  |  valid_loss: 0.843
# [epoch: 8, i:  7349]  train_loss: 1.006  |  valid_loss: 0.918
# [epoch: 8, i:  7524]  train_loss: 1.077  |  valid_loss: 0.657
# [epoch: 8, i:  7699]  train_loss: 1.004  |  valid_loss: 0.911
# [epoch: 8, i:  7874]  train_loss: 1.081  |  valid_loss: 0.791
# [epoch: 8, i:  8049]  train_loss: 0.994  |  valid_loss: 0.894
# [epoch: 8, i:  8224]  train_loss: 0.971  |  valid_loss: 0.719
# [epoch: 8, i:  8399]  train_loss: 1.052  |  valid_loss: 0.902
# [epoch: 8, i:  8574]  train_loss: 1.048  |  valid_loss: 0.808
# [epoch: 8, i:  8749]  train_loss: 1.044  |  valid_loss: 0.922
# [epoch: 8, i:  8924]  train_loss: 1.058  |  valid_loss: 0.855
# [epoch: 8, i:  9099]  train_loss: 1.014  |  valid_loss: 0.890
# [epoch: 8, i:  9274]  train_loss: 1.037  |  valid_loss: 0.682
# [epoch: 8, i:  9449]  train_loss: 1.055  |  valid_loss: 0.971
# [epoch: 8, i:  9624]  train_loss: 1.097  |  valid_loss: 0.910
# [epoch: 8, i:  9799]  train_loss: 1.014  |  valid_loss: 1.023
# [epoch: 8, i:  9974]  train_loss: 1.067  |  valid_loss: 0.966
# [epoch: 8, i: 10149]  train_loss: 1.072  |  valid_loss: 0.755
# [epoch: 8, i: 10324]  train_loss: 1.036  |  valid_loss: 1.040
# [epoch: 8, i: 10499]  train_loss: 1.043  |  valid_loss: 0.962
# [epoch: 8, i: 10674]  train_loss: 1.071  |  valid_loss: 0.989
# [epoch: 8, i: 10849]  train_loss: 1.108  |  valid_loss: 1.008
# [epoch: 8, i: 11024]  train_loss: 1.097  |  valid_loss: 0.781
# [epoch: 8, i: 11199]  train_loss: 1.059  |  valid_loss: 0.840
# [epoch: 8, i: 11374]  train_loss: 0.998  |  valid_loss: 0.919
# [epoch: 8, i: 11549]  train_loss: 0.988  |  valid_loss: 0.923
# [epoch: 8, i: 11724]  train_loss: 1.058  |  valid_loss: 0.815
# [epoch: 8, i: 11899]  train_loss: 1.068  |  valid_loss: 0.929
# [epoch: 8, i: 12074]  train_loss: 0.988  |  valid_loss: 0.832
# [epoch: 8, i: 12249]  train_loss: 1.095  |  valid_loss: 1.011
# [epoch: 8, i: 12424]  train_loss: 1.027  |  valid_loss: 0.850
# [epoch: 8, i: 12599]  train_loss: 1.013  |  valid_loss: 0.825
# [epoch: 8, i: 12774]  train_loss: 0.982  |  valid_loss: 0.910
# [epoch: 8, i: 12949]  train_loss: 1.046  |  valid_loss: 0.698
# [epoch: 8, i: 13124]  train_loss: 1.081  |  valid_loss: 0.815
# [epoch: 8, i: 13299]  train_loss: 1.048  |  valid_loss: 0.812
# [epoch: 8, i: 13474]  train_loss: 1.031  |  valid_loss: 1.050
# [epoch: 8, i: 13649]  train_loss: 1.043  |  valid_loss: 0.850
# [epoch: 8, i: 13824]  train_loss: 1.066  |  valid_loss: 0.885
# [epoch: 8, i: 13999]  train_loss: 1.011  |  valid_loss: 0.997
# [epoch: 8, i: 14174]  train_loss: 1.131  |  valid_loss: 0.755
# [epoch: 8, i: 14349]  train_loss: 0.954  |  valid_loss: 0.835
# [epoch: 8, i: 14524]  train_loss: 1.050  |  valid_loss: 0.852
# [epoch: 8, i: 14699]  train_loss: 0.986  |  valid_loss: 0.952
# [epoch: 8, i: 14874]  train_loss: 1.028  |  valid_loss: 0.921
# [epoch: 8, i: 15049]  train_loss: 1.103  |  valid_loss: 0.799
# [epoch: 8, i: 15224]  train_loss: 1.030  |  valid_loss: 0.870
# [epoch: 8, i: 15399]  train_loss: 0.980  |  valid_loss: 0.904
# [epoch: 8, i: 15574]  train_loss: 0.986  |  valid_loss: 0.873
# [epoch: 8, i: 15749]  train_loss: 1.064  |  valid_loss: 0.951
# [epoch: 8, i: 15924]  train_loss: 1.051  |  valid_loss: 0.802
# [epoch: 8, i: 16099]  train_loss: 0.972  |  valid_loss: 0.662
# [epoch: 8, i: 16274]  train_loss: 1.054  |  valid_loss: 0.828
# [epoch: 8, i: 16449]  train_loss: 1.075  |  valid_loss: 0.856
# [epoch: 8, i: 16624]  train_loss: 1.122  |  valid_loss: 0.763
# [epoch: 8, i: 16799]  train_loss: 1.069  |  valid_loss: 0.743
# [epoch: 8, i: 16974]  train_loss: 1.039  |  valid_loss: 0.818
# [epoch: 8, i: 17149]  train_loss: 1.097  |  valid_loss: 1.100
# [epoch: 8, i: 17324]  train_loss: 1.025  |  valid_loss: 0.907
# [epoch: 8, i: 17499]  train_loss: 1.005  |  valid_loss: 0.857
# --> [End of epoch 8] train_accuracy: 64.76%  |  valid_accuracy: 69.73%
# --> [Start of epoch 9]  lr: 0.000500
# [epoch: 9, i:   174]  train_loss: 0.960  |  valid_loss: 0.820
# [epoch: 9, i:   349]  train_loss: 0.968  |  valid_loss: 0.827
# [epoch: 9, i:   524]  train_loss: 0.919  |  valid_loss: 0.910
# [epoch: 9, i:   699]  train_loss: 1.016  |  valid_loss: 0.884
# [epoch: 9, i:   874]  train_loss: 1.018  |  valid_loss: 0.847
# [epoch: 9, i:  1049]  train_loss: 0.968  |  valid_loss: 0.692
# [epoch: 9, i:  1224]  train_loss: 1.012  |  valid_loss: 0.831
# [epoch: 9, i:  1399]  train_loss: 1.074  |  valid_loss: 0.961
# [epoch: 9, i:  1574]  train_loss: 1.015  |  valid_loss: 0.976
# [epoch: 9, i:  1749]  train_loss: 1.027  |  valid_loss: 0.793
# [epoch: 9, i:  1924]  train_loss: 1.001  |  valid_loss: 0.745
# [epoch: 9, i:  2099]  train_loss: 1.004  |  valid_loss: 0.957
# [epoch: 9, i:  2274]  train_loss: 1.023  |  valid_loss: 0.800
# [epoch: 9, i:  2449]  train_loss: 0.999  |  valid_loss: 0.888
# [epoch: 9, i:  2624]  train_loss: 0.942  |  valid_loss: 0.690
# [epoch: 9, i:  2799]  train_loss: 1.048  |  valid_loss: 1.002
# [epoch: 9, i:  2974]  train_loss: 0.977  |  valid_loss: 0.891
# [epoch: 9, i:  3149]  train_loss: 1.016  |  valid_loss: 0.902
# [epoch: 9, i:  3324]  train_loss: 0.989  |  valid_loss: 0.877
# [epoch: 9, i:  3499]  train_loss: 1.002  |  valid_loss: 1.065
# [epoch: 9, i:  3674]  train_loss: 0.991  |  valid_loss: 0.979
# [epoch: 9, i:  3849]  train_loss: 1.060  |  valid_loss: 0.905
# [epoch: 9, i:  4024]  train_loss: 0.959  |  valid_loss: 0.864
# [epoch: 9, i:  4199]  train_loss: 1.003  |  valid_loss: 0.871
# [epoch: 9, i:  4374]  train_loss: 1.064  |  valid_loss: 0.953
# [epoch: 9, i:  4549]  train_loss: 0.979  |  valid_loss: 1.025
# [epoch: 9, i:  4724]  train_loss: 1.050  |  valid_loss: 0.702
# [epoch: 9, i:  4899]  train_loss: 0.989  |  valid_loss: 0.914
# [epoch: 9, i:  5074]  train_loss: 1.065  |  valid_loss: 0.860
# [epoch: 9, i:  5249]  train_loss: 1.061  |  valid_loss: 0.815
# [epoch: 9, i:  5424]  train_loss: 0.954  |  valid_loss: 0.864
# [epoch: 9, i:  5599]  train_loss: 1.090  |  valid_loss: 0.854
# [epoch: 9, i:  5774]  train_loss: 1.002  |  valid_loss: 0.848
# [epoch: 9, i:  5949]  train_loss: 1.054  |  valid_loss: 0.923
# [epoch: 9, i:  6124]  train_loss: 1.104  |  valid_loss: 1.062
# [epoch: 9, i:  6299]  train_loss: 1.020  |  valid_loss: 0.847
# [epoch: 9, i:  6474]  train_loss: 0.978  |  valid_loss: 0.934
# [epoch: 9, i:  6649]  train_loss: 1.035  |  valid_loss: 0.913
# [epoch: 9, i:  6824]  train_loss: 0.938  |  valid_loss: 0.757
# [epoch: 9, i:  6999]  train_loss: 1.061  |  valid_loss: 0.774
# [epoch: 9, i:  7174]  train_loss: 0.994  |  valid_loss: 0.774
# [epoch: 9, i:  7349]  train_loss: 1.010  |  valid_loss: 0.861
# [epoch: 9, i:  7524]  train_loss: 0.952  |  valid_loss: 0.768
# [epoch: 9, i:  7699]  train_loss: 0.982  |  valid_loss: 0.895
# [epoch: 9, i:  7874]  train_loss: 0.949  |  valid_loss: 0.902
# [epoch: 9, i:  8049]  train_loss: 1.053  |  valid_loss: 0.841
# [epoch: 9, i:  8224]  train_loss: 0.968  |  valid_loss: 0.735
# [epoch: 9, i:  8399]  train_loss: 0.930  |  valid_loss: 0.799
# [epoch: 9, i:  8574]  train_loss: 0.993  |  valid_loss: 0.793
# [epoch: 9, i:  8749]  train_loss: 0.998  |  valid_loss: 0.951
# [epoch: 9, i:  8924]  train_loss: 0.999  |  valid_loss: 0.844
# [epoch: 9, i:  9099]  train_loss: 0.959  |  valid_loss: 0.890
# [epoch: 9, i:  9274]  train_loss: 0.991  |  valid_loss: 0.731
# [epoch: 9, i:  9449]  train_loss: 1.136  |  valid_loss: 0.962
# [epoch: 9, i:  9624]  train_loss: 1.022  |  valid_loss: 0.903
# [epoch: 9, i:  9799]  train_loss: 0.962  |  valid_loss: 0.989
# [epoch: 9, i:  9974]  train_loss: 1.044  |  valid_loss: 0.981
# [epoch: 9, i: 10149]  train_loss: 0.995  |  valid_loss: 0.779
# [epoch: 9, i: 10324]  train_loss: 0.943  |  valid_loss: 0.915
# [epoch: 9, i: 10499]  train_loss: 1.057  |  valid_loss: 0.893
# [epoch: 9, i: 10674]  train_loss: 1.107  |  valid_loss: 0.955
# [epoch: 9, i: 10849]  train_loss: 1.026  |  valid_loss: 0.806
# [epoch: 9, i: 11024]  train_loss: 1.068  |  valid_loss: 0.895
# [epoch: 9, i: 11199]  train_loss: 1.059  |  valid_loss: 0.775
# [epoch: 9, i: 11374]  train_loss: 1.076  |  valid_loss: 0.966
# [epoch: 9, i: 11549]  train_loss: 1.006  |  valid_loss: 0.882
# [epoch: 9, i: 11724]  train_loss: 1.078  |  valid_loss: 0.930
# [epoch: 9, i: 11899]  train_loss: 0.990  |  valid_loss: 0.876
# [epoch: 9, i: 12074]  train_loss: 1.084  |  valid_loss: 0.840
# [epoch: 9, i: 12249]  train_loss: 1.092  |  valid_loss: 0.992
# [epoch: 9, i: 12424]  train_loss: 0.922  |  valid_loss: 0.735
# [epoch: 9, i: 12599]  train_loss: 0.986  |  valid_loss: 0.893
# [epoch: 9, i: 12774]  train_loss: 1.095  |  valid_loss: 0.909
# [epoch: 9, i: 12949]  train_loss: 1.045  |  valid_loss: 0.740
# [epoch: 9, i: 13124]  train_loss: 1.003  |  valid_loss: 0.777
# [epoch: 9, i: 13299]  train_loss: 1.011  |  valid_loss: 0.886
# [epoch: 9, i: 13474]  train_loss: 1.046  |  valid_loss: 0.932
# [epoch: 9, i: 13649]  train_loss: 1.064  |  valid_loss: 0.837
# [epoch: 9, i: 13824]  train_loss: 1.024  |  valid_loss: 0.909
# [epoch: 9, i: 13999]  train_loss: 1.000  |  valid_loss: 0.888
# [epoch: 9, i: 14174]  train_loss: 0.981  |  valid_loss: 0.757
# [epoch: 9, i: 14349]  train_loss: 1.037  |  valid_loss: 0.837
# [epoch: 9, i: 14524]  train_loss: 0.967  |  valid_loss: 0.838
# [epoch: 9, i: 14699]  train_loss: 1.051  |  valid_loss: 0.902
# [epoch: 9, i: 14874]  train_loss: 0.958  |  valid_loss: 0.897
# [epoch: 9, i: 15049]  train_loss: 1.061  |  valid_loss: 0.769
# [epoch: 9, i: 15224]  train_loss: 0.998  |  valid_loss: 0.927
# [epoch: 9, i: 15399]  train_loss: 0.976  |  valid_loss: 0.917
# [epoch: 9, i: 15574]  train_loss: 1.027  |  valid_loss: 0.858
# [epoch: 9, i: 15749]  train_loss: 1.021  |  valid_loss: 0.917
# [epoch: 9, i: 15924]  train_loss: 0.983  |  valid_loss: 0.738
# [epoch: 9, i: 16099]  train_loss: 0.992  |  valid_loss: 0.671
# [epoch: 9, i: 16274]  train_loss: 1.002  |  valid_loss: 0.976
# [epoch: 9, i: 16449]  train_loss: 1.013  |  valid_loss: 0.845
# [epoch: 9, i: 16624]  train_loss: 1.010  |  valid_loss: 0.792
# [epoch: 9, i: 16799]  train_loss: 1.030  |  valid_loss: 0.716
# [epoch: 9, i: 16974]  train_loss: 1.029  |  valid_loss: 0.791
# [epoch: 9, i: 17149]  train_loss: 0.957  |  valid_loss: 1.011
# [epoch: 9, i: 17324]  train_loss: 1.064  |  valid_loss: 0.905
# [epoch: 9, i: 17499]  train_loss: 1.078  |  valid_loss: 0.813
# --> [End of epoch 9] train_accuracy: 65.44%  |  valid_accuracy: 70.51%
# Finished Training.

# %%
plt.plot(avg_train_losses)
plt.plot(avg_valid_losses)
plt.title('Dense_max_1 + plateau scheduling + l2 regularization')
plt.xlabel('mini-batch index / {}'.format(iter_n_per_record))
plt.ylabel('avg. mini-batch loss')
plt.legend(['training loss', 'validation loss'])
plt.show()

# %%
def moving_average(data, window_size):
    """Compute the moving average of the data using a specified window size."""
    return np.convolve(data, np.ones(window_size)/window_size, mode='valid')

window_size = 20  # Adjust this based on your preference
train_losses_ma = moving_average(avg_train_losses, window_size)
valid_losses_ma = moving_average(avg_valid_losses, window_size)

# x_axis = np.arange(len(train_losses_ma))/100 
x_axis = np.arange(window_size - 1, len(train_losses_ma) + window_size - 1)

plt.plot(avg_train_losses)
plt.plot(avg_valid_losses)
plt.plot(x_axis, train_losses_ma, linewidth=2)
plt.plot(x_axis, valid_losses_ma, linewidth=2)
plt.title('DenseNet loss trend + exponential scheduling + l2 regularization')
plt.xlabel('mini-batch index / {}'.format(iter_n_per_record))
plt.ylabel('avg. mini-batch loss')
plt.legend(['training loss', 'validation loss', 'training loss (moving avg)', 'validation loss (moving avg)'])
plt.show()

# %%
plt.plot(train_accuracies)
plt.plot(valid_accuracies)
plt.title('DenseMax accuracy curve for plateau scheduling + l2 regularization')
plt.xlabel('epoch / {}'.format(iter_n_per_record))
plt.ylabel('accuracy')
plt.legend(['train accuracy', 'validation accuracy'])
plt.show()

# %%
# print average time per epoch to 2nd decimal place
print(f"Average time per epoch: {np.mean(time_per_epoch):.2f} seconds")
print("number of parameters:", count_parameters(model))
print(f'model size: {get_model_size(model):.3f}MB')
# Out:
# Average time per epoch: 825.81 seconds
# number of parameters: 136536
# model size: 0.524MB

# %%
# The function to show an image.
def imshow(img):
    img = img / 2 + 0.5     # Unnormalize.
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# %%
# Check several images.
dataiter = iter(validloader)
images, labels = next(dataiter)
imshow(torchvision.utils.make_grid(images))
print('GroundTruth: ', ' '.join('%5s' % classes[labels[j]] for j in range(4)))
outputs = model(images.to(device))

# max compare along the row, return the index of the max value, which is the predicted class
_, predicted = torch.max(outputs, 1)

print('Predicted: ', ' '.join('%5s' % classes[predicted[j]]
                              for j in range(4)))
# Out:
# GroundTruth:    cat  ship  ship plane
# Predicted:    cat  ship   car plane

# %%
images, labels = next(iter(validloader))
print(len(images))
# Out:
# 4

# %%
inference_time_per_image = []


model.to(device)
model.eval()
# Get test accuracy.
correct = 0
total = 0
with torch.no_grad():
    for data in validloader:
        images, labels = data
        images, labels = images.to(device), labels.to(device)
        inference_start = time.time()
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        inference_end = time.time()
        inference_time_per_image.append((inference_end - inference_start) / len(images))
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print('Accuracy of the network on the 10000 test images: %.2f %%' % (
    100 * correct / total))

# print average inference time per image in ms
print(f"average inference time per image: {sum(inference_time_per_image) * 1000 / len(inference_time_per_image):.3f} ms")
# Out:
# Accuracy of the network on the 10000 test images: 70.10 %
# average inference time per image: 1.192 ms

# %%
model.to(device)
model.eval()

# Get test accuracy for each class.
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))
with torch.no_grad():
    for data in validloader:
        images, labels = data
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels).squeeze()
        for i in range(4):
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1

for i in range(10):
    print('Accuracy of %5s : %2d %%' % (
        classes[i], 100 * class_correct[i] / class_total[i]))
# Out:
# Accuracy of plane : 71 %
# Accuracy of   car : 86 %
# Accuracy of  bird : 62 %
# Accuracy of   cat : 51 %
# Accuracy of  deer : 68 %
# Accuracy of   dog : 69 %
# Accuracy of  frog : 73 %
# Accuracy of horse : 74 %
# Accuracy of  ship : 83 %
# Accuracy of truck : 89 %

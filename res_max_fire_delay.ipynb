# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

batch_size = 4

std_transforms = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

std_trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=std_transforms)
trainloader = torch.utils.data.DataLoader(std_trainset, batch_size=batch_size,
                                          shuffle=True, num_workers=2)

validset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=std_transforms)
validloader = torch.utils.data.DataLoader(validset, batch_size=batch_size,
                                         shuffle=False, num_workers=2)

# If there are GPUs, choose the first one for computing. Otherwise use CPU.
device = torch.device("cuda:0" if torch.cuda.is_available() else ("mps" if torch.backends.mps.is_available() else "cpu"))

# the order for cifar10 10 classes
classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

print(device)
print(len(std_trainset))
print(len(trainloader))  
# If 'mps or cuda:0' is printed, it means GPU is available.
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# mps
# 50000
# 12500

# %% [markdown]
# #### Optional: Apply data augmentation

# %%
from custom_nn.datasets import CustomCIFAR10

# Additional focused augmentations
focused_augmentations = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
])

# using custom dataset class to add focused augmentations capability
aug_trainset = CustomCIFAR10(
    root='./data',
    train=True,
    download=True,
    transform=std_transforms,
    focused_transform=focused_augmentations
)

# the class we want the augmentation for birds, cats, deer, and dogs
desired_classes = [1, 2, 3, 4]

# Filter the dataset
filtered_indices = [i for i, (_, label) in enumerate(aug_trainset) if label in desired_classes]

filtered_dataset = torch.utils.data.Subset(aug_trainset, filtered_indices)

# Combine the two datasets
combined_trainset = torch.utils.data.ConcatDataset([std_trainset, filtered_dataset])
trainloader = torch.utils.data.DataLoader(combined_trainset, batch_size=batch_size,
                                          shuffle=True, num_workers=2)
print(len(combined_trainset))
print(len(trainloader))
# Out:
# Files already downloaded and verified
# 70000
# 17500

# %%
from custom_nn.blocks import FireResBlock
class ResFireDelay(nn.Module):
    def __init__(self):
        super().__init__()
        
         ### RES 1
         
        # 3x32x32 to 40x32x32
        self.fb1 = FireResBlock(3, 8, 10, 10)
        self.act1 = nn.ReLU()

        ### RES 2
        
        # 20x32x32 to 20x32x32
        self.fb2 = FireResBlock(20, 8, 10, 10)
        self.act2 = nn.ReLU()
        
        ### RES 3
        
        # 20x32x32 to 20x32x32
        self.fb3 = FireResBlock(20, 8, 10, 10)
        self.act3 = nn.ReLU()
        
        ### RES 4
        
        # 20x32x32 to 20x32x32
        self.fb4 = FireResBlock(20, 8, 10, 10)
        self.act4 = nn.ReLU()
        
        # 20x32x32 to 20x16x16
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        
        # 20x16x16 to 20x16x16
        self.fb5 = FireResBlock(20, 8, 10, 10)
        self.act5 = nn.ReLU()
        
        # 20x16x16 to 20x8x8
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        
                
        self.flatten = nn.Flatten(1)
        # 20x8x8 affine operation to hidden layer with 100 neurons
        self.fc1 = nn.Linear(20 * 8 * 8, 100)
        self.bn1 = nn.BatchNorm1d(100)
        self.act4 = nn.ReLU()
        
        # affine operation to output layer with 10 neurons
        self.fc2 = nn.Linear(100, 10)
        
    def forward(self, x):
        
        x = self.fb1(x)
        x = self.act1(x)
    
        x = self.fb2(x)
        x = self.act2(x)

        
        x = self.fb3(x)
        x = self.act3(x)
        
        x = self.fb4(x)
        x = self.act4(x)
        x = self.pool1(x)
        
        x = self.fb5(x)
        x = self.act5(x)
        x = self.pool2(x)
                
        # flatten and pass through fully connected layers
        x = self.flatten(x)
        x = self.fc1(x)
        x = self.bn1(x)
        x = self.act4(x)
        x = self.fc2(x)
        return x
test = ResFireDelay()
test.to(device)
test(torch.randn(4, 3, 32, 32).to(device))
# Out:
# tensor([[ 0.1323,  0.3889, -0.2387,  0.3970,  0.4221, -0.5531, -0.2358, -0.2973,
#           0.2724,  0.7414],
#         [ 0.6712, -0.6313,  0.5678,  0.4191,  0.5815,  0.2407, -0.6994, -0.0069,
#           0.5070, -0.1387],
#         [ 0.3334,  0.1521, -0.3338,  0.1536, -0.1661, -0.0025, -0.4387,  0.4702,
#          -0.1818,  0.3779],
#         [ 0.2215,  0.6324,  0.2163,  0.5085,  0.2655, -0.3157, -0.1104, -0.0189,
#          -0.6447,  0.0035]], device='mps:0', grad_fn=<LinearBackward0>)

# %%
from pathlib import Path
import time
from custom_nn.utils.model_utils import count_parameters, get_model_size

epoch_start = 0     # Start from epoch 0 or last checkpoint epoch
iter_n = len(trainloader)  # number of iteration per epoch
record_freq = 100 # how many times to record the loss and accuracy per epoch
print_freq = 100 # how many times to print the loss and accuracy per epoch
iter_n_per_record = iter_n // record_freq  # Record frequency.
iter_n_per_print = iter_n // print_freq # Print frequency, need to be multiple of record_freq.

# a number for computing running validation loss in each iteration.
train_per_valid = len(trainloader) / len(validloader)  

avg_train_losses, avg_valid_losses = [], []   # Avg. losses.
train_accuracies, valid_accuracies = [], []  # Train and test accuracies.
time_per_epoch = []  # Time per epoch.

model = ResFireDelay()     # Create the network instance.
# Move the network parameters to the specified device
# need to be done before passing to optimizer.
model.to(device)  

assert model(torch.randn(4, 3, 32, 32).to(device)).shape == torch.Size([4, 10])

# We use Adam as optimizer.
opt = optim.Adam(model.parameters(), lr=5e-4, betas=(0.9, 0.999), eps=1e-08, weight_decay=1e-4)
# We use cross-entropy as loss function.
loss_func = nn.CrossEntropyLoss() 

# add scheduling
# scheduler = optim.lr_scheduler.ExponentialLR(opt, gamma=0.8)
# scheduler = optim.lr_scheduler.StepLR(opt, step_size=5, gamma=0.8)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(opt, mode='max', factor=0.1, patience=4, threshold=1e-4)

# directory to save the model
directory_path = Path("./checkpoints/res_max_fire_delay" + "_batch" + str(batch_size))
# Make the directory if it doesn't exist
directory_path.mkdir(parents=True, exist_ok=True)

print("train_per_valid:", train_per_valid)

print("number of parameters:", count_parameters(model))
print('model size: {:.4f}MB'.format(get_model_size(model)))
# Out:
# train_per_valid: 7.0
# number of parameters: 136354
# model size: 0.5229MB

# %%
import re

# Pattern to match the files and extract epoch numbers
pattern = r'epoch_(\d+).pth'

# Use Path.glob to list all files matching the pattern
files = list(directory_path.glob('epoch_*.pth'))

# Extract epochs and files into a list of tuples
epoch_files = []
for file_path in files:
    match = re.search(pattern, file_path.name)
    if match:
        epoch_num = int(match.group(1))
        epoch_files.append((epoch_num, file_path))

# Sort the list by epoch number in descending order
epoch_files.sort(key=lambda x: x[0], reverse=False)

if epoch_files:
    # populating history for loss and accuracy for plotting
    for file in epoch_files:
        checkpoint = torch.load(file[1])
        avg_train_losses += checkpoint['avg_train_losses']
        avg_valid_losses += checkpoint['avg_valid_losses']
        train_accuracies.append(checkpoint['train_accuracy'])
        valid_accuracies.append(checkpoint['valid_accuracy'])
        time_per_epoch.append(checkpoint['time_per_epoch'])
    
    # load the model from the latest checkpoint file
    latest_file_path = epoch_files[-1][1]
    print(f"The latest checkpoint file is: {latest_file_path}")
    checkpoint = torch.load(latest_file_path)
    model.load_state_dict(checkpoint['model_state_dict'])
    opt.load_state_dict(checkpoint['optimizer_state_dict'])
    scheduler.load_state_dict(checkpoint['scheduler_state_dict'])
    
    # start training from the next epoch
    epoch_start = checkpoint['epoch'] + 1
else:
    print("No checkpoint files found.")
# Out:
# No checkpoint files found.

# %%
epochs = 10  # Total epochs.

for epoch in range(epoch_start, epoch_start + epochs):  # Loop over the dataset multiple times.
    running_train_loss = 0.0       # Initialize running train_loss for training set.
    running_val_loss = 0.0     # Initialize running train_loss for validation set.
    
    # Initialize running total and correct for computing train accuracy.
    train_correct = 0 
    train_total = 0
    # Initialize running total and correct for computing test accuracy.
    valid_total = 0   
    valid_correct = 0
    
    
    
    print('--> [Start of epoch {}]'.format(epoch) +
          '  lr: {:.6f}'.format(opt.param_groups[0]['lr']))
    
    # print('--> [Start of epoch {}]'.format(epoch))
    
    epoch_start_time = time.time()
    
    validiter = iter(validloader)
    for i, data in enumerate(iterable=trainloader, start=0):
        
        # Set the model to training mode.
        model.train()
        
        # Get the inputs.
        inputs, labels = data
        
        # Move the inputs to the specified device.
        inputs, labels = inputs.to(device), labels.to(device)
        
        # Zero the parameter gradients.
        opt.zero_grad()

        # Forward step
        train_output = model(inputs)
        train_loss = loss_func(train_output, labels)
        
        # Backward step.
        train_loss.backward()
        
        # Optimization step (update the parameters).
        opt.step()
        
        model.eval()
        
        # record statistics.
        running_train_loss += train_loss.item()
        
        # this is for recording training accuracy
        _, train_predicted = torch.max(train_output.data, 1)
        train_total += labels.size(0)
        train_correct += (train_predicted == labels).sum().item()
        
        # only iterate through validation set according to train_per_valid ratio
        if i % train_per_valid == train_per_valid - 1:
            # Set the model to evaluation mode.
            with torch.no_grad():
                valid_inputs, valid_labels = next(validiter)
                valid_inputs, valid_labels = valid_inputs.to(device), valid_labels.to(device)
                valid_output = model(valid_inputs)
                valid_loss = loss_func(valid_output, valid_labels)
                running_val_loss += valid_loss.item()
                
                _, valid_predicted = torch.max(valid_output.data, 1)
                valid_total += valid_labels.size(0)
                valid_correct += (valid_predicted == valid_labels).sum().item()
            
        # Record training/validation loss every several mini-batches.
        if i % iter_n_per_record == iter_n_per_record - 1: 
            avg_train_loss = running_train_loss / iter_n_per_record
            avg_train_losses.append(avg_train_loss)
            avg_valid_loss = train_per_valid * running_val_loss / iter_n_per_record
            avg_valid_losses.append(avg_valid_loss)
            running_train_loss, running_val_loss = 0.0, 0.0
            
            # only print traing training loss once in a while to avoid cluster output
            if i % iter_n_per_print == iter_n_per_print - 1:
                print('[epoch: {}, i: {:5d}]'.format(epoch, i) +
                      '  train_loss: {:.3f}'.format(avg_train_loss) + 
                      '  |  valid_loss: {:.3f}'.format(avg_valid_loss))
                            
    epoch_end_time = time.time()
    time_per_epoch.append(epoch_end_time - epoch_start_time)
    
    # calculating train accuracy
    train_accuracy = 100 * train_correct / train_total
    train_accuracies.append(train_accuracy)
    
    valid_accuracy = 100 * valid_correct / valid_total
    valid_accuracies.append(valid_accuracy)     
    
    # reduce on plateau scheduling
    scheduler.step(valid_accuracy)
    
    # Store the networks after each epochs.
    # in case we want to do simple average or weighted average
    file_name = f'epoch_{epoch:04d}.pth'
    save_path = directory_path / file_name
    
    torch.save({
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': opt.state_dict(),
            'scheduler_state_dict': scheduler.state_dict(),
            'avg_train_losses': avg_train_losses[epoch * iter_n_per_record : (epoch + 1) * iter_n_per_record],
            'avg_valid_losses': avg_valid_losses[epoch * iter_n_per_record : (epoch + 1) * iter_n_per_record],
            'train_accuracy': train_accuracies[epoch],
            'valid_accuracy': valid_accuracies[epoch],
            'time_per_epoch': time_per_epoch[epoch],
            }, save_path)
    
    print('--> [End of epoch {}]'.format(epoch) +
                      ' train_accuracy: {:.2f}%'.format(train_accuracy) + 
                      '  |  valid_accuracy: {:.2f}%'.format(valid_accuracy))

print('Finished Training.')
# Out:
# --> [Start of epoch 0]  lr: 0.000500
# [epoch: 0, i:   174]  train_loss: 2.118  |  valid_loss: 2.225
# [epoch: 0, i:   349]  train_loss: 1.922  |  valid_loss: 2.011
# [epoch: 0, i:   524]  train_loss: 1.857  |  valid_loss: 1.974
# [epoch: 0, i:   699]  train_loss: 1.805  |  valid_loss: 1.785
# [epoch: 0, i:   874]  train_loss: 1.721  |  valid_loss: 1.832
# [epoch: 0, i:  1049]  train_loss: 1.787  |  valid_loss: 1.774
# [epoch: 0, i:  1224]  train_loss: 1.677  |  valid_loss: 1.752
# [epoch: 0, i:  1399]  train_loss: 1.666  |  valid_loss: 1.667
# [epoch: 0, i:  1574]  train_loss: 1.721  |  valid_loss: 1.660
# [epoch: 0, i:  1749]  train_loss: 1.698  |  valid_loss: 1.508
# [epoch: 0, i:  1924]  train_loss: 1.631  |  valid_loss: 1.497
# [epoch: 0, i:  2099]  train_loss: 1.671  |  valid_loss: 1.462
# [epoch: 0, i:  2274]  train_loss: 1.660  |  valid_loss: 1.570
# [epoch: 0, i:  2449]  train_loss: 1.609  |  valid_loss: 1.575
# [epoch: 0, i:  2624]  train_loss: 1.584  |  valid_loss: 1.470
# [epoch: 0, i:  2799]  train_loss: 1.608  |  valid_loss: 1.438
# [epoch: 0, i:  2974]  train_loss: 1.585  |  valid_loss: 1.456
# [epoch: 0, i:  3149]  train_loss: 1.597  |  valid_loss: 1.502
# [epoch: 0, i:  3324]  train_loss: 1.559  |  valid_loss: 1.445
# [epoch: 0, i:  3499]  train_loss: 1.614  |  valid_loss: 1.489
# [epoch: 0, i:  3674]  train_loss: 1.580  |  valid_loss: 1.353
# [epoch: 0, i:  3849]  train_loss: 1.625  |  valid_loss: 1.475
# [epoch: 0, i:  4024]  train_loss: 1.522  |  valid_loss: 1.463
# [epoch: 0, i:  4199]  train_loss: 1.524  |  valid_loss: 1.536
# [epoch: 0, i:  4374]  train_loss: 1.542  |  valid_loss: 1.447
# [epoch: 0, i:  4549]  train_loss: 1.545  |  valid_loss: 1.715
# [epoch: 0, i:  4724]  train_loss: 1.547  |  valid_loss: 1.350
# [epoch: 0, i:  4899]  train_loss: 1.526  |  valid_loss: 1.342
# [epoch: 0, i:  5074]  train_loss: 1.527  |  valid_loss: 1.425
# [epoch: 0, i:  5249]  train_loss: 1.452  |  valid_loss: 1.345
# [epoch: 0, i:  5424]  train_loss: 1.494  |  valid_loss: 1.280
# [epoch: 0, i:  5599]  train_loss: 1.497  |  valid_loss: 1.263
# [epoch: 0, i:  5774]  train_loss: 1.499  |  valid_loss: 1.319
# [epoch: 0, i:  5949]  train_loss: 1.541  |  valid_loss: 1.338
# [epoch: 0, i:  6124]  train_loss: 1.419  |  valid_loss: 1.437
# [epoch: 0, i:  6299]  train_loss: 1.509  |  valid_loss: 1.180
# [epoch: 0, i:  6474]  train_loss: 1.446  |  valid_loss: 1.380
# [epoch: 0, i:  6649]  train_loss: 1.445  |  valid_loss: 1.479
# [epoch: 0, i:  6824]  train_loss: 1.493  |  valid_loss: 1.136
# [epoch: 0, i:  6999]  train_loss: 1.439  |  valid_loss: 1.296
# [epoch: 0, i:  7174]  train_loss: 1.480  |  valid_loss: 1.348
# [epoch: 0, i:  7349]  train_loss: 1.469  |  valid_loss: 1.195
# [epoch: 0, i:  7524]  train_loss: 1.441  |  valid_loss: 1.185
# [epoch: 0, i:  7699]  train_loss: 1.433  |  valid_loss: 1.259
# [epoch: 0, i:  7874]  train_loss: 1.408  |  valid_loss: 1.255
# [epoch: 0, i:  8049]  train_loss: 1.432  |  valid_loss: 1.341
# [epoch: 0, i:  8224]  train_loss: 1.421  |  valid_loss: 1.143
# [epoch: 0, i:  8399]  train_loss: 1.489  |  valid_loss: 1.301
# [epoch: 0, i:  8574]  train_loss: 1.509  |  valid_loss: 1.179
# [epoch: 0, i:  8749]  train_loss: 1.405  |  valid_loss: 1.290
# [epoch: 0, i:  8924]  train_loss: 1.408  |  valid_loss: 1.244
# [epoch: 0, i:  9099]  train_loss: 1.412  |  valid_loss: 1.317
# [epoch: 0, i:  9274]  train_loss: 1.478  |  valid_loss: 1.121
# [epoch: 0, i:  9449]  train_loss: 1.393  |  valid_loss: 1.326
# [epoch: 0, i:  9624]  train_loss: 1.410  |  valid_loss: 1.368
# [epoch: 0, i:  9799]  train_loss: 1.371  |  valid_loss: 1.284
# [epoch: 0, i:  9974]  train_loss: 1.396  |  valid_loss: 1.244
# [epoch: 0, i: 10149]  train_loss: 1.457  |  valid_loss: 1.166
# [epoch: 0, i: 10324]  train_loss: 1.325  |  valid_loss: 1.451
# [epoch: 0, i: 10499]  train_loss: 1.366  |  valid_loss: 1.297
# [epoch: 0, i: 10674]  train_loss: 1.398  |  valid_loss: 1.123
# [epoch: 0, i: 10849]  train_loss: 1.389  |  valid_loss: 1.137
# [epoch: 0, i: 11024]  train_loss: 1.403  |  valid_loss: 1.201
# [epoch: 0, i: 11199]  train_loss: 1.314  |  valid_loss: 1.139
# [epoch: 0, i: 11374]  train_loss: 1.416  |  valid_loss: 1.289
# [epoch: 0, i: 11549]  train_loss: 1.432  |  valid_loss: 1.319
# [epoch: 0, i: 11724]  train_loss: 1.397  |  valid_loss: 1.233
# [epoch: 0, i: 11899]  train_loss: 1.368  |  valid_loss: 1.190
# [epoch: 0, i: 12074]  train_loss: 1.377  |  valid_loss: 1.175
# [epoch: 0, i: 12249]  train_loss: 1.315  |  valid_loss: 1.285
# [epoch: 0, i: 12424]  train_loss: 1.342  |  valid_loss: 1.166
# [epoch: 0, i: 12599]  train_loss: 1.343  |  valid_loss: 1.067
# [epoch: 0, i: 12774]  train_loss: 1.271  |  valid_loss: 1.041
# [epoch: 0, i: 12949]  train_loss: 1.324  |  valid_loss: 1.030
# [epoch: 0, i: 13124]  train_loss: 1.290  |  valid_loss: 1.110
# [epoch: 0, i: 13299]  train_loss: 1.348  |  valid_loss: 1.117
# [epoch: 0, i: 13474]  train_loss: 1.338  |  valid_loss: 1.192
# [epoch: 0, i: 13649]  train_loss: 1.341  |  valid_loss: 1.125
# [epoch: 0, i: 13824]  train_loss: 1.328  |  valid_loss: 1.276
# [epoch: 0, i: 13999]  train_loss: 1.298  |  valid_loss: 1.378
# [epoch: 0, i: 14174]  train_loss: 1.418  |  valid_loss: 1.105
# [epoch: 0, i: 14349]  train_loss: 1.302  |  valid_loss: 1.198
# [epoch: 0, i: 14524]  train_loss: 1.284  |  valid_loss: 1.253
# [epoch: 0, i: 14699]  train_loss: 1.295  |  valid_loss: 1.255
# [epoch: 0, i: 14874]  train_loss: 1.317  |  valid_loss: 1.190
# [epoch: 0, i: 15049]  train_loss: 1.244  |  valid_loss: 1.199
# [epoch: 0, i: 15224]  train_loss: 1.359  |  valid_loss: 1.166
# [epoch: 0, i: 15399]  train_loss: 1.275  |  valid_loss: 1.219
# [epoch: 0, i: 15574]  train_loss: 1.327  |  valid_loss: 1.177
# [epoch: 0, i: 15749]  train_loss: 1.349  |  valid_loss: 1.134
# [epoch: 0, i: 15924]  train_loss: 1.377  |  valid_loss: 1.219
# [epoch: 0, i: 16099]  train_loss: 1.292  |  valid_loss: 1.048
# [epoch: 0, i: 16274]  train_loss: 1.276  |  valid_loss: 1.107
# [epoch: 0, i: 16449]  train_loss: 1.248  |  valid_loss: 1.148
# [epoch: 0, i: 16624]  train_loss: 1.241  |  valid_loss: 1.229
# [epoch: 0, i: 16799]  train_loss: 1.305  |  valid_loss: 1.013
# [epoch: 0, i: 16974]  train_loss: 1.237  |  valid_loss: 1.066
# [epoch: 0, i: 17149]  train_loss: 1.339  |  valid_loss: 1.173
# [epoch: 0, i: 17324]  train_loss: 1.353  |  valid_loss: 1.218
# [epoch: 0, i: 17499]  train_loss: 1.355  |  valid_loss: 1.108
# --> [End of epoch 0] train_accuracy: 47.85%  |  valid_accuracy: 53.04%
# --> [Start of epoch 1]  lr: 0.000500
# [epoch: 1, i:   174]  train_loss: 1.321  |  valid_loss: 1.006
# [epoch: 1, i:   349]  train_loss: 1.296  |  valid_loss: 1.161
# [epoch: 1, i:   524]  train_loss: 1.281  |  valid_loss: 1.122
# [epoch: 1, i:   699]  train_loss: 1.197  |  valid_loss: 1.097
# [epoch: 1, i:   874]  train_loss: 1.302  |  valid_loss: 1.035
# [epoch: 1, i:  1049]  train_loss: 1.175  |  valid_loss: 0.916
# [epoch: 1, i:  1224]  train_loss: 1.278  |  valid_loss: 1.052
# [epoch: 1, i:  1399]  train_loss: 1.239  |  valid_loss: 1.217
# [epoch: 1, i:  1574]  train_loss: 1.314  |  valid_loss: 1.099
# [epoch: 1, i:  1749]  train_loss: 1.204  |  valid_loss: 1.009
# [epoch: 1, i:  1924]  train_loss: 1.191  |  valid_loss: 0.980
# [epoch: 1, i:  2099]  train_loss: 1.265  |  valid_loss: 1.081
# [epoch: 1, i:  2274]  train_loss: 1.239  |  valid_loss: 1.130
# [epoch: 1, i:  2449]  train_loss: 1.255  |  valid_loss: 1.083
# [epoch: 1, i:  2624]  train_loss: 1.149  |  valid_loss: 0.949
# [epoch: 1, i:  2799]  train_loss: 1.275  |  valid_loss: 1.069
# [epoch: 1, i:  2974]  train_loss: 1.253  |  valid_loss: 1.033
# [epoch: 1, i:  3149]  train_loss: 1.179  |  valid_loss: 1.058
# [epoch: 1, i:  3324]  train_loss: 1.174  |  valid_loss: 1.079
# [epoch: 1, i:  3499]  train_loss: 1.229  |  valid_loss: 1.117
# [epoch: 1, i:  3674]  train_loss: 1.207  |  valid_loss: 0.995
# [epoch: 1, i:  3849]  train_loss: 1.243  |  valid_loss: 1.161
# [epoch: 1, i:  4024]  train_loss: 1.260  |  valid_loss: 1.109
# [epoch: 1, i:  4199]  train_loss: 1.135  |  valid_loss: 1.086
# [epoch: 1, i:  4374]  train_loss: 1.233  |  valid_loss: 1.052
# [epoch: 1, i:  4549]  train_loss: 1.224  |  valid_loss: 1.267
# [epoch: 1, i:  4724]  train_loss: 1.243  |  valid_loss: 0.945
# [epoch: 1, i:  4899]  train_loss: 1.282  |  valid_loss: 1.051
# [epoch: 1, i:  5074]  train_loss: 1.233  |  valid_loss: 0.979
# [epoch: 1, i:  5249]  train_loss: 1.222  |  valid_loss: 0.948
# [epoch: 1, i:  5424]  train_loss: 1.280  |  valid_loss: 0.989
# [epoch: 1, i:  5599]  train_loss: 1.187  |  valid_loss: 1.052
# [epoch: 1, i:  5774]  train_loss: 1.237  |  valid_loss: 1.104
# [epoch: 1, i:  5949]  train_loss: 1.256  |  valid_loss: 1.162
# [epoch: 1, i:  6124]  train_loss: 1.165  |  valid_loss: 1.122
# [epoch: 1, i:  6299]  train_loss: 1.201  |  valid_loss: 1.048
# [epoch: 1, i:  6474]  train_loss: 1.245  |  valid_loss: 1.148
# [epoch: 1, i:  6649]  train_loss: 1.171  |  valid_loss: 1.177
# [epoch: 1, i:  6824]  train_loss: 1.243  |  valid_loss: 0.880
# [epoch: 1, i:  6999]  train_loss: 1.188  |  valid_loss: 0.991
# [epoch: 1, i:  7174]  train_loss: 1.294  |  valid_loss: 1.020
# [epoch: 1, i:  7349]  train_loss: 1.232  |  valid_loss: 1.137
# [epoch: 1, i:  7524]  train_loss: 1.243  |  valid_loss: 0.933
# [epoch: 1, i:  7699]  train_loss: 1.208  |  valid_loss: 0.938
# [epoch: 1, i:  7874]  train_loss: 1.262  |  valid_loss: 1.011
# [epoch: 1, i:  8049]  train_loss: 1.253  |  valid_loss: 1.159
# [epoch: 1, i:  8224]  train_loss: 1.234  |  valid_loss: 0.934
# [epoch: 1, i:  8399]  train_loss: 1.227  |  valid_loss: 0.916
# [epoch: 1, i:  8574]  train_loss: 1.198  |  valid_loss: 0.845
# [epoch: 1, i:  8749]  train_loss: 1.214  |  valid_loss: 1.114
# [epoch: 1, i:  8924]  train_loss: 1.203  |  valid_loss: 0.992
# [epoch: 1, i:  9099]  train_loss: 1.183  |  valid_loss: 1.072
# [epoch: 1, i:  9274]  train_loss: 1.223  |  valid_loss: 0.969
# [epoch: 1, i:  9449]  train_loss: 1.153  |  valid_loss: 1.128
# [epoch: 1, i:  9624]  train_loss: 1.169  |  valid_loss: 1.007
# [epoch: 1, i:  9799]  train_loss: 1.156  |  valid_loss: 1.100
# [epoch: 1, i:  9974]  train_loss: 1.313  |  valid_loss: 1.139
# [epoch: 1, i: 10149]  train_loss: 1.160  |  valid_loss: 0.885
# [epoch: 1, i: 10324]  train_loss: 1.246  |  valid_loss: 1.235
# [epoch: 1, i: 10499]  train_loss: 1.246  |  valid_loss: 1.040
# [epoch: 1, i: 10674]  train_loss: 1.198  |  valid_loss: 1.082
# [epoch: 1, i: 10849]  train_loss: 1.159  |  valid_loss: 0.889
# [epoch: 1, i: 11024]  train_loss: 1.212  |  valid_loss: 1.050
# [epoch: 1, i: 11199]  train_loss: 1.186  |  valid_loss: 0.833
# [epoch: 1, i: 11374]  train_loss: 1.212  |  valid_loss: 0.941
# [epoch: 1, i: 11549]  train_loss: 1.230  |  valid_loss: 1.070
# [epoch: 1, i: 11724]  train_loss: 1.137  |  valid_loss: 1.064
# [epoch: 1, i: 11899]  train_loss: 1.232  |  valid_loss: 1.112
# [epoch: 1, i: 12074]  train_loss: 1.160  |  valid_loss: 1.021
# [epoch: 1, i: 12249]  train_loss: 1.227  |  valid_loss: 1.232
# [epoch: 1, i: 12424]  train_loss: 1.171  |  valid_loss: 1.068
# [epoch: 1, i: 12599]  train_loss: 1.090  |  valid_loss: 0.930
# [epoch: 1, i: 12774]  train_loss: 1.228  |  valid_loss: 0.924
# [epoch: 1, i: 12949]  train_loss: 1.238  |  valid_loss: 0.888
# [epoch: 1, i: 13124]  train_loss: 1.290  |  valid_loss: 0.944
# [epoch: 1, i: 13299]  train_loss: 1.212  |  valid_loss: 0.878
# [epoch: 1, i: 13474]  train_loss: 1.169  |  valid_loss: 0.970
# [epoch: 1, i: 13649]  train_loss: 1.167  |  valid_loss: 0.942
# [epoch: 1, i: 13824]  train_loss: 1.196  |  valid_loss: 1.036
# [epoch: 1, i: 13999]  train_loss: 1.226  |  valid_loss: 1.013
# [epoch: 1, i: 14174]  train_loss: 1.174  |  valid_loss: 0.976
# [epoch: 1, i: 14349]  train_loss: 1.223  |  valid_loss: 1.032
# [epoch: 1, i: 14524]  train_loss: 1.292  |  valid_loss: 1.100
# [epoch: 1, i: 14699]  train_loss: 1.195  |  valid_loss: 1.153
# [epoch: 1, i: 14874]  train_loss: 1.201  |  valid_loss: 1.161
# [epoch: 1, i: 15049]  train_loss: 1.224  |  valid_loss: 1.044
# [epoch: 1, i: 15224]  train_loss: 1.225  |  valid_loss: 1.031
# [epoch: 1, i: 15399]  train_loss: 1.220  |  valid_loss: 1.068
# [epoch: 1, i: 15574]  train_loss: 1.161  |  valid_loss: 1.032
# [epoch: 1, i: 15749]  train_loss: 1.168  |  valid_loss: 0.937
# [epoch: 1, i: 15924]  train_loss: 1.189  |  valid_loss: 1.099
# [epoch: 1, i: 16099]  train_loss: 1.204  |  valid_loss: 0.855
# [epoch: 1, i: 16274]  train_loss: 1.174  |  valid_loss: 0.937
# [epoch: 1, i: 16449]  train_loss: 1.285  |  valid_loss: 1.098
# [epoch: 1, i: 16624]  train_loss: 1.192  |  valid_loss: 1.001
# [epoch: 1, i: 16799]  train_loss: 1.127  |  valid_loss: 0.910
# [epoch: 1, i: 16974]  train_loss: 1.185  |  valid_loss: 0.879
# [epoch: 1, i: 17149]  train_loss: 1.266  |  valid_loss: 1.021
# [epoch: 1, i: 17324]  train_loss: 1.123  |  valid_loss: 1.090
# [epoch: 1, i: 17499]  train_loss: 1.180  |  valid_loss: 0.980
# --> [End of epoch 1] train_accuracy: 57.67%  |  valid_accuracy: 63.65%
# --> [Start of epoch 2]  lr: 0.000500
# [epoch: 2, i:   174]  train_loss: 1.148  |  valid_loss: 0.880
# [epoch: 2, i:   349]  train_loss: 1.150  |  valid_loss: 1.018
# [epoch: 2, i:   524]  train_loss: 1.197  |  valid_loss: 1.054
# [epoch: 2, i:   699]  train_loss: 1.147  |  valid_loss: 1.035
# [epoch: 2, i:   874]  train_loss: 1.153  |  valid_loss: 1.004
# [epoch: 2, i:  1049]  train_loss: 1.172  |  valid_loss: 0.879
# [epoch: 2, i:  1224]  train_loss: 1.113  |  valid_loss: 0.917
# [epoch: 2, i:  1399]  train_loss: 1.111  |  valid_loss: 1.072
# [epoch: 2, i:  1574]  train_loss: 1.129  |  valid_loss: 1.025
# [epoch: 2, i:  1749]  train_loss: 1.229  |  valid_loss: 0.882
# [epoch: 2, i:  1924]  train_loss: 1.141  |  valid_loss: 0.834
# [epoch: 2, i:  2099]  train_loss: 1.060  |  valid_loss: 1.053
# [epoch: 2, i:  2274]  train_loss: 1.132  |  valid_loss: 1.014
# [epoch: 2, i:  2449]  train_loss: 1.128  |  valid_loss: 0.986
# [epoch: 2, i:  2624]  train_loss: 1.094  |  valid_loss: 0.823
# [epoch: 2, i:  2799]  train_loss: 1.147  |  valid_loss: 0.942
# [epoch: 2, i:  2974]  train_loss: 1.174  |  valid_loss: 0.891
# [epoch: 2, i:  3149]  train_loss: 1.186  |  valid_loss: 0.970
# [epoch: 2, i:  3324]  train_loss: 1.049  |  valid_loss: 0.937
# [epoch: 2, i:  3499]  train_loss: 1.077  |  valid_loss: 1.051
# [epoch: 2, i:  3674]  train_loss: 1.149  |  valid_loss: 0.960
# [epoch: 2, i:  3849]  train_loss: 1.118  |  valid_loss: 0.924
# [epoch: 2, i:  4024]  train_loss: 1.140  |  valid_loss: 1.060
# [epoch: 2, i:  4199]  train_loss: 1.093  |  valid_loss: 0.976
# [epoch: 2, i:  4374]  train_loss: 1.141  |  valid_loss: 0.985
# [epoch: 2, i:  4549]  train_loss: 1.150  |  valid_loss: 1.149
# [epoch: 2, i:  4724]  train_loss: 1.176  |  valid_loss: 0.938
# [epoch: 2, i:  4899]  train_loss: 1.115  |  valid_loss: 1.015
# [epoch: 2, i:  5074]  train_loss: 1.095  |  valid_loss: 1.061
# [epoch: 2, i:  5249]  train_loss: 1.064  |  valid_loss: 0.884
# [epoch: 2, i:  5424]  train_loss: 1.137  |  valid_loss: 0.954
# [epoch: 2, i:  5599]  train_loss: 1.175  |  valid_loss: 0.869
# [epoch: 2, i:  5774]  train_loss: 1.023  |  valid_loss: 0.958
# [epoch: 2, i:  5949]  train_loss: 1.148  |  valid_loss: 1.041
# [epoch: 2, i:  6124]  train_loss: 1.054  |  valid_loss: 1.005
# [epoch: 2, i:  6299]  train_loss: 1.142  |  valid_loss: 0.888
# [epoch: 2, i:  6474]  train_loss: 1.142  |  valid_loss: 1.054
# [epoch: 2, i:  6649]  train_loss: 1.107  |  valid_loss: 1.142
# [epoch: 2, i:  6824]  train_loss: 1.126  |  valid_loss: 0.823
# [epoch: 2, i:  6999]  train_loss: 1.137  |  valid_loss: 0.958
# [epoch: 2, i:  7174]  train_loss: 1.170  |  valid_loss: 0.881
# [epoch: 2, i:  7349]  train_loss: 1.124  |  valid_loss: 1.016
# [epoch: 2, i:  7524]  train_loss: 1.174  |  valid_loss: 0.815
# [epoch: 2, i:  7699]  train_loss: 1.166  |  valid_loss: 0.772
# [epoch: 2, i:  7874]  train_loss: 1.189  |  valid_loss: 0.974
# [epoch: 2, i:  8049]  train_loss: 1.090  |  valid_loss: 1.067
# [epoch: 2, i:  8224]  train_loss: 1.178  |  valid_loss: 0.879
# [epoch: 2, i:  8399]  train_loss: 1.172  |  valid_loss: 0.918
# [epoch: 2, i:  8574]  train_loss: 1.169  |  valid_loss: 0.810
# [epoch: 2, i:  8749]  train_loss: 1.099  |  valid_loss: 1.088
# [epoch: 2, i:  8924]  train_loss: 1.177  |  valid_loss: 0.934
# [epoch: 2, i:  9099]  train_loss: 1.098  |  valid_loss: 0.966
# [epoch: 2, i:  9274]  train_loss: 1.197  |  valid_loss: 0.891
# [epoch: 2, i:  9449]  train_loss: 1.122  |  valid_loss: 1.021
# [epoch: 2, i:  9624]  train_loss: 1.135  |  valid_loss: 1.002
# [epoch: 2, i:  9799]  train_loss: 1.199  |  valid_loss: 1.001
# [epoch: 2, i:  9974]  train_loss: 1.107  |  valid_loss: 1.013
# [epoch: 2, i: 10149]  train_loss: 1.193  |  valid_loss: 0.828
# [epoch: 2, i: 10324]  train_loss: 1.218  |  valid_loss: 1.115
# [epoch: 2, i: 10499]  train_loss: 1.114  |  valid_loss: 0.876
# [epoch: 2, i: 10674]  train_loss: 1.141  |  valid_loss: 1.027
# [epoch: 2, i: 10849]  train_loss: 1.088  |  valid_loss: 0.892
# [epoch: 2, i: 11024]  train_loss: 1.110  |  valid_loss: 0.979
# [epoch: 2, i: 11199]  train_loss: 1.137  |  valid_loss: 0.867
# [epoch: 2, i: 11374]  train_loss: 1.157  |  valid_loss: 0.947
# [epoch: 2, i: 11549]  train_loss: 1.121  |  valid_loss: 0.980
# [epoch: 2, i: 11724]  train_loss: 1.010  |  valid_loss: 0.934
# [epoch: 2, i: 11899]  train_loss: 1.141  |  valid_loss: 1.075
# [epoch: 2, i: 12074]  train_loss: 1.178  |  valid_loss: 1.015
# [epoch: 2, i: 12249]  train_loss: 1.069  |  valid_loss: 1.154
# [epoch: 2, i: 12424]  train_loss: 1.210  |  valid_loss: 0.967
# [epoch: 2, i: 12599]  train_loss: 1.167  |  valid_loss: 0.874
# [epoch: 2, i: 12774]  train_loss: 1.091  |  valid_loss: 0.844
# [epoch: 2, i: 12949]  train_loss: 1.093  |  valid_loss: 0.828
# [epoch: 2, i: 13124]  train_loss: 1.086  |  valid_loss: 0.982
# [epoch: 2, i: 13299]  train_loss: 1.121  |  valid_loss: 0.851
# [epoch: 2, i: 13474]  train_loss: 1.039  |  valid_loss: 0.998
# [epoch: 2, i: 13649]  train_loss: 1.130  |  valid_loss: 0.852
# [epoch: 2, i: 13824]  train_loss: 1.144  |  valid_loss: 1.034
# [epoch: 2, i: 13999]  train_loss: 1.147  |  valid_loss: 0.930
# [epoch: 2, i: 14174]  train_loss: 1.143  |  valid_loss: 0.926
# [epoch: 2, i: 14349]  train_loss: 1.161  |  valid_loss: 0.977
# [epoch: 2, i: 14524]  train_loss: 1.154  |  valid_loss: 1.006
# [epoch: 2, i: 14699]  train_loss: 1.115  |  valid_loss: 0.980
# [epoch: 2, i: 14874]  train_loss: 1.171  |  valid_loss: 1.147
# [epoch: 2, i: 15049]  train_loss: 1.180  |  valid_loss: 0.914
# [epoch: 2, i: 15224]  train_loss: 1.103  |  valid_loss: 1.012
# [epoch: 2, i: 15399]  train_loss: 1.113  |  valid_loss: 1.027
# [epoch: 2, i: 15574]  train_loss: 1.215  |  valid_loss: 0.951
# [epoch: 2, i: 15749]  train_loss: 1.140  |  valid_loss: 1.004
# [epoch: 2, i: 15924]  train_loss: 1.133  |  valid_loss: 0.956
# [epoch: 2, i: 16099]  train_loss: 1.100  |  valid_loss: 0.820
# [epoch: 2, i: 16274]  train_loss: 1.132  |  valid_loss: 0.908
# [epoch: 2, i: 16449]  train_loss: 1.134  |  valid_loss: 1.022
# [epoch: 2, i: 16624]  train_loss: 1.069  |  valid_loss: 0.910
# [epoch: 2, i: 16799]  train_loss: 1.136  |  valid_loss: 0.964
# [epoch: 2, i: 16974]  train_loss: 1.178  |  valid_loss: 0.879
# [epoch: 2, i: 17149]  train_loss: 1.080  |  valid_loss: 1.074
# [epoch: 2, i: 17324]  train_loss: 1.065  |  valid_loss: 0.985
# [epoch: 2, i: 17499]  train_loss: 1.175  |  valid_loss: 1.027
# --> [End of epoch 2] train_accuracy: 60.45%  |  valid_accuracy: 66.71%
# --> [Start of epoch 3]  lr: 0.000500
# [epoch: 3, i:   174]  train_loss: 1.123  |  valid_loss: 0.803
# [epoch: 3, i:   349]  train_loss: 1.086  |  valid_loss: 0.995
# [epoch: 3, i:   524]  train_loss: 1.038  |  valid_loss: 0.922
# [epoch: 3, i:   699]  train_loss: 1.110  |  valid_loss: 0.971
# [epoch: 3, i:   874]  train_loss: 1.076  |  valid_loss: 0.866
# [epoch: 3, i:  1049]  train_loss: 1.118  |  valid_loss: 0.830
# [epoch: 3, i:  1224]  train_loss: 1.173  |  valid_loss: 0.942
# [epoch: 3, i:  1399]  train_loss: 1.118  |  valid_loss: 0.979
# [epoch: 3, i:  1574]  train_loss: 1.106  |  valid_loss: 1.038
# [epoch: 3, i:  1749]  train_loss: 1.135  |  valid_loss: 0.918
# [epoch: 3, i:  1924]  train_loss: 1.064  |  valid_loss: 0.866
# [epoch: 3, i:  2099]  train_loss: 1.016  |  valid_loss: 1.000
# [epoch: 3, i:  2274]  train_loss: 1.066  |  valid_loss: 0.947
# [epoch: 3, i:  2449]  train_loss: 1.134  |  valid_loss: 0.957
# [epoch: 3, i:  2624]  train_loss: 0.991  |  valid_loss: 0.774
# [epoch: 3, i:  2799]  train_loss: 1.070  |  valid_loss: 0.838
# [epoch: 3, i:  2974]  train_loss: 1.065  |  valid_loss: 0.866
# [epoch: 3, i:  3149]  train_loss: 1.162  |  valid_loss: 0.960
# [epoch: 3, i:  3324]  train_loss: 1.037  |  valid_loss: 0.851
# [epoch: 3, i:  3499]  train_loss: 1.043  |  valid_loss: 1.043
# [epoch: 3, i:  3674]  train_loss: 1.082  |  valid_loss: 0.985
# [epoch: 3, i:  3849]  train_loss: 1.045  |  valid_loss: 0.921
# [epoch: 3, i:  4024]  train_loss: 1.081  |  valid_loss: 0.888
# [epoch: 3, i:  4199]  train_loss: 1.104  |  valid_loss: 0.969
# [epoch: 3, i:  4374]  train_loss: 1.022  |  valid_loss: 0.928
# [epoch: 3, i:  4549]  train_loss: 1.204  |  valid_loss: 1.151
# [epoch: 3, i:  4724]  train_loss: 1.168  |  valid_loss: 0.830
# [epoch: 3, i:  4899]  train_loss: 1.040  |  valid_loss: 0.936
# [epoch: 3, i:  5074]  train_loss: 1.120  |  valid_loss: 0.982
# [epoch: 3, i:  5249]  train_loss: 1.050  |  valid_loss: 0.914
# [epoch: 3, i:  5424]  train_loss: 1.096  |  valid_loss: 0.921
# [epoch: 3, i:  5599]  train_loss: 1.146  |  valid_loss: 0.914
# [epoch: 3, i:  5774]  train_loss: 1.089  |  valid_loss: 0.983
# [epoch: 3, i:  5949]  train_loss: 1.149  |  valid_loss: 1.007
# [epoch: 3, i:  6124]  train_loss: 0.946  |  valid_loss: 1.019
# [epoch: 3, i:  6299]  train_loss: 1.138  |  valid_loss: 0.851
# [epoch: 3, i:  6474]  train_loss: 1.143  |  valid_loss: 1.012
# [epoch: 3, i:  6649]  train_loss: 1.128  |  valid_loss: 1.138
# [epoch: 3, i:  6824]  train_loss: 1.003  |  valid_loss: 0.773
# [epoch: 3, i:  6999]  train_loss: 1.061  |  valid_loss: 0.813
# [epoch: 3, i:  7174]  train_loss: 1.135  |  valid_loss: 0.872
# [epoch: 3, i:  7349]  train_loss: 1.171  |  valid_loss: 0.909
# [epoch: 3, i:  7524]  train_loss: 1.182  |  valid_loss: 0.845
# [epoch: 3, i:  7699]  train_loss: 1.113  |  valid_loss: 0.886
# [epoch: 3, i:  7874]  train_loss: 1.082  |  valid_loss: 0.924
# [epoch: 3, i:  8049]  train_loss: 1.066  |  valid_loss: 1.032
# [epoch: 3, i:  8224]  train_loss: 1.080  |  valid_loss: 0.847
# [epoch: 3, i:  8399]  train_loss: 1.041  |  valid_loss: 0.842
# [epoch: 3, i:  8574]  train_loss: 1.059  |  valid_loss: 0.828
# [epoch: 3, i:  8749]  train_loss: 1.113  |  valid_loss: 1.060
# [epoch: 3, i:  8924]  train_loss: 1.056  |  valid_loss: 0.839
# [epoch: 3, i:  9099]  train_loss: 1.095  |  valid_loss: 0.968
# [epoch: 3, i:  9274]  train_loss: 1.130  |  valid_loss: 0.878
# [epoch: 3, i:  9449]  train_loss: 1.044  |  valid_loss: 1.050
# [epoch: 3, i:  9624]  train_loss: 1.111  |  valid_loss: 0.977
# [epoch: 3, i:  9799]  train_loss: 1.052  |  valid_loss: 0.985
# [epoch: 3, i:  9974]  train_loss: 1.127  |  valid_loss: 0.934
# [epoch: 3, i: 10149]  train_loss: 1.135  |  valid_loss: 0.791
# [epoch: 3, i: 10324]  train_loss: 1.109  |  valid_loss: 1.054
# [epoch: 3, i: 10499]  train_loss: 1.132  |  valid_loss: 0.927
# [epoch: 3, i: 10674]  train_loss: 1.039  |  valid_loss: 0.930
# [epoch: 3, i: 10849]  train_loss: 1.073  |  valid_loss: 0.886
# [epoch: 3, i: 11024]  train_loss: 1.060  |  valid_loss: 0.947
# [epoch: 3, i: 11199]  train_loss: 1.134  |  valid_loss: 0.879
# [epoch: 3, i: 11374]  train_loss: 1.081  |  valid_loss: 0.848
# [epoch: 3, i: 11549]  train_loss: 1.018  |  valid_loss: 0.937
# [epoch: 3, i: 11724]  train_loss: 1.045  |  valid_loss: 0.907
# [epoch: 3, i: 11899]  train_loss: 1.081  |  valid_loss: 1.025
# [epoch: 3, i: 12074]  train_loss: 1.143  |  valid_loss: 0.949
# [epoch: 3, i: 12249]  train_loss: 1.125  |  valid_loss: 1.129
# [epoch: 3, i: 12424]  train_loss: 1.091  |  valid_loss: 0.945
# [epoch: 3, i: 12599]  train_loss: 1.106  |  valid_loss: 0.870
# [epoch: 3, i: 12774]  train_loss: 1.067  |  valid_loss: 0.842
# [epoch: 3, i: 12949]  train_loss: 1.109  |  valid_loss: 0.776
# [epoch: 3, i: 13124]  train_loss: 1.102  |  valid_loss: 0.894
# [epoch: 3, i: 13299]  train_loss: 1.047  |  valid_loss: 0.845
# [epoch: 3, i: 13474]  train_loss: 1.086  |  valid_loss: 0.859
# [epoch: 3, i: 13649]  train_loss: 1.032  |  valid_loss: 0.871
# [epoch: 3, i: 13824]  train_loss: 1.108  |  valid_loss: 0.982
# [epoch: 3, i: 13999]  train_loss: 1.159  |  valid_loss: 0.967
# [epoch: 3, i: 14174]  train_loss: 1.001  |  valid_loss: 0.941
# [epoch: 3, i: 14349]  train_loss: 1.018  |  valid_loss: 0.868
# [epoch: 3, i: 14524]  train_loss: 1.073  |  valid_loss: 0.982
# [epoch: 3, i: 14699]  train_loss: 1.179  |  valid_loss: 0.881
# [epoch: 3, i: 14874]  train_loss: 1.070  |  valid_loss: 1.099
# [epoch: 3, i: 15049]  train_loss: 1.186  |  valid_loss: 0.909
# [epoch: 3, i: 15224]  train_loss: 1.088  |  valid_loss: 0.818
# [epoch: 3, i: 15399]  train_loss: 1.081  |  valid_loss: 0.918
# [epoch: 3, i: 15574]  train_loss: 1.173  |  valid_loss: 0.911
# [epoch: 3, i: 15749]  train_loss: 1.068  |  valid_loss: 0.956
# [epoch: 3, i: 15924]  train_loss: 1.072  |  valid_loss: 0.856
# [epoch: 3, i: 16099]  train_loss: 1.055  |  valid_loss: 0.778
# [epoch: 3, i: 16274]  train_loss: 1.036  |  valid_loss: 0.859
# [epoch: 3, i: 16449]  train_loss: 1.033  |  valid_loss: 0.950
# [epoch: 3, i: 16624]  train_loss: 1.090  |  valid_loss: 0.957
# [epoch: 3, i: 16799]  train_loss: 1.062  |  valid_loss: 0.908
# [epoch: 3, i: 16974]  train_loss: 1.059  |  valid_loss: 0.766
# [epoch: 3, i: 17149]  train_loss: 1.147  |  valid_loss: 1.100
# [epoch: 3, i: 17324]  train_loss: 1.016  |  valid_loss: 0.954
# [epoch: 3, i: 17499]  train_loss: 1.045  |  valid_loss: 0.920
# --> [End of epoch 3] train_accuracy: 62.64%  |  valid_accuracy: 68.36%
# --> [Start of epoch 4]  lr: 0.000500
# [epoch: 4, i:   174]  train_loss: 1.065  |  valid_loss: 0.860
# [epoch: 4, i:   349]  train_loss: 1.036  |  valid_loss: 0.873
# [epoch: 4, i:   524]  train_loss: 1.064  |  valid_loss: 0.923
# [epoch: 4, i:   699]  train_loss: 1.067  |  valid_loss: 0.900
# [epoch: 4, i:   874]  train_loss: 1.036  |  valid_loss: 0.887
# [epoch: 4, i:  1049]  train_loss: 1.017  |  valid_loss: 0.778
# [epoch: 4, i:  1224]  train_loss: 1.021  |  valid_loss: 0.826
# [epoch: 4, i:  1399]  train_loss: 1.095  |  valid_loss: 0.938
# [epoch: 4, i:  1574]  train_loss: 1.071  |  valid_loss: 0.935
# [epoch: 4, i:  1749]  train_loss: 1.062  |  valid_loss: 0.844
# [epoch: 4, i:  1924]  train_loss: 1.041  |  valid_loss: 0.789
# [epoch: 4, i:  2099]  train_loss: 1.044  |  valid_loss: 0.942
# [epoch: 4, i:  2274]  train_loss: 1.052  |  valid_loss: 0.952
# [epoch: 4, i:  2449]  train_loss: 1.048  |  valid_loss: 0.896
# [epoch: 4, i:  2624]  train_loss: 1.037  |  valid_loss: 0.736
# [epoch: 4, i:  2799]  train_loss: 1.084  |  valid_loss: 0.817
# [epoch: 4, i:  2974]  train_loss: 1.059  |  valid_loss: 0.783
# [epoch: 4, i:  3149]  train_loss: 1.042  |  valid_loss: 0.900
# [epoch: 4, i:  3324]  train_loss: 1.077  |  valid_loss: 0.845
# [epoch: 4, i:  3499]  train_loss: 1.006  |  valid_loss: 1.046
# [epoch: 4, i:  3674]  train_loss: 1.116  |  valid_loss: 0.892
# [epoch: 4, i:  3849]  train_loss: 1.062  |  valid_loss: 0.863
# [epoch: 4, i:  4024]  train_loss: 1.094  |  valid_loss: 0.924
# [epoch: 4, i:  4199]  train_loss: 1.013  |  valid_loss: 0.903
# [epoch: 4, i:  4374]  train_loss: 1.052  |  valid_loss: 0.911
# [epoch: 4, i:  4549]  train_loss: 1.059  |  valid_loss: 1.103
# [epoch: 4, i:  4724]  train_loss: 1.035  |  valid_loss: 0.769
# [epoch: 4, i:  4899]  train_loss: 1.101  |  valid_loss: 0.934
# [epoch: 4, i:  5074]  train_loss: 1.003  |  valid_loss: 0.971
# [epoch: 4, i:  5249]  train_loss: 1.022  |  valid_loss: 0.872
# [epoch: 4, i:  5424]  train_loss: 1.075  |  valid_loss: 0.879
# [epoch: 4, i:  5599]  train_loss: 1.051  |  valid_loss: 0.857
# [epoch: 4, i:  5774]  train_loss: 1.063  |  valid_loss: 0.913
# [epoch: 4, i:  5949]  train_loss: 1.070  |  valid_loss: 0.925
# [epoch: 4, i:  6124]  train_loss: 1.134  |  valid_loss: 1.048
# [epoch: 4, i:  6299]  train_loss: 1.123  |  valid_loss: 0.839
# [epoch: 4, i:  6474]  train_loss: 1.124  |  valid_loss: 0.967
# [epoch: 4, i:  6649]  train_loss: 1.031  |  valid_loss: 1.058
# [epoch: 4, i:  6824]  train_loss: 0.991  |  valid_loss: 0.735
# [epoch: 4, i:  6999]  train_loss: 1.052  |  valid_loss: 0.801
# [epoch: 4, i:  7174]  train_loss: 1.035  |  valid_loss: 0.848
# [epoch: 4, i:  7349]  train_loss: 1.023  |  valid_loss: 0.874
# [epoch: 4, i:  7524]  train_loss: 1.053  |  valid_loss: 0.807
# [epoch: 4, i:  7699]  train_loss: 1.043  |  valid_loss: 0.808
# [epoch: 4, i:  7874]  train_loss: 1.128  |  valid_loss: 0.880
# [epoch: 4, i:  8049]  train_loss: 1.188  |  valid_loss: 0.972
# [epoch: 4, i:  8224]  train_loss: 0.953  |  valid_loss: 0.850
# [epoch: 4, i:  8399]  train_loss: 1.030  |  valid_loss: 0.861
# [epoch: 4, i:  8574]  train_loss: 1.064  |  valid_loss: 0.736
# [epoch: 4, i:  8749]  train_loss: 1.012  |  valid_loss: 1.043
# [epoch: 4, i:  8924]  train_loss: 1.005  |  valid_loss: 0.821
# [epoch: 4, i:  9099]  train_loss: 1.026  |  valid_loss: 0.934
# [epoch: 4, i:  9274]  train_loss: 1.034  |  valid_loss: 0.730
# [epoch: 4, i:  9449]  train_loss: 1.134  |  valid_loss: 0.931
# [epoch: 4, i:  9624]  train_loss: 1.068  |  valid_loss: 0.960
# [epoch: 4, i:  9799]  train_loss: 1.008  |  valid_loss: 0.910
# [epoch: 4, i:  9974]  train_loss: 1.088  |  valid_loss: 0.975
# [epoch: 4, i: 10149]  train_loss: 1.078  |  valid_loss: 0.763
# [epoch: 4, i: 10324]  train_loss: 1.070  |  valid_loss: 1.158
# [epoch: 4, i: 10499]  train_loss: 0.941  |  valid_loss: 0.920
# [epoch: 4, i: 10674]  train_loss: 1.065  |  valid_loss: 0.912
# [epoch: 4, i: 10849]  train_loss: 1.092  |  valid_loss: 0.887
# [epoch: 4, i: 11024]  train_loss: 1.104  |  valid_loss: 0.937
# [epoch: 4, i: 11199]  train_loss: 1.149  |  valid_loss: 0.867
# [epoch: 4, i: 11374]  train_loss: 1.090  |  valid_loss: 0.847
# [epoch: 4, i: 11549]  train_loss: 1.086  |  valid_loss: 0.870
# [epoch: 4, i: 11724]  train_loss: 1.024  |  valid_loss: 0.866
# [epoch: 4, i: 11899]  train_loss: 1.085  |  valid_loss: 1.068
# [epoch: 4, i: 12074]  train_loss: 1.079  |  valid_loss: 0.824
# [epoch: 4, i: 12249]  train_loss: 0.989  |  valid_loss: 1.123
# [epoch: 4, i: 12424]  train_loss: 1.031  |  valid_loss: 0.900
# [epoch: 4, i: 12599]  train_loss: 1.101  |  valid_loss: 0.882
# [epoch: 4, i: 12774]  train_loss: 1.123  |  valid_loss: 0.822
# [epoch: 4, i: 12949]  train_loss: 0.997  |  valid_loss: 0.753
# [epoch: 4, i: 13124]  train_loss: 1.047  |  valid_loss: 0.948
# [epoch: 4, i: 13299]  train_loss: 0.996  |  valid_loss: 0.798
# [epoch: 4, i: 13474]  train_loss: 1.094  |  valid_loss: 0.824
# [epoch: 4, i: 13649]  train_loss: 1.054  |  valid_loss: 0.855
# [epoch: 4, i: 13824]  train_loss: 1.063  |  valid_loss: 0.939
# [epoch: 4, i: 13999]  train_loss: 1.014  |  valid_loss: 0.849
# [epoch: 4, i: 14174]  train_loss: 1.047  |  valid_loss: 0.853
# [epoch: 4, i: 14349]  train_loss: 1.040  |  valid_loss: 0.789
# [epoch: 4, i: 14524]  train_loss: 1.105  |  valid_loss: 1.033
# [epoch: 4, i: 14699]  train_loss: 1.036  |  valid_loss: 0.931
# [epoch: 4, i: 14874]  train_loss: 1.046  |  valid_loss: 1.041
# [epoch: 4, i: 15049]  train_loss: 1.039  |  valid_loss: 0.887
# [epoch: 4, i: 15224]  train_loss: 1.025  |  valid_loss: 0.854
# [epoch: 4, i: 15399]  train_loss: 1.061  |  valid_loss: 0.935
# [epoch: 4, i: 15574]  train_loss: 1.101  |  valid_loss: 0.845
# [epoch: 4, i: 15749]  train_loss: 1.098  |  valid_loss: 0.947
# [epoch: 4, i: 15924]  train_loss: 1.054  |  valid_loss: 0.875
# [epoch: 4, i: 16099]  train_loss: 1.114  |  valid_loss: 0.780
# [epoch: 4, i: 16274]  train_loss: 1.045  |  valid_loss: 0.821
# [epoch: 4, i: 16449]  train_loss: 1.118  |  valid_loss: 0.853
# [epoch: 4, i: 16624]  train_loss: 1.084  |  valid_loss: 0.950
# [epoch: 4, i: 16799]  train_loss: 1.033  |  valid_loss: 0.853
# [epoch: 4, i: 16974]  train_loss: 1.008  |  valid_loss: 0.699
# [epoch: 4, i: 17149]  train_loss: 1.051  |  valid_loss: 1.014
# [epoch: 4, i: 17324]  train_loss: 1.080  |  valid_loss: 0.884
# [epoch: 4, i: 17499]  train_loss: 1.059  |  valid_loss: 0.818
# --> [End of epoch 4] train_accuracy: 63.63%  |  valid_accuracy: 69.55%
# --> [Start of epoch 5]  lr: 0.000500
# [epoch: 5, i:   174]  train_loss: 1.060  |  valid_loss: 0.801
# [epoch: 5, i:   349]  train_loss: 1.045  |  valid_loss: 0.823
# [epoch: 5, i:   524]  train_loss: 1.002  |  valid_loss: 0.925
# [epoch: 5, i:   699]  train_loss: 1.077  |  valid_loss: 0.834
# [epoch: 5, i:   874]  train_loss: 1.013  |  valid_loss: 0.845
# [epoch: 5, i:  1049]  train_loss: 1.065  |  valid_loss: 0.693
# [epoch: 5, i:  1224]  train_loss: 1.014  |  valid_loss: 0.816
# [epoch: 5, i:  1399]  train_loss: 1.024  |  valid_loss: 0.952
# [epoch: 5, i:  1574]  train_loss: 1.065  |  valid_loss: 0.871
# [epoch: 5, i:  1749]  train_loss: 0.928  |  valid_loss: 0.899
# [epoch: 5, i:  1924]  train_loss: 1.175  |  valid_loss: 0.727
# [epoch: 5, i:  2099]  train_loss: 1.016  |  valid_loss: 0.918
# [epoch: 5, i:  2274]  train_loss: 1.037  |  valid_loss: 0.804
# [epoch: 5, i:  2449]  train_loss: 1.021  |  valid_loss: 0.846
# [epoch: 5, i:  2624]  train_loss: 1.025  |  valid_loss: 0.766
# [epoch: 5, i:  2799]  train_loss: 1.045  |  valid_loss: 0.918
# [epoch: 5, i:  2974]  train_loss: 1.005  |  valid_loss: 0.763
# [epoch: 5, i:  3149]  train_loss: 0.983  |  valid_loss: 0.879
# [epoch: 5, i:  3324]  train_loss: 1.025  |  valid_loss: 0.875
# [epoch: 5, i:  3499]  train_loss: 1.062  |  valid_loss: 1.023
# [epoch: 5, i:  3674]  train_loss: 1.028  |  valid_loss: 0.991
# [epoch: 5, i:  3849]  train_loss: 0.988  |  valid_loss: 0.917
# [epoch: 5, i:  4024]  train_loss: 1.016  |  valid_loss: 0.898
# [epoch: 5, i:  4199]  train_loss: 1.019  |  valid_loss: 0.874
# [epoch: 5, i:  4374]  train_loss: 0.972  |  valid_loss: 0.858
# [epoch: 5, i:  4549]  train_loss: 1.036  |  valid_loss: 1.104
# [epoch: 5, i:  4724]  train_loss: 0.932  |  valid_loss: 0.823
# [epoch: 5, i:  4899]  train_loss: 1.007  |  valid_loss: 0.957
# [epoch: 5, i:  5074]  train_loss: 0.991  |  valid_loss: 0.975
# [epoch: 5, i:  5249]  train_loss: 1.054  |  valid_loss: 0.793
# [epoch: 5, i:  5424]  train_loss: 0.974  |  valid_loss: 0.798
# [epoch: 5, i:  5599]  train_loss: 1.048  |  valid_loss: 0.779
# [epoch: 5, i:  5774]  train_loss: 1.007  |  valid_loss: 0.885
# [epoch: 5, i:  5949]  train_loss: 1.033  |  valid_loss: 1.065
# [epoch: 5, i:  6124]  train_loss: 1.032  |  valid_loss: 0.904
# [epoch: 5, i:  6299]  train_loss: 1.063  |  valid_loss: 0.851
# [epoch: 5, i:  6474]  train_loss: 1.038  |  valid_loss: 0.913
# [epoch: 5, i:  6649]  train_loss: 1.066  |  valid_loss: 1.017
# [epoch: 5, i:  6824]  train_loss: 1.052  |  valid_loss: 0.721
# [epoch: 5, i:  6999]  train_loss: 1.054  |  valid_loss: 0.788
# [epoch: 5, i:  7174]  train_loss: 1.023  |  valid_loss: 0.804
# [epoch: 5, i:  7349]  train_loss: 1.021  |  valid_loss: 0.888
# [epoch: 5, i:  7524]  train_loss: 1.025  |  valid_loss: 0.826
# [epoch: 5, i:  7699]  train_loss: 0.966  |  valid_loss: 0.790
# [epoch: 5, i:  7874]  train_loss: 1.066  |  valid_loss: 0.793
# [epoch: 5, i:  8049]  train_loss: 1.030  |  valid_loss: 0.920
# [epoch: 5, i:  8224]  train_loss: 0.981  |  valid_loss: 0.782
# [epoch: 5, i:  8399]  train_loss: 0.934  |  valid_loss: 0.833
# [epoch: 5, i:  8574]  train_loss: 1.012  |  valid_loss: 0.770
# [epoch: 5, i:  8749]  train_loss: 1.020  |  valid_loss: 1.016
# [epoch: 5, i:  8924]  train_loss: 1.004  |  valid_loss: 0.799
# [epoch: 5, i:  9099]  train_loss: 1.062  |  valid_loss: 0.969
# [epoch: 5, i:  9274]  train_loss: 1.045  |  valid_loss: 0.754
# [epoch: 5, i:  9449]  train_loss: 1.065  |  valid_loss: 0.848
# [epoch: 5, i:  9624]  train_loss: 1.003  |  valid_loss: 0.863
# [epoch: 5, i:  9799]  train_loss: 1.077  |  valid_loss: 0.812
# [epoch: 5, i:  9974]  train_loss: 1.031  |  valid_loss: 0.970
# [epoch: 5, i: 10149]  train_loss: 1.010  |  valid_loss: 0.726
# [epoch: 5, i: 10324]  train_loss: 1.000  |  valid_loss: 1.118
# [epoch: 5, i: 10499]  train_loss: 1.091  |  valid_loss: 0.840
# [epoch: 5, i: 10674]  train_loss: 1.059  |  valid_loss: 0.898
# [epoch: 5, i: 10849]  train_loss: 0.998  |  valid_loss: 0.829
# [epoch: 5, i: 11024]  train_loss: 1.030  |  valid_loss: 0.847
# [epoch: 5, i: 11199]  train_loss: 1.024  |  valid_loss: 0.811
# [epoch: 5, i: 11374]  train_loss: 1.025  |  valid_loss: 0.784
# [epoch: 5, i: 11549]  train_loss: 1.056  |  valid_loss: 0.888
# [epoch: 5, i: 11724]  train_loss: 1.062  |  valid_loss: 0.801
# [epoch: 5, i: 11899]  train_loss: 1.026  |  valid_loss: 0.981
# [epoch: 5, i: 12074]  train_loss: 1.046  |  valid_loss: 0.788
# [epoch: 5, i: 12249]  train_loss: 1.093  |  valid_loss: 1.025
# [epoch: 5, i: 12424]  train_loss: 1.080  |  valid_loss: 0.956
# [epoch: 5, i: 12599]  train_loss: 1.003  |  valid_loss: 0.764
# [epoch: 5, i: 12774]  train_loss: 1.068  |  valid_loss: 0.830
# [epoch: 5, i: 12949]  train_loss: 1.059  |  valid_loss: 0.772
# [epoch: 5, i: 13124]  train_loss: 0.974  |  valid_loss: 0.832
# [epoch: 5, i: 13299]  train_loss: 1.038  |  valid_loss: 0.851
# [epoch: 5, i: 13474]  train_loss: 0.963  |  valid_loss: 0.847
# [epoch: 5, i: 13649]  train_loss: 1.034  |  valid_loss: 0.806
# [epoch: 5, i: 13824]  train_loss: 1.017  |  valid_loss: 0.994
# [epoch: 5, i: 13999]  train_loss: 1.074  |  valid_loss: 0.862
# [epoch: 5, i: 14174]  train_loss: 0.964  |  valid_loss: 0.846
# [epoch: 5, i: 14349]  train_loss: 0.998  |  valid_loss: 0.792
# [epoch: 5, i: 14524]  train_loss: 1.051  |  valid_loss: 0.973
# [epoch: 5, i: 14699]  train_loss: 0.965  |  valid_loss: 0.846
# [epoch: 5, i: 14874]  train_loss: 1.077  |  valid_loss: 1.008
# [epoch: 5, i: 15049]  train_loss: 1.066  |  valid_loss: 0.868
# [epoch: 5, i: 15224]  train_loss: 1.090  |  valid_loss: 0.925
# [epoch: 5, i: 15399]  train_loss: 1.033  |  valid_loss: 0.920
# [epoch: 5, i: 15574]  train_loss: 1.027  |  valid_loss: 0.819
# [epoch: 5, i: 15749]  train_loss: 0.999  |  valid_loss: 0.937
# [epoch: 5, i: 15924]  train_loss: 1.048  |  valid_loss: 0.897
# [epoch: 5, i: 16099]  train_loss: 0.965  |  valid_loss: 0.722
# [epoch: 5, i: 16274]  train_loss: 1.101  |  valid_loss: 0.831
# [epoch: 5, i: 16449]  train_loss: 1.034  |  valid_loss: 0.867
# [epoch: 5, i: 16624]  train_loss: 1.009  |  valid_loss: 0.909
# [epoch: 5, i: 16799]  train_loss: 1.049  |  valid_loss: 0.789
# [epoch: 5, i: 16974]  train_loss: 1.105  |  valid_loss: 0.746
# [epoch: 5, i: 17149]  train_loss: 1.105  |  valid_loss: 1.022
# [epoch: 5, i: 17324]  train_loss: 1.034  |  valid_loss: 0.824
# [epoch: 5, i: 17499]  train_loss: 1.049  |  valid_loss: 0.847
# --> [End of epoch 5] train_accuracy: 64.73%  |  valid_accuracy: 70.06%
# --> [Start of epoch 6]  lr: 0.000500
# [epoch: 6, i:   174]  train_loss: 0.985  |  valid_loss: 0.790
# [epoch: 6, i:   349]  train_loss: 0.993  |  valid_loss: 0.773
# [epoch: 6, i:   524]  train_loss: 0.894  |  valid_loss: 0.836
# [epoch: 6, i:   699]  train_loss: 0.963  |  valid_loss: 0.832
# [epoch: 6, i:   874]  train_loss: 1.048  |  valid_loss: 0.816
# [epoch: 6, i:  1049]  train_loss: 1.064  |  valid_loss: 0.731
# [epoch: 6, i:  1224]  train_loss: 1.077  |  valid_loss: 0.770
# [epoch: 6, i:  1399]  train_loss: 0.926  |  valid_loss: 0.932
# [epoch: 6, i:  1574]  train_loss: 1.015  |  valid_loss: 0.913
# [epoch: 6, i:  1749]  train_loss: 0.999  |  valid_loss: 0.836
# [epoch: 6, i:  1924]  train_loss: 1.018  |  valid_loss: 0.803
# [epoch: 6, i:  2099]  train_loss: 0.977  |  valid_loss: 0.863
# [epoch: 6, i:  2274]  train_loss: 0.986  |  valid_loss: 0.807
# [epoch: 6, i:  2449]  train_loss: 0.943  |  valid_loss: 0.874
# [epoch: 6, i:  2624]  train_loss: 1.064  |  valid_loss: 0.660
# [epoch: 6, i:  2799]  train_loss: 1.026  |  valid_loss: 0.860
# [epoch: 6, i:  2974]  train_loss: 1.011  |  valid_loss: 0.798
# [epoch: 6, i:  3149]  train_loss: 1.054  |  valid_loss: 0.945
# [epoch: 6, i:  3324]  train_loss: 1.044  |  valid_loss: 0.851
# [epoch: 6, i:  3499]  train_loss: 0.969  |  valid_loss: 0.980
# [epoch: 6, i:  3674]  train_loss: 1.014  |  valid_loss: 0.922
# [epoch: 6, i:  3849]  train_loss: 0.934  |  valid_loss: 0.881
# [epoch: 6, i:  4024]  train_loss: 1.015  |  valid_loss: 0.906
# [epoch: 6, i:  4199]  train_loss: 0.948  |  valid_loss: 0.850
# [epoch: 6, i:  4374]  train_loss: 1.024  |  valid_loss: 0.790
# [epoch: 6, i:  4549]  train_loss: 0.978  |  valid_loss: 1.147
# [epoch: 6, i:  4724]  train_loss: 0.955  |  valid_loss: 0.747
# [epoch: 6, i:  4899]  train_loss: 1.009  |  valid_loss: 0.924
# [epoch: 6, i:  5074]  train_loss: 1.017  |  valid_loss: 0.920
# [epoch: 6, i:  5249]  train_loss: 1.059  |  valid_loss: 0.782
# [epoch: 6, i:  5424]  train_loss: 0.993  |  valid_loss: 0.769
# [epoch: 6, i:  5599]  train_loss: 1.042  |  valid_loss: 0.809
# [epoch: 6, i:  5774]  train_loss: 1.007  |  valid_loss: 0.851
# [epoch: 6, i:  5949]  train_loss: 1.009  |  valid_loss: 0.942
# [epoch: 6, i:  6124]  train_loss: 0.982  |  valid_loss: 0.887
# [epoch: 6, i:  6299]  train_loss: 1.023  |  valid_loss: 0.826
# [epoch: 6, i:  6474]  train_loss: 1.037  |  valid_loss: 0.873
# [epoch: 6, i:  6649]  train_loss: 1.072  |  valid_loss: 1.056
# [epoch: 6, i:  6824]  train_loss: 0.954  |  valid_loss: 0.732
# [epoch: 6, i:  6999]  train_loss: 1.026  |  valid_loss: 0.728
# [epoch: 6, i:  7174]  train_loss: 1.016  |  valid_loss: 0.810
# [epoch: 6, i:  7349]  train_loss: 1.038  |  valid_loss: 0.801
# [epoch: 6, i:  7524]  train_loss: 0.864  |  valid_loss: 0.774
# [epoch: 6, i:  7699]  train_loss: 0.957  |  valid_loss: 0.833
# [epoch: 6, i:  7874]  train_loss: 0.930  |  valid_loss: 0.782
# [epoch: 6, i:  8049]  train_loss: 1.011  |  valid_loss: 0.932
# [epoch: 6, i:  8224]  train_loss: 1.038  |  valid_loss: 0.775
# [epoch: 6, i:  8399]  train_loss: 0.953  |  valid_loss: 0.858
# [epoch: 6, i:  8574]  train_loss: 0.969  |  valid_loss: 0.666
# [epoch: 6, i:  8749]  train_loss: 0.954  |  valid_loss: 0.992
# [epoch: 6, i:  8924]  train_loss: 0.971  |  valid_loss: 0.785
# [epoch: 6, i:  9099]  train_loss: 0.963  |  valid_loss: 0.868
# [epoch: 6, i:  9274]  train_loss: 1.159  |  valid_loss: 0.748
# [epoch: 6, i:  9449]  train_loss: 0.993  |  valid_loss: 0.838
# [epoch: 6, i:  9624]  train_loss: 1.001  |  valid_loss: 0.820
# [epoch: 6, i:  9799]  train_loss: 1.023  |  valid_loss: 0.805
# [epoch: 6, i:  9974]  train_loss: 0.985  |  valid_loss: 0.858
# [epoch: 6, i: 10149]  train_loss: 0.947  |  valid_loss: 0.734
# [epoch: 6, i: 10324]  train_loss: 1.043  |  valid_loss: 1.036
# [epoch: 6, i: 10499]  train_loss: 1.007  |  valid_loss: 0.834
# [epoch: 6, i: 10674]  train_loss: 1.020  |  valid_loss: 0.850
# [epoch: 6, i: 10849]  train_loss: 1.036  |  valid_loss: 0.866
# [epoch: 6, i: 11024]  train_loss: 0.988  |  valid_loss: 0.892
# [epoch: 6, i: 11199]  train_loss: 0.966  |  valid_loss: 0.825
# [epoch: 6, i: 11374]  train_loss: 1.006  |  valid_loss: 0.797
# [epoch: 6, i: 11549]  train_loss: 0.976  |  valid_loss: 0.803
# [epoch: 6, i: 11724]  train_loss: 0.965  |  valid_loss: 0.794
# [epoch: 6, i: 11899]  train_loss: 1.002  |  valid_loss: 0.957
# [epoch: 6, i: 12074]  train_loss: 0.986  |  valid_loss: 0.828
# [epoch: 6, i: 12249]  train_loss: 0.996  |  valid_loss: 1.020
# [epoch: 6, i: 12424]  train_loss: 1.009  |  valid_loss: 0.865
# [epoch: 6, i: 12599]  train_loss: 1.029  |  valid_loss: 0.759
# [epoch: 6, i: 12774]  train_loss: 1.010  |  valid_loss: 0.760
# [epoch: 6, i: 12949]  train_loss: 1.062  |  valid_loss: 0.766
# [epoch: 6, i: 13124]  train_loss: 1.049  |  valid_loss: 0.774
# [epoch: 6, i: 13299]  train_loss: 1.042  |  valid_loss: 0.825
# [epoch: 6, i: 13474]  train_loss: 0.947  |  valid_loss: 0.838
# [epoch: 6, i: 13649]  train_loss: 0.977  |  valid_loss: 0.806
# [epoch: 6, i: 13824]  train_loss: 1.053  |  valid_loss: 0.867
# [epoch: 6, i: 13999]  train_loss: 1.049  |  valid_loss: 0.853
# [epoch: 6, i: 14174]  train_loss: 1.004  |  valid_loss: 0.849
# [epoch: 6, i: 14349]  train_loss: 0.996  |  valid_loss: 0.819
# [epoch: 6, i: 14524]  train_loss: 1.008  |  valid_loss: 0.962
# [epoch: 6, i: 14699]  train_loss: 1.122  |  valid_loss: 0.866
# [epoch: 6, i: 14874]  train_loss: 1.032  |  valid_loss: 1.017
# [epoch: 6, i: 15049]  train_loss: 1.074  |  valid_loss: 0.873
# [epoch: 6, i: 15224]  train_loss: 1.040  |  valid_loss: 0.827
# [epoch: 6, i: 15399]  train_loss: 1.115  |  valid_loss: 0.961
# [epoch: 6, i: 15574]  train_loss: 1.005  |  valid_loss: 0.957
# [epoch: 6, i: 15749]  train_loss: 0.990  |  valid_loss: 0.941
# [epoch: 6, i: 15924]  train_loss: 1.011  |  valid_loss: 0.898
# [epoch: 6, i: 16099]  train_loss: 0.981  |  valid_loss: 0.722
# [epoch: 6, i: 16274]  train_loss: 1.066  |  valid_loss: 0.774
# [epoch: 6, i: 16449]  train_loss: 1.007  |  valid_loss: 0.893
# [epoch: 6, i: 16624]  train_loss: 1.020  |  valid_loss: 0.896
# [epoch: 6, i: 16799]  train_loss: 0.969  |  valid_loss: 0.830
# [epoch: 6, i: 16974]  train_loss: 1.022  |  valid_loss: 0.725
# [epoch: 6, i: 17149]  train_loss: 1.046  |  valid_loss: 0.986
# [epoch: 6, i: 17324]  train_loss: 1.019  |  valid_loss: 0.907
# [epoch: 6, i: 17499]  train_loss: 0.991  |  valid_loss: 0.746
# --> [End of epoch 6] train_accuracy: 65.38%  |  valid_accuracy: 70.85%
# --> [Start of epoch 7]  lr: 0.000500
# [epoch: 7, i:   174]  train_loss: 0.970  |  valid_loss: 0.781
# [epoch: 7, i:   349]  train_loss: 0.871  |  valid_loss: 0.857
# [epoch: 7, i:   524]  train_loss: 1.017  |  valid_loss: 0.912
# [epoch: 7, i:   699]  train_loss: 1.000  |  valid_loss: 0.826
# [epoch: 7, i:   874]  train_loss: 1.033  |  valid_loss: 0.860
# [epoch: 7, i:  1049]  train_loss: 0.995  |  valid_loss: 0.716
# [epoch: 7, i:  1224]  train_loss: 0.967  |  valid_loss: 0.754
# [epoch: 7, i:  1399]  train_loss: 0.995  |  valid_loss: 0.871
# [epoch: 7, i:  1574]  train_loss: 1.012  |  valid_loss: 0.837
# [epoch: 7, i:  1749]  train_loss: 1.019  |  valid_loss: 0.816
# [epoch: 7, i:  1924]  train_loss: 0.979  |  valid_loss: 0.716
# [epoch: 7, i:  2099]  train_loss: 0.970  |  valid_loss: 0.873
# [epoch: 7, i:  2274]  train_loss: 0.978  |  valid_loss: 0.769
# [epoch: 7, i:  2449]  train_loss: 1.105  |  valid_loss: 0.810
# [epoch: 7, i:  2624]  train_loss: 0.931  |  valid_loss: 0.728
# [epoch: 7, i:  2799]  train_loss: 1.002  |  valid_loss: 0.873
# [epoch: 7, i:  2974]  train_loss: 0.966  |  valid_loss: 0.725
# [epoch: 7, i:  3149]  train_loss: 0.969  |  valid_loss: 0.893
# [epoch: 7, i:  3324]  train_loss: 1.041  |  valid_loss: 0.833
# [epoch: 7, i:  3499]  train_loss: 0.979  |  valid_loss: 1.007
# [epoch: 7, i:  3674]  train_loss: 1.002  |  valid_loss: 0.908
# [epoch: 7, i:  3849]  train_loss: 1.011  |  valid_loss: 0.882
# [epoch: 7, i:  4024]  train_loss: 0.971  |  valid_loss: 0.884
# [epoch: 7, i:  4199]  train_loss: 0.933  |  valid_loss: 0.844
# [epoch: 7, i:  4374]  train_loss: 0.997  |  valid_loss: 0.777
# [epoch: 7, i:  4549]  train_loss: 0.947  |  valid_loss: 1.083
# [epoch: 7, i:  4724]  train_loss: 1.025  |  valid_loss: 0.756
# [epoch: 7, i:  4899]  train_loss: 1.037  |  valid_loss: 0.882
# [epoch: 7, i:  5074]  train_loss: 0.964  |  valid_loss: 0.921
# [epoch: 7, i:  5249]  train_loss: 0.954  |  valid_loss: 0.772
# [epoch: 7, i:  5424]  train_loss: 0.992  |  valid_loss: 0.846
# [epoch: 7, i:  5599]  train_loss: 1.032  |  valid_loss: 0.761
# [epoch: 7, i:  5774]  train_loss: 1.051  |  valid_loss: 0.881
# [epoch: 7, i:  5949]  train_loss: 1.000  |  valid_loss: 0.962
# [epoch: 7, i:  6124]  train_loss: 0.896  |  valid_loss: 0.969
# [epoch: 7, i:  6299]  train_loss: 1.003  |  valid_loss: 0.756
# [epoch: 7, i:  6474]  train_loss: 0.882  |  valid_loss: 0.907
# [epoch: 7, i:  6649]  train_loss: 1.025  |  valid_loss: 1.042
# [epoch: 7, i:  6824]  train_loss: 0.991  |  valid_loss: 0.716
# [epoch: 7, i:  6999]  train_loss: 1.065  |  valid_loss: 0.653
# [epoch: 7, i:  7174]  train_loss: 0.934  |  valid_loss: 0.737
# [epoch: 7, i:  7349]  train_loss: 1.062  |  valid_loss: 0.797
# [epoch: 7, i:  7524]  train_loss: 0.985  |  valid_loss: 0.689
# [epoch: 7, i:  7699]  train_loss: 1.008  |  valid_loss: 0.797
# [epoch: 7, i:  7874]  train_loss: 0.994  |  valid_loss: 0.726
# [epoch: 7, i:  8049]  train_loss: 1.003  |  valid_loss: 0.942
# [epoch: 7, i:  8224]  train_loss: 0.935  |  valid_loss: 0.796
# [epoch: 7, i:  8399]  train_loss: 0.935  |  valid_loss: 0.780
# [epoch: 7, i:  8574]  train_loss: 1.021  |  valid_loss: 0.694
# [epoch: 7, i:  8749]  train_loss: 1.134  |  valid_loss: 0.995
# [epoch: 7, i:  8924]  train_loss: 0.973  |  valid_loss: 0.795
# [epoch: 7, i:  9099]  train_loss: 1.032  |  valid_loss: 0.861
# [epoch: 7, i:  9274]  train_loss: 0.953  |  valid_loss: 0.747
# [epoch: 7, i:  9449]  train_loss: 1.054  |  valid_loss: 0.854
# [epoch: 7, i:  9624]  train_loss: 1.020  |  valid_loss: 0.874
# [epoch: 7, i:  9799]  train_loss: 1.000  |  valid_loss: 0.822
# [epoch: 7, i:  9974]  train_loss: 0.976  |  valid_loss: 0.879
# [epoch: 7, i: 10149]  train_loss: 1.012  |  valid_loss: 0.737
# [epoch: 7, i: 10324]  train_loss: 1.048  |  valid_loss: 0.987
# [epoch: 7, i: 10499]  train_loss: 0.987  |  valid_loss: 0.809
# [epoch: 7, i: 10674]  train_loss: 0.976  |  valid_loss: 0.823
# [epoch: 7, i: 10849]  train_loss: 1.062  |  valid_loss: 0.795
# [epoch: 7, i: 11024]  train_loss: 1.055  |  valid_loss: 0.782
# [epoch: 7, i: 11199]  train_loss: 0.985  |  valid_loss: 0.753
# [epoch: 7, i: 11374]  train_loss: 1.085  |  valid_loss: 0.812
# [epoch: 7, i: 11549]  train_loss: 1.016  |  valid_loss: 0.751
# [epoch: 7, i: 11724]  train_loss: 1.016  |  valid_loss: 0.886
# [epoch: 7, i: 11899]  train_loss: 1.004  |  valid_loss: 0.983
# [epoch: 7, i: 12074]  train_loss: 0.962  |  valid_loss: 0.736
# [epoch: 7, i: 12249]  train_loss: 1.010  |  valid_loss: 0.991
# [epoch: 7, i: 12424]  train_loss: 1.021  |  valid_loss: 0.903
# [epoch: 7, i: 12599]  train_loss: 1.000  |  valid_loss: 0.768
# [epoch: 7, i: 12774]  train_loss: 0.960  |  valid_loss: 0.800
# [epoch: 7, i: 12949]  train_loss: 1.001  |  valid_loss: 0.740
# [epoch: 7, i: 13124]  train_loss: 0.948  |  valid_loss: 0.825
# [epoch: 7, i: 13299]  train_loss: 0.971  |  valid_loss: 0.762
# [epoch: 7, i: 13474]  train_loss: 0.972  |  valid_loss: 0.773
# [epoch: 7, i: 13649]  train_loss: 0.996  |  valid_loss: 0.710
# [epoch: 7, i: 13824]  train_loss: 0.959  |  valid_loss: 0.928
# [epoch: 7, i: 13999]  train_loss: 1.054  |  valid_loss: 0.824
# [epoch: 7, i: 14174]  train_loss: 1.092  |  valid_loss: 0.836
# [epoch: 7, i: 14349]  train_loss: 1.012  |  valid_loss: 0.778
# [epoch: 7, i: 14524]  train_loss: 1.025  |  valid_loss: 0.933
# [epoch: 7, i: 14699]  train_loss: 0.949  |  valid_loss: 0.889
# [epoch: 7, i: 14874]  train_loss: 1.021  |  valid_loss: 0.992
# [epoch: 7, i: 15049]  train_loss: 1.004  |  valid_loss: 0.787
# [epoch: 7, i: 15224]  train_loss: 0.999  |  valid_loss: 0.909
# [epoch: 7, i: 15399]  train_loss: 0.972  |  valid_loss: 0.859
# [epoch: 7, i: 15574]  train_loss: 0.947  |  valid_loss: 0.906
# [epoch: 7, i: 15749]  train_loss: 0.933  |  valid_loss: 0.998
# [epoch: 7, i: 15924]  train_loss: 1.012  |  valid_loss: 0.915
# [epoch: 7, i: 16099]  train_loss: 1.055  |  valid_loss: 0.712
# [epoch: 7, i: 16274]  train_loss: 0.962  |  valid_loss: 0.823
# [epoch: 7, i: 16449]  train_loss: 0.924  |  valid_loss: 0.776
# [epoch: 7, i: 16624]  train_loss: 1.041  |  valid_loss: 0.831
# [epoch: 7, i: 16799]  train_loss: 0.987  |  valid_loss: 0.793
# [epoch: 7, i: 16974]  train_loss: 0.993  |  valid_loss: 0.671
# [epoch: 7, i: 17149]  train_loss: 0.967  |  valid_loss: 1.055
# [epoch: 7, i: 17324]  train_loss: 0.963  |  valid_loss: 0.861
# [epoch: 7, i: 17499]  train_loss: 1.017  |  valid_loss: 0.812
# --> [End of epoch 7] train_accuracy: 65.83%  |  valid_accuracy: 71.14%
# --> [Start of epoch 8]  lr: 0.000500
# [epoch: 8, i:   174]  train_loss: 0.882  |  valid_loss: 0.800
# [epoch: 8, i:   349]  train_loss: 0.908  |  valid_loss: 0.767
# [epoch: 8, i:   524]  train_loss: 0.994  |  valid_loss: 0.881
# [epoch: 8, i:   699]  train_loss: 0.988  |  valid_loss: 0.836
# [epoch: 8, i:   874]  train_loss: 0.985  |  valid_loss: 0.855
# [epoch: 8, i:  1049]  train_loss: 0.964  |  valid_loss: 0.665
# [epoch: 8, i:  1224]  train_loss: 1.005  |  valid_loss: 0.775
# [epoch: 8, i:  1399]  train_loss: 0.930  |  valid_loss: 0.837
# [epoch: 8, i:  1574]  train_loss: 1.036  |  valid_loss: 0.817
# [epoch: 8, i:  1749]  train_loss: 0.960  |  valid_loss: 0.809
# [epoch: 8, i:  1924]  train_loss: 0.993  |  valid_loss: 0.734
# [epoch: 8, i:  2099]  train_loss: 0.895  |  valid_loss: 0.804
# [epoch: 8, i:  2274]  train_loss: 0.962  |  valid_loss: 0.779
# [epoch: 8, i:  2449]  train_loss: 0.945  |  valid_loss: 0.774
# [epoch: 8, i:  2624]  train_loss: 0.971  |  valid_loss: 0.757
# [epoch: 8, i:  2799]  train_loss: 0.995  |  valid_loss: 0.875
# [epoch: 8, i:  2974]  train_loss: 0.998  |  valid_loss: 0.772
# [epoch: 8, i:  3149]  train_loss: 1.020  |  valid_loss: 0.832
# [epoch: 8, i:  3324]  train_loss: 0.928  |  valid_loss: 0.831
# [epoch: 8, i:  3499]  train_loss: 1.076  |  valid_loss: 0.986
# [epoch: 8, i:  3674]  train_loss: 0.952  |  valid_loss: 0.892
# [epoch: 8, i:  3849]  train_loss: 0.992  |  valid_loss: 0.909
# [epoch: 8, i:  4024]  train_loss: 0.902  |  valid_loss: 0.850
# [epoch: 8, i:  4199]  train_loss: 0.903  |  valid_loss: 0.853
# [epoch: 8, i:  4374]  train_loss: 0.957  |  valid_loss: 0.848
# [epoch: 8, i:  4549]  train_loss: 1.069  |  valid_loss: 1.039
# [epoch: 8, i:  4724]  train_loss: 1.066  |  valid_loss: 0.660
# [epoch: 8, i:  4899]  train_loss: 1.027  |  valid_loss: 0.802
# [epoch: 8, i:  5074]  train_loss: 0.936  |  valid_loss: 0.842
# [epoch: 8, i:  5249]  train_loss: 0.943  |  valid_loss: 0.826
# [epoch: 8, i:  5424]  train_loss: 0.982  |  valid_loss: 0.827
# [epoch: 8, i:  5599]  train_loss: 1.005  |  valid_loss: 0.711
# [epoch: 8, i:  5774]  train_loss: 0.946  |  valid_loss: 0.897
# [epoch: 8, i:  5949]  train_loss: 0.896  |  valid_loss: 0.887
# [epoch: 8, i:  6124]  train_loss: 0.963  |  valid_loss: 0.892
# [epoch: 8, i:  6299]  train_loss: 0.996  |  valid_loss: 0.813
# [epoch: 8, i:  6474]  train_loss: 0.957  |  valid_loss: 0.909
# [epoch: 8, i:  6649]  train_loss: 0.919  |  valid_loss: 1.105
# [epoch: 8, i:  6824]  train_loss: 1.038  |  valid_loss: 0.648
# [epoch: 8, i:  6999]  train_loss: 0.974  |  valid_loss: 0.735
# [epoch: 8, i:  7174]  train_loss: 0.917  |  valid_loss: 0.745
# [epoch: 8, i:  7349]  train_loss: 1.042  |  valid_loss: 0.817
# [epoch: 8, i:  7524]  train_loss: 0.954  |  valid_loss: 0.789
# [epoch: 8, i:  7699]  train_loss: 1.057  |  valid_loss: 0.795
# [epoch: 8, i:  7874]  train_loss: 1.034  |  valid_loss: 0.776
# [epoch: 8, i:  8049]  train_loss: 1.038  |  valid_loss: 0.925
# [epoch: 8, i:  8224]  train_loss: 1.012  |  valid_loss: 0.817
# [epoch: 8, i:  8399]  train_loss: 0.955  |  valid_loss: 0.783
# [epoch: 8, i:  8574]  train_loss: 0.911  |  valid_loss: 0.702
# [epoch: 8, i:  8749]  train_loss: 0.901  |  valid_loss: 0.946
# [epoch: 8, i:  8924]  train_loss: 1.046  |  valid_loss: 0.792
# [epoch: 8, i:  9099]  train_loss: 0.980  |  valid_loss: 0.910
# [epoch: 8, i:  9274]  train_loss: 0.977  |  valid_loss: 0.697
# [epoch: 8, i:  9449]  train_loss: 0.992  |  valid_loss: 0.903
# [epoch: 8, i:  9624]  train_loss: 1.030  |  valid_loss: 0.810
# [epoch: 8, i:  9799]  train_loss: 0.985  |  valid_loss: 0.839
# [epoch: 8, i:  9974]  train_loss: 0.989  |  valid_loss: 0.925
# [epoch: 8, i: 10149]  train_loss: 0.965  |  valid_loss: 0.786
# [epoch: 8, i: 10324]  train_loss: 0.919  |  valid_loss: 0.982
# [epoch: 8, i: 10499]  train_loss: 1.013  |  valid_loss: 0.826
# [epoch: 8, i: 10674]  train_loss: 1.064  |  valid_loss: 0.853
# [epoch: 8, i: 10849]  train_loss: 1.008  |  valid_loss: 0.763
# [epoch: 8, i: 11024]  train_loss: 1.033  |  valid_loss: 0.819
# [epoch: 8, i: 11199]  train_loss: 0.976  |  valid_loss: 0.738
# [epoch: 8, i: 11374]  train_loss: 1.054  |  valid_loss: 0.748
# [epoch: 8, i: 11549]  train_loss: 0.978  |  valid_loss: 0.763
# [epoch: 8, i: 11724]  train_loss: 0.931  |  valid_loss: 0.794
# [epoch: 8, i: 11899]  train_loss: 0.966  |  valid_loss: 0.886
# [epoch: 8, i: 12074]  train_loss: 1.002  |  valid_loss: 0.892
# [epoch: 8, i: 12249]  train_loss: 0.950  |  valid_loss: 1.024
# [epoch: 8, i: 12424]  train_loss: 1.021  |  valid_loss: 0.881
# [epoch: 8, i: 12599]  train_loss: 0.972  |  valid_loss: 0.789
# [epoch: 8, i: 12774]  train_loss: 1.018  |  valid_loss: 0.767
# [epoch: 8, i: 12949]  train_loss: 0.998  |  valid_loss: 0.670
# [epoch: 8, i: 13124]  train_loss: 0.991  |  valid_loss: 0.770
# [epoch: 8, i: 13299]  train_loss: 1.008  |  valid_loss: 0.745
# [epoch: 8, i: 13474]  train_loss: 0.981  |  valid_loss: 0.836
# [epoch: 8, i: 13649]  train_loss: 0.972  |  valid_loss: 0.687
# [epoch: 8, i: 13824]  train_loss: 1.006  |  valid_loss: 0.901
# [epoch: 8, i: 13999]  train_loss: 0.969  |  valid_loss: 0.851
# [epoch: 8, i: 14174]  train_loss: 1.006  |  valid_loss: 0.807
# [epoch: 8, i: 14349]  train_loss: 1.036  |  valid_loss: 0.795
# [epoch: 8, i: 14524]  train_loss: 0.942  |  valid_loss: 0.860
# [epoch: 8, i: 14699]  train_loss: 0.981  |  valid_loss: 0.846
# [epoch: 8, i: 14874]  train_loss: 0.978  |  valid_loss: 0.923
# [epoch: 8, i: 15049]  train_loss: 0.964  |  valid_loss: 0.809
# [epoch: 8, i: 15224]  train_loss: 1.036  |  valid_loss: 0.818
# [epoch: 8, i: 15399]  train_loss: 0.957  |  valid_loss: 0.874
# [epoch: 8, i: 15574]  train_loss: 1.012  |  valid_loss: 0.844
# [epoch: 8, i: 15749]  train_loss: 1.071  |  valid_loss: 0.925
# [epoch: 8, i: 15924]  train_loss: 1.008  |  valid_loss: 0.845
# [epoch: 8, i: 16099]  train_loss: 0.936  |  valid_loss: 0.631
# [epoch: 8, i: 16274]  train_loss: 1.028  |  valid_loss: 0.764
# [epoch: 8, i: 16449]  train_loss: 0.972  |  valid_loss: 0.812
# [epoch: 8, i: 16624]  train_loss: 0.978  |  valid_loss: 0.856
# [epoch: 8, i: 16799]  train_loss: 0.982  |  valid_loss: 0.748
# [epoch: 8, i: 16974]  train_loss: 0.921  |  valid_loss: 0.706
# [epoch: 8, i: 17149]  train_loss: 1.083  |  valid_loss: 0.991
# [epoch: 8, i: 17324]  train_loss: 0.894  |  valid_loss: 0.886
# [epoch: 8, i: 17499]  train_loss: 1.027  |  valid_loss: 0.791
# --> [End of epoch 8] train_accuracy: 66.22%  |  valid_accuracy: 71.41%
# --> [Start of epoch 9]  lr: 0.000500
# [epoch: 9, i:   174]  train_loss: 1.058  |  valid_loss: 0.716
# [epoch: 9, i:   349]  train_loss: 1.037  |  valid_loss: 0.756
# [epoch: 9, i:   524]  train_loss: 0.884  |  valid_loss: 0.778
# [epoch: 9, i:   699]  train_loss: 0.965  |  valid_loss: 0.855
# [epoch: 9, i:   874]  train_loss: 0.939  |  valid_loss: 0.822
# [epoch: 9, i:  1049]  train_loss: 0.992  |  valid_loss: 0.641
# [epoch: 9, i:  1224]  train_loss: 0.961  |  valid_loss: 0.785
# [epoch: 9, i:  1399]  train_loss: 0.944  |  valid_loss: 0.848
# [epoch: 9, i:  1574]  train_loss: 1.000  |  valid_loss: 0.874
# [epoch: 9, i:  1749]  train_loss: 1.002  |  valid_loss: 0.728
# [epoch: 9, i:  1924]  train_loss: 0.901  |  valid_loss: 0.722
# [epoch: 9, i:  2099]  train_loss: 0.923  |  valid_loss: 0.778
# [epoch: 9, i:  2274]  train_loss: 0.984  |  valid_loss: 0.772
# [epoch: 9, i:  2449]  train_loss: 0.958  |  valid_loss: 0.815
# [epoch: 9, i:  2624]  train_loss: 0.988  |  valid_loss: 0.652
# [epoch: 9, i:  2799]  train_loss: 0.995  |  valid_loss: 0.844
# [epoch: 9, i:  2974]  train_loss: 1.074  |  valid_loss: 0.730
# [epoch: 9, i:  3149]  train_loss: 0.972  |  valid_loss: 0.886
# [epoch: 9, i:  3324]  train_loss: 0.973  |  valid_loss: 0.865
# [epoch: 9, i:  3499]  train_loss: 0.979  |  valid_loss: 1.008
# [epoch: 9, i:  3674]  train_loss: 0.978  |  valid_loss: 0.885
# [epoch: 9, i:  3849]  train_loss: 0.914  |  valid_loss: 0.854
# [epoch: 9, i:  4024]  train_loss: 0.967  |  valid_loss: 0.870
# [epoch: 9, i:  4199]  train_loss: 0.951  |  valid_loss: 0.842
# [epoch: 9, i:  4374]  train_loss: 0.971  |  valid_loss: 0.819
# [epoch: 9, i:  4549]  train_loss: 0.973  |  valid_loss: 1.129
# [epoch: 9, i:  4724]  train_loss: 0.905  |  valid_loss: 0.749
# [epoch: 9, i:  4899]  train_loss: 0.966  |  valid_loss: 0.827
# [epoch: 9, i:  5074]  train_loss: 1.008  |  valid_loss: 0.844
# [epoch: 9, i:  5249]  train_loss: 0.946  |  valid_loss: 0.794
# [epoch: 9, i:  5424]  train_loss: 0.969  |  valid_loss: 0.843
# [epoch: 9, i:  5599]  train_loss: 0.951  |  valid_loss: 0.721
# [epoch: 9, i:  5774]  train_loss: 1.000  |  valid_loss: 0.803
# [epoch: 9, i:  5949]  train_loss: 1.009  |  valid_loss: 0.876
# [epoch: 9, i:  6124]  train_loss: 0.923  |  valid_loss: 0.898
# [epoch: 9, i:  6299]  train_loss: 0.928  |  valid_loss: 0.828
# [epoch: 9, i:  6474]  train_loss: 0.960  |  valid_loss: 0.823
# [epoch: 9, i:  6649]  train_loss: 1.024  |  valid_loss: 0.983
# [epoch: 9, i:  6824]  train_loss: 0.990  |  valid_loss: 0.743
# [epoch: 9, i:  6999]  train_loss: 0.917  |  valid_loss: 0.678
# [epoch: 9, i:  7174]  train_loss: 0.938  |  valid_loss: 0.795
# [epoch: 9, i:  7349]  train_loss: 0.973  |  valid_loss: 0.815
# [epoch: 9, i:  7524]  train_loss: 0.956  |  valid_loss: 0.803
# [epoch: 9, i:  7699]  train_loss: 0.983  |  valid_loss: 0.820
# [epoch: 9, i:  7874]  train_loss: 0.912  |  valid_loss: 0.780
# [epoch: 9, i:  8049]  train_loss: 0.916  |  valid_loss: 0.923
# [epoch: 9, i:  8224]  train_loss: 0.961  |  valid_loss: 0.827
# [epoch: 9, i:  8399]  train_loss: 0.954  |  valid_loss: 0.741
# [epoch: 9, i:  8574]  train_loss: 0.927  |  valid_loss: 0.669
# [epoch: 9, i:  8749]  train_loss: 0.908  |  valid_loss: 0.957
# [epoch: 9, i:  8924]  train_loss: 0.858  |  valid_loss: 0.769
# [epoch: 9, i:  9099]  train_loss: 1.048  |  valid_loss: 0.803
# [epoch: 9, i:  9274]  train_loss: 0.966  |  valid_loss: 0.691
# [epoch: 9, i:  9449]  train_loss: 0.952  |  valid_loss: 0.804
# [epoch: 9, i:  9624]  train_loss: 0.963  |  valid_loss: 0.812
# [epoch: 9, i:  9799]  train_loss: 0.998  |  valid_loss: 0.841
# [epoch: 9, i:  9974]  train_loss: 1.002  |  valid_loss: 1.018
# [epoch: 9, i: 10149]  train_loss: 1.075  |  valid_loss: 0.732
# [epoch: 9, i: 10324]  train_loss: 0.956  |  valid_loss: 0.956
# [epoch: 9, i: 10499]  train_loss: 0.990  |  valid_loss: 0.908
# [epoch: 9, i: 10674]  train_loss: 0.958  |  valid_loss: 0.798
# [epoch: 9, i: 10849]  train_loss: 0.930  |  valid_loss: 0.774
# [epoch: 9, i: 11024]  train_loss: 1.016  |  valid_loss: 0.734
# [epoch: 9, i: 11199]  train_loss: 0.967  |  valid_loss: 0.714
# [epoch: 9, i: 11374]  train_loss: 1.030  |  valid_loss: 0.871
# [epoch: 9, i: 11549]  train_loss: 0.926  |  valid_loss: 0.798
# [epoch: 9, i: 11724]  train_loss: 0.978  |  valid_loss: 0.785
# [epoch: 9, i: 11899]  train_loss: 0.993  |  valid_loss: 0.866
# [epoch: 9, i: 12074]  train_loss: 1.022  |  valid_loss: 0.803
# [epoch: 9, i: 12249]  train_loss: 0.995  |  valid_loss: 1.008
# [epoch: 9, i: 12424]  train_loss: 1.019  |  valid_loss: 0.906
# [epoch: 9, i: 12599]  train_loss: 0.967  |  valid_loss: 0.742
# [epoch: 9, i: 12774]  train_loss: 0.959  |  valid_loss: 0.663
# [epoch: 9, i: 12949]  train_loss: 0.911  |  valid_loss: 0.751
# [epoch: 9, i: 13124]  train_loss: 0.952  |  valid_loss: 0.758
# [epoch: 9, i: 13299]  train_loss: 0.980  |  valid_loss: 0.741
# [epoch: 9, i: 13474]  train_loss: 0.994  |  valid_loss: 0.838
# [epoch: 9, i: 13649]  train_loss: 0.953  |  valid_loss: 0.697
# [epoch: 9, i: 13824]  train_loss: 0.985  |  valid_loss: 0.799
# [epoch: 9, i: 13999]  train_loss: 0.968  |  valid_loss: 0.839
# [epoch: 9, i: 14174]  train_loss: 0.974  |  valid_loss: 0.779
# [epoch: 9, i: 14349]  train_loss: 0.936  |  valid_loss: 0.801
# [epoch: 9, i: 14524]  train_loss: 0.935  |  valid_loss: 0.907
# [epoch: 9, i: 14699]  train_loss: 0.946  |  valid_loss: 0.815
# [epoch: 9, i: 14874]  train_loss: 0.992  |  valid_loss: 1.002
# [epoch: 9, i: 15049]  train_loss: 0.949  |  valid_loss: 0.763
# [epoch: 9, i: 15224]  train_loss: 0.976  |  valid_loss: 0.864
# [epoch: 9, i: 15399]  train_loss: 0.978  |  valid_loss: 0.892
# [epoch: 9, i: 15574]  train_loss: 1.031  |  valid_loss: 0.810
# [epoch: 9, i: 15749]  train_loss: 0.970  |  valid_loss: 0.886
# [epoch: 9, i: 15924]  train_loss: 1.001  |  valid_loss: 0.796
# [epoch: 9, i: 16099]  train_loss: 0.996  |  valid_loss: 0.678
# [epoch: 9, i: 16274]  train_loss: 0.932  |  valid_loss: 0.724
# [epoch: 9, i: 16449]  train_loss: 0.943  |  valid_loss: 0.755
# [epoch: 9, i: 16624]  train_loss: 0.922  |  valid_loss: 0.793
# [epoch: 9, i: 16799]  train_loss: 0.978  |  valid_loss: 0.791
# [epoch: 9, i: 16974]  train_loss: 1.025  |  valid_loss: 0.707
# [epoch: 9, i: 17149]  train_loss: 0.945  |  valid_loss: 1.025
# [epoch: 9, i: 17324]  train_loss: 1.036  |  valid_loss: 0.850
# [epoch: 9, i: 17499]  train_loss: 1.046  |  valid_loss: 0.736
# --> [End of epoch 9] train_accuracy: 66.93%  |  valid_accuracy: 72.24%
# Finished Training.

# %%
plt.plot(avg_train_losses)
plt.plot(avg_valid_losses)
plt.title('Dense_max_1 + plateau scheduling + l2 regularization')
plt.xlabel('mini-batch index / {}'.format(iter_n_per_record))
plt.ylabel('avg. mini-batch loss')
plt.legend(['training loss', 'validation loss'])
plt.show()

# %%
def moving_average(data, window_size):
    """Compute the moving average of the data using a specified window size."""
    return np.convolve(data, np.ones(window_size)/window_size, mode='valid')

window_size = 20  # Adjust this based on your preference
train_losses_ma = moving_average(avg_train_losses, window_size)
valid_losses_ma = moving_average(avg_valid_losses, window_size)

# x_axis = np.arange(len(train_losses_ma))/100 
x_axis = np.arange(window_size - 1, len(train_losses_ma) + window_size - 1)

plt.plot(avg_train_losses)
plt.plot(avg_valid_losses)
plt.plot(x_axis, train_losses_ma, linewidth=2)
plt.plot(x_axis, valid_losses_ma, linewidth=2)
plt.title('DenseNet loss trend + exponential scheduling + l2 regularization')
plt.xlabel('mini-batch index / {}'.format(iter_n_per_record))
plt.ylabel('avg. mini-batch loss')
plt.legend(['training loss', 'validation loss', 'training loss (moving avg)', 'validation loss (moving avg)'])
plt.show()

# %%
plt.plot(train_accuracies)
plt.plot(valid_accuracies)
plt.title('DenseMax accuracy curve for plateau scheduling + l2 regularization')
plt.xlabel('epoch / {}'.format(iter_n_per_record))
plt.ylabel('accuracy')
plt.legend(['train accuracy', 'validation accuracy'])
plt.show()

# %%
# print average time per epoch to 2nd decimal place
print(f"Average time per epoch: {np.mean(time_per_epoch):.2f} seconds")
print("number of parameters:", count_parameters(model))
print(f'model size: {get_model_size(model):.3f}MB')
# Out:
# Average time per epoch: 724.67 seconds
# number of parameters: 136354
# model size: 0.523MB

# %%
# The function to show an image.
def imshow(img):
    img = img / 2 + 0.5     # Unnormalize.
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# %%
# Check several images.
dataiter = iter(validloader)
images, labels = next(dataiter)
imshow(torchvision.utils.make_grid(images))
print('GroundTruth: ', ' '.join('%5s' % classes[labels[j]] for j in range(4)))
outputs = model(images.to(device))

# max compare along the row, return the index of the max value, which is the predicted class
_, predicted = torch.max(outputs, 1)

print('Predicted: ', ' '.join('%5s' % classes[predicted[j]]
                              for j in range(4)))
# Out:
# GroundTruth:    cat  ship  ship plane
# Predicted:    cat  ship  ship  ship

# %%
images, labels = next(iter(validloader))
print(len(images))
# Out:
# 4

# %%
inference_time_per_image = []


model.to(device)
model.eval()
# Get test accuracy.
correct = 0
total = 0
with torch.no_grad():
    for data in validloader:
        images, labels = data
        images, labels = images.to(device), labels.to(device)
        inference_start = time.time()
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        inference_end = time.time()
        inference_time_per_image.append((inference_end - inference_start) / len(images))
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print('Accuracy of the network on the 10000 test images: %.2f %%' % (
    100 * correct / total))

# print average inference time per image in ms
print(f"average inference time per image: {sum(inference_time_per_image) * 1000 / len(inference_time_per_image):.3f} ms")
# Out:
# Accuracy of the network on the 10000 test images: 72.14 %
# average inference time per image: 1.381 ms

# %%
model.to(device)
model.eval()

# Get test accuracy for each class.
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))
with torch.no_grad():
    for data in validloader:
        images, labels = data
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels).squeeze()
        for i in range(4):
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1

for i in range(10):
    print('Accuracy of %5s : %2d %%' % (
        classes[i], 100 * class_correct[i] / class_total[i]))
# Out:
# Accuracy of plane : 71 %
# Accuracy of   car : 86 %
# Accuracy of  bird : 62 %
# Accuracy of   cat : 51 %
# Accuracy of  deer : 68 %
# Accuracy of   dog : 69 %
# Accuracy of  frog : 73 %
# Accuracy of horse : 74 %
# Accuracy of  ship : 83 %
# Accuracy of truck : 89 %

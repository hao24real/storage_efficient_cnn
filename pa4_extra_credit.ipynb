# %% [markdown]
# ### Extra Credit

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=4,
                                          shuffle=True, num_workers=2)

validset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)
validloader = torch.utils.data.DataLoader(validset, batch_size=4,
                                         shuffle=False, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

# If there are GPUs, choose the first one for computing. Otherwise use CPU.
device = torch.device("cuda:0" if torch.cuda.is_available() else ("mps" if torch.backends.mps.is_available() else "cpu"))
print(device)  
# If 'mps or cuda:0' is printed, it means GPU is available.
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# mps

# %%
class ShortConn2d(nn.Module):
    def __init__(self, in_channels, out_channels, stride=1):
        super().__init__()
        
        self.conv = nn.Conv2d(in_channels, out_channels,
                              kernel_size=1, stride=stride, padding=0)
            
        self.bn = nn.BatchNorm2d(out_channels)
    def forward(self, x):
        x = self.conv(x)
        x = self.bn(x)
        return x

# %%
class ResBlock(nn.Module):
    def __init__(self, in_channels, out_channels, stride=1):
        super(ResBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_channels, out_channels, 
                             kernel_size=3, stride=stride, padding=1)
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.act1 = nn.ReLU()
        self.conv2 = nn.Conv2d(out_channels, out_channels, 
                               kernel_size=3, stride=1, padding=1)
        self.bn2 = nn.BatchNorm2d(out_channels)
        
        # skip connect projection from in_channels to out_channels
        # depending on the stride and channels to do a projection
        # or just pass on the input
        if stride == 1 and in_channels == out_channels:
            self.shortcut = nn.Identity()
        else:
            self.shortcut = ShortConn2d(in_channels, out_channels, stride)
        
    def forward(self, x):
        # reserve this now for the skip connection
        shortcut = self.shortcut(x)
        x = self.conv1(x)
        x = self.bn1(x)
        x = self.act1(x)
        x = self.conv2(x)
        x = self.bn2(x)

        # not applying activation here for densenet implementation
        return x + shortcut

# %%
class DenseMax(nn.Module):
    def __init__(self):
        super(DenseMax, self).__init__()
        
         ### RES 1
         
        # 3x32x32 to 10x32x32
        self.rb1 = ResBlock(3, 10, 1)
        self.act1 = nn.ReLU()
        # 10x32x32 to 10x16x16
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        
        ### RES 2
        
        # 10x16x16 to 20x16x16
        self.rb2 = ResBlock(10, 20, 1)
        # 3x32x32 to 20x16x16 skip connection
        self.res1_sc1 = ShortConn2d(3, 20, 2)
        self.act2 = nn.ReLU()
        # 20x16x16 to 20x8x8
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
                
        # 20x8x8 to 20x8x8
        self.rb3 = ResBlock(20, 20, 1)
        # 3x32x32 to 20x8x8 skip connection
        self.res1_sc2 = ShortConn2d(3, 20, 4)
        # 10x16x16 to 20x8x8 skip connection
        self.res2_sc1 = ShortConn2d(10, 20, 2)
        self.act3 = nn.ReLU()
        # 20x8x8 to 20x4x4
        self.pool3 = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)

        # 20x4x4 affine operation to hidden layer with 100 neurons
        self.fc1 = nn.Linear(20 * 4 * 4, 100)
        self.bn1 = nn.BatchNorm1d(100)
        self.act4 = nn.ReLU()
        
        # affine operation to output layer with 10 neurons
        self.fc2 = nn.Linear(100, 10)
        
    def forward(self, x):
       
        res1_sc1 = self.res1_sc1(x)
        res1_sc2 = self.res1_sc2(x)
        
        x = self.rb1(x)
        x = self.act1(x)
        x = self.pool1(x)
        
        res2_sc1 = self.res2_sc1(x)

        x = self.rb2(x)
        x = self.act2(x + res1_sc1)
        x = self.pool2(x)
        
        x = self.rb3(x)
        x = self.act3(x + res1_sc2 + res2_sc1)
        x = self.pool3(x)
                
        # flatten and pass through fully connected layers
        x = torch.flatten(x, 1)
        x = self.fc1(x)
        x = self.bn1(x)
        x = self.act4(x)
        x = self.fc2(x)
        return x

# %%
PATH = './models/cifar_dense_max_adam.pth'

epochs = 10             # Total epochs.
iter_n = len(trainloader)  # number of iteration per epoch
record_freq = iter_n // 100  # Record frequency.
print_freq = iter_n // 100 # Print frequency, need to be multiple of record_freq.

# a number for computing running validation loss in each iteration.
train_per_valid = len(trainloader) / len(validloader)  

avg_train_losses, avg_valid_losses = [], []   # Avg. losses.
train_accuracies, valid_accuracies = [], []  # Train and test accuracies.

dense_max = DenseMax()     # Create the network instance.
dense_max.to(device)  # Move the network parameters to the specified device.

# We use cross-entropy as loss function.
loss_func = nn.CrossEntropyLoss()  

# We use Adam as optimizer.
opt = optim.Adam(dense_max.parameters(), lr=0.001, betas=(0.9, 0.999), eps=1e-08, weight_decay=1e-4)

# add scheduling
scheduler = optim.lr_scheduler.ExponentialLR(opt, gamma=0.7)

for epoch in range(epochs):  # Loop over the dataset multiple times.
    running_train_loss = 0.0       # Initialize running train_loss for training set.
    running_val_loss = 0.0     # Initialize running train_loss for validation set.
    
    # Initialize running total and correct for computing train accuracy.
    train_correct = 0 
    train_total = 0
    # Initialize running total and correct for computing test accuracy.
    valid_total = 0   
    valid_correct = 0
    
        
    print('--> [Start of epoch {}]'.format(epoch) +
          '  lr: {:.6f}'.format(scheduler.get_last_lr()[0]))
    
    validiter = iter(validloader)
    for i, data in enumerate(iterable=trainloader, start=0):
        
        # Set the model to training mode.
        dense_max.train()
        
        # Get the inputs.
        inputs, labels = data
        
        # Move the inputs to the specified device.
        inputs, labels = inputs.to(device), labels.to(device)
        
        # Zero the parameter gradients.
        opt.zero_grad()

        # Forward step
        train_output = dense_max(inputs)
        train_loss = loss_func(train_output, labels)
        
        # Backward step.
        train_loss.backward()
        
        # Optimization step (update the parameters).
        opt.step()
        
        dense_max.eval()
        
        # record statistics.
        running_train_loss += train_loss.item()
        
        # this is for recording training accuracy
        _, train_predicted = torch.max(train_output.data, 1)
        train_total += labels.size(0)
        train_correct += (train_predicted == labels).sum().item()
        
        # only iterate through validation set according to train_per_valid ratio
        if i % train_per_valid == train_per_valid - 1:
            # Set the model to evaluation mode.
            with torch.no_grad():
                valid_inputs, valid_labels = next(validiter)
                valid_inputs, valid_labels = valid_inputs.to(device), valid_labels.to(device)
                valid_output = dense_max(valid_inputs)
                valid_loss = loss_func(valid_output, valid_labels)
                running_val_loss += valid_loss.item()
                
                _, valid_predicted = torch.max(valid_output.data, 1)
                valid_total += valid_labels.size(0)
                valid_correct += (valid_predicted == valid_labels).sum().item()
            
        # Record training/validation loss every several mini-batches.
        if i % record_freq == record_freq - 1: 
            avg_train_loss = running_train_loss / record_freq
            avg_train_losses.append(avg_train_loss)
            avg_valid_loss = train_per_valid * running_val_loss / record_freq
            avg_valid_losses.append(avg_valid_loss)
            running_train_loss, running_val_loss = 0.0, 0.0
            
            # only print traing training loss once in a while to avoid cluster output
            if i % print_freq == print_freq - 1:
                print('[epoch: {}, i: {:5d}]'.format(epoch, i) +
                      '  train_loss: {:.3f}'.format(avg_train_loss) + 
                      '  |  valid_loss: {:.3f}'.format(avg_valid_loss))
                            

    # exponential scheduling
    scheduler.step()

                   
    # calculating train accuracy
    train_accuracy = 100 * train_correct / train_total
    train_accuracies.append(train_accuracy)
    
    valid_accuracy = 100 * valid_correct / valid_total
    valid_accuracies.append(valid_accuracy)     
    
    # Store the networks after each epochs.
    # in case we want to do simple average or weighted average
    torch.save({
            'epoch': epoch,
            'model_state_dict': dense_max.state_dict(),
            'optimizer_state_dict': opt.state_dict(),
            'train_loss': avg_train_losses[epoch],
            'train_accuracy': train_accuracies[epoch],
            'valid_accuracy': valid_accuracies[epoch],
            }, PATH)
    
    print('--> [End of epoch {}]'.format(epoch) +
                      ' train_accuracy: {:.2f}%'.format(train_accuracy) + 
                      '  |  valid_accuracy: {:.2f}%'.format(valid_accuracy))

print('Finished Training.')
# Out:
# --> [Start of epoch 0]  lr: 0.001000
# [epoch: 0, i:   124]  train_loss: 2.157  |  valid_loss: 2.137
# [epoch: 0, i:   249]  train_loss: 1.987  |  valid_loss: 1.916
# [epoch: 0, i:   374]  train_loss: 1.929  |  valid_loss: 1.829
# [epoch: 0, i:   499]  train_loss: 1.948  |  valid_loss: 1.696
# [epoch: 0, i:   624]  train_loss: 1.887  |  valid_loss: 1.699
# [epoch: 0, i:   749]  train_loss: 1.837  |  valid_loss: 1.655
# [epoch: 0, i:   874]  train_loss: 1.808  |  valid_loss: 1.660
# [epoch: 0, i:   999]  train_loss: 1.758  |  valid_loss: 1.583
# [epoch: 0, i:  1124]  train_loss: 1.795  |  valid_loss: 1.552
# [epoch: 0, i:  1249]  train_loss: 1.791  |  valid_loss: 1.469
# [epoch: 0, i:  1374]  train_loss: 1.750  |  valid_loss: 1.525
# [epoch: 0, i:  1499]  train_loss: 1.712  |  valid_loss: 1.520
# [epoch: 0, i:  1624]  train_loss: 1.720  |  valid_loss: 1.585
# [epoch: 0, i:  1749]  train_loss: 1.730  |  valid_loss: 1.549
# [epoch: 0, i:  1874]  train_loss: 1.724  |  valid_loss: 1.365
# [epoch: 0, i:  1999]  train_loss: 1.756  |  valid_loss: 1.561
# [epoch: 0, i:  2124]  train_loss: 1.737  |  valid_loss: 1.460
# [epoch: 0, i:  2249]  train_loss: 1.670  |  valid_loss: 1.508
# [epoch: 0, i:  2374]  train_loss: 1.690  |  valid_loss: 1.422
# [epoch: 0, i:  2499]  train_loss: 1.733  |  valid_loss: 1.581
# [epoch: 0, i:  2624]  train_loss: 1.676  |  valid_loss: 1.265
# [epoch: 0, i:  2749]  train_loss: 1.614  |  valid_loss: 1.353
# [epoch: 0, i:  2874]  train_loss: 1.648  |  valid_loss: 1.425
# [epoch: 0, i:  2999]  train_loss: 1.581  |  valid_loss: 1.414
# [epoch: 0, i:  3124]  train_loss: 1.598  |  valid_loss: 1.341
# [epoch: 0, i:  3249]  train_loss: 1.645  |  valid_loss: 1.546
# [epoch: 0, i:  3374]  train_loss: 1.594  |  valid_loss: 1.247
# [epoch: 0, i:  3499]  train_loss: 1.665  |  valid_loss: 1.411
# [epoch: 0, i:  3624]  train_loss: 1.572  |  valid_loss: 1.429
# [epoch: 0, i:  3749]  train_loss: 1.636  |  valid_loss: 1.380
# [epoch: 0, i:  3874]  train_loss: 1.528  |  valid_loss: 1.307
# [epoch: 0, i:  3999]  train_loss: 1.563  |  valid_loss: 1.328
# [epoch: 0, i:  4124]  train_loss: 1.634  |  valid_loss: 1.278
# [epoch: 0, i:  4249]  train_loss: 1.557  |  valid_loss: 1.380
# [epoch: 0, i:  4374]  train_loss: 1.639  |  valid_loss: 1.421
# [epoch: 0, i:  4499]  train_loss: 1.574  |  valid_loss: 1.192
# [epoch: 0, i:  4624]  train_loss: 1.492  |  valid_loss: 1.351
# [epoch: 0, i:  4749]  train_loss: 1.484  |  valid_loss: 1.376
# [epoch: 0, i:  4874]  train_loss: 1.546  |  valid_loss: 1.210
# [epoch: 0, i:  4999]  train_loss: 1.556  |  valid_loss: 1.313
# [epoch: 0, i:  5124]  train_loss: 1.466  |  valid_loss: 1.324
# [epoch: 0, i:  5249]  train_loss: 1.489  |  valid_loss: 1.239
# [epoch: 0, i:  5374]  train_loss: 1.528  |  valid_loss: 1.205
# [epoch: 0, i:  5499]  train_loss: 1.524  |  valid_loss: 1.103
# [epoch: 0, i:  5624]  train_loss: 1.508  |  valid_loss: 1.348
# [epoch: 0, i:  5749]  train_loss: 1.524  |  valid_loss: 1.365
# [epoch: 0, i:  5874]  train_loss: 1.530  |  valid_loss: 1.265
# [epoch: 0, i:  5999]  train_loss: 1.553  |  valid_loss: 1.176
# [epoch: 0, i:  6124]  train_loss: 1.434  |  valid_loss: 1.088
# [epoch: 0, i:  6249]  train_loss: 1.426  |  valid_loss: 1.298
# [epoch: 0, i:  6374]  train_loss: 1.555  |  valid_loss: 1.293
# [epoch: 0, i:  6499]  train_loss: 1.441  |  valid_loss: 1.231
# [epoch: 0, i:  6624]  train_loss: 1.548  |  valid_loss: 1.061
# [epoch: 0, i:  6749]  train_loss: 1.456  |  valid_loss: 1.450
# [epoch: 0, i:  6874]  train_loss: 1.428  |  valid_loss: 1.255
# [epoch: 0, i:  6999]  train_loss: 1.393  |  valid_loss: 1.349
# [epoch: 0, i:  7124]  train_loss: 1.444  |  valid_loss: 1.247
# [epoch: 0, i:  7249]  train_loss: 1.509  |  valid_loss: 0.945
# [epoch: 0, i:  7374]  train_loss: 1.410  |  valid_loss: 1.445
# [epoch: 0, i:  7499]  train_loss: 1.363  |  valid_loss: 1.194
# [epoch: 0, i:  7624]  train_loss: 1.347  |  valid_loss: 1.232
# [epoch: 0, i:  7749]  train_loss: 1.420  |  valid_loss: 1.256
# [epoch: 0, i:  7874]  train_loss: 1.437  |  valid_loss: 1.093
# [epoch: 0, i:  7999]  train_loss: 1.494  |  valid_loss: 1.041
# [epoch: 0, i:  8124]  train_loss: 1.439  |  valid_loss: 1.230
# [epoch: 0, i:  8249]  train_loss: 1.358  |  valid_loss: 1.345
# [epoch: 0, i:  8374]  train_loss: 1.483  |  valid_loss: 1.155
# [epoch: 0, i:  8499]  train_loss: 1.450  |  valid_loss: 1.192
# [epoch: 0, i:  8624]  train_loss: 1.394  |  valid_loss: 1.165
# [epoch: 0, i:  8749]  train_loss: 1.389  |  valid_loss: 1.368
# [epoch: 0, i:  8874]  train_loss: 1.390  |  valid_loss: 1.213
# [epoch: 0, i:  8999]  train_loss: 1.461  |  valid_loss: 1.100
# [epoch: 0, i:  9124]  train_loss: 1.407  |  valid_loss: 1.097
# [epoch: 0, i:  9249]  train_loss: 1.377  |  valid_loss: 0.985
# [epoch: 0, i:  9374]  train_loss: 1.350  |  valid_loss: 1.129
# [epoch: 0, i:  9499]  train_loss: 1.438  |  valid_loss: 1.045
# [epoch: 0, i:  9624]  train_loss: 1.329  |  valid_loss: 1.207
# [epoch: 0, i:  9749]  train_loss: 1.452  |  valid_loss: 1.134
# [epoch: 0, i:  9874]  train_loss: 1.441  |  valid_loss: 1.320
# [epoch: 0, i:  9999]  train_loss: 1.471  |  valid_loss: 1.202
# [epoch: 0, i: 10124]  train_loss: 1.294  |  valid_loss: 1.014
# [epoch: 0, i: 10249]  train_loss: 1.367  |  valid_loss: 1.092
# [epoch: 0, i: 10374]  train_loss: 1.405  |  valid_loss: 1.275
# [epoch: 0, i: 10499]  train_loss: 1.350  |  valid_loss: 1.222
# [epoch: 0, i: 10624]  train_loss: 1.371  |  valid_loss: 1.161
# [epoch: 0, i: 10749]  train_loss: 1.331  |  valid_loss: 0.930
# [epoch: 0, i: 10874]  train_loss: 1.380  |  valid_loss: 1.073
# [epoch: 0, i: 10999]  train_loss: 1.321  |  valid_loss: 1.234
# [epoch: 0, i: 11124]  train_loss: 1.282  |  valid_loss: 1.104
# [epoch: 0, i: 11249]  train_loss: 1.360  |  valid_loss: 1.098
# [epoch: 0, i: 11374]  train_loss: 1.388  |  valid_loss: 1.081
# [epoch: 0, i: 11499]  train_loss: 1.434  |  valid_loss: 0.888
# [epoch: 0, i: 11624]  train_loss: 1.398  |  valid_loss: 1.092
# [epoch: 0, i: 11749]  train_loss: 1.435  |  valid_loss: 1.135
# [epoch: 0, i: 11874]  train_loss: 1.313  |  valid_loss: 1.098
# [epoch: 0, i: 11999]  train_loss: 1.319  |  valid_loss: 1.130
# [epoch: 0, i: 12124]  train_loss: 1.260  |  valid_loss: 0.949
# [epoch: 0, i: 12249]  train_loss: 1.363  |  valid_loss: 1.107
# [epoch: 0, i: 12374]  train_loss: 1.413  |  valid_loss: 1.089
# [epoch: 0, i: 12499]  train_loss: 1.248  |  valid_loss: 1.058
# --> [End of epoch 0] train_accuracy: 46.15%  |  valid_accuracy: 54.10%
# --> [Start of epoch 1]  lr: 0.000700
# [epoch: 1, i:   124]  train_loss: 1.406  |  valid_loss: 1.007
# [epoch: 1, i:   249]  train_loss: 1.255  |  valid_loss: 1.034
# [epoch: 1, i:   374]  train_loss: 1.336  |  valid_loss: 1.049
# [epoch: 1, i:   499]  train_loss: 1.308  |  valid_loss: 1.035
# [epoch: 1, i:   624]  train_loss: 1.266  |  valid_loss: 1.132
# [epoch: 1, i:   749]  train_loss: 1.261  |  valid_loss: 0.901
# [epoch: 1, i:   874]  train_loss: 1.311  |  valid_loss: 1.063
# [epoch: 1, i:   999]  train_loss: 1.232  |  valid_loss: 1.073
# [epoch: 1, i:  1124]  train_loss: 1.235  |  valid_loss: 1.030
# [epoch: 1, i:  1249]  train_loss: 1.350  |  valid_loss: 0.889
# [epoch: 1, i:  1374]  train_loss: 1.182  |  valid_loss: 0.822
# [epoch: 1, i:  1499]  train_loss: 1.312  |  valid_loss: 1.044
# [epoch: 1, i:  1624]  train_loss: 1.277  |  valid_loss: 1.058
# [epoch: 1, i:  1749]  train_loss: 1.238  |  valid_loss: 1.018
# [epoch: 1, i:  1874]  train_loss: 1.172  |  valid_loss: 0.948
# [epoch: 1, i:  1999]  train_loss: 1.306  |  valid_loss: 1.182
# [epoch: 1, i:  2124]  train_loss: 1.339  |  valid_loss: 0.950
# [epoch: 1, i:  2249]  train_loss: 1.353  |  valid_loss: 1.084
# [epoch: 1, i:  2374]  train_loss: 1.275  |  valid_loss: 0.883
# [epoch: 1, i:  2499]  train_loss: 1.275  |  valid_loss: 1.086
# [epoch: 1, i:  2624]  train_loss: 1.240  |  valid_loss: 0.967
# [epoch: 1, i:  2749]  train_loss: 1.305  |  valid_loss: 1.035
# [epoch: 1, i:  2874]  train_loss: 1.280  |  valid_loss: 0.938
# [epoch: 1, i:  2999]  train_loss: 1.295  |  valid_loss: 1.043
# [epoch: 1, i:  3124]  train_loss: 1.260  |  valid_loss: 1.014
# [epoch: 1, i:  3249]  train_loss: 1.242  |  valid_loss: 1.278
# [epoch: 1, i:  3374]  train_loss: 1.290  |  valid_loss: 0.911
# [epoch: 1, i:  3499]  train_loss: 1.122  |  valid_loss: 1.057
# [epoch: 1, i:  3624]  train_loss: 1.225  |  valid_loss: 0.965
# [epoch: 1, i:  3749]  train_loss: 1.243  |  valid_loss: 0.971
# [epoch: 1, i:  3874]  train_loss: 1.274  |  valid_loss: 0.927
# [epoch: 1, i:  3999]  train_loss: 1.226  |  valid_loss: 0.888
# [epoch: 1, i:  4124]  train_loss: 1.241  |  valid_loss: 1.046
# [epoch: 1, i:  4249]  train_loss: 1.217  |  valid_loss: 1.024
# [epoch: 1, i:  4374]  train_loss: 1.285  |  valid_loss: 1.034
# [epoch: 1, i:  4499]  train_loss: 1.355  |  valid_loss: 1.023
# [epoch: 1, i:  4624]  train_loss: 1.219  |  valid_loss: 1.142
# [epoch: 1, i:  4749]  train_loss: 1.205  |  valid_loss: 1.065
# [epoch: 1, i:  4874]  train_loss: 1.267  |  valid_loss: 0.784
# [epoch: 1, i:  4999]  train_loss: 1.292  |  valid_loss: 0.880
# [epoch: 1, i:  5124]  train_loss: 1.296  |  valid_loss: 0.914
# [epoch: 1, i:  5249]  train_loss: 1.233  |  valid_loss: 0.901
# [epoch: 1, i:  5374]  train_loss: 1.185  |  valid_loss: 0.852
# [epoch: 1, i:  5499]  train_loss: 1.227  |  valid_loss: 0.879
# [epoch: 1, i:  5624]  train_loss: 1.223  |  valid_loss: 0.957
# [epoch: 1, i:  5749]  train_loss: 1.185  |  valid_loss: 1.011
# [epoch: 1, i:  5874]  train_loss: 1.238  |  valid_loss: 0.801
# [epoch: 1, i:  5999]  train_loss: 1.163  |  valid_loss: 0.946
# [epoch: 1, i:  6124]  train_loss: 1.198  |  valid_loss: 0.767
# [epoch: 1, i:  6249]  train_loss: 1.292  |  valid_loss: 1.051
# [epoch: 1, i:  6374]  train_loss: 1.277  |  valid_loss: 0.895
# [epoch: 1, i:  6499]  train_loss: 1.172  |  valid_loss: 0.906
# [epoch: 1, i:  6624]  train_loss: 1.239  |  valid_loss: 0.859
# [epoch: 1, i:  6749]  train_loss: 1.167  |  valid_loss: 1.060
# [epoch: 1, i:  6874]  train_loss: 1.321  |  valid_loss: 0.936
# [epoch: 1, i:  6999]  train_loss: 1.240  |  valid_loss: 1.102
# [epoch: 1, i:  7124]  train_loss: 1.209  |  valid_loss: 0.988
# [epoch: 1, i:  7249]  train_loss: 1.167  |  valid_loss: 0.828
# [epoch: 1, i:  7374]  train_loss: 1.122  |  valid_loss: 1.116
# [epoch: 1, i:  7499]  train_loss: 1.187  |  valid_loss: 0.991
# [epoch: 1, i:  7624]  train_loss: 1.135  |  valid_loss: 0.999
# [epoch: 1, i:  7749]  train_loss: 1.151  |  valid_loss: 1.010
# [epoch: 1, i:  7874]  train_loss: 1.182  |  valid_loss: 0.893
# [epoch: 1, i:  7999]  train_loss: 1.234  |  valid_loss: 0.840
# [epoch: 1, i:  8124]  train_loss: 1.212  |  valid_loss: 0.950
# [epoch: 1, i:  8249]  train_loss: 1.249  |  valid_loss: 1.121
# [epoch: 1, i:  8374]  train_loss: 1.284  |  valid_loss: 0.856
# [epoch: 1, i:  8499]  train_loss: 1.192  |  valid_loss: 1.015
# [epoch: 1, i:  8624]  train_loss: 1.165  |  valid_loss: 0.919
# [epoch: 1, i:  8749]  train_loss: 1.159  |  valid_loss: 1.142
# [epoch: 1, i:  8874]  train_loss: 1.161  |  valid_loss: 0.874
# [epoch: 1, i:  8999]  train_loss: 1.236  |  valid_loss: 0.821
# [epoch: 1, i:  9124]  train_loss: 1.248  |  valid_loss: 0.948
# [epoch: 1, i:  9249]  train_loss: 1.137  |  valid_loss: 0.758
# [epoch: 1, i:  9374]  train_loss: 1.179  |  valid_loss: 0.887
# [epoch: 1, i:  9499]  train_loss: 1.185  |  valid_loss: 0.772
# [epoch: 1, i:  9624]  train_loss: 1.257  |  valid_loss: 0.979
# [epoch: 1, i:  9749]  train_loss: 1.226  |  valid_loss: 0.942
# [epoch: 1, i:  9874]  train_loss: 1.246  |  valid_loss: 1.033
# [epoch: 1, i:  9999]  train_loss: 1.225  |  valid_loss: 1.062
# [epoch: 1, i: 10124]  train_loss: 1.230  |  valid_loss: 0.748
# [epoch: 1, i: 10249]  train_loss: 1.136  |  valid_loss: 0.970
# [epoch: 1, i: 10374]  train_loss: 1.158  |  valid_loss: 0.954
# [epoch: 1, i: 10499]  train_loss: 1.245  |  valid_loss: 0.970
# [epoch: 1, i: 10624]  train_loss: 1.192  |  valid_loss: 1.051
# [epoch: 1, i: 10749]  train_loss: 1.266  |  valid_loss: 0.837
# [epoch: 1, i: 10874]  train_loss: 1.252  |  valid_loss: 0.989
# [epoch: 1, i: 10999]  train_loss: 1.181  |  valid_loss: 1.041
# [epoch: 1, i: 11124]  train_loss: 1.158  |  valid_loss: 1.089
# [epoch: 1, i: 11249]  train_loss: 1.225  |  valid_loss: 0.893
# [epoch: 1, i: 11374]  train_loss: 1.175  |  valid_loss: 0.827
# [epoch: 1, i: 11499]  train_loss: 1.171  |  valid_loss: 0.706
# [epoch: 1, i: 11624]  train_loss: 1.137  |  valid_loss: 1.033
# [epoch: 1, i: 11749]  train_loss: 1.252  |  valid_loss: 0.921
# [epoch: 1, i: 11874]  train_loss: 1.205  |  valid_loss: 0.841
# [epoch: 1, i: 11999]  train_loss: 1.199  |  valid_loss: 0.862
# [epoch: 1, i: 12124]  train_loss: 1.230  |  valid_loss: 0.889
# [epoch: 1, i: 12249]  train_loss: 1.177  |  valid_loss: 0.976
# [epoch: 1, i: 12374]  train_loss: 1.169  |  valid_loss: 1.064
# [epoch: 1, i: 12499]  train_loss: 1.235  |  valid_loss: 0.931
# --> [End of epoch 1] train_accuracy: 57.85%  |  valid_accuracy: 66.98%
# --> [Start of epoch 2]  lr: 0.000490
# [epoch: 2, i:   124]  train_loss: 1.130  |  valid_loss: 0.824
# [epoch: 2, i:   249]  train_loss: 1.213  |  valid_loss: 0.835
# [epoch: 2, i:   374]  train_loss: 1.132  |  valid_loss: 0.895
# [epoch: 2, i:   499]  train_loss: 1.108  |  valid_loss: 0.820
# [epoch: 2, i:   624]  train_loss: 1.102  |  valid_loss: 0.908
# [epoch: 2, i:   749]  train_loss: 1.125  |  valid_loss: 0.789
# [epoch: 2, i:   874]  train_loss: 1.079  |  valid_loss: 0.899
# [epoch: 2, i:   999]  train_loss: 1.151  |  valid_loss: 0.878
# [epoch: 2, i:  1124]  train_loss: 1.085  |  valid_loss: 0.962
# [epoch: 2, i:  1249]  train_loss: 1.218  |  valid_loss: 0.797
# [epoch: 2, i:  1374]  train_loss: 1.124  |  valid_loss: 0.774
# [epoch: 2, i:  1499]  train_loss: 1.172  |  valid_loss: 0.872
# [epoch: 2, i:  1624]  train_loss: 1.169  |  valid_loss: 0.893
# [epoch: 2, i:  1749]  train_loss: 1.066  |  valid_loss: 0.939
# [epoch: 2, i:  1874]  train_loss: 1.081  |  valid_loss: 0.716
# [epoch: 2, i:  1999]  train_loss: 1.123  |  valid_loss: 1.037
# [epoch: 2, i:  2124]  train_loss: 1.254  |  valid_loss: 0.857
# [epoch: 2, i:  2249]  train_loss: 1.177  |  valid_loss: 0.869
# [epoch: 2, i:  2374]  train_loss: 1.141  |  valid_loss: 0.775
# [epoch: 2, i:  2499]  train_loss: 1.164  |  valid_loss: 1.021
# [epoch: 2, i:  2624]  train_loss: 1.048  |  valid_loss: 0.843
# [epoch: 2, i:  2749]  train_loss: 1.101  |  valid_loss: 0.945
# [epoch: 2, i:  2874]  train_loss: 1.203  |  valid_loss: 0.876
# [epoch: 2, i:  2999]  train_loss: 1.137  |  valid_loss: 0.900
# [epoch: 2, i:  3124]  train_loss: 1.168  |  valid_loss: 0.878
# [epoch: 2, i:  3249]  train_loss: 1.163  |  valid_loss: 1.125
# [epoch: 2, i:  3374]  train_loss: 1.091  |  valid_loss: 0.778
# [epoch: 2, i:  3499]  train_loss: 1.136  |  valid_loss: 0.868
# [epoch: 2, i:  3624]  train_loss: 1.122  |  valid_loss: 0.841
# [epoch: 2, i:  3749]  train_loss: 1.110  |  valid_loss: 0.858
# [epoch: 2, i:  3874]  train_loss: 1.307  |  valid_loss: 0.781
# [epoch: 2, i:  3999]  train_loss: 1.091  |  valid_loss: 0.797
# [epoch: 2, i:  4124]  train_loss: 1.189  |  valid_loss: 0.939
# [epoch: 2, i:  4249]  train_loss: 1.168  |  valid_loss: 0.991
# [epoch: 2, i:  4374]  train_loss: 1.115  |  valid_loss: 0.867
# [epoch: 2, i:  4499]  train_loss: 1.157  |  valid_loss: 0.905
# [epoch: 2, i:  4624]  train_loss: 1.126  |  valid_loss: 1.036
# [epoch: 2, i:  4749]  train_loss: 1.148  |  valid_loss: 1.018
# [epoch: 2, i:  4874]  train_loss: 1.085  |  valid_loss: 0.683
# [epoch: 2, i:  4999]  train_loss: 1.193  |  valid_loss: 0.734
# [epoch: 2, i:  5124]  train_loss: 1.189  |  valid_loss: 0.788
# [epoch: 2, i:  5249]  train_loss: 1.048  |  valid_loss: 0.872
# [epoch: 2, i:  5374]  train_loss: 1.175  |  valid_loss: 0.789
# [epoch: 2, i:  5499]  train_loss: 1.098  |  valid_loss: 0.812
# [epoch: 2, i:  5624]  train_loss: 1.138  |  valid_loss: 0.869
# [epoch: 2, i:  5749]  train_loss: 1.152  |  valid_loss: 0.850
# [epoch: 2, i:  5874]  train_loss: 1.008  |  valid_loss: 0.752
# [epoch: 2, i:  5999]  train_loss: 1.143  |  valid_loss: 0.840
# [epoch: 2, i:  6124]  train_loss: 1.176  |  valid_loss: 0.686
# [epoch: 2, i:  6249]  train_loss: 1.141  |  valid_loss: 0.935
# [epoch: 2, i:  6374]  train_loss: 1.183  |  valid_loss: 0.824
# [epoch: 2, i:  6499]  train_loss: 1.076  |  valid_loss: 0.873
# [epoch: 2, i:  6624]  train_loss: 1.161  |  valid_loss: 0.793
# [epoch: 2, i:  6749]  train_loss: 1.137  |  valid_loss: 0.932
# [epoch: 2, i:  6874]  train_loss: 1.145  |  valid_loss: 0.839
# [epoch: 2, i:  6999]  train_loss: 1.068  |  valid_loss: 0.963
# [epoch: 2, i:  7124]  train_loss: 1.148  |  valid_loss: 0.905
# [epoch: 2, i:  7249]  train_loss: 0.955  |  valid_loss: 0.723
# [epoch: 2, i:  7374]  train_loss: 1.165  |  valid_loss: 0.985
# [epoch: 2, i:  7499]  train_loss: 1.172  |  valid_loss: 0.940
# [epoch: 2, i:  7624]  train_loss: 1.078  |  valid_loss: 0.905
# [epoch: 2, i:  7749]  train_loss: 1.090  |  valid_loss: 0.880
# [epoch: 2, i:  7874]  train_loss: 1.103  |  valid_loss: 0.781
# [epoch: 2, i:  7999]  train_loss: 1.156  |  valid_loss: 0.743
# [epoch: 2, i:  8124]  train_loss: 1.057  |  valid_loss: 0.812
# [epoch: 2, i:  8249]  train_loss: 1.081  |  valid_loss: 1.047
# [epoch: 2, i:  8374]  train_loss: 1.168  |  valid_loss: 0.776
# [epoch: 2, i:  8499]  train_loss: 1.137  |  valid_loss: 0.919
# [epoch: 2, i:  8624]  train_loss: 1.125  |  valid_loss: 0.874
# [epoch: 2, i:  8749]  train_loss: 1.100  |  valid_loss: 0.969
# [epoch: 2, i:  8874]  train_loss: 1.110  |  valid_loss: 0.798
# [epoch: 2, i:  8999]  train_loss: 1.018  |  valid_loss: 0.779
# [epoch: 2, i:  9124]  train_loss: 1.068  |  valid_loss: 0.812
# [epoch: 2, i:  9249]  train_loss: 1.115  |  valid_loss: 0.699
# [epoch: 2, i:  9374]  train_loss: 1.173  |  valid_loss: 0.850
# [epoch: 2, i:  9499]  train_loss: 1.134  |  valid_loss: 0.749
# [epoch: 2, i:  9624]  train_loss: 1.032  |  valid_loss: 1.007
# [epoch: 2, i:  9749]  train_loss: 1.116  |  valid_loss: 0.788
# [epoch: 2, i:  9874]  train_loss: 1.158  |  valid_loss: 0.923
# [epoch: 2, i:  9999]  train_loss: 1.161  |  valid_loss: 1.009
# [epoch: 2, i: 10124]  train_loss: 1.148  |  valid_loss: 0.684
# [epoch: 2, i: 10249]  train_loss: 1.116  |  valid_loss: 0.858
# [epoch: 2, i: 10374]  train_loss: 1.093  |  valid_loss: 0.915
# [epoch: 2, i: 10499]  train_loss: 1.181  |  valid_loss: 0.904
# [epoch: 2, i: 10624]  train_loss: 1.145  |  valid_loss: 0.926
# [epoch: 2, i: 10749]  train_loss: 1.099  |  valid_loss: 0.701
# [epoch: 2, i: 10874]  train_loss: 1.076  |  valid_loss: 0.934
# [epoch: 2, i: 10999]  train_loss: 1.109  |  valid_loss: 0.918
# [epoch: 2, i: 11124]  train_loss: 1.111  |  valid_loss: 0.862
# [epoch: 2, i: 11249]  train_loss: 1.018  |  valid_loss: 0.889
# [epoch: 2, i: 11374]  train_loss: 1.160  |  valid_loss: 0.819
# [epoch: 2, i: 11499]  train_loss: 1.129  |  valid_loss: 0.600
# [epoch: 2, i: 11624]  train_loss: 1.102  |  valid_loss: 0.975
# [epoch: 2, i: 11749]  train_loss: 1.158  |  valid_loss: 0.854
# [epoch: 2, i: 11874]  train_loss: 1.089  |  valid_loss: 0.808
# [epoch: 2, i: 11999]  train_loss: 1.072  |  valid_loss: 0.742
# [epoch: 2, i: 12124]  train_loss: 1.120  |  valid_loss: 0.766
# [epoch: 2, i: 12249]  train_loss: 1.114  |  valid_loss: 1.033
# [epoch: 2, i: 12374]  train_loss: 1.094  |  valid_loss: 0.941
# [epoch: 2, i: 12499]  train_loss: 1.149  |  valid_loss: 0.837
# --> [End of epoch 2] train_accuracy: 61.94%  |  valid_accuracy: 70.42%
# --> [Start of epoch 3]  lr: 0.000343
# [epoch: 3, i:   124]  train_loss: 0.979  |  valid_loss: 0.762
# [epoch: 3, i:   249]  train_loss: 1.060  |  valid_loss: 0.769
# [epoch: 3, i:   374]  train_loss: 1.127  |  valid_loss: 0.823
# [epoch: 3, i:   499]  train_loss: 1.101  |  valid_loss: 0.807
# [epoch: 3, i:   624]  train_loss: 1.039  |  valid_loss: 0.881
# [epoch: 3, i:   749]  train_loss: 1.112  |  valid_loss: 0.686
# [epoch: 3, i:   874]  train_loss: 1.090  |  valid_loss: 0.847
# [epoch: 3, i:   999]  train_loss: 0.960  |  valid_loss: 0.867
# [epoch: 3, i:  1124]  train_loss: 1.007  |  valid_loss: 0.880
# [epoch: 3, i:  1249]  train_loss: 0.946  |  valid_loss: 0.696
# [epoch: 3, i:  1374]  train_loss: 1.076  |  valid_loss: 0.674
# [epoch: 3, i:  1499]  train_loss: 1.052  |  valid_loss: 0.833
# [epoch: 3, i:  1624]  train_loss: 1.066  |  valid_loss: 0.828
# [epoch: 3, i:  1749]  train_loss: 1.089  |  valid_loss: 0.848
# [epoch: 3, i:  1874]  train_loss: 1.044  |  valid_loss: 0.704
# [epoch: 3, i:  1999]  train_loss: 1.103  |  valid_loss: 1.021
# [epoch: 3, i:  2124]  train_loss: 1.105  |  valid_loss: 0.779
# [epoch: 3, i:  2249]  train_loss: 1.049  |  valid_loss: 0.748
# [epoch: 3, i:  2374]  train_loss: 1.139  |  valid_loss: 0.705
# [epoch: 3, i:  2499]  train_loss: 1.051  |  valid_loss: 0.952
# [epoch: 3, i:  2624]  train_loss: 0.983  |  valid_loss: 0.827
# [epoch: 3, i:  2749]  train_loss: 1.118  |  valid_loss: 0.856
# [epoch: 3, i:  2874]  train_loss: 1.131  |  valid_loss: 0.840
# [epoch: 3, i:  2999]  train_loss: 1.074  |  valid_loss: 0.795
# [epoch: 3, i:  3124]  train_loss: 1.046  |  valid_loss: 0.755
# [epoch: 3, i:  3249]  train_loss: 1.122  |  valid_loss: 1.056
# [epoch: 3, i:  3374]  train_loss: 1.008  |  valid_loss: 0.761
# [epoch: 3, i:  3499]  train_loss: 1.017  |  valid_loss: 0.832
# [epoch: 3, i:  3624]  train_loss: 1.051  |  valid_loss: 0.739
# [epoch: 3, i:  3749]  train_loss: 0.958  |  valid_loss: 0.797
# [epoch: 3, i:  3874]  train_loss: 1.063  |  valid_loss: 0.730
# [epoch: 3, i:  3999]  train_loss: 0.967  |  valid_loss: 0.766
# [epoch: 3, i:  4124]  train_loss: 1.051  |  valid_loss: 0.845
# [epoch: 3, i:  4249]  train_loss: 1.036  |  valid_loss: 0.952
# [epoch: 3, i:  4374]  train_loss: 1.118  |  valid_loss: 0.878
# [epoch: 3, i:  4499]  train_loss: 1.028  |  valid_loss: 0.833
# [epoch: 3, i:  4624]  train_loss: 1.075  |  valid_loss: 1.001
# [epoch: 3, i:  4749]  train_loss: 1.078  |  valid_loss: 0.939
# [epoch: 3, i:  4874]  train_loss: 1.097  |  valid_loss: 0.724
# [epoch: 3, i:  4999]  train_loss: 1.080  |  valid_loss: 0.779
# [epoch: 3, i:  5124]  train_loss: 1.176  |  valid_loss: 0.778
# [epoch: 3, i:  5249]  train_loss: 1.094  |  valid_loss: 0.808
# [epoch: 3, i:  5374]  train_loss: 1.083  |  valid_loss: 0.745
# [epoch: 3, i:  5499]  train_loss: 1.087  |  valid_loss: 0.778
# [epoch: 3, i:  5624]  train_loss: 1.161  |  valid_loss: 0.859
# [epoch: 3, i:  5749]  train_loss: 1.065  |  valid_loss: 0.795
# [epoch: 3, i:  5874]  train_loss: 1.022  |  valid_loss: 0.721
# [epoch: 3, i:  5999]  train_loss: 1.021  |  valid_loss: 0.775
# [epoch: 3, i:  6124]  train_loss: 1.191  |  valid_loss: 0.711
# [epoch: 3, i:  6249]  train_loss: 1.050  |  valid_loss: 0.939
# [epoch: 3, i:  6374]  train_loss: 1.071  |  valid_loss: 0.760
# [epoch: 3, i:  6499]  train_loss: 1.058  |  valid_loss: 0.788
# [epoch: 3, i:  6624]  train_loss: 1.054  |  valid_loss: 0.781
# [epoch: 3, i:  6749]  train_loss: 1.070  |  valid_loss: 0.900
# [epoch: 3, i:  6874]  train_loss: 0.957  |  valid_loss: 0.763
# [epoch: 3, i:  6999]  train_loss: 1.020  |  valid_loss: 0.891
# [epoch: 3, i:  7124]  train_loss: 0.949  |  valid_loss: 0.862
# [epoch: 3, i:  7249]  train_loss: 1.067  |  valid_loss: 0.699
# [epoch: 3, i:  7374]  train_loss: 1.002  |  valid_loss: 0.912
# [epoch: 3, i:  7499]  train_loss: 1.031  |  valid_loss: 0.899
# [epoch: 3, i:  7624]  train_loss: 1.098  |  valid_loss: 0.811
# [epoch: 3, i:  7749]  train_loss: 1.027  |  valid_loss: 0.836
# [epoch: 3, i:  7874]  train_loss: 1.066  |  valid_loss: 0.745
# [epoch: 3, i:  7999]  train_loss: 0.963  |  valid_loss: 0.704
# [epoch: 3, i:  8124]  train_loss: 1.001  |  valid_loss: 0.791
# [epoch: 3, i:  8249]  train_loss: 1.081  |  valid_loss: 0.960
# [epoch: 3, i:  8374]  train_loss: 1.082  |  valid_loss: 0.705
# [epoch: 3, i:  8499]  train_loss: 1.051  |  valid_loss: 0.868
# [epoch: 3, i:  8624]  train_loss: 0.965  |  valid_loss: 0.779
# [epoch: 3, i:  8749]  train_loss: 1.044  |  valid_loss: 0.969
# [epoch: 3, i:  8874]  train_loss: 1.027  |  valid_loss: 0.786
# [epoch: 3, i:  8999]  train_loss: 1.069  |  valid_loss: 0.738
# [epoch: 3, i:  9124]  train_loss: 1.032  |  valid_loss: 0.903
# [epoch: 3, i:  9249]  train_loss: 0.981  |  valid_loss: 0.666
# [epoch: 3, i:  9374]  train_loss: 0.974  |  valid_loss: 0.790
# [epoch: 3, i:  9499]  train_loss: 0.992  |  valid_loss: 0.724
# [epoch: 3, i:  9624]  train_loss: 0.978  |  valid_loss: 0.842
# [epoch: 3, i:  9749]  train_loss: 1.007  |  valid_loss: 0.762
# [epoch: 3, i:  9874]  train_loss: 1.034  |  valid_loss: 0.875
# [epoch: 3, i:  9999]  train_loss: 1.066  |  valid_loss: 0.931
# [epoch: 3, i: 10124]  train_loss: 1.070  |  valid_loss: 0.620
# [epoch: 3, i: 10249]  train_loss: 0.991  |  valid_loss: 0.846
# [epoch: 3, i: 10374]  train_loss: 1.033  |  valid_loss: 0.793
# [epoch: 3, i: 10499]  train_loss: 1.141  |  valid_loss: 0.853
# [epoch: 3, i: 10624]  train_loss: 1.008  |  valid_loss: 0.906
# [epoch: 3, i: 10749]  train_loss: 0.993  |  valid_loss: 0.686
# [epoch: 3, i: 10874]  train_loss: 1.121  |  valid_loss: 0.852
# [epoch: 3, i: 10999]  train_loss: 1.080  |  valid_loss: 0.877
# [epoch: 3, i: 11124]  train_loss: 1.056  |  valid_loss: 0.869
# [epoch: 3, i: 11249]  train_loss: 1.113  |  valid_loss: 0.871
# [epoch: 3, i: 11374]  train_loss: 0.975  |  valid_loss: 0.785
# [epoch: 3, i: 11499]  train_loss: 1.094  |  valid_loss: 0.581
# [epoch: 3, i: 11624]  train_loss: 1.011  |  valid_loss: 0.986
# [epoch: 3, i: 11749]  train_loss: 1.089  |  valid_loss: 0.830
# [epoch: 3, i: 11874]  train_loss: 1.021  |  valid_loss: 0.798
# [epoch: 3, i: 11999]  train_loss: 1.037  |  valid_loss: 0.629
# [epoch: 3, i: 12124]  train_loss: 0.948  |  valid_loss: 0.738
# [epoch: 3, i: 12249]  train_loss: 1.105  |  valid_loss: 0.985
# [epoch: 3, i: 12374]  train_loss: 1.023  |  valid_loss: 0.898
# [epoch: 3, i: 12499]  train_loss: 1.039  |  valid_loss: 0.740
# --> [End of epoch 3] train_accuracy: 64.69%  |  valid_accuracy: 72.06%
# --> [Start of epoch 4]  lr: 0.000240
# [epoch: 4, i:   124]  train_loss: 1.049  |  valid_loss: 0.704
# [epoch: 4, i:   249]  train_loss: 0.970  |  valid_loss: 0.715
# [epoch: 4, i:   374]  train_loss: 0.966  |  valid_loss: 0.846
# [epoch: 4, i:   499]  train_loss: 1.077  |  valid_loss: 0.729
# [epoch: 4, i:   624]  train_loss: 1.035  |  valid_loss: 0.826
# [epoch: 4, i:   749]  train_loss: 0.911  |  valid_loss: 0.659
# [epoch: 4, i:   874]  train_loss: 1.099  |  valid_loss: 0.741
# [epoch: 4, i:   999]  train_loss: 1.041  |  valid_loss: 0.864
# [epoch: 4, i:  1124]  train_loss: 0.988  |  valid_loss: 0.946
# [epoch: 4, i:  1249]  train_loss: 0.998  |  valid_loss: 0.655
# [epoch: 4, i:  1374]  train_loss: 0.926  |  valid_loss: 0.657
# [epoch: 4, i:  1499]  train_loss: 0.931  |  valid_loss: 0.844
# [epoch: 4, i:  1624]  train_loss: 1.003  |  valid_loss: 0.803
# [epoch: 4, i:  1749]  train_loss: 0.920  |  valid_loss: 0.799
# [epoch: 4, i:  1874]  train_loss: 0.995  |  valid_loss: 0.594
# [epoch: 4, i:  1999]  train_loss: 1.006  |  valid_loss: 0.943
# [epoch: 4, i:  2124]  train_loss: 1.022  |  valid_loss: 0.731
# [epoch: 4, i:  2249]  train_loss: 1.073  |  valid_loss: 0.763
# [epoch: 4, i:  2374]  train_loss: 0.945  |  valid_loss: 0.718
# [epoch: 4, i:  2499]  train_loss: 1.036  |  valid_loss: 0.947
# [epoch: 4, i:  2624]  train_loss: 1.031  |  valid_loss: 0.837
# [epoch: 4, i:  2749]  train_loss: 0.970  |  valid_loss: 0.837
# [epoch: 4, i:  2874]  train_loss: 0.938  |  valid_loss: 0.772
# [epoch: 4, i:  2999]  train_loss: 1.003  |  valid_loss: 0.838
# [epoch: 4, i:  3124]  train_loss: 1.016  |  valid_loss: 0.728
# [epoch: 4, i:  3249]  train_loss: 0.959  |  valid_loss: 1.036
# [epoch: 4, i:  3374]  train_loss: 0.966  |  valid_loss: 0.739
# [epoch: 4, i:  3499]  train_loss: 1.091  |  valid_loss: 0.810
# [epoch: 4, i:  3624]  train_loss: 0.995  |  valid_loss: 0.742
# [epoch: 4, i:  3749]  train_loss: 1.014  |  valid_loss: 0.744
# [epoch: 4, i:  3874]  train_loss: 0.962  |  valid_loss: 0.726
# [epoch: 4, i:  3999]  train_loss: 1.006  |  valid_loss: 0.707
# [epoch: 4, i:  4124]  train_loss: 1.044  |  valid_loss: 0.746
# [epoch: 4, i:  4249]  train_loss: 0.870  |  valid_loss: 0.882
# [epoch: 4, i:  4374]  train_loss: 1.036  |  valid_loss: 0.867
# [epoch: 4, i:  4499]  train_loss: 0.987  |  valid_loss: 0.825
# [epoch: 4, i:  4624]  train_loss: 0.997  |  valid_loss: 0.976
# [epoch: 4, i:  4749]  train_loss: 1.109  |  valid_loss: 0.947
# [epoch: 4, i:  4874]  train_loss: 1.015  |  valid_loss: 0.688
# [epoch: 4, i:  4999]  train_loss: 0.943  |  valid_loss: 0.667
# [epoch: 4, i:  5124]  train_loss: 0.986  |  valid_loss: 0.713
# [epoch: 4, i:  5249]  train_loss: 1.075  |  valid_loss: 0.766
# [epoch: 4, i:  5374]  train_loss: 1.061  |  valid_loss: 0.732
# [epoch: 4, i:  5499]  train_loss: 1.033  |  valid_loss: 0.736
# [epoch: 4, i:  5624]  train_loss: 1.008  |  valid_loss: 0.836
# [epoch: 4, i:  5749]  train_loss: 1.019  |  valid_loss: 0.767
# [epoch: 4, i:  5874]  train_loss: 1.028  |  valid_loss: 0.669
# [epoch: 4, i:  5999]  train_loss: 0.997  |  valid_loss: 0.726
# [epoch: 4, i:  6124]  train_loss: 0.993  |  valid_loss: 0.657
# [epoch: 4, i:  6249]  train_loss: 1.058  |  valid_loss: 0.874
# [epoch: 4, i:  6374]  train_loss: 1.058  |  valid_loss: 0.777
# [epoch: 4, i:  6499]  train_loss: 1.040  |  valid_loss: 0.806
# [epoch: 4, i:  6624]  train_loss: 0.985  |  valid_loss: 0.731
# [epoch: 4, i:  6749]  train_loss: 0.965  |  valid_loss: 0.897
# [epoch: 4, i:  6874]  train_loss: 1.070  |  valid_loss: 0.764
# [epoch: 4, i:  6999]  train_loss: 1.007  |  valid_loss: 0.832
# [epoch: 4, i:  7124]  train_loss: 1.092  |  valid_loss: 0.848
# [epoch: 4, i:  7249]  train_loss: 1.021  |  valid_loss: 0.613
# [epoch: 4, i:  7374]  train_loss: 1.036  |  valid_loss: 0.907
# [epoch: 4, i:  7499]  train_loss: 1.021  |  valid_loss: 0.871
# [epoch: 4, i:  7624]  train_loss: 0.975  |  valid_loss: 0.800
# [epoch: 4, i:  7749]  train_loss: 0.997  |  valid_loss: 0.820
# [epoch: 4, i:  7874]  train_loss: 0.957  |  valid_loss: 0.649
# [epoch: 4, i:  7999]  train_loss: 1.023  |  valid_loss: 0.704
# [epoch: 4, i:  8124]  train_loss: 1.047  |  valid_loss: 0.759
# [epoch: 4, i:  8249]  train_loss: 1.073  |  valid_loss: 0.932
# [epoch: 4, i:  8374]  train_loss: 0.968  |  valid_loss: 0.756
# [epoch: 4, i:  8499]  train_loss: 0.978  |  valid_loss: 0.816
# [epoch: 4, i:  8624]  train_loss: 1.076  |  valid_loss: 0.747
# [epoch: 4, i:  8749]  train_loss: 0.997  |  valid_loss: 0.944
# [epoch: 4, i:  8874]  train_loss: 1.012  |  valid_loss: 0.707
# [epoch: 4, i:  8999]  train_loss: 1.139  |  valid_loss: 0.721
# [epoch: 4, i:  9124]  train_loss: 0.939  |  valid_loss: 0.806
# [epoch: 4, i:  9249]  train_loss: 1.021  |  valid_loss: 0.703
# [epoch: 4, i:  9374]  train_loss: 1.055  |  valid_loss: 0.739
# [epoch: 4, i:  9499]  train_loss: 0.922  |  valid_loss: 0.701
# [epoch: 4, i:  9624]  train_loss: 0.947  |  valid_loss: 0.862
# [epoch: 4, i:  9749]  train_loss: 1.030  |  valid_loss: 0.675
# [epoch: 4, i:  9874]  train_loss: 1.042  |  valid_loss: 0.909
# [epoch: 4, i:  9999]  train_loss: 1.022  |  valid_loss: 0.947
# [epoch: 4, i: 10124]  train_loss: 1.063  |  valid_loss: 0.648
# [epoch: 4, i: 10249]  train_loss: 1.086  |  valid_loss: 0.788
# [epoch: 4, i: 10374]  train_loss: 0.981  |  valid_loss: 0.811
# [epoch: 4, i: 10499]  train_loss: 1.039  |  valid_loss: 0.835
# [epoch: 4, i: 10624]  train_loss: 1.000  |  valid_loss: 0.857
# [epoch: 4, i: 10749]  train_loss: 1.010  |  valid_loss: 0.728
# [epoch: 4, i: 10874]  train_loss: 0.950  |  valid_loss: 0.849
# [epoch: 4, i: 10999]  train_loss: 1.073  |  valid_loss: 0.845
# [epoch: 4, i: 11124]  train_loss: 0.899  |  valid_loss: 0.854
# [epoch: 4, i: 11249]  train_loss: 0.960  |  valid_loss: 0.805
# [epoch: 4, i: 11374]  train_loss: 1.035  |  valid_loss: 0.716
# [epoch: 4, i: 11499]  train_loss: 0.969  |  valid_loss: 0.539
# [epoch: 4, i: 11624]  train_loss: 1.132  |  valid_loss: 0.844
# [epoch: 4, i: 11749]  train_loss: 1.014  |  valid_loss: 0.861
# [epoch: 4, i: 11874]  train_loss: 0.974  |  valid_loss: 0.778
# [epoch: 4, i: 11999]  train_loss: 1.053  |  valid_loss: 0.633
# [epoch: 4, i: 12124]  train_loss: 1.013  |  valid_loss: 0.693
# [epoch: 4, i: 12249]  train_loss: 1.020  |  valid_loss: 1.002
# [epoch: 4, i: 12374]  train_loss: 1.019  |  valid_loss: 0.849
# [epoch: 4, i: 12499]  train_loss: 1.048  |  valid_loss: 0.679
# --> [End of epoch 4] train_accuracy: 66.25%  |  valid_accuracy: 73.18%
# --> [Start of epoch 5]  lr: 0.000168
# [epoch: 5, i:   124]  train_loss: 1.031  |  valid_loss: 0.659
# [epoch: 5, i:   249]  train_loss: 0.970  |  valid_loss: 0.710
# [epoch: 5, i:   374]  train_loss: 1.051  |  valid_loss: 0.800
# [epoch: 5, i:   499]  train_loss: 0.965  |  valid_loss: 0.713
# [epoch: 5, i:   624]  train_loss: 0.935  |  valid_loss: 0.799
# [epoch: 5, i:   749]  train_loss: 1.056  |  valid_loss: 0.654
# [epoch: 5, i:   874]  train_loss: 0.916  |  valid_loss: 0.802
# [epoch: 5, i:   999]  train_loss: 0.906  |  valid_loss: 0.818
# [epoch: 5, i:  1124]  train_loss: 0.975  |  valid_loss: 0.892
# [epoch: 5, i:  1249]  train_loss: 0.897  |  valid_loss: 0.649
# [epoch: 5, i:  1374]  train_loss: 0.966  |  valid_loss: 0.660
# [epoch: 5, i:  1499]  train_loss: 1.030  |  valid_loss: 0.768
# [epoch: 5, i:  1624]  train_loss: 1.032  |  valid_loss: 0.816
# [epoch: 5, i:  1749]  train_loss: 0.981  |  valid_loss: 0.800
# [epoch: 5, i:  1874]  train_loss: 1.007  |  valid_loss: 0.619
# [epoch: 5, i:  1999]  train_loss: 0.932  |  valid_loss: 0.898
# [epoch: 5, i:  2124]  train_loss: 0.952  |  valid_loss: 0.704
# [epoch: 5, i:  2249]  train_loss: 0.820  |  valid_loss: 0.753
# [epoch: 5, i:  2374]  train_loss: 0.972  |  valid_loss: 0.688
# [epoch: 5, i:  2499]  train_loss: 0.985  |  valid_loss: 0.965
# [epoch: 5, i:  2624]  train_loss: 0.911  |  valid_loss: 0.858
# [epoch: 5, i:  2749]  train_loss: 1.052  |  valid_loss: 0.776
# [epoch: 5, i:  2874]  train_loss: 1.034  |  valid_loss: 0.793
# [epoch: 5, i:  2999]  train_loss: 0.812  |  valid_loss: 0.785
# [epoch: 5, i:  3124]  train_loss: 0.955  |  valid_loss: 0.712
# [epoch: 5, i:  3249]  train_loss: 0.992  |  valid_loss: 0.988
# [epoch: 5, i:  3374]  train_loss: 0.965  |  valid_loss: 0.698
# [epoch: 5, i:  3499]  train_loss: 1.000  |  valid_loss: 0.779
# [epoch: 5, i:  3624]  train_loss: 0.999  |  valid_loss: 0.714
# [epoch: 5, i:  3749]  train_loss: 1.026  |  valid_loss: 0.764
# [epoch: 5, i:  3874]  train_loss: 0.990  |  valid_loss: 0.691
# [epoch: 5, i:  3999]  train_loss: 1.021  |  valid_loss: 0.723
# [epoch: 5, i:  4124]  train_loss: 1.036  |  valid_loss: 0.733
# [epoch: 5, i:  4249]  train_loss: 0.980  |  valid_loss: 0.857
# [epoch: 5, i:  4374]  train_loss: 0.954  |  valid_loss: 0.755
# [epoch: 5, i:  4499]  train_loss: 0.974  |  valid_loss: 0.811
# [epoch: 5, i:  4624]  train_loss: 0.851  |  valid_loss: 0.969
# [epoch: 5, i:  4749]  train_loss: 1.026  |  valid_loss: 0.960
# [epoch: 5, i:  4874]  train_loss: 0.900  |  valid_loss: 0.643
# [epoch: 5, i:  4999]  train_loss: 0.984  |  valid_loss: 0.640
# [epoch: 5, i:  5124]  train_loss: 0.958  |  valid_loss: 0.693
# [epoch: 5, i:  5249]  train_loss: 0.979  |  valid_loss: 0.751
# [epoch: 5, i:  5374]  train_loss: 0.966  |  valid_loss: 0.691
# [epoch: 5, i:  5499]  train_loss: 0.899  |  valid_loss: 0.713
# [epoch: 5, i:  5624]  train_loss: 0.945  |  valid_loss: 0.805
# [epoch: 5, i:  5749]  train_loss: 0.940  |  valid_loss: 0.781
# [epoch: 5, i:  5874]  train_loss: 0.884  |  valid_loss: 0.687
# [epoch: 5, i:  5999]  train_loss: 1.026  |  valid_loss: 0.697
# [epoch: 5, i:  6124]  train_loss: 0.911  |  valid_loss: 0.667
# [epoch: 5, i:  6249]  train_loss: 0.914  |  valid_loss: 0.850
# [epoch: 5, i:  6374]  train_loss: 1.018  |  valid_loss: 0.707
# [epoch: 5, i:  6499]  train_loss: 0.928  |  valid_loss: 0.761
# [epoch: 5, i:  6624]  train_loss: 0.854  |  valid_loss: 0.757
# [epoch: 5, i:  6749]  train_loss: 0.996  |  valid_loss: 0.853
# [epoch: 5, i:  6874]  train_loss: 0.953  |  valid_loss: 0.724
# [epoch: 5, i:  6999]  train_loss: 1.168  |  valid_loss: 0.856
# [epoch: 5, i:  7124]  train_loss: 0.995  |  valid_loss: 0.797
# [epoch: 5, i:  7249]  train_loss: 0.879  |  valid_loss: 0.609
# [epoch: 5, i:  7374]  train_loss: 0.996  |  valid_loss: 0.883
# [epoch: 5, i:  7499]  train_loss: 0.999  |  valid_loss: 0.808
# [epoch: 5, i:  7624]  train_loss: 0.973  |  valid_loss: 0.805
# [epoch: 5, i:  7749]  train_loss: 0.995  |  valid_loss: 0.804
# [epoch: 5, i:  7874]  train_loss: 0.911  |  valid_loss: 0.658
# [epoch: 5, i:  7999]  train_loss: 1.058  |  valid_loss: 0.648
# [epoch: 5, i:  8124]  train_loss: 1.021  |  valid_loss: 0.757
# [epoch: 5, i:  8249]  train_loss: 0.897  |  valid_loss: 0.848
# [epoch: 5, i:  8374]  train_loss: 0.895  |  valid_loss: 0.774
# [epoch: 5, i:  8499]  train_loss: 1.002  |  valid_loss: 0.792
# [epoch: 5, i:  8624]  train_loss: 0.867  |  valid_loss: 0.784
# [epoch: 5, i:  8749]  train_loss: 0.943  |  valid_loss: 0.911
# [epoch: 5, i:  8874]  train_loss: 0.993  |  valid_loss: 0.756
# [epoch: 5, i:  8999]  train_loss: 0.934  |  valid_loss: 0.686
# [epoch: 5, i:  9124]  train_loss: 1.033  |  valid_loss: 0.752
# [epoch: 5, i:  9249]  train_loss: 0.959  |  valid_loss: 0.678
# [epoch: 5, i:  9374]  train_loss: 0.967  |  valid_loss: 0.693
# [epoch: 5, i:  9499]  train_loss: 1.056  |  valid_loss: 0.691
# [epoch: 5, i:  9624]  train_loss: 1.089  |  valid_loss: 0.845
# [epoch: 5, i:  9749]  train_loss: 1.011  |  valid_loss: 0.662
# [epoch: 5, i:  9874]  train_loss: 0.987  |  valid_loss: 0.859
# [epoch: 5, i:  9999]  train_loss: 1.032  |  valid_loss: 0.907
# [epoch: 5, i: 10124]  train_loss: 0.969  |  valid_loss: 0.601
# [epoch: 5, i: 10249]  train_loss: 0.992  |  valid_loss: 0.798
# [epoch: 5, i: 10374]  train_loss: 0.994  |  valid_loss: 0.750
# [epoch: 5, i: 10499]  train_loss: 0.941  |  valid_loss: 0.833
# [epoch: 5, i: 10624]  train_loss: 0.932  |  valid_loss: 0.882
# [epoch: 5, i: 10749]  train_loss: 1.035  |  valid_loss: 0.664
# [epoch: 5, i: 10874]  train_loss: 0.905  |  valid_loss: 0.795
# [epoch: 5, i: 10999]  train_loss: 1.056  |  valid_loss: 0.790
# [epoch: 5, i: 11124]  train_loss: 0.997  |  valid_loss: 0.804
# [epoch: 5, i: 11249]  train_loss: 0.996  |  valid_loss: 0.803
# [epoch: 5, i: 11374]  train_loss: 1.003  |  valid_loss: 0.710
# [epoch: 5, i: 11499]  train_loss: 0.894  |  valid_loss: 0.506
# [epoch: 5, i: 11624]  train_loss: 0.951  |  valid_loss: 0.898
# [epoch: 5, i: 11749]  train_loss: 1.102  |  valid_loss: 0.829
# [epoch: 5, i: 11874]  train_loss: 0.934  |  valid_loss: 0.785
# [epoch: 5, i: 11999]  train_loss: 0.947  |  valid_loss: 0.661
# [epoch: 5, i: 12124]  train_loss: 0.935  |  valid_loss: 0.636
# [epoch: 5, i: 12249]  train_loss: 0.917  |  valid_loss: 0.980
# [epoch: 5, i: 12374]  train_loss: 0.992  |  valid_loss: 0.863
# [epoch: 5, i: 12499]  train_loss: 1.070  |  valid_loss: 0.623
# --> [End of epoch 5] train_accuracy: 67.36%  |  valid_accuracy: 73.43%
# --> [Start of epoch 6]  lr: 0.000118
# [epoch: 6, i:   124]  train_loss: 0.958  |  valid_loss: 0.623
# [epoch: 6, i:   249]  train_loss: 0.948  |  valid_loss: 0.698
# [epoch: 6, i:   374]  train_loss: 0.943  |  valid_loss: 0.769
# [epoch: 6, i:   499]  train_loss: 0.999  |  valid_loss: 0.775
# [epoch: 6, i:   624]  train_loss: 0.912  |  valid_loss: 0.753
# [epoch: 6, i:   749]  train_loss: 1.100  |  valid_loss: 0.603
# [epoch: 6, i:   874]  train_loss: 0.935  |  valid_loss: 0.812
# [epoch: 6, i:   999]  train_loss: 0.938  |  valid_loss: 0.772
# [epoch: 6, i:  1124]  train_loss: 0.940  |  valid_loss: 0.940
# [epoch: 6, i:  1249]  train_loss: 0.878  |  valid_loss: 0.602
# [epoch: 6, i:  1374]  train_loss: 0.879  |  valid_loss: 0.591
# [epoch: 6, i:  1499]  train_loss: 0.882  |  valid_loss: 0.739
# [epoch: 6, i:  1624]  train_loss: 0.848  |  valid_loss: 0.766
# [epoch: 6, i:  1749]  train_loss: 0.947  |  valid_loss: 0.802
# [epoch: 6, i:  1874]  train_loss: 0.977  |  valid_loss: 0.585
# [epoch: 6, i:  1999]  train_loss: 1.009  |  valid_loss: 0.873
# [epoch: 6, i:  2124]  train_loss: 0.943  |  valid_loss: 0.648
# [epoch: 6, i:  2249]  train_loss: 0.924  |  valid_loss: 0.691
# [epoch: 6, i:  2374]  train_loss: 0.959  |  valid_loss: 0.671
# [epoch: 6, i:  2499]  train_loss: 0.924  |  valid_loss: 0.911
# [epoch: 6, i:  2624]  train_loss: 1.004  |  valid_loss: 0.812
# [epoch: 6, i:  2749]  train_loss: 0.917  |  valid_loss: 0.780
# [epoch: 6, i:  2874]  train_loss: 0.957  |  valid_loss: 0.721
# [epoch: 6, i:  2999]  train_loss: 0.944  |  valid_loss: 0.793
# [epoch: 6, i:  3124]  train_loss: 0.933  |  valid_loss: 0.693
# [epoch: 6, i:  3249]  train_loss: 1.008  |  valid_loss: 0.974
# [epoch: 6, i:  3374]  train_loss: 0.928  |  valid_loss: 0.679
# [epoch: 6, i:  3499]  train_loss: 0.988  |  valid_loss: 0.745
# [epoch: 6, i:  3624]  train_loss: 0.907  |  valid_loss: 0.744
# [epoch: 6, i:  3749]  train_loss: 0.879  |  valid_loss: 0.753
# [epoch: 6, i:  3874]  train_loss: 1.042  |  valid_loss: 0.752
# [epoch: 6, i:  3999]  train_loss: 0.910  |  valid_loss: 0.672
# [epoch: 6, i:  4124]  train_loss: 0.938  |  valid_loss: 0.772
# [epoch: 6, i:  4249]  train_loss: 0.924  |  valid_loss: 0.838
# [epoch: 6, i:  4374]  train_loss: 0.995  |  valid_loss: 0.763
# [epoch: 6, i:  4499]  train_loss: 0.958  |  valid_loss: 0.796
# [epoch: 6, i:  4624]  train_loss: 1.023  |  valid_loss: 0.952
# [epoch: 6, i:  4749]  train_loss: 0.917  |  valid_loss: 0.876
# [epoch: 6, i:  4874]  train_loss: 0.871  |  valid_loss: 0.682
# [epoch: 6, i:  4999]  train_loss: 0.915  |  valid_loss: 0.751
# [epoch: 6, i:  5124]  train_loss: 0.977  |  valid_loss: 0.680
# [epoch: 6, i:  5249]  train_loss: 0.937  |  valid_loss: 0.769
# [epoch: 6, i:  5374]  train_loss: 0.939  |  valid_loss: 0.708
# [epoch: 6, i:  5499]  train_loss: 1.013  |  valid_loss: 0.686
# [epoch: 6, i:  5624]  train_loss: 0.912  |  valid_loss: 0.732
# [epoch: 6, i:  5749]  train_loss: 0.991  |  valid_loss: 0.743
# [epoch: 6, i:  5874]  train_loss: 1.017  |  valid_loss: 0.688
# [epoch: 6, i:  5999]  train_loss: 0.864  |  valid_loss: 0.658
# [epoch: 6, i:  6124]  train_loss: 0.939  |  valid_loss: 0.643
# [epoch: 6, i:  6249]  train_loss: 0.954  |  valid_loss: 0.887
# [epoch: 6, i:  6374]  train_loss: 1.004  |  valid_loss: 0.711
# [epoch: 6, i:  6499]  train_loss: 0.910  |  valid_loss: 0.776
# [epoch: 6, i:  6624]  train_loss: 0.931  |  valid_loss: 0.732
# [epoch: 6, i:  6749]  train_loss: 0.953  |  valid_loss: 0.795
# [epoch: 6, i:  6874]  train_loss: 0.810  |  valid_loss: 0.735
# [epoch: 6, i:  6999]  train_loss: 0.960  |  valid_loss: 0.828
# [epoch: 6, i:  7124]  train_loss: 0.952  |  valid_loss: 0.757
# [epoch: 6, i:  7249]  train_loss: 0.947  |  valid_loss: 0.635
# [epoch: 6, i:  7374]  train_loss: 0.939  |  valid_loss: 0.814
# [epoch: 6, i:  7499]  train_loss: 0.935  |  valid_loss: 0.857
# [epoch: 6, i:  7624]  train_loss: 0.928  |  valid_loss: 0.762
# [epoch: 6, i:  7749]  train_loss: 0.918  |  valid_loss: 0.786
# [epoch: 6, i:  7874]  train_loss: 0.984  |  valid_loss: 0.594
# [epoch: 6, i:  7999]  train_loss: 1.001  |  valid_loss: 0.629
# [epoch: 6, i:  8124]  train_loss: 0.928  |  valid_loss: 0.727
# [epoch: 6, i:  8249]  train_loss: 0.867  |  valid_loss: 0.870
# [epoch: 6, i:  8374]  train_loss: 1.007  |  valid_loss: 0.725
# [epoch: 6, i:  8499]  train_loss: 0.904  |  valid_loss: 0.809
# [epoch: 6, i:  8624]  train_loss: 0.888  |  valid_loss: 0.738
# [epoch: 6, i:  8749]  train_loss: 0.941  |  valid_loss: 0.930
# [epoch: 6, i:  8874]  train_loss: 0.870  |  valid_loss: 0.683
# [epoch: 6, i:  8999]  train_loss: 0.934  |  valid_loss: 0.660
# [epoch: 6, i:  9124]  train_loss: 0.952  |  valid_loss: 0.746
# [epoch: 6, i:  9249]  train_loss: 0.931  |  valid_loss: 0.651
# [epoch: 6, i:  9374]  train_loss: 1.024  |  valid_loss: 0.707
# [epoch: 6, i:  9499]  train_loss: 0.988  |  valid_loss: 0.719
# [epoch: 6, i:  9624]  train_loss: 0.920  |  valid_loss: 0.810
# [epoch: 6, i:  9749]  train_loss: 0.921  |  valid_loss: 0.670
# [epoch: 6, i:  9874]  train_loss: 0.926  |  valid_loss: 0.827
# [epoch: 6, i:  9999]  train_loss: 0.916  |  valid_loss: 0.826
# [epoch: 6, i: 10124]  train_loss: 0.906  |  valid_loss: 0.591
# [epoch: 6, i: 10249]  train_loss: 0.967  |  valid_loss: 0.805
# [epoch: 6, i: 10374]  train_loss: 0.971  |  valid_loss: 0.759
# [epoch: 6, i: 10499]  train_loss: 0.964  |  valid_loss: 0.778
# [epoch: 6, i: 10624]  train_loss: 0.988  |  valid_loss: 0.827
# [epoch: 6, i: 10749]  train_loss: 1.004  |  valid_loss: 0.670
# [epoch: 6, i: 10874]  train_loss: 0.902  |  valid_loss: 0.747
# [epoch: 6, i: 10999]  train_loss: 1.026  |  valid_loss: 0.797
# [epoch: 6, i: 11124]  train_loss: 1.035  |  valid_loss: 0.751
# [epoch: 6, i: 11249]  train_loss: 0.941  |  valid_loss: 0.780
# [epoch: 6, i: 11374]  train_loss: 0.902  |  valid_loss: 0.708
# [epoch: 6, i: 11499]  train_loss: 0.944  |  valid_loss: 0.474
# [epoch: 6, i: 11624]  train_loss: 0.881  |  valid_loss: 0.890
# [epoch: 6, i: 11749]  train_loss: 0.978  |  valid_loss: 0.812
# [epoch: 6, i: 11874]  train_loss: 1.006  |  valid_loss: 0.740
# [epoch: 6, i: 11999]  train_loss: 0.879  |  valid_loss: 0.648
# [epoch: 6, i: 12124]  train_loss: 0.995  |  valid_loss: 0.605
# [epoch: 6, i: 12249]  train_loss: 0.949  |  valid_loss: 0.949
# [epoch: 6, i: 12374]  train_loss: 0.932  |  valid_loss: 0.830
# [epoch: 6, i: 12499]  train_loss: 0.948  |  valid_loss: 0.658
# --> [End of epoch 6] train_accuracy: 68.24%  |  valid_accuracy: 74.22%
# --> [Start of epoch 7]  lr: 0.000082
# [epoch: 7, i:   124]  train_loss: 0.955  |  valid_loss: 0.600
# [epoch: 7, i:   249]  train_loss: 0.923  |  valid_loss: 0.634
# [epoch: 7, i:   374]  train_loss: 0.839  |  valid_loss: 0.775
# [epoch: 7, i:   499]  train_loss: 0.958  |  valid_loss: 0.701
# [epoch: 7, i:   624]  train_loss: 0.917  |  valid_loss: 0.771
# [epoch: 7, i:   749]  train_loss: 0.924  |  valid_loss: 0.567
# [epoch: 7, i:   874]  train_loss: 0.928  |  valid_loss: 0.736
# [epoch: 7, i:   999]  train_loss: 0.993  |  valid_loss: 0.727
# [epoch: 7, i:  1124]  train_loss: 0.932  |  valid_loss: 0.929
# [epoch: 7, i:  1249]  train_loss: 0.889  |  valid_loss: 0.559
# [epoch: 7, i:  1374]  train_loss: 0.972  |  valid_loss: 0.587
# [epoch: 7, i:  1499]  train_loss: 0.932  |  valid_loss: 0.689
# [epoch: 7, i:  1624]  train_loss: 0.948  |  valid_loss: 0.748
# [epoch: 7, i:  1749]  train_loss: 0.872  |  valid_loss: 0.766
# [epoch: 7, i:  1874]  train_loss: 0.895  |  valid_loss: 0.592
# [epoch: 7, i:  1999]  train_loss: 1.007  |  valid_loss: 0.838
# [epoch: 7, i:  2124]  train_loss: 0.782  |  valid_loss: 0.640
# [epoch: 7, i:  2249]  train_loss: 0.945  |  valid_loss: 0.723
# [epoch: 7, i:  2374]  train_loss: 1.010  |  valid_loss: 0.661
# [epoch: 7, i:  2499]  train_loss: 0.971  |  valid_loss: 0.910
# [epoch: 7, i:  2624]  train_loss: 0.885  |  valid_loss: 0.800
# [epoch: 7, i:  2749]  train_loss: 0.904  |  valid_loss: 0.772
# [epoch: 7, i:  2874]  train_loss: 0.949  |  valid_loss: 0.762
# [epoch: 7, i:  2999]  train_loss: 0.844  |  valid_loss: 0.760
# [epoch: 7, i:  3124]  train_loss: 0.909  |  valid_loss: 0.621
# [epoch: 7, i:  3249]  train_loss: 1.003  |  valid_loss: 0.963
# [epoch: 7, i:  3374]  train_loss: 0.923  |  valid_loss: 0.653
# [epoch: 7, i:  3499]  train_loss: 0.909  |  valid_loss: 0.785
# [epoch: 7, i:  3624]  train_loss: 0.996  |  valid_loss: 0.716
# [epoch: 7, i:  3749]  train_loss: 0.925  |  valid_loss: 0.721
# [epoch: 7, i:  3874]  train_loss: 0.889  |  valid_loss: 0.710
# [epoch: 7, i:  3999]  train_loss: 0.906  |  valid_loss: 0.700
# [epoch: 7, i:  4124]  train_loss: 0.866  |  valid_loss: 0.753
# [epoch: 7, i:  4249]  train_loss: 0.972  |  valid_loss: 0.820
# [epoch: 7, i:  4374]  train_loss: 1.025  |  valid_loss: 0.786
# [epoch: 7, i:  4499]  train_loss: 0.933  |  valid_loss: 0.779
# [epoch: 7, i:  4624]  train_loss: 0.829  |  valid_loss: 0.949
# [epoch: 7, i:  4749]  train_loss: 0.858  |  valid_loss: 0.857
# [epoch: 7, i:  4874]  train_loss: 0.955  |  valid_loss: 0.650
# [epoch: 7, i:  4999]  train_loss: 0.937  |  valid_loss: 0.718
# [epoch: 7, i:  5124]  train_loss: 0.916  |  valid_loss: 0.708
# [epoch: 7, i:  5249]  train_loss: 0.933  |  valid_loss: 0.723
# [epoch: 7, i:  5374]  train_loss: 0.983  |  valid_loss: 0.684
# [epoch: 7, i:  5499]  train_loss: 0.999  |  valid_loss: 0.769
# [epoch: 7, i:  5624]  train_loss: 0.915  |  valid_loss: 0.798
# [epoch: 7, i:  5749]  train_loss: 0.885  |  valid_loss: 0.722
# [epoch: 7, i:  5874]  train_loss: 0.904  |  valid_loss: 0.646
# [epoch: 7, i:  5999]  train_loss: 0.919  |  valid_loss: 0.704
# [epoch: 7, i:  6124]  train_loss: 0.895  |  valid_loss: 0.678
# [epoch: 7, i:  6249]  train_loss: 0.921  |  valid_loss: 0.857
# [epoch: 7, i:  6374]  train_loss: 0.987  |  valid_loss: 0.670
# [epoch: 7, i:  6499]  train_loss: 1.029  |  valid_loss: 0.765
# [epoch: 7, i:  6624]  train_loss: 0.927  |  valid_loss: 0.725
# [epoch: 7, i:  6749]  train_loss: 0.981  |  valid_loss: 0.764
# [epoch: 7, i:  6874]  train_loss: 0.915  |  valid_loss: 0.716
# [epoch: 7, i:  6999]  train_loss: 0.928  |  valid_loss: 0.870
# [epoch: 7, i:  7124]  train_loss: 0.969  |  valid_loss: 0.800
# [epoch: 7, i:  7249]  train_loss: 0.956  |  valid_loss: 0.614
# [epoch: 7, i:  7374]  train_loss: 0.988  |  valid_loss: 0.861
# [epoch: 7, i:  7499]  train_loss: 0.959  |  valid_loss: 0.822
# [epoch: 7, i:  7624]  train_loss: 1.068  |  valid_loss: 0.774
# [epoch: 7, i:  7749]  train_loss: 0.906  |  valid_loss: 0.804
# [epoch: 7, i:  7874]  train_loss: 0.894  |  valid_loss: 0.593
# [epoch: 7, i:  7999]  train_loss: 0.947  |  valid_loss: 0.656
# [epoch: 7, i:  8124]  train_loss: 0.889  |  valid_loss: 0.726
# [epoch: 7, i:  8249]  train_loss: 1.011  |  valid_loss: 0.870
# [epoch: 7, i:  8374]  train_loss: 1.015  |  valid_loss: 0.698
# [epoch: 7, i:  8499]  train_loss: 0.937  |  valid_loss: 0.769
# [epoch: 7, i:  8624]  train_loss: 0.874  |  valid_loss: 0.738
# [epoch: 7, i:  8749]  train_loss: 0.966  |  valid_loss: 0.896
# [epoch: 7, i:  8874]  train_loss: 1.001  |  valid_loss: 0.684
# [epoch: 7, i:  8999]  train_loss: 0.913  |  valid_loss: 0.642
# [epoch: 7, i:  9124]  train_loss: 0.956  |  valid_loss: 0.756
# [epoch: 7, i:  9249]  train_loss: 0.920  |  valid_loss: 0.643
# [epoch: 7, i:  9374]  train_loss: 0.931  |  valid_loss: 0.747
# [epoch: 7, i:  9499]  train_loss: 1.012  |  valid_loss: 0.672
# [epoch: 7, i:  9624]  train_loss: 0.920  |  valid_loss: 0.836
# [epoch: 7, i:  9749]  train_loss: 0.937  |  valid_loss: 0.640
# [epoch: 7, i:  9874]  train_loss: 0.894  |  valid_loss: 0.856
# [epoch: 7, i:  9999]  train_loss: 0.931  |  valid_loss: 0.834
# [epoch: 7, i: 10124]  train_loss: 0.918  |  valid_loss: 0.625
# [epoch: 7, i: 10249]  train_loss: 1.013  |  valid_loss: 0.789
# [epoch: 7, i: 10374]  train_loss: 0.947  |  valid_loss: 0.737
# [epoch: 7, i: 10499]  train_loss: 0.930  |  valid_loss: 0.746
# [epoch: 7, i: 10624]  train_loss: 0.877  |  valid_loss: 0.818
# [epoch: 7, i: 10749]  train_loss: 0.890  |  valid_loss: 0.733
# [epoch: 7, i: 10874]  train_loss: 0.981  |  valid_loss: 0.772
# [epoch: 7, i: 10999]  train_loss: 0.995  |  valid_loss: 0.792
# [epoch: 7, i: 11124]  train_loss: 0.973  |  valid_loss: 0.771
# [epoch: 7, i: 11249]  train_loss: 0.980  |  valid_loss: 0.782
# [epoch: 7, i: 11374]  train_loss: 0.819  |  valid_loss: 0.672
# [epoch: 7, i: 11499]  train_loss: 0.993  |  valid_loss: 0.480
# [epoch: 7, i: 11624]  train_loss: 0.965  |  valid_loss: 0.909
# [epoch: 7, i: 11749]  train_loss: 0.875  |  valid_loss: 0.814
# [epoch: 7, i: 11874]  train_loss: 0.952  |  valid_loss: 0.758
# [epoch: 7, i: 11999]  train_loss: 0.908  |  valid_loss: 0.594
# [epoch: 7, i: 12124]  train_loss: 0.904  |  valid_loss: 0.582
# [epoch: 7, i: 12249]  train_loss: 1.027  |  valid_loss: 0.940
# [epoch: 7, i: 12374]  train_loss: 0.965  |  valid_loss: 0.801
# [epoch: 7, i: 12499]  train_loss: 0.881  |  valid_loss: 0.676
# --> [End of epoch 7] train_accuracy: 68.78%  |  valid_accuracy: 74.59%
# --> [Start of epoch 8]  lr: 0.000058
# [epoch: 8, i:   124]  train_loss: 0.879  |  valid_loss: 0.581
# [epoch: 8, i:   249]  train_loss: 0.932  |  valid_loss: 0.652
# [epoch: 8, i:   374]  train_loss: 0.913  |  valid_loss: 0.750
# [epoch: 8, i:   499]  train_loss: 0.909  |  valid_loss: 0.689
# [epoch: 8, i:   624]  train_loss: 0.818  |  valid_loss: 0.750
# [epoch: 8, i:   749]  train_loss: 0.934  |  valid_loss: 0.559
# [epoch: 8, i:   874]  train_loss: 0.936  |  valid_loss: 0.764
# [epoch: 8, i:   999]  train_loss: 0.948  |  valid_loss: 0.776
# [epoch: 8, i:  1124]  train_loss: 0.871  |  valid_loss: 0.898
# [epoch: 8, i:  1249]  train_loss: 0.965  |  valid_loss: 0.593
# [epoch: 8, i:  1374]  train_loss: 0.899  |  valid_loss: 0.578
# [epoch: 8, i:  1499]  train_loss: 0.903  |  valid_loss: 0.751
# [epoch: 8, i:  1624]  train_loss: 0.834  |  valid_loss: 0.758
# [epoch: 8, i:  1749]  train_loss: 0.867  |  valid_loss: 0.753
# [epoch: 8, i:  1874]  train_loss: 0.958  |  valid_loss: 0.548
# [epoch: 8, i:  1999]  train_loss: 0.849  |  valid_loss: 0.862
# [epoch: 8, i:  2124]  train_loss: 0.947  |  valid_loss: 0.665
# [epoch: 8, i:  2249]  train_loss: 1.026  |  valid_loss: 0.682
# [epoch: 8, i:  2374]  train_loss: 1.094  |  valid_loss: 0.657
# [epoch: 8, i:  2499]  train_loss: 0.901  |  valid_loss: 0.937
# [epoch: 8, i:  2624]  train_loss: 0.926  |  valid_loss: 0.779
# [epoch: 8, i:  2749]  train_loss: 0.909  |  valid_loss: 0.770
# [epoch: 8, i:  2874]  train_loss: 0.922  |  valid_loss: 0.734
# [epoch: 8, i:  2999]  train_loss: 0.959  |  valid_loss: 0.754
# [epoch: 8, i:  3124]  train_loss: 0.897  |  valid_loss: 0.659
# [epoch: 8, i:  3249]  train_loss: 0.939  |  valid_loss: 0.952
# [epoch: 8, i:  3374]  train_loss: 0.937  |  valid_loss: 0.706
# [epoch: 8, i:  3499]  train_loss: 0.870  |  valid_loss: 0.736
# [epoch: 8, i:  3624]  train_loss: 0.924  |  valid_loss: 0.748
# [epoch: 8, i:  3749]  train_loss: 0.812  |  valid_loss: 0.686
# [epoch: 8, i:  3874]  train_loss: 0.872  |  valid_loss: 0.719
# [epoch: 8, i:  3999]  train_loss: 0.962  |  valid_loss: 0.692
# [epoch: 8, i:  4124]  train_loss: 0.938  |  valid_loss: 0.748
# [epoch: 8, i:  4249]  train_loss: 0.983  |  valid_loss: 0.806
# [epoch: 8, i:  4374]  train_loss: 0.918  |  valid_loss: 0.764
# [epoch: 8, i:  4499]  train_loss: 0.947  |  valid_loss: 0.762
# [epoch: 8, i:  4624]  train_loss: 0.986  |  valid_loss: 0.909
# [epoch: 8, i:  4749]  train_loss: 0.975  |  valid_loss: 0.845
# [epoch: 8, i:  4874]  train_loss: 0.910  |  valid_loss: 0.632
# [epoch: 8, i:  4999]  train_loss: 0.945  |  valid_loss: 0.670
# [epoch: 8, i:  5124]  train_loss: 0.819  |  valid_loss: 0.710
# [epoch: 8, i:  5249]  train_loss: 0.866  |  valid_loss: 0.729
# [epoch: 8, i:  5374]  train_loss: 0.827  |  valid_loss: 0.642
# [epoch: 8, i:  5499]  train_loss: 0.854  |  valid_loss: 0.685
# [epoch: 8, i:  5624]  train_loss: 0.904  |  valid_loss: 0.780
# [epoch: 8, i:  5749]  train_loss: 0.941  |  valid_loss: 0.758
# [epoch: 8, i:  5874]  train_loss: 0.924  |  valid_loss: 0.615
# [epoch: 8, i:  5999]  train_loss: 0.926  |  valid_loss: 0.661
# [epoch: 8, i:  6124]  train_loss: 0.923  |  valid_loss: 0.633
# [epoch: 8, i:  6249]  train_loss: 0.908  |  valid_loss: 0.903
# [epoch: 8, i:  6374]  train_loss: 0.900  |  valid_loss: 0.696
# [epoch: 8, i:  6499]  train_loss: 0.873  |  valid_loss: 0.757
# [epoch: 8, i:  6624]  train_loss: 0.959  |  valid_loss: 0.730
# [epoch: 8, i:  6749]  train_loss: 0.879  |  valid_loss: 0.792
# [epoch: 8, i:  6874]  train_loss: 0.959  |  valid_loss: 0.743
# [epoch: 8, i:  6999]  train_loss: 0.904  |  valid_loss: 0.857
# [epoch: 8, i:  7124]  train_loss: 0.962  |  valid_loss: 0.798
# [epoch: 8, i:  7249]  train_loss: 0.874  |  valid_loss: 0.573
# [epoch: 8, i:  7374]  train_loss: 0.892  |  valid_loss: 0.829
# [epoch: 8, i:  7499]  train_loss: 0.896  |  valid_loss: 0.822
# [epoch: 8, i:  7624]  train_loss: 0.844  |  valid_loss: 0.741
# [epoch: 8, i:  7749]  train_loss: 0.949  |  valid_loss: 0.823
# [epoch: 8, i:  7874]  train_loss: 0.888  |  valid_loss: 0.570
# [epoch: 8, i:  7999]  train_loss: 0.930  |  valid_loss: 0.646
# [epoch: 8, i:  8124]  train_loss: 0.917  |  valid_loss: 0.674
# [epoch: 8, i:  8249]  train_loss: 0.909  |  valid_loss: 0.887
# [epoch: 8, i:  8374]  train_loss: 0.947  |  valid_loss: 0.700
# [epoch: 8, i:  8499]  train_loss: 0.948  |  valid_loss: 0.765
# [epoch: 8, i:  8624]  train_loss: 0.990  |  valid_loss: 0.727
# [epoch: 8, i:  8749]  train_loss: 0.986  |  valid_loss: 0.902
# [epoch: 8, i:  8874]  train_loss: 0.906  |  valid_loss: 0.697
# [epoch: 8, i:  8999]  train_loss: 0.895  |  valid_loss: 0.646
# [epoch: 8, i:  9124]  train_loss: 0.976  |  valid_loss: 0.814
# [epoch: 8, i:  9249]  train_loss: 0.831  |  valid_loss: 0.664
# [epoch: 8, i:  9374]  train_loss: 0.890  |  valid_loss: 0.695
# [epoch: 8, i:  9499]  train_loss: 0.849  |  valid_loss: 0.665
# [epoch: 8, i:  9624]  train_loss: 0.876  |  valid_loss: 0.845
# [epoch: 8, i:  9749]  train_loss: 0.949  |  valid_loss: 0.680
# [epoch: 8, i:  9874]  train_loss: 0.785  |  valid_loss: 0.856
# [epoch: 8, i:  9999]  train_loss: 0.835  |  valid_loss: 0.810
# [epoch: 8, i: 10124]  train_loss: 0.934  |  valid_loss: 0.588
# [epoch: 8, i: 10249]  train_loss: 0.879  |  valid_loss: 0.790
# [epoch: 8, i: 10374]  train_loss: 0.936  |  valid_loss: 0.726
# [epoch: 8, i: 10499]  train_loss: 0.925  |  valid_loss: 0.742
# [epoch: 8, i: 10624]  train_loss: 0.903  |  valid_loss: 0.804
# [epoch: 8, i: 10749]  train_loss: 0.911  |  valid_loss: 0.660
# [epoch: 8, i: 10874]  train_loss: 0.910  |  valid_loss: 0.780
# [epoch: 8, i: 10999]  train_loss: 0.926  |  valid_loss: 0.775
# [epoch: 8, i: 11124]  train_loss: 0.908  |  valid_loss: 0.738
# [epoch: 8, i: 11249]  train_loss: 0.891  |  valid_loss: 0.780
# [epoch: 8, i: 11374]  train_loss: 0.931  |  valid_loss: 0.643
# [epoch: 8, i: 11499]  train_loss: 0.947  |  valid_loss: 0.460
# [epoch: 8, i: 11624]  train_loss: 1.025  |  valid_loss: 0.874
# [epoch: 8, i: 11749]  train_loss: 1.003  |  valid_loss: 0.783
# [epoch: 8, i: 11874]  train_loss: 0.948  |  valid_loss: 0.722
# [epoch: 8, i: 11999]  train_loss: 0.982  |  valid_loss: 0.620
# [epoch: 8, i: 12124]  train_loss: 0.927  |  valid_loss: 0.576
# [epoch: 8, i: 12249]  train_loss: 0.998  |  valid_loss: 0.925
# [epoch: 8, i: 12374]  train_loss: 0.961  |  valid_loss: 0.814
# [epoch: 8, i: 12499]  train_loss: 0.870  |  valid_loss: 0.627
# --> [End of epoch 8] train_accuracy: 69.20%  |  valid_accuracy: 75.09%
# --> [Start of epoch 9]  lr: 0.000040
# [epoch: 9, i:   124]  train_loss: 0.888  |  valid_loss: 0.602
# [epoch: 9, i:   249]  train_loss: 0.945  |  valid_loss: 0.652
# [epoch: 9, i:   374]  train_loss: 0.879  |  valid_loss: 0.813
# [epoch: 9, i:   499]  train_loss: 0.925  |  valid_loss: 0.708
# [epoch: 9, i:   624]  train_loss: 0.951  |  valid_loss: 0.744
# [epoch: 9, i:   749]  train_loss: 0.918  |  valid_loss: 0.549
# [epoch: 9, i:   874]  train_loss: 0.993  |  valid_loss: 0.745
# [epoch: 9, i:   999]  train_loss: 0.847  |  valid_loss: 0.722
# [epoch: 9, i:  1124]  train_loss: 0.874  |  valid_loss: 0.902
# [epoch: 9, i:  1249]  train_loss: 0.891  |  valid_loss: 0.599
# [epoch: 9, i:  1374]  train_loss: 0.862  |  valid_loss: 0.578
# [epoch: 9, i:  1499]  train_loss: 0.941  |  valid_loss: 0.712
# [epoch: 9, i:  1624]  train_loss: 0.941  |  valid_loss: 0.764
# [epoch: 9, i:  1749]  train_loss: 0.914  |  valid_loss: 0.767
# [epoch: 9, i:  1874]  train_loss: 0.933  |  valid_loss: 0.562
# [epoch: 9, i:  1999]  train_loss: 0.861  |  valid_loss: 0.868
# [epoch: 9, i:  2124]  train_loss: 0.920  |  valid_loss: 0.665
# [epoch: 9, i:  2249]  train_loss: 0.837  |  valid_loss: 0.695
# [epoch: 9, i:  2374]  train_loss: 0.962  |  valid_loss: 0.635
# [epoch: 9, i:  2499]  train_loss: 0.857  |  valid_loss: 0.921
# [epoch: 9, i:  2624]  train_loss: 0.833  |  valid_loss: 0.769
# [epoch: 9, i:  2749]  train_loss: 0.899  |  valid_loss: 0.747
# [epoch: 9, i:  2874]  train_loss: 0.966  |  valid_loss: 0.740
# [epoch: 9, i:  2999]  train_loss: 0.962  |  valid_loss: 0.750
# [epoch: 9, i:  3124]  train_loss: 0.869  |  valid_loss: 0.657
# [epoch: 9, i:  3249]  train_loss: 0.998  |  valid_loss: 0.970
# [epoch: 9, i:  3374]  train_loss: 1.002  |  valid_loss: 0.670
# [epoch: 9, i:  3499]  train_loss: 0.962  |  valid_loss: 0.765
# [epoch: 9, i:  3624]  train_loss: 0.933  |  valid_loss: 0.740
# [epoch: 9, i:  3749]  train_loss: 0.833  |  valid_loss: 0.688
# [epoch: 9, i:  3874]  train_loss: 0.908  |  valid_loss: 0.716
# [epoch: 9, i:  3999]  train_loss: 0.920  |  valid_loss: 0.668
# [epoch: 9, i:  4124]  train_loss: 0.866  |  valid_loss: 0.731
# [epoch: 9, i:  4249]  train_loss: 1.044  |  valid_loss: 0.792
# [epoch: 9, i:  4374]  train_loss: 0.988  |  valid_loss: 0.749
# [epoch: 9, i:  4499]  train_loss: 0.950  |  valid_loss: 0.784
# [epoch: 9, i:  4624]  train_loss: 0.908  |  valid_loss: 0.941
# [epoch: 9, i:  4749]  train_loss: 0.870  |  valid_loss: 0.874
# [epoch: 9, i:  4874]  train_loss: 1.015  |  valid_loss: 0.655
# [epoch: 9, i:  4999]  train_loss: 0.850  |  valid_loss: 0.694
# [epoch: 9, i:  5124]  train_loss: 0.882  |  valid_loss: 0.688
# [epoch: 9, i:  5249]  train_loss: 0.877  |  valid_loss: 0.735
# [epoch: 9, i:  5374]  train_loss: 0.867  |  valid_loss: 0.695
# [epoch: 9, i:  5499]  train_loss: 1.065  |  valid_loss: 0.731
# [epoch: 9, i:  5624]  train_loss: 1.078  |  valid_loss: 0.743
# [epoch: 9, i:  5749]  train_loss: 0.912  |  valid_loss: 0.740
# [epoch: 9, i:  5874]  train_loss: 0.918  |  valid_loss: 0.633
# [epoch: 9, i:  5999]  train_loss: 0.916  |  valid_loss: 0.667
# [epoch: 9, i:  6124]  train_loss: 0.894  |  valid_loss: 0.629
# [epoch: 9, i:  6249]  train_loss: 0.939  |  valid_loss: 0.904
# [epoch: 9, i:  6374]  train_loss: 0.967  |  valid_loss: 0.727
# [epoch: 9, i:  6499]  train_loss: 0.971  |  valid_loss: 0.774
# [epoch: 9, i:  6624]  train_loss: 0.852  |  valid_loss: 0.712
# [epoch: 9, i:  6749]  train_loss: 0.872  |  valid_loss: 0.792
# [epoch: 9, i:  6874]  train_loss: 0.969  |  valid_loss: 0.713
# [epoch: 9, i:  6999]  train_loss: 0.922  |  valid_loss: 0.845
# [epoch: 9, i:  7124]  train_loss: 0.879  |  valid_loss: 0.792
# [epoch: 9, i:  7249]  train_loss: 0.842  |  valid_loss: 0.624
# [epoch: 9, i:  7374]  train_loss: 0.961  |  valid_loss: 0.832
# [epoch: 9, i:  7499]  train_loss: 0.878  |  valid_loss: 0.786
# [epoch: 9, i:  7624]  train_loss: 0.868  |  valid_loss: 0.721
# [epoch: 9, i:  7749]  train_loss: 0.903  |  valid_loss: 0.775
# [epoch: 9, i:  7874]  train_loss: 0.935  |  valid_loss: 0.585
# [epoch: 9, i:  7999]  train_loss: 0.867  |  valid_loss: 0.678
# [epoch: 9, i:  8124]  train_loss: 0.831  |  valid_loss: 0.735
# [epoch: 9, i:  8249]  train_loss: 0.913  |  valid_loss: 0.837
# [epoch: 9, i:  8374]  train_loss: 0.938  |  valid_loss: 0.704
# [epoch: 9, i:  8499]  train_loss: 0.899  |  valid_loss: 0.765
# [epoch: 9, i:  8624]  train_loss: 0.983  |  valid_loss: 0.742
# [epoch: 9, i:  8749]  train_loss: 0.936  |  valid_loss: 0.880
# [epoch: 9, i:  8874]  train_loss: 0.877  |  valid_loss: 0.661
# [epoch: 9, i:  8999]  train_loss: 0.909  |  valid_loss: 0.576
# [epoch: 9, i:  9124]  train_loss: 0.886  |  valid_loss: 0.758
# [epoch: 9, i:  9249]  train_loss: 0.884  |  valid_loss: 0.657
# [epoch: 9, i:  9374]  train_loss: 0.908  |  valid_loss: 0.691
# [epoch: 9, i:  9499]  train_loss: 0.883  |  valid_loss: 0.666
# [epoch: 9, i:  9624]  train_loss: 0.951  |  valid_loss: 0.813
# [epoch: 9, i:  9749]  train_loss: 1.015  |  valid_loss: 0.633
# [epoch: 9, i:  9874]  train_loss: 0.966  |  valid_loss: 0.825
# [epoch: 9, i:  9999]  train_loss: 0.963  |  valid_loss: 0.848
# [epoch: 9, i: 10124]  train_loss: 0.945  |  valid_loss: 0.576
# [epoch: 9, i: 10249]  train_loss: 0.888  |  valid_loss: 0.794
# [epoch: 9, i: 10374]  train_loss: 0.831  |  valid_loss: 0.724
# [epoch: 9, i: 10499]  train_loss: 0.887  |  valid_loss: 0.716
# [epoch: 9, i: 10624]  train_loss: 0.944  |  valid_loss: 0.801
# [epoch: 9, i: 10749]  train_loss: 0.865  |  valid_loss: 0.656
# [epoch: 9, i: 10874]  train_loss: 1.001  |  valid_loss: 0.777
# [epoch: 9, i: 10999]  train_loss: 0.918  |  valid_loss: 0.731
# [epoch: 9, i: 11124]  train_loss: 0.862  |  valid_loss: 0.742
# [epoch: 9, i: 11249]  train_loss: 0.868  |  valid_loss: 0.751
# [epoch: 9, i: 11374]  train_loss: 0.851  |  valid_loss: 0.628
# [epoch: 9, i: 11499]  train_loss: 0.802  |  valid_loss: 0.458
# [epoch: 9, i: 11624]  train_loss: 0.961  |  valid_loss: 0.893
# [epoch: 9, i: 11749]  train_loss: 0.854  |  valid_loss: 0.743
# [epoch: 9, i: 11874]  train_loss: 0.920  |  valid_loss: 0.719
# [epoch: 9, i: 11999]  train_loss: 0.914  |  valid_loss: 0.595
# [epoch: 9, i: 12124]  train_loss: 0.971  |  valid_loss: 0.598
# [epoch: 9, i: 12249]  train_loss: 0.886  |  valid_loss: 0.933
# [epoch: 9, i: 12374]  train_loss: 0.773  |  valid_loss: 0.849
# [epoch: 9, i: 12499]  train_loss: 0.854  |  valid_loss: 0.623
# --> [End of epoch 9] train_accuracy: 69.63%  |  valid_accuracy: 75.10%
# Finished Training.

# %%
def moving_average(data, window_size):
    """Compute the moving average of the data using a specified window size."""
    return np.convolve(data, np.ones(window_size)/window_size, mode='valid')

window_size = 20  # Adjust this based on your preference
train_losses_ma = moving_average(avg_train_losses, window_size)
valid_losses_ma = moving_average(avg_valid_losses, window_size)

# x_axis = np.arange(len(train_losses_ma))/100 
x_axis = np.arange(window_size - 1, len(train_losses_ma) + window_size - 1)

plt.plot(avg_train_losses)
plt.plot(avg_valid_losses)
plt.plot(x_axis, train_losses_ma, linewidth=2)
plt.plot(x_axis, valid_losses_ma, linewidth=2)
plt.title('DenseNet loss trend + exponential scheduling + l2 regularization')
plt.xlabel('mini-batch index / {}'.format(record_freq))
plt.ylabel('avg. mini-batch loss')
plt.legend(['training loss', 'validation loss', 'training loss (moving avg)', 'validation loss (moving avg)'])
plt.show()

# %%
plt.plot(train_accuracies)
plt.plot(valid_accuracies)
plt.title('DenseMax accuracy curve for exponential scheduling + l2 regularization')
plt.xlabel('epoch / {}'.format(record_freq))
plt.ylabel('accuracy')
plt.legend(['train accuracy', 'validation accuracy'])
plt.show()

# %%
# The function to show an image.
def imshow(img):
    img = img / 2 + 0.5     # Unnormalize.
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# %%
# Check several images.
dataiter = iter(validloader)
images, labels = next(dataiter)
imshow(torchvision.utils.make_grid(images))
print('GroundTruth: ', ' '.join('%5s' % classes[labels[j]] for j in range(4)))
outputs = dense_max(images.to(device))

# max compare along the row, return the index of the max value, which is the predicted class
_, predicted = torch.max(outputs, 1)

print('Predicted: ', ' '.join('%5s' % classes[predicted[j]]
                              for j in range(4)))
# Out:
# GroundTruth:    cat  ship  ship plane
# Predicted:   frog   car  ship plane

# %%
dense_max.to(device)

dense_max.eval()
# Get test accuracy.
correct = 0
total = 0
with torch.no_grad():
    for data in validloader:
        images, labels = data
        images, labels = images.to(device), labels.to(device)
        outputs = dense_max(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print('Accuracy of the network on the 10000 test images: %.2f %%' % (
    100 * correct / total))
# Out:
# Accuracy of the network on the 10000 test images: 75.73 %

# %%
# Get test accuracy for each class.
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))
with torch.no_grad():
    for data in validloader:
        images, labels = data
        images, labels = images.to(device), labels.to(device)
        outputs = dense_max(images)
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels).squeeze()
        for i in range(4):
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1

for i in range(10):
    print('Accuracy of %5s : %2d %%' % (
        classes[i], 100 * class_correct[i] / class_total[i]))
# Out:
# Accuracy of plane : 78 %
# Accuracy of   car : 86 %
# Accuracy of  bird : 56 %
# Accuracy of   cat : 57 %
# Accuracy of  deer : 74 %
# Accuracy of   dog : 66 %
# Accuracy of  frog : 81 %
# Accuracy of horse : 83 %
# Accuracy of  ship : 87 %
# Accuracy of truck : 86 %

# %% [markdown]
# #### Observation
# Before doing any experiment, I gathered some information from the average pooling based model as described in Q5.
#
# I first plot the training loss curve at a frequency of 100 times per epoch to understand the training process. Then I plot the accuracy comparison once per epoch (computing accuracy is expensive) to make more observations.
#
# Judging from the training loss curve alone, the model converge nicely and the loss does not fluctuate too much toward the end of the training,
#
# Observing the accuracy comparison chart from average pooling based model as described in Q5, we can see the gap between train accuracy and test accuracy start getting bigger in each epoch; more precisely, test accuracy does not increase in proportion to train accuracy. This is a clear sign of overfitting.
#
# #### Experiment
# To address overfitting, some form of regularization is needed, therefore I decided to try out various techniques such as Batch Normalization and Dropout. I've also tried switching from average pooling to max pooling because it's a more common practice than average pooling to extract features from the input.
#
# I was then to achieve around 68-69 percent in different variations of the max pooling model with either dropout or l2 regularization.
#
# The ones I've found giving the most consistent good result is just either max or average pooling approach with batch normalization after every Conv2D layer and linear layer before activation function.
#
# #### Final Implementation (went crazy)
# However, I then decided to restructure my model completely, I was able to achieve around 70 percent with very simple 2 residual blocks Resnet model + batch normalization + l2 regularization
#
# Then I added one extra layer, and implement Densenet's idea, you can see in my code I not only have the standard skip connection, I also have the dense connection, which is the concatenation of all previous layers. This model initially achieved incredible 73.98% validation accuracies, but this process definitely took a lot of time to train just 10 epochs
#
# Then I decided to add back max pooling in between residual blocks just right after concatenation with dense skip connection because from my understanding in limited resources, having max pooling can reduce some computation while allowing deeper network to be trained, which proven to be the case.
#
# There, my final model is a Densenet with 3 residual blocks + 3 max pooling layers + 3 dense skip connections + all associated batch normalization layers + 2 fully connection layers, using Adam with default betas (0.9, 0.99) and weight decay of 1e-4 (which is the equivalence of l2 regularization in Pytorch implementation). This model achieved 75.73% accuracy from just 10 epochs.
#
# #### Potential further improvement
# The model still have problem with classifying cat, dog and bird, which I believe can be improved by adding more data augmentation on the training set just for those classes. I think it wouldn't be too much of a challenge to get my accuracy to 80% with cyclic learning rate scheduling + data augmentation, and then just use model esembling to get that couple more percents.
#
# #### Some Interesting Notes
# In Resnet's paper, they don't use max pooling in their model, which I believe is not suitable in achieving the best result for the purpose of this experiment because I don't have the resource to train a very deep network. Resnet also doesn't use fully connected layer, instead they only have one global avg pooling layer that compute one mean per feature map and pass to a linear layer right into Softmax for classification.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

batch_size = 4

std_transforms = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

std_trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=std_transforms)
trainloader = torch.utils.data.DataLoader(std_trainset, batch_size=batch_size,
                                          shuffle=True, num_workers=2)

validset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=std_transforms)
validloader = torch.utils.data.DataLoader(validset, batch_size=batch_size,
                                         shuffle=False, num_workers=2)

# If there are GPUs, choose the first one for computing. Otherwise use CPU.
device = torch.device("cuda:0" if torch.cuda.is_available() else ("mps" if torch.backends.mps.is_available() else "cpu"))

# the order for cifar10 10 classes
classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

print(device)
print(len(std_trainset))
print(len(trainloader))  
# If 'mps or cuda:0' is printed, it means GPU is available.
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# mps
# 50000
# 12500

# %% [markdown]
# #### Optional: Apply data augmentation

# %%
from custom_nn.datasets import CustomCIFAR10

# Additional focused augmentations
focused_augmentations = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
])

# using custom dataset class to add focused augmentations capability
aug_trainset = CustomCIFAR10(
    root='./data',
    train=True,
    download=True,
    transform=std_transforms,
    focused_transform=focused_augmentations
)

# the class we want the augmentation for birds, cats, deer, and dogs
desired_classes = [1, 2, 3, 4]

# Filter the dataset
filtered_indices = [i for i, (_, label) in enumerate(aug_trainset) if label in desired_classes]

filtered_dataset = torch.utils.data.Subset(aug_trainset, filtered_indices)

# Combine the two datasets
combined_trainset = torch.utils.data.ConcatDataset([std_trainset, filtered_dataset])
trainloader = torch.utils.data.DataLoader(combined_trainset, batch_size=batch_size,
                                          shuffle=True, num_workers=2)
print(len(combined_trainset))
print(len(trainloader))
# Out:
# Files already downloaded and verified
# 70000
# 17500

# %%
""" delay down sample for bigger activation maps early """
from custom_nn.blocks import ResBlock
class ResMaxDelay(nn.Module):
    def __init__(self):
        super().__init__()
        
         ### RES 1
        # 3x32x32 to 3x32x32
        self.rb1 = ResBlock(3, 5, 1)
        self.act1 = nn.ReLU()
        
        ### RES 2
        # 3x32x32 to 3x32x32
        self.rb2 = ResBlock(5, 5, 1)
        self.act2 = nn.ReLU()
        
        ### RES 3
        # 3x32x32 to 3x32x32
        self.rb3 = ResBlock(5, 5, 1)
        self.act3 = nn.ReLU()
        
        ### RES 4
        # 3x32x32 to 3x32x32
        self.rb4 = ResBlock(5, 5, 1)
        self.act4 = nn.ReLU()
        
        ### RES 5
        # 3x32x32 to 10x32x32
        self.rb5 = ResBlock(5, 5, 1)
        self.act5 = nn.ReLU()
        
        # 10x32x32 to 10x16x16
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        
        ### RES 6
        # 10x16x16 to 10x16x16
        self.rb6 = ResBlock(5, 20, 1)
        self.act6 = nn.ReLU()
        
        # 10x16x16 to 10x8x8
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)                
                
        self.flatten = nn.Flatten(1)
        # 20x8x8 affine operation to hidden layer with 100 neurons
        self.fc1 = nn.Linear(20 * 8 * 8, 100)
        self.bn1 = nn.BatchNorm1d(100)
        self.act4 = nn.ReLU()
        
        # affine operation to output layer with 10 neurons
        self.fc2 = nn.Linear(100, 10)
        
    def forward(self, x):
        
        x = self.rb1(x)
        x = self.act1(x) 
           
        x = self.rb2(x)
        x = self.act2(x)
        
        x = self.rb3(x)
        x = self.act3(x)
        
        x = self.rb4(x)
        x = self.act4(x)
        
        x = self.rb5(x)
        x = self.act5(x)
        x = self.pool1(x)
        
        x = self.rb6(x)
        x = self.act6(x)
        x = self.pool2(x)
                
        # flatten and pass through fully connected layers
        x = self.flatten(x)
        x = self.fc1(x)
        x = self.bn1(x)
        x = self.act4(x)
        x = self.fc2(x)
        return x
test = ResMaxDelay()
test.to(device)
test(torch.randn(4, 3, 32, 32).to(device))
# Out:
# tensor([[-0.7935,  0.4363, -0.2262,  0.1480, -0.2341, -0.4035,  0.0107, -0.4012,
#          -0.0617,  0.1363],
#         [-0.6588, -0.0356,  0.3967,  0.3465,  0.3892,  0.2232, -0.0761, -0.0030,
#           0.4063, -0.3186],
#         [-0.7027,  0.7692, -0.3919,  0.3705, -0.9460,  0.0046, -0.9097, -0.5430,
#          -0.2682, -0.5275],
#         [ 0.1284, -0.1281,  0.2498, -0.1181,  0.0040, -0.4392, -0.2651, -0.1863,
#           0.4436, -0.0224]], device='mps:0', grad_fn=<LinearBackward0>)

# %%
from pathlib import Path
import time
from custom_nn.utils.model_utils import count_parameters, get_model_size

epoch_start = 0     # Start from epoch 0 or last checkpoint epoch
iter_n = len(trainloader)  # number of iteration per epoch
record_freq = 100 # how many times to record the loss and accuracy per epoch
print_freq = 100 # how many times to print the loss and accuracy per epoch
iter_n_per_record = iter_n // record_freq  # Record frequency.
iter_n_per_print = iter_n // print_freq # Print frequency, need to be multiple of record_freq.

# a number for computing running validation loss in each iteration.
train_per_valid = len(trainloader) / len(validloader)  

avg_train_losses, avg_valid_losses = [], []   # Avg. losses.
train_accuracies, valid_accuracies = [], []  # Train and test accuracies.
time_per_epoch = []  # Time per epoch.

model = ResMaxDelay()     # Create the network instance.
# Move the network parameters to the specified device
# need to be done before passing to optimizer.
model.to(device)  

assert model(torch.randn(4, 3, 32, 32).to(device)).shape == torch.Size([4, 10])

# We use Adam as optimizer.
opt = optim.Adam(model.parameters(), lr=5e-4, betas=(0.9, 0.999), eps=1e-08, weight_decay=1e-4)
# We use cross-entropy as loss function.
loss_func = nn.CrossEntropyLoss() 

# add scheduling
# scheduler = optim.lr_scheduler.ExponentialLR(opt, gamma=0.8)
# scheduler = optim.lr_scheduler.StepLR(opt, step_size=5, gamma=0.8)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(opt, mode='max', factor=0.1, patience=4, threshold=1e-4)

# directory to save the model
directory_path = Path("./checkpoints/res_max_delay" + "_batch" + str(batch_size))
# Make the directory if it doesn't exist
directory_path.mkdir(parents=True, exist_ok=True)

print("train_per_valid:", train_per_valid)

print("number of parameters:", count_parameters(model))
print('model size: {:.4f}MB'.format(get_model_size(model)))
# Out:
# train_per_valid: 7.0
# number of parameters: 136430
# model size: 0.5222MB

# %%
import re

# Pattern to match the files and extract epoch numbers
pattern = r'epoch_(\d+).pth'

# Use Path.glob to list all files matching the pattern
files = list(directory_path.glob('epoch_*.pth'))

# Extract epochs and files into a list of tuples
epoch_files = []
for file_path in files:
    match = re.search(pattern, file_path.name)
    if match:
        epoch_num = int(match.group(1))
        epoch_files.append((epoch_num, file_path))

# Sort the list by epoch number in descending order
epoch_files.sort(key=lambda x: x[0], reverse=False)

if epoch_files:
    # populating history for loss and accuracy for plotting
    for file in epoch_files:
        checkpoint = torch.load(file[1])
        avg_train_losses += checkpoint['avg_train_losses']
        avg_valid_losses += checkpoint['avg_valid_losses']
        train_accuracies.append(checkpoint['train_accuracy'])
        valid_accuracies.append(checkpoint['valid_accuracy'])
        time_per_epoch.append(checkpoint['time_per_epoch'])
    
    # load the model from the latest checkpoint file
    latest_file_path = epoch_files[-1][1]
    print(f"The latest checkpoint file is: {latest_file_path}")
    checkpoint = torch.load(latest_file_path)
    model.load_state_dict(checkpoint['model_state_dict'])
    opt.load_state_dict(checkpoint['optimizer_state_dict'])
    scheduler.load_state_dict(checkpoint['scheduler_state_dict'])
    
    # start training from the next epoch
    epoch_start = checkpoint['epoch'] + 1
else:
    print("No checkpoint files found.")
# Out:
# No checkpoint files found.

# %%
epochs = 10  # Total epochs.

for epoch in range(epoch_start, epoch_start + epochs):  # Loop over the dataset multiple times.
    running_train_loss = 0.0       # Initialize running train_loss for training set.
    running_val_loss = 0.0     # Initialize running train_loss for validation set.
    
    # Initialize running total and correct for computing train accuracy.
    train_correct = 0 
    train_total = 0
    # Initialize running total and correct for computing test accuracy.
    valid_total = 0   
    valid_correct = 0
    
    
    
    print('--> [Start of epoch {}]'.format(epoch) +
          '  lr: {:.6f}'.format(opt.param_groups[0]['lr']))
    
    # print('--> [Start of epoch {}]'.format(epoch))
    
    epoch_start_time = time.time()
    
    validiter = iter(validloader)
    for i, data in enumerate(iterable=trainloader, start=0):
        
        # Set the model to training mode.
        model.train()
        
        # Get the inputs.
        inputs, labels = data
        
        # Move the inputs to the specified device.
        inputs, labels = inputs.to(device), labels.to(device)
        
        # Zero the parameter gradients.
        opt.zero_grad()

        # Forward step
        train_output = model(inputs)
        train_loss = loss_func(train_output, labels)
        
        # Backward step.
        train_loss.backward()
        
        # Optimization step (update the parameters).
        opt.step()
        
        model.eval()
        
        # record statistics.
        running_train_loss += train_loss.item()
        
        # this is for recording training accuracy
        _, train_predicted = torch.max(train_output.data, 1)
        train_total += labels.size(0)
        train_correct += (train_predicted == labels).sum().item()
        
        # only iterate through validation set according to train_per_valid ratio
        if i % train_per_valid == train_per_valid - 1:
            # Set the model to evaluation mode.
            with torch.no_grad():
                valid_inputs, valid_labels = next(validiter)
                valid_inputs, valid_labels = valid_inputs.to(device), valid_labels.to(device)
                valid_output = model(valid_inputs)
                valid_loss = loss_func(valid_output, valid_labels)
                running_val_loss += valid_loss.item()
                
                _, valid_predicted = torch.max(valid_output.data, 1)
                valid_total += valid_labels.size(0)
                valid_correct += (valid_predicted == valid_labels).sum().item()
            
        # Record training/validation loss every several mini-batches.
        if i % iter_n_per_record == iter_n_per_record - 1: 
            avg_train_loss = running_train_loss / iter_n_per_record
            avg_train_losses.append(avg_train_loss)
            avg_valid_loss = train_per_valid * running_val_loss / iter_n_per_record
            avg_valid_losses.append(avg_valid_loss)
            running_train_loss, running_val_loss = 0.0, 0.0
            
            # only print traing training loss once in a while to avoid cluster output
            if i % iter_n_per_print == iter_n_per_print - 1:
                print('[epoch: {}, i: {:5d}]'.format(epoch, i) +
                      '  train_loss: {:.3f}'.format(avg_train_loss) + 
                      '  |  valid_loss: {:.3f}'.format(avg_valid_loss))
                            
    epoch_end_time = time.time()
    time_per_epoch.append(epoch_end_time - epoch_start_time)
    
    # calculating train accuracy
    train_accuracy = 100 * train_correct / train_total
    train_accuracies.append(train_accuracy)
    
    valid_accuracy = 100 * valid_correct / valid_total
    valid_accuracies.append(valid_accuracy)     
    
    # reduce on plateau scheduling
    scheduler.step(valid_accuracy)
    
    # Store the networks after each epochs.
    # in case we want to do simple average or weighted average
    file_name = f'epoch_{epoch:04d}.pth'
    save_path = directory_path / file_name
    
    torch.save({
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': opt.state_dict(),
            'scheduler_state_dict': scheduler.state_dict(),
            'avg_train_losses': avg_train_losses[epoch * iter_n_per_record : (epoch + 1) * iter_n_per_record],
            'avg_valid_losses': avg_valid_losses[epoch * iter_n_per_record : (epoch + 1) * iter_n_per_record],
            'train_accuracy': train_accuracies[epoch],
            'valid_accuracy': valid_accuracies[epoch],
            'time_per_epoch': time_per_epoch[epoch],
            }, save_path)
    
    print('--> [End of epoch {}]'.format(epoch) +
                      ' train_accuracy: {:.2f}%'.format(train_accuracy) + 
                      '  |  valid_accuracy: {:.2f}%'.format(valid_accuracy))

print('Finished Training.')
# Out:
# --> [Start of epoch 0]  lr: 0.000500
# [epoch: 0, i:   174]  train_loss: 2.083  |  valid_loss: 2.227
# [epoch: 0, i:   349]  train_loss: 1.900  |  valid_loss: 1.979
# [epoch: 0, i:   524]  train_loss: 1.873  |  valid_loss: 1.915
# [epoch: 0, i:   699]  train_loss: 1.839  |  valid_loss: 1.909
# [epoch: 0, i:   874]  train_loss: 1.814  |  valid_loss: 1.850
# [epoch: 0, i:  1049]  train_loss: 1.806  |  valid_loss: 1.810
# [epoch: 0, i:  1224]  train_loss: 1.827  |  valid_loss: 1.706
# [epoch: 0, i:  1399]  train_loss: 1.724  |  valid_loss: 1.797
# [epoch: 0, i:  1574]  train_loss: 1.706  |  valid_loss: 1.580
# [epoch: 0, i:  1749]  train_loss: 1.700  |  valid_loss: 1.553
# [epoch: 0, i:  1924]  train_loss: 1.668  |  valid_loss: 1.634
# [epoch: 0, i:  2099]  train_loss: 1.611  |  valid_loss: 1.528
# [epoch: 0, i:  2274]  train_loss: 1.654  |  valid_loss: 1.653
# [epoch: 0, i:  2449]  train_loss: 1.669  |  valid_loss: 1.636
# [epoch: 0, i:  2624]  train_loss: 1.672  |  valid_loss: 1.330
# [epoch: 0, i:  2799]  train_loss: 1.623  |  valid_loss: 1.533
# [epoch: 0, i:  2974]  train_loss: 1.602  |  valid_loss: 1.512
# [epoch: 0, i:  3149]  train_loss: 1.579  |  valid_loss: 1.459
# [epoch: 0, i:  3324]  train_loss: 1.541  |  valid_loss: 1.387
# [epoch: 0, i:  3499]  train_loss: 1.607  |  valid_loss: 1.608
# [epoch: 0, i:  3674]  train_loss: 1.600  |  valid_loss: 1.328
# [epoch: 0, i:  3849]  train_loss: 1.586  |  valid_loss: 1.416
# [epoch: 0, i:  4024]  train_loss: 1.595  |  valid_loss: 1.419
# [epoch: 0, i:  4199]  train_loss: 1.490  |  valid_loss: 1.473
# [epoch: 0, i:  4374]  train_loss: 1.497  |  valid_loss: 1.368
# [epoch: 0, i:  4549]  train_loss: 1.587  |  valid_loss: 1.586
# [epoch: 0, i:  4724]  train_loss: 1.523  |  valid_loss: 1.423
# [epoch: 0, i:  4899]  train_loss: 1.511  |  valid_loss: 1.459
# [epoch: 0, i:  5074]  train_loss: 1.522  |  valid_loss: 1.484
# [epoch: 0, i:  5249]  train_loss: 1.494  |  valid_loss: 1.326
# [epoch: 0, i:  5424]  train_loss: 1.515  |  valid_loss: 1.306
# [epoch: 0, i:  5599]  train_loss: 1.488  |  valid_loss: 1.235
# [epoch: 0, i:  5774]  train_loss: 1.533  |  valid_loss: 1.315
# [epoch: 0, i:  5949]  train_loss: 1.518  |  valid_loss: 1.562
# [epoch: 0, i:  6124]  train_loss: 1.430  |  valid_loss: 1.431
# [epoch: 0, i:  6299]  train_loss: 1.464  |  valid_loss: 1.381
# [epoch: 0, i:  6474]  train_loss: 1.451  |  valid_loss: 1.355
# [epoch: 0, i:  6649]  train_loss: 1.501  |  valid_loss: 1.376
# [epoch: 0, i:  6824]  train_loss: 1.441  |  valid_loss: 1.278
# [epoch: 0, i:  6999]  train_loss: 1.464  |  valid_loss: 1.151
# [epoch: 0, i:  7174]  train_loss: 1.475  |  valid_loss: 1.203
# [epoch: 0, i:  7349]  train_loss: 1.425  |  valid_loss: 1.293
# [epoch: 0, i:  7524]  train_loss: 1.450  |  valid_loss: 1.222
# [epoch: 0, i:  7699]  train_loss: 1.453  |  valid_loss: 1.332
# [epoch: 0, i:  7874]  train_loss: 1.384  |  valid_loss: 1.200
# [epoch: 0, i:  8049]  train_loss: 1.468  |  valid_loss: 1.290
# [epoch: 0, i:  8224]  train_loss: 1.474  |  valid_loss: 1.278
# [epoch: 0, i:  8399]  train_loss: 1.428  |  valid_loss: 1.215
# [epoch: 0, i:  8574]  train_loss: 1.365  |  valid_loss: 1.163
# [epoch: 0, i:  8749]  train_loss: 1.438  |  valid_loss: 1.328
# [epoch: 0, i:  8924]  train_loss: 1.512  |  valid_loss: 1.270
# [epoch: 0, i:  9099]  train_loss: 1.459  |  valid_loss: 1.318
# [epoch: 0, i:  9274]  train_loss: 1.427  |  valid_loss: 1.153
# [epoch: 0, i:  9449]  train_loss: 1.433  |  valid_loss: 1.367
# [epoch: 0, i:  9624]  train_loss: 1.404  |  valid_loss: 1.259
# [epoch: 0, i:  9799]  train_loss: 1.394  |  valid_loss: 1.238
# [epoch: 0, i:  9974]  train_loss: 1.352  |  valid_loss: 1.200
# [epoch: 0, i: 10149]  train_loss: 1.377  |  valid_loss: 1.120
# [epoch: 0, i: 10324]  train_loss: 1.479  |  valid_loss: 1.316
# [epoch: 0, i: 10499]  train_loss: 1.422  |  valid_loss: 1.203
# [epoch: 0, i: 10674]  train_loss: 1.337  |  valid_loss: 1.289
# [epoch: 0, i: 10849]  train_loss: 1.426  |  valid_loss: 1.257
# [epoch: 0, i: 11024]  train_loss: 1.423  |  valid_loss: 1.292
# [epoch: 0, i: 11199]  train_loss: 1.355  |  valid_loss: 1.202
# [epoch: 0, i: 11374]  train_loss: 1.417  |  valid_loss: 1.248
# [epoch: 0, i: 11549]  train_loss: 1.390  |  valid_loss: 1.235
# [epoch: 0, i: 11724]  train_loss: 1.382  |  valid_loss: 1.292
# [epoch: 0, i: 11899]  train_loss: 1.389  |  valid_loss: 1.364
# [epoch: 0, i: 12074]  train_loss: 1.375  |  valid_loss: 1.319
# [epoch: 0, i: 12249]  train_loss: 1.386  |  valid_loss: 1.233
# [epoch: 0, i: 12424]  train_loss: 1.363  |  valid_loss: 1.202
# [epoch: 0, i: 12599]  train_loss: 1.455  |  valid_loss: 1.102
# [epoch: 0, i: 12774]  train_loss: 1.435  |  valid_loss: 1.131
# [epoch: 0, i: 12949]  train_loss: 1.442  |  valid_loss: 1.031
# [epoch: 0, i: 13124]  train_loss: 1.417  |  valid_loss: 1.162
# [epoch: 0, i: 13299]  train_loss: 1.378  |  valid_loss: 1.263
# [epoch: 0, i: 13474]  train_loss: 1.390  |  valid_loss: 1.128
# [epoch: 0, i: 13649]  train_loss: 1.347  |  valid_loss: 1.084
# [epoch: 0, i: 13824]  train_loss: 1.364  |  valid_loss: 1.281
# [epoch: 0, i: 13999]  train_loss: 1.322  |  valid_loss: 1.208
# [epoch: 0, i: 14174]  train_loss: 1.354  |  valid_loss: 1.014
# [epoch: 0, i: 14349]  train_loss: 1.384  |  valid_loss: 1.213
# [epoch: 0, i: 14524]  train_loss: 1.372  |  valid_loss: 1.238
# [epoch: 0, i: 14699]  train_loss: 1.347  |  valid_loss: 1.225
# [epoch: 0, i: 14874]  train_loss: 1.288  |  valid_loss: 1.275
# [epoch: 0, i: 15049]  train_loss: 1.320  |  valid_loss: 1.133
# [epoch: 0, i: 15224]  train_loss: 1.333  |  valid_loss: 1.246
# [epoch: 0, i: 15399]  train_loss: 1.372  |  valid_loss: 1.227
# [epoch: 0, i: 15574]  train_loss: 1.330  |  valid_loss: 1.139
# [epoch: 0, i: 15749]  train_loss: 1.246  |  valid_loss: 1.254
# [epoch: 0, i: 15924]  train_loss: 1.393  |  valid_loss: 1.237
# [epoch: 0, i: 16099]  train_loss: 1.303  |  valid_loss: 1.013
# [epoch: 0, i: 16274]  train_loss: 1.314  |  valid_loss: 1.135
# [epoch: 0, i: 16449]  train_loss: 1.292  |  valid_loss: 1.153
# [epoch: 0, i: 16624]  train_loss: 1.333  |  valid_loss: 1.237
# [epoch: 0, i: 16799]  train_loss: 1.311  |  valid_loss: 1.071
# [epoch: 0, i: 16974]  train_loss: 1.306  |  valid_loss: 0.985
# [epoch: 0, i: 17149]  train_loss: 1.378  |  valid_loss: 1.180
# [epoch: 0, i: 17324]  train_loss: 1.215  |  valid_loss: 1.271
# [epoch: 0, i: 17499]  train_loss: 1.316  |  valid_loss: 1.243
# --> [End of epoch 0] train_accuracy: 47.76%  |  valid_accuracy: 52.21%
# --> [Start of epoch 1]  lr: 0.000500
# [epoch: 1, i:   174]  train_loss: 1.323  |  valid_loss: 1.100
# [epoch: 1, i:   349]  train_loss: 1.467  |  valid_loss: 1.258
# [epoch: 1, i:   524]  train_loss: 1.293  |  valid_loss: 1.147
# [epoch: 1, i:   699]  train_loss: 1.289  |  valid_loss: 1.109
# [epoch: 1, i:   874]  train_loss: 1.334  |  valid_loss: 1.253
# [epoch: 1, i:  1049]  train_loss: 1.372  |  valid_loss: 1.033
# [epoch: 1, i:  1224]  train_loss: 1.307  |  valid_loss: 1.027
# [epoch: 1, i:  1399]  train_loss: 1.340  |  valid_loss: 1.139
# [epoch: 1, i:  1574]  train_loss: 1.279  |  valid_loss: 1.124
# [epoch: 1, i:  1749]  train_loss: 1.321  |  valid_loss: 1.084
# [epoch: 1, i:  1924]  train_loss: 1.232  |  valid_loss: 1.050
# [epoch: 1, i:  2099]  train_loss: 1.344  |  valid_loss: 1.131
# [epoch: 1, i:  2274]  train_loss: 1.327  |  valid_loss: 1.054
# [epoch: 1, i:  2449]  train_loss: 1.272  |  valid_loss: 1.110
# [epoch: 1, i:  2624]  train_loss: 1.249  |  valid_loss: 0.993
# [epoch: 1, i:  2799]  train_loss: 1.265  |  valid_loss: 1.181
# [epoch: 1, i:  2974]  train_loss: 1.287  |  valid_loss: 1.124
# [epoch: 1, i:  3149]  train_loss: 1.256  |  valid_loss: 1.117
# [epoch: 1, i:  3324]  train_loss: 1.269  |  valid_loss: 0.976
# [epoch: 1, i:  3499]  train_loss: 1.313  |  valid_loss: 1.226
# [epoch: 1, i:  3674]  train_loss: 1.253  |  valid_loss: 1.137
# [epoch: 1, i:  3849]  train_loss: 1.240  |  valid_loss: 1.115
# [epoch: 1, i:  4024]  train_loss: 1.252  |  valid_loss: 1.173
# [epoch: 1, i:  4199]  train_loss: 1.211  |  valid_loss: 1.063
# [epoch: 1, i:  4374]  train_loss: 1.260  |  valid_loss: 0.971
# [epoch: 1, i:  4549]  train_loss: 1.225  |  valid_loss: 1.374
# [epoch: 1, i:  4724]  train_loss: 1.230  |  valid_loss: 0.949
# [epoch: 1, i:  4899]  train_loss: 1.311  |  valid_loss: 1.181
# [epoch: 1, i:  5074]  train_loss: 1.229  |  valid_loss: 1.174
# [epoch: 1, i:  5249]  train_loss: 1.241  |  valid_loss: 0.953
# [epoch: 1, i:  5424]  train_loss: 1.239  |  valid_loss: 0.983
# [epoch: 1, i:  5599]  train_loss: 1.276  |  valid_loss: 1.035
# [epoch: 1, i:  5774]  train_loss: 1.264  |  valid_loss: 1.080
# [epoch: 1, i:  5949]  train_loss: 1.211  |  valid_loss: 1.277
# [epoch: 1, i:  6124]  train_loss: 1.266  |  valid_loss: 1.139
# [epoch: 1, i:  6299]  train_loss: 1.249  |  valid_loss: 1.026
# [epoch: 1, i:  6474]  train_loss: 1.216  |  valid_loss: 1.157
# [epoch: 1, i:  6649]  train_loss: 1.233  |  valid_loss: 1.285
# [epoch: 1, i:  6824]  train_loss: 1.301  |  valid_loss: 0.998
# [epoch: 1, i:  6999]  train_loss: 1.240  |  valid_loss: 1.059
# [epoch: 1, i:  7174]  train_loss: 1.206  |  valid_loss: 0.943
# [epoch: 1, i:  7349]  train_loss: 1.200  |  valid_loss: 0.955
# [epoch: 1, i:  7524]  train_loss: 1.207  |  valid_loss: 0.912
# [epoch: 1, i:  7699]  train_loss: 1.246  |  valid_loss: 1.001
# [epoch: 1, i:  7874]  train_loss: 1.237  |  valid_loss: 1.025
# [epoch: 1, i:  8049]  train_loss: 1.215  |  valid_loss: 1.124
# [epoch: 1, i:  8224]  train_loss: 1.288  |  valid_loss: 0.975
# [epoch: 1, i:  8399]  train_loss: 1.241  |  valid_loss: 0.996
# [epoch: 1, i:  8574]  train_loss: 1.206  |  valid_loss: 0.883
# [epoch: 1, i:  8749]  train_loss: 1.222  |  valid_loss: 1.149
# [epoch: 1, i:  8924]  train_loss: 1.251  |  valid_loss: 1.094
# [epoch: 1, i:  9099]  train_loss: 1.325  |  valid_loss: 1.074
# [epoch: 1, i:  9274]  train_loss: 1.237  |  valid_loss: 1.015
# [epoch: 1, i:  9449]  train_loss: 1.203  |  valid_loss: 1.095
# [epoch: 1, i:  9624]  train_loss: 1.212  |  valid_loss: 1.176
# [epoch: 1, i:  9799]  train_loss: 1.267  |  valid_loss: 1.121
# [epoch: 1, i:  9974]  train_loss: 1.249  |  valid_loss: 1.046
# [epoch: 1, i: 10149]  train_loss: 1.230  |  valid_loss: 0.891
# [epoch: 1, i: 10324]  train_loss: 1.235  |  valid_loss: 1.287
# [epoch: 1, i: 10499]  train_loss: 1.266  |  valid_loss: 1.016
# [epoch: 1, i: 10674]  train_loss: 1.285  |  valid_loss: 1.114
# [epoch: 1, i: 10849]  train_loss: 1.222  |  valid_loss: 1.084
# [epoch: 1, i: 11024]  train_loss: 1.226  |  valid_loss: 1.015
# [epoch: 1, i: 11199]  train_loss: 1.204  |  valid_loss: 1.054
# [epoch: 1, i: 11374]  train_loss: 1.296  |  valid_loss: 1.033
# [epoch: 1, i: 11549]  train_loss: 1.268  |  valid_loss: 1.093
# [epoch: 1, i: 11724]  train_loss: 1.236  |  valid_loss: 1.009
# [epoch: 1, i: 11899]  train_loss: 1.289  |  valid_loss: 1.192
# [epoch: 1, i: 12074]  train_loss: 1.196  |  valid_loss: 1.070
# [epoch: 1, i: 12249]  train_loss: 1.302  |  valid_loss: 1.244
# [epoch: 1, i: 12424]  train_loss: 1.320  |  valid_loss: 1.145
# [epoch: 1, i: 12599]  train_loss: 1.215  |  valid_loss: 0.923
# [epoch: 1, i: 12774]  train_loss: 1.214  |  valid_loss: 1.005
# [epoch: 1, i: 12949]  train_loss: 1.293  |  valid_loss: 0.872
# [epoch: 1, i: 13124]  train_loss: 1.217  |  valid_loss: 1.015
# [epoch: 1, i: 13299]  train_loss: 1.304  |  valid_loss: 1.013
# [epoch: 1, i: 13474]  train_loss: 1.237  |  valid_loss: 1.047
# [epoch: 1, i: 13649]  train_loss: 1.198  |  valid_loss: 1.031
# [epoch: 1, i: 13824]  train_loss: 1.295  |  valid_loss: 1.167
# [epoch: 1, i: 13999]  train_loss: 1.230  |  valid_loss: 1.055
# [epoch: 1, i: 14174]  train_loss: 1.255  |  valid_loss: 0.916
# [epoch: 1, i: 14349]  train_loss: 1.171  |  valid_loss: 1.084
# [epoch: 1, i: 14524]  train_loss: 1.274  |  valid_loss: 1.074
# [epoch: 1, i: 14699]  train_loss: 1.254  |  valid_loss: 1.089
# [epoch: 1, i: 14874]  train_loss: 1.181  |  valid_loss: 1.075
# [epoch: 1, i: 15049]  train_loss: 1.239  |  valid_loss: 1.000
# [epoch: 1, i: 15224]  train_loss: 1.178  |  valid_loss: 1.116
# [epoch: 1, i: 15399]  train_loss: 1.237  |  valid_loss: 1.128
# [epoch: 1, i: 15574]  train_loss: 1.181  |  valid_loss: 1.064
# [epoch: 1, i: 15749]  train_loss: 1.290  |  valid_loss: 1.102
# [epoch: 1, i: 15924]  train_loss: 1.284  |  valid_loss: 1.014
# [epoch: 1, i: 16099]  train_loss: 1.205  |  valid_loss: 0.864
# [epoch: 1, i: 16274]  train_loss: 1.186  |  valid_loss: 1.045
# [epoch: 1, i: 16449]  train_loss: 1.188  |  valid_loss: 1.037
# [epoch: 1, i: 16624]  train_loss: 1.207  |  valid_loss: 0.983
# [epoch: 1, i: 16799]  train_loss: 1.192  |  valid_loss: 0.970
# [epoch: 1, i: 16974]  train_loss: 1.202  |  valid_loss: 0.858
# [epoch: 1, i: 17149]  train_loss: 1.214  |  valid_loss: 1.191
# [epoch: 1, i: 17324]  train_loss: 1.315  |  valid_loss: 1.051
# [epoch: 1, i: 17499]  train_loss: 1.249  |  valid_loss: 0.961
# --> [End of epoch 1] train_accuracy: 56.34%  |  valid_accuracy: 62.53%
# --> [Start of epoch 2]  lr: 0.000500
# [epoch: 2, i:   174]  train_loss: 1.156  |  valid_loss: 0.989
# [epoch: 2, i:   349]  train_loss: 1.175  |  valid_loss: 0.989
# [epoch: 2, i:   524]  train_loss: 1.175  |  valid_loss: 0.979
# [epoch: 2, i:   699]  train_loss: 1.158  |  valid_loss: 0.939
# [epoch: 2, i:   874]  train_loss: 1.121  |  valid_loss: 1.029
# [epoch: 2, i:  1049]  train_loss: 1.229  |  valid_loss: 0.873
# [epoch: 2, i:  1224]  train_loss: 1.203  |  valid_loss: 0.939
# [epoch: 2, i:  1399]  train_loss: 1.200  |  valid_loss: 1.134
# [epoch: 2, i:  1574]  train_loss: 1.193  |  valid_loss: 1.067
# [epoch: 2, i:  1749]  train_loss: 1.195  |  valid_loss: 0.929
# [epoch: 2, i:  1924]  train_loss: 1.137  |  valid_loss: 0.866
# [epoch: 2, i:  2099]  train_loss: 1.139  |  valid_loss: 0.982
# [epoch: 2, i:  2274]  train_loss: 1.238  |  valid_loss: 0.982
# [epoch: 2, i:  2449]  train_loss: 1.077  |  valid_loss: 1.002
# [epoch: 2, i:  2624]  train_loss: 1.204  |  valid_loss: 0.902
# [epoch: 2, i:  2799]  train_loss: 1.213  |  valid_loss: 1.076
# [epoch: 2, i:  2974]  train_loss: 1.158  |  valid_loss: 1.034
# [epoch: 2, i:  3149]  train_loss: 1.114  |  valid_loss: 0.990
# [epoch: 2, i:  3324]  train_loss: 1.152  |  valid_loss: 0.978
# [epoch: 2, i:  3499]  train_loss: 1.198  |  valid_loss: 1.221
# [epoch: 2, i:  3674]  train_loss: 1.191  |  valid_loss: 1.014
# [epoch: 2, i:  3849]  train_loss: 1.188  |  valid_loss: 0.996
# [epoch: 2, i:  4024]  train_loss: 1.182  |  valid_loss: 0.967
# [epoch: 2, i:  4199]  train_loss: 1.124  |  valid_loss: 1.017
# [epoch: 2, i:  4374]  train_loss: 1.163  |  valid_loss: 1.023
# [epoch: 2, i:  4549]  train_loss: 1.168  |  valid_loss: 1.138
# [epoch: 2, i:  4724]  train_loss: 1.170  |  valid_loss: 0.845
# [epoch: 2, i:  4899]  train_loss: 1.155  |  valid_loss: 1.053
# [epoch: 2, i:  5074]  train_loss: 1.115  |  valid_loss: 1.082
# [epoch: 2, i:  5249]  train_loss: 1.128  |  valid_loss: 0.916
# [epoch: 2, i:  5424]  train_loss: 1.101  |  valid_loss: 0.892
# [epoch: 2, i:  5599]  train_loss: 1.243  |  valid_loss: 0.940
# [epoch: 2, i:  5774]  train_loss: 1.285  |  valid_loss: 0.967
# [epoch: 2, i:  5949]  train_loss: 1.127  |  valid_loss: 1.136
# [epoch: 2, i:  6124]  train_loss: 1.183  |  valid_loss: 1.065
# [epoch: 2, i:  6299]  train_loss: 1.194  |  valid_loss: 0.928
# [epoch: 2, i:  6474]  train_loss: 1.151  |  valid_loss: 1.104
# [epoch: 2, i:  6649]  train_loss: 1.082  |  valid_loss: 0.985
# [epoch: 2, i:  6824]  train_loss: 1.215  |  valid_loss: 0.961
# [epoch: 2, i:  6999]  train_loss: 1.150  |  valid_loss: 0.846
# [epoch: 2, i:  7174]  train_loss: 1.154  |  valid_loss: 0.874
# [epoch: 2, i:  7349]  train_loss: 1.200  |  valid_loss: 0.849
# [epoch: 2, i:  7524]  train_loss: 1.169  |  valid_loss: 0.777
# [epoch: 2, i:  7699]  train_loss: 1.141  |  valid_loss: 0.898
# [epoch: 2, i:  7874]  train_loss: 1.139  |  valid_loss: 0.877
# [epoch: 2, i:  8049]  train_loss: 1.169  |  valid_loss: 0.980
# [epoch: 2, i:  8224]  train_loss: 1.099  |  valid_loss: 0.928
# [epoch: 2, i:  8399]  train_loss: 1.156  |  valid_loss: 0.956
# [epoch: 2, i:  8574]  train_loss: 1.129  |  valid_loss: 0.795
# [epoch: 2, i:  8749]  train_loss: 1.216  |  valid_loss: 1.047
# [epoch: 2, i:  8924]  train_loss: 1.197  |  valid_loss: 0.999
# [epoch: 2, i:  9099]  train_loss: 1.074  |  valid_loss: 1.054
# [epoch: 2, i:  9274]  train_loss: 1.100  |  valid_loss: 0.882
# [epoch: 2, i:  9449]  train_loss: 1.175  |  valid_loss: 1.132
# [epoch: 2, i:  9624]  train_loss: 1.198  |  valid_loss: 1.034
# [epoch: 2, i:  9799]  train_loss: 1.126  |  valid_loss: 1.045
# [epoch: 2, i:  9974]  train_loss: 1.083  |  valid_loss: 1.029
# [epoch: 2, i: 10149]  train_loss: 1.167  |  valid_loss: 0.805
# [epoch: 2, i: 10324]  train_loss: 1.192  |  valid_loss: 1.222
# [epoch: 2, i: 10499]  train_loss: 1.245  |  valid_loss: 0.969
# [epoch: 2, i: 10674]  train_loss: 1.136  |  valid_loss: 1.066
# [epoch: 2, i: 10849]  train_loss: 1.142  |  valid_loss: 0.980
# [epoch: 2, i: 11024]  train_loss: 1.174  |  valid_loss: 0.888
# [epoch: 2, i: 11199]  train_loss: 1.143  |  valid_loss: 0.893
# [epoch: 2, i: 11374]  train_loss: 1.176  |  valid_loss: 1.039
# [epoch: 2, i: 11549]  train_loss: 1.196  |  valid_loss: 1.040
# [epoch: 2, i: 11724]  train_loss: 1.194  |  valid_loss: 0.961
# [epoch: 2, i: 11899]  train_loss: 1.184  |  valid_loss: 0.978
# [epoch: 2, i: 12074]  train_loss: 1.126  |  valid_loss: 0.888
# [epoch: 2, i: 12249]  train_loss: 1.227  |  valid_loss: 1.164
# [epoch: 2, i: 12424]  train_loss: 1.235  |  valid_loss: 0.928
# [epoch: 2, i: 12599]  train_loss: 1.143  |  valid_loss: 0.888
# [epoch: 2, i: 12774]  train_loss: 1.137  |  valid_loss: 0.985
# [epoch: 2, i: 12949]  train_loss: 1.192  |  valid_loss: 0.828
# [epoch: 2, i: 13124]  train_loss: 1.164  |  valid_loss: 0.899
# [epoch: 2, i: 13299]  train_loss: 1.139  |  valid_loss: 0.933
# [epoch: 2, i: 13474]  train_loss: 1.171  |  valid_loss: 0.918
# [epoch: 2, i: 13649]  train_loss: 1.123  |  valid_loss: 0.936
# [epoch: 2, i: 13824]  train_loss: 1.296  |  valid_loss: 1.020
# [epoch: 2, i: 13999]  train_loss: 1.086  |  valid_loss: 1.001
# [epoch: 2, i: 14174]  train_loss: 1.105  |  valid_loss: 0.819
# [epoch: 2, i: 14349]  train_loss: 1.100  |  valid_loss: 1.017
# [epoch: 2, i: 14524]  train_loss: 1.119  |  valid_loss: 0.971
# [epoch: 2, i: 14699]  train_loss: 1.120  |  valid_loss: 1.021
# [epoch: 2, i: 14874]  train_loss: 1.151  |  valid_loss: 1.037
# [epoch: 2, i: 15049]  train_loss: 1.131  |  valid_loss: 0.925
# [epoch: 2, i: 15224]  train_loss: 1.170  |  valid_loss: 1.055
# [epoch: 2, i: 15399]  train_loss: 1.199  |  valid_loss: 0.983
# [epoch: 2, i: 15574]  train_loss: 1.133  |  valid_loss: 1.021
# [epoch: 2, i: 15749]  train_loss: 1.176  |  valid_loss: 1.030
# [epoch: 2, i: 15924]  train_loss: 1.099  |  valid_loss: 0.889
# [epoch: 2, i: 16099]  train_loss: 1.225  |  valid_loss: 0.805
# [epoch: 2, i: 16274]  train_loss: 1.097  |  valid_loss: 0.940
# [epoch: 2, i: 16449]  train_loss: 1.129  |  valid_loss: 1.061
# [epoch: 2, i: 16624]  train_loss: 1.139  |  valid_loss: 0.934
# [epoch: 2, i: 16799]  train_loss: 1.100  |  valid_loss: 0.882
# [epoch: 2, i: 16974]  train_loss: 1.148  |  valid_loss: 0.926
# [epoch: 2, i: 17149]  train_loss: 1.111  |  valid_loss: 1.186
# [epoch: 2, i: 17324]  train_loss: 1.143  |  valid_loss: 1.070
# [epoch: 2, i: 17499]  train_loss: 1.143  |  valid_loss: 0.923
# --> [End of epoch 2] train_accuracy: 59.87%  |  valid_accuracy: 66.33%
# --> [Start of epoch 3]  lr: 0.000500
# [epoch: 3, i:   174]  train_loss: 1.052  |  valid_loss: 0.781
# [epoch: 3, i:   349]  train_loss: 1.073  |  valid_loss: 0.971
# [epoch: 3, i:   524]  train_loss: 1.146  |  valid_loss: 1.015
# [epoch: 3, i:   699]  train_loss: 1.146  |  valid_loss: 0.942
# [epoch: 3, i:   874]  train_loss: 1.168  |  valid_loss: 0.982
# [epoch: 3, i:  1049]  train_loss: 1.090  |  valid_loss: 0.703
# [epoch: 3, i:  1224]  train_loss: 1.152  |  valid_loss: 0.812
# [epoch: 3, i:  1399]  train_loss: 1.133  |  valid_loss: 1.073
# [epoch: 3, i:  1574]  train_loss: 1.158  |  valid_loss: 1.073
# [epoch: 3, i:  1749]  train_loss: 1.119  |  valid_loss: 0.824
# [epoch: 3, i:  1924]  train_loss: 1.126  |  valid_loss: 0.853
# [epoch: 3, i:  2099]  train_loss: 1.094  |  valid_loss: 0.900
# [epoch: 3, i:  2274]  train_loss: 1.077  |  valid_loss: 1.014
# [epoch: 3, i:  2449]  train_loss: 1.086  |  valid_loss: 0.873
# [epoch: 3, i:  2624]  train_loss: 1.094  |  valid_loss: 0.880
# [epoch: 3, i:  2799]  train_loss: 1.125  |  valid_loss: 0.965
# [epoch: 3, i:  2974]  train_loss: 1.079  |  valid_loss: 0.908
# [epoch: 3, i:  3149]  train_loss: 1.151  |  valid_loss: 0.939
# [epoch: 3, i:  3324]  train_loss: 1.061  |  valid_loss: 0.879
# [epoch: 3, i:  3499]  train_loss: 1.081  |  valid_loss: 1.063
# [epoch: 3, i:  3674]  train_loss: 1.061  |  valid_loss: 1.082
# [epoch: 3, i:  3849]  train_loss: 1.120  |  valid_loss: 0.935
# [epoch: 3, i:  4024]  train_loss: 1.116  |  valid_loss: 0.872
# [epoch: 3, i:  4199]  train_loss: 1.101  |  valid_loss: 0.919
# [epoch: 3, i:  4374]  train_loss: 1.094  |  valid_loss: 1.088
# [epoch: 3, i:  4549]  train_loss: 1.146  |  valid_loss: 1.106
# [epoch: 3, i:  4724]  train_loss: 1.155  |  valid_loss: 0.773
# [epoch: 3, i:  4899]  train_loss: 1.070  |  valid_loss: 1.082
# [epoch: 3, i:  5074]  train_loss: 1.077  |  valid_loss: 0.972
# [epoch: 3, i:  5249]  train_loss: 1.127  |  valid_loss: 0.874
# [epoch: 3, i:  5424]  train_loss: 1.110  |  valid_loss: 0.921
# [epoch: 3, i:  5599]  train_loss: 1.032  |  valid_loss: 0.795
# [epoch: 3, i:  5774]  train_loss: 1.159  |  valid_loss: 0.899
# [epoch: 3, i:  5949]  train_loss: 1.042  |  valid_loss: 1.092
# [epoch: 3, i:  6124]  train_loss: 1.100  |  valid_loss: 0.951
# [epoch: 3, i:  6299]  train_loss: 1.071  |  valid_loss: 0.873
# [epoch: 3, i:  6474]  train_loss: 1.148  |  valid_loss: 0.982
# [epoch: 3, i:  6649]  train_loss: 1.119  |  valid_loss: 1.036
# [epoch: 3, i:  6824]  train_loss: 1.078  |  valid_loss: 0.870
# [epoch: 3, i:  6999]  train_loss: 1.189  |  valid_loss: 0.852
# [epoch: 3, i:  7174]  train_loss: 1.130  |  valid_loss: 0.833
# [epoch: 3, i:  7349]  train_loss: 1.125  |  valid_loss: 0.898
# [epoch: 3, i:  7524]  train_loss: 1.124  |  valid_loss: 0.725
# [epoch: 3, i:  7699]  train_loss: 1.094  |  valid_loss: 0.853
# [epoch: 3, i:  7874]  train_loss: 1.110  |  valid_loss: 0.791
# [epoch: 3, i:  8049]  train_loss: 1.099  |  valid_loss: 0.979
# [epoch: 3, i:  8224]  train_loss: 1.072  |  valid_loss: 0.921
# [epoch: 3, i:  8399]  train_loss: 1.106  |  valid_loss: 0.900
# [epoch: 3, i:  8574]  train_loss: 1.094  |  valid_loss: 0.763
# [epoch: 3, i:  8749]  train_loss: 1.010  |  valid_loss: 1.030
# [epoch: 3, i:  8924]  train_loss: 1.109  |  valid_loss: 0.851
# [epoch: 3, i:  9099]  train_loss: 1.126  |  valid_loss: 0.999
# [epoch: 3, i:  9274]  train_loss: 1.104  |  valid_loss: 0.810
# [epoch: 3, i:  9449]  train_loss: 1.171  |  valid_loss: 0.997
# [epoch: 3, i:  9624]  train_loss: 1.121  |  valid_loss: 0.917
# [epoch: 3, i:  9799]  train_loss: 1.141  |  valid_loss: 0.990
# [epoch: 3, i:  9974]  train_loss: 0.945  |  valid_loss: 0.983
# [epoch: 3, i: 10149]  train_loss: 1.087  |  valid_loss: 0.730
# [epoch: 3, i: 10324]  train_loss: 1.075  |  valid_loss: 1.089
# [epoch: 3, i: 10499]  train_loss: 1.172  |  valid_loss: 0.930
# [epoch: 3, i: 10674]  train_loss: 1.109  |  valid_loss: 1.001
# [epoch: 3, i: 10849]  train_loss: 1.098  |  valid_loss: 0.922
# [epoch: 3, i: 11024]  train_loss: 1.058  |  valid_loss: 0.897
# [epoch: 3, i: 11199]  train_loss: 1.137  |  valid_loss: 0.876
# [epoch: 3, i: 11374]  train_loss: 1.112  |  valid_loss: 0.904
# [epoch: 3, i: 11549]  train_loss: 1.089  |  valid_loss: 0.930
# [epoch: 3, i: 11724]  train_loss: 1.044  |  valid_loss: 0.871
# [epoch: 3, i: 11899]  train_loss: 1.153  |  valid_loss: 0.978
# [epoch: 3, i: 12074]  train_loss: 1.105  |  valid_loss: 0.908
# [epoch: 3, i: 12249]  train_loss: 1.074  |  valid_loss: 1.040
# [epoch: 3, i: 12424]  train_loss: 1.130  |  valid_loss: 0.943
# [epoch: 3, i: 12599]  train_loss: 1.180  |  valid_loss: 0.865
# [epoch: 3, i: 12774]  train_loss: 1.096  |  valid_loss: 0.864
# [epoch: 3, i: 12949]  train_loss: 1.105  |  valid_loss: 0.769
# [epoch: 3, i: 13124]  train_loss: 1.064  |  valid_loss: 0.989
# [epoch: 3, i: 13299]  train_loss: 1.095  |  valid_loss: 0.921
# [epoch: 3, i: 13474]  train_loss: 1.076  |  valid_loss: 0.955
# [epoch: 3, i: 13649]  train_loss: 1.170  |  valid_loss: 0.921
# [epoch: 3, i: 13824]  train_loss: 1.141  |  valid_loss: 1.019
# [epoch: 3, i: 13999]  train_loss: 1.127  |  valid_loss: 0.979
# [epoch: 3, i: 14174]  train_loss: 1.068  |  valid_loss: 0.802
# [epoch: 3, i: 14349]  train_loss: 1.057  |  valid_loss: 0.970
# [epoch: 3, i: 14524]  train_loss: 1.128  |  valid_loss: 0.902
# [epoch: 3, i: 14699]  train_loss: 1.106  |  valid_loss: 0.967
# [epoch: 3, i: 14874]  train_loss: 1.191  |  valid_loss: 1.008
# [epoch: 3, i: 15049]  train_loss: 1.098  |  valid_loss: 0.876
# [epoch: 3, i: 15224]  train_loss: 1.159  |  valid_loss: 0.946
# [epoch: 3, i: 15399]  train_loss: 1.057  |  valid_loss: 1.024
# [epoch: 3, i: 15574]  train_loss: 1.183  |  valid_loss: 1.000
# [epoch: 3, i: 15749]  train_loss: 1.078  |  valid_loss: 0.985
# [epoch: 3, i: 15924]  train_loss: 1.054  |  valid_loss: 0.842
# [epoch: 3, i: 16099]  train_loss: 1.086  |  valid_loss: 0.750
# [epoch: 3, i: 16274]  train_loss: 1.217  |  valid_loss: 0.966
# [epoch: 3, i: 16449]  train_loss: 1.034  |  valid_loss: 0.969
# [epoch: 3, i: 16624]  train_loss: 1.138  |  valid_loss: 0.859
# [epoch: 3, i: 16799]  train_loss: 1.136  |  valid_loss: 0.851
# [epoch: 3, i: 16974]  train_loss: 1.042  |  valid_loss: 0.747
# [epoch: 3, i: 17149]  train_loss: 0.976  |  valid_loss: 1.065
# [epoch: 3, i: 17324]  train_loss: 1.095  |  valid_loss: 0.956
# [epoch: 3, i: 17499]  train_loss: 1.066  |  valid_loss: 0.821
# --> [End of epoch 3] train_accuracy: 61.80%  |  valid_accuracy: 67.95%
# --> [Start of epoch 4]  lr: 0.000500
# [epoch: 4, i:   174]  train_loss: 1.075  |  valid_loss: 0.853
# [epoch: 4, i:   349]  train_loss: 1.008  |  valid_loss: 0.872
# [epoch: 4, i:   524]  train_loss: 1.110  |  valid_loss: 0.957
# [epoch: 4, i:   699]  train_loss: 1.050  |  valid_loss: 0.813
# [epoch: 4, i:   874]  train_loss: 1.014  |  valid_loss: 1.021
# [epoch: 4, i:  1049]  train_loss: 1.054  |  valid_loss: 0.717
# [epoch: 4, i:  1224]  train_loss: 1.142  |  valid_loss: 0.835
# [epoch: 4, i:  1399]  train_loss: 1.045  |  valid_loss: 0.947
# [epoch: 4, i:  1574]  train_loss: 1.040  |  valid_loss: 1.030
# [epoch: 4, i:  1749]  train_loss: 1.100  |  valid_loss: 0.824
# [epoch: 4, i:  1924]  train_loss: 1.111  |  valid_loss: 0.755
# [epoch: 4, i:  2099]  train_loss: 1.059  |  valid_loss: 0.952
# [epoch: 4, i:  2274]  train_loss: 1.113  |  valid_loss: 0.819
# [epoch: 4, i:  2449]  train_loss: 1.080  |  valid_loss: 0.833
# [epoch: 4, i:  2624]  train_loss: 1.028  |  valid_loss: 0.850
# [epoch: 4, i:  2799]  train_loss: 1.037  |  valid_loss: 0.913
# [epoch: 4, i:  2974]  train_loss: 1.019  |  valid_loss: 0.988
# [epoch: 4, i:  3149]  train_loss: 1.049  |  valid_loss: 0.956
# [epoch: 4, i:  3324]  train_loss: 1.086  |  valid_loss: 0.821
# [epoch: 4, i:  3499]  train_loss: 1.113  |  valid_loss: 1.028
# [epoch: 4, i:  3674]  train_loss: 1.051  |  valid_loss: 1.049
# [epoch: 4, i:  3849]  train_loss: 1.101  |  valid_loss: 0.918
# [epoch: 4, i:  4024]  train_loss: 1.089  |  valid_loss: 0.875
# [epoch: 4, i:  4199]  train_loss: 1.028  |  valid_loss: 0.902
# [epoch: 4, i:  4374]  train_loss: 1.060  |  valid_loss: 0.932
# [epoch: 4, i:  4549]  train_loss: 1.037  |  valid_loss: 1.078
# [epoch: 4, i:  4724]  train_loss: 1.038  |  valid_loss: 0.782
# [epoch: 4, i:  4899]  train_loss: 1.111  |  valid_loss: 1.091
# [epoch: 4, i:  5074]  train_loss: 1.077  |  valid_loss: 0.893
# [epoch: 4, i:  5249]  train_loss: 1.001  |  valid_loss: 0.815
# [epoch: 4, i:  5424]  train_loss: 1.061  |  valid_loss: 0.832
# [epoch: 4, i:  5599]  train_loss: 1.044  |  valid_loss: 0.851
# [epoch: 4, i:  5774]  train_loss: 1.040  |  valid_loss: 0.933
# [epoch: 4, i:  5949]  train_loss: 1.118  |  valid_loss: 1.039
# [epoch: 4, i:  6124]  train_loss: 0.989  |  valid_loss: 0.893
# [epoch: 4, i:  6299]  train_loss: 1.106  |  valid_loss: 0.855
# [epoch: 4, i:  6474]  train_loss: 1.050  |  valid_loss: 0.981
# [epoch: 4, i:  6649]  train_loss: 1.138  |  valid_loss: 1.022
# [epoch: 4, i:  6824]  train_loss: 1.116  |  valid_loss: 0.842
# [epoch: 4, i:  6999]  train_loss: 1.159  |  valid_loss: 0.762
# [epoch: 4, i:  7174]  train_loss: 1.030  |  valid_loss: 0.795
# [epoch: 4, i:  7349]  train_loss: 1.123  |  valid_loss: 0.818
# [epoch: 4, i:  7524]  train_loss: 1.079  |  valid_loss: 0.742
# [epoch: 4, i:  7699]  train_loss: 1.110  |  valid_loss: 0.842
# [epoch: 4, i:  7874]  train_loss: 1.065  |  valid_loss: 0.792
# [epoch: 4, i:  8049]  train_loss: 1.074  |  valid_loss: 0.906
# [epoch: 4, i:  8224]  train_loss: 1.076  |  valid_loss: 0.852
# [epoch: 4, i:  8399]  train_loss: 1.110  |  valid_loss: 0.888
# [epoch: 4, i:  8574]  train_loss: 1.089  |  valid_loss: 0.736
# [epoch: 4, i:  8749]  train_loss: 1.102  |  valid_loss: 0.950
# [epoch: 4, i:  8924]  train_loss: 1.091  |  valid_loss: 0.881
# [epoch: 4, i:  9099]  train_loss: 1.036  |  valid_loss: 0.915
# [epoch: 4, i:  9274]  train_loss: 1.081  |  valid_loss: 0.854
# [epoch: 4, i:  9449]  train_loss: 1.063  |  valid_loss: 1.012
# [epoch: 4, i:  9624]  train_loss: 1.135  |  valid_loss: 0.933
# [epoch: 4, i:  9799]  train_loss: 1.062  |  valid_loss: 0.995
# [epoch: 4, i:  9974]  train_loss: 1.063  |  valid_loss: 0.972
# [epoch: 4, i: 10149]  train_loss: 1.038  |  valid_loss: 0.758
# [epoch: 4, i: 10324]  train_loss: 1.109  |  valid_loss: 1.076
# [epoch: 4, i: 10499]  train_loss: 1.077  |  valid_loss: 0.964
# [epoch: 4, i: 10674]  train_loss: 1.012  |  valid_loss: 0.913
# [epoch: 4, i: 10849]  train_loss: 0.974  |  valid_loss: 0.935
# [epoch: 4, i: 11024]  train_loss: 1.083  |  valid_loss: 0.799
# [epoch: 4, i: 11199]  train_loss: 1.072  |  valid_loss: 0.787
# [epoch: 4, i: 11374]  train_loss: 1.037  |  valid_loss: 0.862
# [epoch: 4, i: 11549]  train_loss: 1.016  |  valid_loss: 0.946
# [epoch: 4, i: 11724]  train_loss: 1.109  |  valid_loss: 0.818
# [epoch: 4, i: 11899]  train_loss: 1.104  |  valid_loss: 0.905
# [epoch: 4, i: 12074]  train_loss: 1.167  |  valid_loss: 0.866
# [epoch: 4, i: 12249]  train_loss: 1.039  |  valid_loss: 1.061
# [epoch: 4, i: 12424]  train_loss: 1.097  |  valid_loss: 0.895
# [epoch: 4, i: 12599]  train_loss: 1.109  |  valid_loss: 0.810
# [epoch: 4, i: 12774]  train_loss: 1.069  |  valid_loss: 0.892
# [epoch: 4, i: 12949]  train_loss: 1.096  |  valid_loss: 0.735
# [epoch: 4, i: 13124]  train_loss: 1.084  |  valid_loss: 0.910
# [epoch: 4, i: 13299]  train_loss: 1.012  |  valid_loss: 0.842
# [epoch: 4, i: 13474]  train_loss: 1.125  |  valid_loss: 0.877
# [epoch: 4, i: 13649]  train_loss: 1.078  |  valid_loss: 0.798
# [epoch: 4, i: 13824]  train_loss: 1.023  |  valid_loss: 0.956
# [epoch: 4, i: 13999]  train_loss: 1.094  |  valid_loss: 0.887
# [epoch: 4, i: 14174]  train_loss: 1.071  |  valid_loss: 0.759
# [epoch: 4, i: 14349]  train_loss: 1.076  |  valid_loss: 0.863
# [epoch: 4, i: 14524]  train_loss: 1.058  |  valid_loss: 0.929
# [epoch: 4, i: 14699]  train_loss: 1.037  |  valid_loss: 0.959
# [epoch: 4, i: 14874]  train_loss: 1.112  |  valid_loss: 0.906
# [epoch: 4, i: 15049]  train_loss: 1.082  |  valid_loss: 0.849
# [epoch: 4, i: 15224]  train_loss: 0.994  |  valid_loss: 0.911
# [epoch: 4, i: 15399]  train_loss: 1.043  |  valid_loss: 0.999
# [epoch: 4, i: 15574]  train_loss: 1.029  |  valid_loss: 0.896
# [epoch: 4, i: 15749]  train_loss: 1.109  |  valid_loss: 0.874
# [epoch: 4, i: 15924]  train_loss: 1.059  |  valid_loss: 0.777
# [epoch: 4, i: 16099]  train_loss: 1.042  |  valid_loss: 0.787
# [epoch: 4, i: 16274]  train_loss: 1.038  |  valid_loss: 1.006
# [epoch: 4, i: 16449]  train_loss: 0.998  |  valid_loss: 0.992
# [epoch: 4, i: 16624]  train_loss: 1.123  |  valid_loss: 0.860
# [epoch: 4, i: 16799]  train_loss: 1.094  |  valid_loss: 0.882
# [epoch: 4, i: 16974]  train_loss: 1.070  |  valid_loss: 0.793
# [epoch: 4, i: 17149]  train_loss: 1.052  |  valid_loss: 0.992
# [epoch: 4, i: 17324]  train_loss: 1.063  |  valid_loss: 0.991
# [epoch: 4, i: 17499]  train_loss: 1.074  |  valid_loss: 0.845
# --> [End of epoch 4] train_accuracy: 63.27%  |  valid_accuracy: 69.42%
# --> [Start of epoch 5]  lr: 0.000500
# [epoch: 5, i:   174]  train_loss: 1.059  |  valid_loss: 0.790
# [epoch: 5, i:   349]  train_loss: 1.058  |  valid_loss: 0.857
# [epoch: 5, i:   524]  train_loss: 1.078  |  valid_loss: 0.930
# [epoch: 5, i:   699]  train_loss: 0.966  |  valid_loss: 0.823
# [epoch: 5, i:   874]  train_loss: 0.970  |  valid_loss: 0.871
# [epoch: 5, i:  1049]  train_loss: 1.041  |  valid_loss: 0.713
# [epoch: 5, i:  1224]  train_loss: 1.093  |  valid_loss: 0.760
# [epoch: 5, i:  1399]  train_loss: 1.017  |  valid_loss: 1.006
# [epoch: 5, i:  1574]  train_loss: 1.121  |  valid_loss: 1.018
# [epoch: 5, i:  1749]  train_loss: 0.998  |  valid_loss: 0.810
# [epoch: 5, i:  1924]  train_loss: 1.082  |  valid_loss: 0.726
# [epoch: 5, i:  2099]  train_loss: 1.023  |  valid_loss: 0.879
# [epoch: 5, i:  2274]  train_loss: 1.016  |  valid_loss: 0.913
# [epoch: 5, i:  2449]  train_loss: 1.040  |  valid_loss: 0.810
# [epoch: 5, i:  2624]  train_loss: 1.028  |  valid_loss: 0.774
# [epoch: 5, i:  2799]  train_loss: 1.037  |  valid_loss: 0.971
# [epoch: 5, i:  2974]  train_loss: 0.956  |  valid_loss: 0.811
# [epoch: 5, i:  3149]  train_loss: 1.083  |  valid_loss: 0.904
# [epoch: 5, i:  3324]  train_loss: 1.058  |  valid_loss: 0.801
# [epoch: 5, i:  3499]  train_loss: 1.115  |  valid_loss: 1.152
# [epoch: 5, i:  3674]  train_loss: 1.038  |  valid_loss: 0.949
# [epoch: 5, i:  3849]  train_loss: 1.041  |  valid_loss: 0.906
# [epoch: 5, i:  4024]  train_loss: 1.050  |  valid_loss: 0.826
# [epoch: 5, i:  4199]  train_loss: 0.996  |  valid_loss: 0.925
# [epoch: 5, i:  4374]  train_loss: 1.070  |  valid_loss: 0.894
# [epoch: 5, i:  4549]  train_loss: 1.014  |  valid_loss: 1.082
# [epoch: 5, i:  4724]  train_loss: 1.070  |  valid_loss: 0.749
# [epoch: 5, i:  4899]  train_loss: 0.994  |  valid_loss: 0.931
# [epoch: 5, i:  5074]  train_loss: 1.093  |  valid_loss: 0.835
# [epoch: 5, i:  5249]  train_loss: 1.022  |  valid_loss: 0.814
# [epoch: 5, i:  5424]  train_loss: 1.017  |  valid_loss: 0.826
# [epoch: 5, i:  5599]  train_loss: 1.025  |  valid_loss: 0.756
# [epoch: 5, i:  5774]  train_loss: 1.053  |  valid_loss: 0.843
# [epoch: 5, i:  5949]  train_loss: 1.057  |  valid_loss: 1.118
# [epoch: 5, i:  6124]  train_loss: 1.018  |  valid_loss: 1.008
# [epoch: 5, i:  6299]  train_loss: 1.031  |  valid_loss: 0.861
# [epoch: 5, i:  6474]  train_loss: 1.123  |  valid_loss: 0.940
# [epoch: 5, i:  6649]  train_loss: 1.069  |  valid_loss: 0.960
# [epoch: 5, i:  6824]  train_loss: 1.089  |  valid_loss: 0.861
# [epoch: 5, i:  6999]  train_loss: 0.986  |  valid_loss: 0.796
# [epoch: 5, i:  7174]  train_loss: 0.987  |  valid_loss: 0.771
# [epoch: 5, i:  7349]  train_loss: 1.039  |  valid_loss: 0.701
# [epoch: 5, i:  7524]  train_loss: 1.027  |  valid_loss: 0.624
# [epoch: 5, i:  7699]  train_loss: 0.957  |  valid_loss: 0.845
# [epoch: 5, i:  7874]  train_loss: 0.968  |  valid_loss: 0.802
# [epoch: 5, i:  8049]  train_loss: 1.077  |  valid_loss: 0.840
# [epoch: 5, i:  8224]  train_loss: 1.088  |  valid_loss: 0.768
# [epoch: 5, i:  8399]  train_loss: 1.044  |  valid_loss: 0.812
# [epoch: 5, i:  8574]  train_loss: 1.032  |  valid_loss: 0.797
# [epoch: 5, i:  8749]  train_loss: 1.020  |  valid_loss: 1.043
# [epoch: 5, i:  8924]  train_loss: 1.083  |  valid_loss: 0.844
# [epoch: 5, i:  9099]  train_loss: 1.044  |  valid_loss: 0.917
# [epoch: 5, i:  9274]  train_loss: 1.001  |  valid_loss: 0.867
# [epoch: 5, i:  9449]  train_loss: 0.996  |  valid_loss: 0.945
# [epoch: 5, i:  9624]  train_loss: 1.072  |  valid_loss: 0.867
# [epoch: 5, i:  9799]  train_loss: 1.018  |  valid_loss: 0.955
# [epoch: 5, i:  9974]  train_loss: 1.048  |  valid_loss: 0.960
# [epoch: 5, i: 10149]  train_loss: 0.995  |  valid_loss: 0.763
# [epoch: 5, i: 10324]  train_loss: 1.095  |  valid_loss: 1.020
# [epoch: 5, i: 10499]  train_loss: 0.978  |  valid_loss: 0.794
# [epoch: 5, i: 10674]  train_loss: 1.074  |  valid_loss: 0.888
# [epoch: 5, i: 10849]  train_loss: 1.058  |  valid_loss: 0.878
# [epoch: 5, i: 11024]  train_loss: 1.011  |  valid_loss: 0.763
# [epoch: 5, i: 11199]  train_loss: 1.095  |  valid_loss: 0.785
# [epoch: 5, i: 11374]  train_loss: 1.014  |  valid_loss: 0.898
# [epoch: 5, i: 11549]  train_loss: 1.074  |  valid_loss: 0.940
# [epoch: 5, i: 11724]  train_loss: 0.990  |  valid_loss: 0.788
# [epoch: 5, i: 11899]  train_loss: 0.984  |  valid_loss: 0.912
# [epoch: 5, i: 12074]  train_loss: 1.003  |  valid_loss: 0.851
# [epoch: 5, i: 12249]  train_loss: 0.977  |  valid_loss: 1.105
# [epoch: 5, i: 12424]  train_loss: 1.037  |  valid_loss: 0.908
# [epoch: 5, i: 12599]  train_loss: 0.980  |  valid_loss: 0.854
# [epoch: 5, i: 12774]  train_loss: 1.078  |  valid_loss: 0.769
# [epoch: 5, i: 12949]  train_loss: 1.015  |  valid_loss: 0.694
# [epoch: 5, i: 13124]  train_loss: 1.096  |  valid_loss: 0.858
# [epoch: 5, i: 13299]  train_loss: 1.002  |  valid_loss: 0.843
# [epoch: 5, i: 13474]  train_loss: 1.075  |  valid_loss: 0.929
# [epoch: 5, i: 13649]  train_loss: 1.112  |  valid_loss: 0.770
# [epoch: 5, i: 13824]  train_loss: 1.003  |  valid_loss: 0.890
# [epoch: 5, i: 13999]  train_loss: 1.111  |  valid_loss: 0.930
# [epoch: 5, i: 14174]  train_loss: 1.120  |  valid_loss: 0.672
# [epoch: 5, i: 14349]  train_loss: 1.090  |  valid_loss: 1.009
# [epoch: 5, i: 14524]  train_loss: 1.043  |  valid_loss: 0.906
# [epoch: 5, i: 14699]  train_loss: 0.941  |  valid_loss: 0.941
# [epoch: 5, i: 14874]  train_loss: 1.038  |  valid_loss: 0.895
# [epoch: 5, i: 15049]  train_loss: 1.077  |  valid_loss: 0.771
# [epoch: 5, i: 15224]  train_loss: 1.076  |  valid_loss: 0.917
# [epoch: 5, i: 15399]  train_loss: 1.112  |  valid_loss: 1.030
# [epoch: 5, i: 15574]  train_loss: 1.089  |  valid_loss: 0.785
# [epoch: 5, i: 15749]  train_loss: 0.987  |  valid_loss: 0.927
# [epoch: 5, i: 15924]  train_loss: 1.033  |  valid_loss: 0.792
# [epoch: 5, i: 16099]  train_loss: 1.066  |  valid_loss: 0.746
# [epoch: 5, i: 16274]  train_loss: 0.969  |  valid_loss: 0.957
# [epoch: 5, i: 16449]  train_loss: 1.091  |  valid_loss: 0.940
# [epoch: 5, i: 16624]  train_loss: 1.064  |  valid_loss: 0.863
# [epoch: 5, i: 16799]  train_loss: 1.013  |  valid_loss: 0.827
# [epoch: 5, i: 16974]  train_loss: 1.014  |  valid_loss: 0.769
# [epoch: 5, i: 17149]  train_loss: 1.071  |  valid_loss: 0.979
# [epoch: 5, i: 17324]  train_loss: 1.015  |  valid_loss: 0.917
# [epoch: 5, i: 17499]  train_loss: 1.097  |  valid_loss: 0.749
# --> [End of epoch 5] train_accuracy: 64.43%  |  valid_accuracy: 70.24%
# --> [Start of epoch 6]  lr: 0.000500
# [epoch: 6, i:   174]  train_loss: 0.955  |  valid_loss: 0.835
# [epoch: 6, i:   349]  train_loss: 0.984  |  valid_loss: 0.811
# [epoch: 6, i:   524]  train_loss: 1.001  |  valid_loss: 0.983
# [epoch: 6, i:   699]  train_loss: 0.959  |  valid_loss: 0.782
# [epoch: 6, i:   874]  train_loss: 1.026  |  valid_loss: 0.804
# [epoch: 6, i:  1049]  train_loss: 0.981  |  valid_loss: 0.697
# [epoch: 6, i:  1224]  train_loss: 1.054  |  valid_loss: 0.792
# [epoch: 6, i:  1399]  train_loss: 0.984  |  valid_loss: 1.020
# [epoch: 6, i:  1574]  train_loss: 1.011  |  valid_loss: 0.992
# [epoch: 6, i:  1749]  train_loss: 1.061  |  valid_loss: 0.777
# [epoch: 6, i:  1924]  train_loss: 1.057  |  valid_loss: 0.653
# [epoch: 6, i:  2099]  train_loss: 0.988  |  valid_loss: 0.869
# [epoch: 6, i:  2274]  train_loss: 0.939  |  valid_loss: 0.879
# [epoch: 6, i:  2449]  train_loss: 0.984  |  valid_loss: 0.826
# [epoch: 6, i:  2624]  train_loss: 1.050  |  valid_loss: 0.788
# [epoch: 6, i:  2799]  train_loss: 0.979  |  valid_loss: 0.918
# [epoch: 6, i:  2974]  train_loss: 1.049  |  valid_loss: 0.800
# [epoch: 6, i:  3149]  train_loss: 1.014  |  valid_loss: 0.756
# [epoch: 6, i:  3324]  train_loss: 1.020  |  valid_loss: 0.804
# [epoch: 6, i:  3499]  train_loss: 1.021  |  valid_loss: 1.076
# [epoch: 6, i:  3674]  train_loss: 0.929  |  valid_loss: 0.975
# [epoch: 6, i:  3849]  train_loss: 0.986  |  valid_loss: 0.909
# [epoch: 6, i:  4024]  train_loss: 1.036  |  valid_loss: 0.768
# [epoch: 6, i:  4199]  train_loss: 0.987  |  valid_loss: 0.881
# [epoch: 6, i:  4374]  train_loss: 1.089  |  valid_loss: 0.958
# [epoch: 6, i:  4549]  train_loss: 1.005  |  valid_loss: 1.163
# [epoch: 6, i:  4724]  train_loss: 0.974  |  valid_loss: 0.750
# [epoch: 6, i:  4899]  train_loss: 0.971  |  valid_loss: 0.943
# [epoch: 6, i:  5074]  train_loss: 0.988  |  valid_loss: 0.855
# [epoch: 6, i:  5249]  train_loss: 0.991  |  valid_loss: 0.741
# [epoch: 6, i:  5424]  train_loss: 0.956  |  valid_loss: 0.791
# [epoch: 6, i:  5599]  train_loss: 1.029  |  valid_loss: 0.767
# [epoch: 6, i:  5774]  train_loss: 1.044  |  valid_loss: 0.878
# [epoch: 6, i:  5949]  train_loss: 1.098  |  valid_loss: 1.080
# [epoch: 6, i:  6124]  train_loss: 1.053  |  valid_loss: 0.953
# [epoch: 6, i:  6299]  train_loss: 0.958  |  valid_loss: 0.796
# [epoch: 6, i:  6474]  train_loss: 1.026  |  valid_loss: 0.884
# [epoch: 6, i:  6649]  train_loss: 1.088  |  valid_loss: 0.992
# [epoch: 6, i:  6824]  train_loss: 1.020  |  valid_loss: 0.848
# [epoch: 6, i:  6999]  train_loss: 1.051  |  valid_loss: 0.789
# [epoch: 6, i:  7174]  train_loss: 1.005  |  valid_loss: 0.801
# [epoch: 6, i:  7349]  train_loss: 1.054  |  valid_loss: 0.755
# [epoch: 6, i:  7524]  train_loss: 1.032  |  valid_loss: 0.647
# [epoch: 6, i:  7699]  train_loss: 0.957  |  valid_loss: 0.753
# [epoch: 6, i:  7874]  train_loss: 0.989  |  valid_loss: 0.777
# [epoch: 6, i:  8049]  train_loss: 1.015  |  valid_loss: 0.908
# [epoch: 6, i:  8224]  train_loss: 1.052  |  valid_loss: 0.787
# [epoch: 6, i:  8399]  train_loss: 0.961  |  valid_loss: 0.791
# [epoch: 6, i:  8574]  train_loss: 1.078  |  valid_loss: 0.685
# [epoch: 6, i:  8749]  train_loss: 1.028  |  valid_loss: 0.926
# [epoch: 6, i:  8924]  train_loss: 0.984  |  valid_loss: 0.851
# [epoch: 6, i:  9099]  train_loss: 0.893  |  valid_loss: 0.936
# [epoch: 6, i:  9274]  train_loss: 1.006  |  valid_loss: 0.812
# [epoch: 6, i:  9449]  train_loss: 1.045  |  valid_loss: 0.964
# [epoch: 6, i:  9624]  train_loss: 1.002  |  valid_loss: 0.792
# [epoch: 6, i:  9799]  train_loss: 0.981  |  valid_loss: 0.848
# [epoch: 6, i:  9974]  train_loss: 1.069  |  valid_loss: 0.877
# [epoch: 6, i: 10149]  train_loss: 0.999  |  valid_loss: 0.744
# [epoch: 6, i: 10324]  train_loss: 1.080  |  valid_loss: 1.064
# [epoch: 6, i: 10499]  train_loss: 1.022  |  valid_loss: 0.821
# [epoch: 6, i: 10674]  train_loss: 0.999  |  valid_loss: 0.910
# [epoch: 6, i: 10849]  train_loss: 0.966  |  valid_loss: 0.911
# [epoch: 6, i: 11024]  train_loss: 1.056  |  valid_loss: 0.745
# [epoch: 6, i: 11199]  train_loss: 1.041  |  valid_loss: 0.700
# [epoch: 6, i: 11374]  train_loss: 0.965  |  valid_loss: 0.793
# [epoch: 6, i: 11549]  train_loss: 1.066  |  valid_loss: 0.953
# [epoch: 6, i: 11724]  train_loss: 1.005  |  valid_loss: 0.675
# [epoch: 6, i: 11899]  train_loss: 1.015  |  valid_loss: 0.914
# [epoch: 6, i: 12074]  train_loss: 1.124  |  valid_loss: 0.863
# [epoch: 6, i: 12249]  train_loss: 0.951  |  valid_loss: 0.978
# [epoch: 6, i: 12424]  train_loss: 1.070  |  valid_loss: 0.852
# [epoch: 6, i: 12599]  train_loss: 1.022  |  valid_loss: 0.778
# [epoch: 6, i: 12774]  train_loss: 0.899  |  valid_loss: 0.825
# [epoch: 6, i: 12949]  train_loss: 0.989  |  valid_loss: 0.694
# [epoch: 6, i: 13124]  train_loss: 1.029  |  valid_loss: 0.896
# [epoch: 6, i: 13299]  train_loss: 1.031  |  valid_loss: 0.837
# [epoch: 6, i: 13474]  train_loss: 1.034  |  valid_loss: 0.939
# [epoch: 6, i: 13649]  train_loss: 1.096  |  valid_loss: 0.787
# [epoch: 6, i: 13824]  train_loss: 1.003  |  valid_loss: 0.901
# [epoch: 6, i: 13999]  train_loss: 1.020  |  valid_loss: 0.857
# [epoch: 6, i: 14174]  train_loss: 1.021  |  valid_loss: 0.773
# [epoch: 6, i: 14349]  train_loss: 1.085  |  valid_loss: 0.859
# [epoch: 6, i: 14524]  train_loss: 1.064  |  valid_loss: 0.848
# [epoch: 6, i: 14699]  train_loss: 1.010  |  valid_loss: 0.914
# [epoch: 6, i: 14874]  train_loss: 0.996  |  valid_loss: 0.885
# [epoch: 6, i: 15049]  train_loss: 1.054  |  valid_loss: 0.836
# [epoch: 6, i: 15224]  train_loss: 1.032  |  valid_loss: 0.885
# [epoch: 6, i: 15399]  train_loss: 1.042  |  valid_loss: 0.869
# [epoch: 6, i: 15574]  train_loss: 1.091  |  valid_loss: 0.811
# [epoch: 6, i: 15749]  train_loss: 1.078  |  valid_loss: 0.902
# [epoch: 6, i: 15924]  train_loss: 1.045  |  valid_loss: 0.768
# [epoch: 6, i: 16099]  train_loss: 1.054  |  valid_loss: 0.720
# [epoch: 6, i: 16274]  train_loss: 1.016  |  valid_loss: 0.903
# [epoch: 6, i: 16449]  train_loss: 1.030  |  valid_loss: 0.894
# [epoch: 6, i: 16624]  train_loss: 0.969  |  valid_loss: 0.833
# [epoch: 6, i: 16799]  train_loss: 1.007  |  valid_loss: 0.835
# [epoch: 6, i: 16974]  train_loss: 0.960  |  valid_loss: 0.793
# [epoch: 6, i: 17149]  train_loss: 0.982  |  valid_loss: 0.924
# [epoch: 6, i: 17324]  train_loss: 0.999  |  valid_loss: 0.874
# [epoch: 6, i: 17499]  train_loss: 1.009  |  valid_loss: 0.804
# --> [End of epoch 6] train_accuracy: 65.27%  |  valid_accuracy: 70.40%
# --> [Start of epoch 7]  lr: 0.000500
# [epoch: 7, i:   174]  train_loss: 0.949  |  valid_loss: 0.764
# [epoch: 7, i:   349]  train_loss: 0.927  |  valid_loss: 0.830
# [epoch: 7, i:   524]  train_loss: 1.028  |  valid_loss: 0.887
# [epoch: 7, i:   699]  train_loss: 1.048  |  valid_loss: 0.763
# [epoch: 7, i:   874]  train_loss: 0.936  |  valid_loss: 0.861
# [epoch: 7, i:  1049]  train_loss: 1.009  |  valid_loss: 0.636
# [epoch: 7, i:  1224]  train_loss: 0.901  |  valid_loss: 0.712
# [epoch: 7, i:  1399]  train_loss: 0.936  |  valid_loss: 0.934
# [epoch: 7, i:  1574]  train_loss: 1.024  |  valid_loss: 0.968
# [epoch: 7, i:  1749]  train_loss: 0.990  |  valid_loss: 0.833
# [epoch: 7, i:  1924]  train_loss: 0.979  |  valid_loss: 0.726
# [epoch: 7, i:  2099]  train_loss: 1.005  |  valid_loss: 0.787
# [epoch: 7, i:  2274]  train_loss: 1.006  |  valid_loss: 0.730
# [epoch: 7, i:  2449]  train_loss: 1.001  |  valid_loss: 0.795
# [epoch: 7, i:  2624]  train_loss: 0.979  |  valid_loss: 0.778
# [epoch: 7, i:  2799]  train_loss: 0.961  |  valid_loss: 0.835
# [epoch: 7, i:  2974]  train_loss: 1.021  |  valid_loss: 0.769
# [epoch: 7, i:  3149]  train_loss: 1.018  |  valid_loss: 0.869
# [epoch: 7, i:  3324]  train_loss: 0.912  |  valid_loss: 0.868
# [epoch: 7, i:  3499]  train_loss: 0.890  |  valid_loss: 1.052
# [epoch: 7, i:  3674]  train_loss: 1.073  |  valid_loss: 0.983
# [epoch: 7, i:  3849]  train_loss: 0.982  |  valid_loss: 0.893
# [epoch: 7, i:  4024]  train_loss: 1.029  |  valid_loss: 0.820
# [epoch: 7, i:  4199]  train_loss: 0.970  |  valid_loss: 0.844
# [epoch: 7, i:  4374]  train_loss: 1.087  |  valid_loss: 0.909
# [epoch: 7, i:  4549]  train_loss: 0.959  |  valid_loss: 1.039
# [epoch: 7, i:  4724]  train_loss: 1.043  |  valid_loss: 0.714
# [epoch: 7, i:  4899]  train_loss: 0.934  |  valid_loss: 0.980
# [epoch: 7, i:  5074]  train_loss: 0.965  |  valid_loss: 0.824
# [epoch: 7, i:  5249]  train_loss: 1.013  |  valid_loss: 0.681
# [epoch: 7, i:  5424]  train_loss: 1.005  |  valid_loss: 0.834
# [epoch: 7, i:  5599]  train_loss: 0.935  |  valid_loss: 0.820
# [epoch: 7, i:  5774]  train_loss: 0.946  |  valid_loss: 0.872
# [epoch: 7, i:  5949]  train_loss: 0.984  |  valid_loss: 1.036
# [epoch: 7, i:  6124]  train_loss: 1.037  |  valid_loss: 0.885
# [epoch: 7, i:  6299]  train_loss: 1.010  |  valid_loss: 0.812
# [epoch: 7, i:  6474]  train_loss: 0.998  |  valid_loss: 0.865
# [epoch: 7, i:  6649]  train_loss: 1.052  |  valid_loss: 0.883
# [epoch: 7, i:  6824]  train_loss: 0.958  |  valid_loss: 0.795
# [epoch: 7, i:  6999]  train_loss: 0.974  |  valid_loss: 0.746
# [epoch: 7, i:  7174]  train_loss: 0.905  |  valid_loss: 0.792
# [epoch: 7, i:  7349]  train_loss: 1.027  |  valid_loss: 0.812
# [epoch: 7, i:  7524]  train_loss: 1.010  |  valid_loss: 0.634
# [epoch: 7, i:  7699]  train_loss: 1.135  |  valid_loss: 0.819
# [epoch: 7, i:  7874]  train_loss: 0.999  |  valid_loss: 0.775
# [epoch: 7, i:  8049]  train_loss: 1.042  |  valid_loss: 0.874
# [epoch: 7, i:  8224]  train_loss: 0.969  |  valid_loss: 0.708
# [epoch: 7, i:  8399]  train_loss: 0.974  |  valid_loss: 0.833
# [epoch: 7, i:  8574]  train_loss: 1.041  |  valid_loss: 0.724
# [epoch: 7, i:  8749]  train_loss: 1.015  |  valid_loss: 0.988
# [epoch: 7, i:  8924]  train_loss: 1.004  |  valid_loss: 0.788
# [epoch: 7, i:  9099]  train_loss: 1.036  |  valid_loss: 0.928
# [epoch: 7, i:  9274]  train_loss: 0.966  |  valid_loss: 0.789
# [epoch: 7, i:  9449]  train_loss: 0.977  |  valid_loss: 0.975
# [epoch: 7, i:  9624]  train_loss: 1.018  |  valid_loss: 0.742
# [epoch: 7, i:  9799]  train_loss: 1.062  |  valid_loss: 0.871
# [epoch: 7, i:  9974]  train_loss: 0.970  |  valid_loss: 0.852
# [epoch: 7, i: 10149]  train_loss: 1.006  |  valid_loss: 0.690
# [epoch: 7, i: 10324]  train_loss: 1.012  |  valid_loss: 1.026
# [epoch: 7, i: 10499]  train_loss: 0.939  |  valid_loss: 0.813
# [epoch: 7, i: 10674]  train_loss: 0.970  |  valid_loss: 0.865
# [epoch: 7, i: 10849]  train_loss: 0.998  |  valid_loss: 0.870
# [epoch: 7, i: 11024]  train_loss: 1.030  |  valid_loss: 0.738
# [epoch: 7, i: 11199]  train_loss: 0.954  |  valid_loss: 0.772
# [epoch: 7, i: 11374]  train_loss: 0.950  |  valid_loss: 0.747
# [epoch: 7, i: 11549]  train_loss: 1.065  |  valid_loss: 0.870
# [epoch: 7, i: 11724]  train_loss: 0.981  |  valid_loss: 0.641
# [epoch: 7, i: 11899]  train_loss: 1.055  |  valid_loss: 0.944
# [epoch: 7, i: 12074]  train_loss: 1.015  |  valid_loss: 0.760
# [epoch: 7, i: 12249]  train_loss: 1.048  |  valid_loss: 0.964
# [epoch: 7, i: 12424]  train_loss: 0.946  |  valid_loss: 0.779
# [epoch: 7, i: 12599]  train_loss: 1.059  |  valid_loss: 0.720
# [epoch: 7, i: 12774]  train_loss: 0.969  |  valid_loss: 0.818
# [epoch: 7, i: 12949]  train_loss: 1.027  |  valid_loss: 0.729
# [epoch: 7, i: 13124]  train_loss: 0.971  |  valid_loss: 0.785
# [epoch: 7, i: 13299]  train_loss: 1.061  |  valid_loss: 0.790
# [epoch: 7, i: 13474]  train_loss: 1.067  |  valid_loss: 0.940
# [epoch: 7, i: 13649]  train_loss: 0.977  |  valid_loss: 0.780
# [epoch: 7, i: 13824]  train_loss: 0.988  |  valid_loss: 0.841
# [epoch: 7, i: 13999]  train_loss: 1.068  |  valid_loss: 0.888
# [epoch: 7, i: 14174]  train_loss: 1.013  |  valid_loss: 0.734
# [epoch: 7, i: 14349]  train_loss: 1.030  |  valid_loss: 0.899
# [epoch: 7, i: 14524]  train_loss: 0.999  |  valid_loss: 0.799
# [epoch: 7, i: 14699]  train_loss: 0.988  |  valid_loss: 0.885
# [epoch: 7, i: 14874]  train_loss: 0.926  |  valid_loss: 0.881
# [epoch: 7, i: 15049]  train_loss: 1.012  |  valid_loss: 0.828
# [epoch: 7, i: 15224]  train_loss: 0.972  |  valid_loss: 0.945
# [epoch: 7, i: 15399]  train_loss: 1.003  |  valid_loss: 0.862
# [epoch: 7, i: 15574]  train_loss: 0.970  |  valid_loss: 0.772
# [epoch: 7, i: 15749]  train_loss: 1.095  |  valid_loss: 0.860
# [epoch: 7, i: 15924]  train_loss: 1.037  |  valid_loss: 0.790
# [epoch: 7, i: 16099]  train_loss: 0.961  |  valid_loss: 0.718
# [epoch: 7, i: 16274]  train_loss: 0.996  |  valid_loss: 0.974
# [epoch: 7, i: 16449]  train_loss: 0.948  |  valid_loss: 0.917
# [epoch: 7, i: 16624]  train_loss: 1.005  |  valid_loss: 0.781
# [epoch: 7, i: 16799]  train_loss: 0.972  |  valid_loss: 0.801
# [epoch: 7, i: 16974]  train_loss: 1.074  |  valid_loss: 0.760
# [epoch: 7, i: 17149]  train_loss: 0.984  |  valid_loss: 1.002
# [epoch: 7, i: 17324]  train_loss: 1.040  |  valid_loss: 0.886
# [epoch: 7, i: 17499]  train_loss: 0.933  |  valid_loss: 0.807
# --> [End of epoch 7] train_accuracy: 65.84%  |  valid_accuracy: 71.83%
# --> [Start of epoch 8]  lr: 0.000500
# [epoch: 8, i:   174]  train_loss: 0.975  |  valid_loss: 0.772
# [epoch: 8, i:   349]  train_loss: 1.002  |  valid_loss: 0.793
# [epoch: 8, i:   524]  train_loss: 0.982  |  valid_loss: 0.970
# [epoch: 8, i:   699]  train_loss: 0.988  |  valid_loss: 0.786
# [epoch: 8, i:   874]  train_loss: 0.986  |  valid_loss: 0.861
# [epoch: 8, i:  1049]  train_loss: 0.971  |  valid_loss: 0.668
# [epoch: 8, i:  1224]  train_loss: 1.021  |  valid_loss: 0.694
# [epoch: 8, i:  1399]  train_loss: 1.035  |  valid_loss: 0.914
# [epoch: 8, i:  1574]  train_loss: 0.902  |  valid_loss: 0.989
# [epoch: 8, i:  1749]  train_loss: 0.987  |  valid_loss: 0.855
# [epoch: 8, i:  1924]  train_loss: 0.987  |  valid_loss: 0.676
# [epoch: 8, i:  2099]  train_loss: 0.906  |  valid_loss: 0.794
# [epoch: 8, i:  2274]  train_loss: 0.949  |  valid_loss: 0.745
# [epoch: 8, i:  2449]  train_loss: 0.910  |  valid_loss: 0.779
# [epoch: 8, i:  2624]  train_loss: 1.146  |  valid_loss: 0.794
# [epoch: 8, i:  2799]  train_loss: 1.010  |  valid_loss: 0.805
# [epoch: 8, i:  2974]  train_loss: 0.953  |  valid_loss: 0.798
# [epoch: 8, i:  3149]  train_loss: 0.972  |  valid_loss: 0.867
# [epoch: 8, i:  3324]  train_loss: 0.903  |  valid_loss: 0.847
# [epoch: 8, i:  3499]  train_loss: 0.926  |  valid_loss: 1.038
# [epoch: 8, i:  3674]  train_loss: 0.913  |  valid_loss: 0.902
# [epoch: 8, i:  3849]  train_loss: 0.940  |  valid_loss: 0.791
# [epoch: 8, i:  4024]  train_loss: 1.034  |  valid_loss: 0.826
# [epoch: 8, i:  4199]  train_loss: 1.034  |  valid_loss: 0.827
# [epoch: 8, i:  4374]  train_loss: 0.946  |  valid_loss: 0.913
# [epoch: 8, i:  4549]  train_loss: 0.957  |  valid_loss: 1.056
# [epoch: 8, i:  4724]  train_loss: 0.920  |  valid_loss: 0.706
# [epoch: 8, i:  4899]  train_loss: 1.006  |  valid_loss: 0.882
# [epoch: 8, i:  5074]  train_loss: 0.966  |  valid_loss: 0.887
# [epoch: 8, i:  5249]  train_loss: 0.955  |  valid_loss: 0.677
# [epoch: 8, i:  5424]  train_loss: 0.987  |  valid_loss: 0.803
# [epoch: 8, i:  5599]  train_loss: 0.976  |  valid_loss: 0.857
# [epoch: 8, i:  5774]  train_loss: 0.990  |  valid_loss: 0.814
# [epoch: 8, i:  5949]  train_loss: 0.945  |  valid_loss: 1.019
# [epoch: 8, i:  6124]  train_loss: 1.003  |  valid_loss: 0.980
# [epoch: 8, i:  6299]  train_loss: 0.916  |  valid_loss: 0.932
# [epoch: 8, i:  6474]  train_loss: 1.030  |  valid_loss: 0.924
# [epoch: 8, i:  6649]  train_loss: 1.008  |  valid_loss: 0.959
# [epoch: 8, i:  6824]  train_loss: 1.043  |  valid_loss: 0.749
# [epoch: 8, i:  6999]  train_loss: 0.918  |  valid_loss: 0.668
# [epoch: 8, i:  7174]  train_loss: 0.999  |  valid_loss: 0.839
# [epoch: 8, i:  7349]  train_loss: 1.013  |  valid_loss: 0.805
# [epoch: 8, i:  7524]  train_loss: 0.975  |  valid_loss: 0.673
# [epoch: 8, i:  7699]  train_loss: 0.963  |  valid_loss: 0.833
# [epoch: 8, i:  7874]  train_loss: 0.986  |  valid_loss: 0.715
# [epoch: 8, i:  8049]  train_loss: 1.029  |  valid_loss: 0.911
# [epoch: 8, i:  8224]  train_loss: 1.016  |  valid_loss: 0.756
# [epoch: 8, i:  8399]  train_loss: 0.980  |  valid_loss: 0.751
# [epoch: 8, i:  8574]  train_loss: 0.981  |  valid_loss: 0.737
# [epoch: 8, i:  8749]  train_loss: 0.983  |  valid_loss: 0.983
# [epoch: 8, i:  8924]  train_loss: 1.046  |  valid_loss: 0.801
# [epoch: 8, i:  9099]  train_loss: 1.002  |  valid_loss: 0.875
# [epoch: 8, i:  9274]  train_loss: 0.977  |  valid_loss: 0.723
# [epoch: 8, i:  9449]  train_loss: 1.016  |  valid_loss: 0.857
# [epoch: 8, i:  9624]  train_loss: 1.026  |  valid_loss: 0.775
# [epoch: 8, i:  9799]  train_loss: 0.956  |  valid_loss: 0.911
# [epoch: 8, i:  9974]  train_loss: 0.944  |  valid_loss: 0.870
# [epoch: 8, i: 10149]  train_loss: 0.998  |  valid_loss: 0.718
# [epoch: 8, i: 10324]  train_loss: 0.935  |  valid_loss: 1.019
# [epoch: 8, i: 10499]  train_loss: 0.943  |  valid_loss: 0.778
# [epoch: 8, i: 10674]  train_loss: 1.015  |  valid_loss: 0.886
# [epoch: 8, i: 10849]  train_loss: 0.930  |  valid_loss: 0.962
# [epoch: 8, i: 11024]  train_loss: 0.991  |  valid_loss: 0.703
# [epoch: 8, i: 11199]  train_loss: 0.950  |  valid_loss: 0.727
# [epoch: 8, i: 11374]  train_loss: 0.910  |  valid_loss: 0.702
# [epoch: 8, i: 11549]  train_loss: 0.878  |  valid_loss: 0.873
# [epoch: 8, i: 11724]  train_loss: 0.873  |  valid_loss: 0.696
# [epoch: 8, i: 11899]  train_loss: 1.043  |  valid_loss: 0.901
# [epoch: 8, i: 12074]  train_loss: 1.042  |  valid_loss: 0.753
# [epoch: 8, i: 12249]  train_loss: 1.058  |  valid_loss: 0.985
# [epoch: 8, i: 12424]  train_loss: 1.016  |  valid_loss: 0.821
# [epoch: 8, i: 12599]  train_loss: 0.962  |  valid_loss: 0.782
# [epoch: 8, i: 12774]  train_loss: 0.935  |  valid_loss: 0.783
# [epoch: 8, i: 12949]  train_loss: 0.937  |  valid_loss: 0.722
# [epoch: 8, i: 13124]  train_loss: 1.024  |  valid_loss: 0.778
# [epoch: 8, i: 13299]  train_loss: 0.993  |  valid_loss: 0.772
# [epoch: 8, i: 13474]  train_loss: 0.907  |  valid_loss: 0.876
# [epoch: 8, i: 13649]  train_loss: 0.888  |  valid_loss: 0.883
# [epoch: 8, i: 13824]  train_loss: 0.989  |  valid_loss: 0.870
# [epoch: 8, i: 13999]  train_loss: 0.926  |  valid_loss: 0.871
# [epoch: 8, i: 14174]  train_loss: 1.024  |  valid_loss: 0.710
# [epoch: 8, i: 14349]  train_loss: 1.018  |  valid_loss: 0.884
# [epoch: 8, i: 14524]  train_loss: 0.999  |  valid_loss: 0.806
# [epoch: 8, i: 14699]  train_loss: 0.985  |  valid_loss: 0.935
# [epoch: 8, i: 14874]  train_loss: 1.042  |  valid_loss: 0.928
# [epoch: 8, i: 15049]  train_loss: 1.069  |  valid_loss: 0.838
# [epoch: 8, i: 15224]  train_loss: 1.116  |  valid_loss: 0.855
# [epoch: 8, i: 15399]  train_loss: 1.045  |  valid_loss: 0.883
# [epoch: 8, i: 15574]  train_loss: 1.051  |  valid_loss: 0.773
# [epoch: 8, i: 15749]  train_loss: 0.988  |  valid_loss: 0.838
# [epoch: 8, i: 15924]  train_loss: 1.021  |  valid_loss: 0.711
# [epoch: 8, i: 16099]  train_loss: 1.073  |  valid_loss: 0.660
# [epoch: 8, i: 16274]  train_loss: 0.942  |  valid_loss: 0.885
# [epoch: 8, i: 16449]  train_loss: 0.943  |  valid_loss: 0.958
# [epoch: 8, i: 16624]  train_loss: 0.942  |  valid_loss: 0.758
# [epoch: 8, i: 16799]  train_loss: 0.920  |  valid_loss: 0.763
# [epoch: 8, i: 16974]  train_loss: 0.945  |  valid_loss: 0.775
# [epoch: 8, i: 17149]  train_loss: 0.974  |  valid_loss: 0.933
# [epoch: 8, i: 17324]  train_loss: 0.938  |  valid_loss: 0.859
# [epoch: 8, i: 17499]  train_loss: 0.965  |  valid_loss: 0.779
# --> [End of epoch 8] train_accuracy: 66.52%  |  valid_accuracy: 71.67%
# --> [Start of epoch 9]  lr: 0.000500
# [epoch: 9, i:   174]  train_loss: 0.980  |  valid_loss: 0.793
# [epoch: 9, i:   349]  train_loss: 0.972  |  valid_loss: 0.831
# [epoch: 9, i:   524]  train_loss: 1.001  |  valid_loss: 0.877
# [epoch: 9, i:   699]  train_loss: 0.971  |  valid_loss: 0.758
# [epoch: 9, i:   874]  train_loss: 0.888  |  valid_loss: 0.764
# [epoch: 9, i:  1049]  train_loss: 0.875  |  valid_loss: 0.670
# [epoch: 9, i:  1224]  train_loss: 0.866  |  valid_loss: 0.756
# [epoch: 9, i:  1399]  train_loss: 1.033  |  valid_loss: 0.834
# [epoch: 9, i:  1574]  train_loss: 0.950  |  valid_loss: 1.023
# [epoch: 9, i:  1749]  train_loss: 0.945  |  valid_loss: 0.856
# [epoch: 9, i:  1924]  train_loss: 1.081  |  valid_loss: 0.685
# [epoch: 9, i:  2099]  train_loss: 0.930  |  valid_loss: 0.766
# [epoch: 9, i:  2274]  train_loss: 0.954  |  valid_loss: 0.745
# [epoch: 9, i:  2449]  train_loss: 0.981  |  valid_loss: 0.714
# [epoch: 9, i:  2624]  train_loss: 1.013  |  valid_loss: 0.737
# [epoch: 9, i:  2799]  train_loss: 0.936  |  valid_loss: 0.825
# [epoch: 9, i:  2974]  train_loss: 0.847  |  valid_loss: 0.801
# [epoch: 9, i:  3149]  train_loss: 1.031  |  valid_loss: 0.884
# [epoch: 9, i:  3324]  train_loss: 0.938  |  valid_loss: 0.805
# [epoch: 9, i:  3499]  train_loss: 0.966  |  valid_loss: 1.052
# [epoch: 9, i:  3674]  train_loss: 1.053  |  valid_loss: 0.943
# [epoch: 9, i:  3849]  train_loss: 0.953  |  valid_loss: 0.847
# [epoch: 9, i:  4024]  train_loss: 0.949  |  valid_loss: 0.806
# [epoch: 9, i:  4199]  train_loss: 0.996  |  valid_loss: 0.808
# [epoch: 9, i:  4374]  train_loss: 0.938  |  valid_loss: 0.947
# [epoch: 9, i:  4549]  train_loss: 0.950  |  valid_loss: 1.004
# [epoch: 9, i:  4724]  train_loss: 0.958  |  valid_loss: 0.694
# [epoch: 9, i:  4899]  train_loss: 0.958  |  valid_loss: 0.852
# [epoch: 9, i:  5074]  train_loss: 0.918  |  valid_loss: 0.838
# [epoch: 9, i:  5249]  train_loss: 1.011  |  valid_loss: 0.714
# [epoch: 9, i:  5424]  train_loss: 0.913  |  valid_loss: 0.722
# [epoch: 9, i:  5599]  train_loss: 0.908  |  valid_loss: 0.805
# [epoch: 9, i:  5774]  train_loss: 0.987  |  valid_loss: 0.852
# [epoch: 9, i:  5949]  train_loss: 0.907  |  valid_loss: 1.020
# [epoch: 9, i:  6124]  train_loss: 0.882  |  valid_loss: 0.889
# [epoch: 9, i:  6299]  train_loss: 0.886  |  valid_loss: 0.782
# [epoch: 9, i:  6474]  train_loss: 0.922  |  valid_loss: 0.847
# [epoch: 9, i:  6649]  train_loss: 1.016  |  valid_loss: 0.916
# [epoch: 9, i:  6824]  train_loss: 0.962  |  valid_loss: 0.761
# [epoch: 9, i:  6999]  train_loss: 0.949  |  valid_loss: 0.707
# [epoch: 9, i:  7174]  train_loss: 0.990  |  valid_loss: 0.753
# [epoch: 9, i:  7349]  train_loss: 0.911  |  valid_loss: 0.691
# [epoch: 9, i:  7524]  train_loss: 1.121  |  valid_loss: 0.684
# [epoch: 9, i:  7699]  train_loss: 0.926  |  valid_loss: 0.852
# [epoch: 9, i:  7874]  train_loss: 1.005  |  valid_loss: 0.795
# [epoch: 9, i:  8049]  train_loss: 1.024  |  valid_loss: 0.860
# [epoch: 9, i:  8224]  train_loss: 0.997  |  valid_loss: 0.717
# [epoch: 9, i:  8399]  train_loss: 0.996  |  valid_loss: 0.780
# [epoch: 9, i:  8574]  train_loss: 0.935  |  valid_loss: 0.711
# [epoch: 9, i:  8749]  train_loss: 0.939  |  valid_loss: 0.942
# [epoch: 9, i:  8924]  train_loss: 0.956  |  valid_loss: 0.778
# [epoch: 9, i:  9099]  train_loss: 0.886  |  valid_loss: 0.813
# [epoch: 9, i:  9274]  train_loss: 0.923  |  valid_loss: 0.735
# [epoch: 9, i:  9449]  train_loss: 0.951  |  valid_loss: 0.844
# [epoch: 9, i:  9624]  train_loss: 0.971  |  valid_loss: 0.760
# [epoch: 9, i:  9799]  train_loss: 0.879  |  valid_loss: 0.815
# [epoch: 9, i:  9974]  train_loss: 0.853  |  valid_loss: 0.943
# [epoch: 9, i: 10149]  train_loss: 0.962  |  valid_loss: 0.761
# [epoch: 9, i: 10324]  train_loss: 0.941  |  valid_loss: 0.932
# [epoch: 9, i: 10499]  train_loss: 0.983  |  valid_loss: 0.837
# [epoch: 9, i: 10674]  train_loss: 1.014  |  valid_loss: 0.894
# [epoch: 9, i: 10849]  train_loss: 0.952  |  valid_loss: 0.834
# [epoch: 9, i: 11024]  train_loss: 0.967  |  valid_loss: 0.671
# [epoch: 9, i: 11199]  train_loss: 0.961  |  valid_loss: 0.675
# [epoch: 9, i: 11374]  train_loss: 0.947  |  valid_loss: 0.736
# [epoch: 9, i: 11549]  train_loss: 0.973  |  valid_loss: 0.842
# [epoch: 9, i: 11724]  train_loss: 0.996  |  valid_loss: 0.729
# [epoch: 9, i: 11899]  train_loss: 0.977  |  valid_loss: 0.829
# [epoch: 9, i: 12074]  train_loss: 1.003  |  valid_loss: 0.720
# [epoch: 9, i: 12249]  train_loss: 1.027  |  valid_loss: 1.029
# [epoch: 9, i: 12424]  train_loss: 1.009  |  valid_loss: 0.816
# [epoch: 9, i: 12599]  train_loss: 1.043  |  valid_loss: 0.833
# [epoch: 9, i: 12774]  train_loss: 1.000  |  valid_loss: 0.788
# [epoch: 9, i: 12949]  train_loss: 0.987  |  valid_loss: 0.688
# [epoch: 9, i: 13124]  train_loss: 1.013  |  valid_loss: 0.822
# [epoch: 9, i: 13299]  train_loss: 0.922  |  valid_loss: 0.836
# [epoch: 9, i: 13474]  train_loss: 1.067  |  valid_loss: 0.852
# [epoch: 9, i: 13649]  train_loss: 0.988  |  valid_loss: 0.747
# [epoch: 9, i: 13824]  train_loss: 1.034  |  valid_loss: 0.889
# [epoch: 9, i: 13999]  train_loss: 0.948  |  valid_loss: 0.909
# [epoch: 9, i: 14174]  train_loss: 0.952  |  valid_loss: 0.698
# [epoch: 9, i: 14349]  train_loss: 0.941  |  valid_loss: 0.766
# [epoch: 9, i: 14524]  train_loss: 0.925  |  valid_loss: 0.794
# [epoch: 9, i: 14699]  train_loss: 0.949  |  valid_loss: 0.943
# [epoch: 9, i: 14874]  train_loss: 1.010  |  valid_loss: 0.886
# [epoch: 9, i: 15049]  train_loss: 0.958  |  valid_loss: 0.718
# [epoch: 9, i: 15224]  train_loss: 1.050  |  valid_loss: 0.808
# [epoch: 9, i: 15399]  train_loss: 0.984  |  valid_loss: 0.823
# [epoch: 9, i: 15574]  train_loss: 1.044  |  valid_loss: 0.834
# [epoch: 9, i: 15749]  train_loss: 0.937  |  valid_loss: 0.813
# [epoch: 9, i: 15924]  train_loss: 1.009  |  valid_loss: 0.761
# [epoch: 9, i: 16099]  train_loss: 0.948  |  valid_loss: 0.685
# [epoch: 9, i: 16274]  train_loss: 0.948  |  valid_loss: 0.826
# [epoch: 9, i: 16449]  train_loss: 1.055  |  valid_loss: 0.893
# [epoch: 9, i: 16624]  train_loss: 0.963  |  valid_loss: 0.794
# [epoch: 9, i: 16799]  train_loss: 0.999  |  valid_loss: 0.772
# [epoch: 9, i: 16974]  train_loss: 0.954  |  valid_loss: 0.734
# [epoch: 9, i: 17149]  train_loss: 1.032  |  valid_loss: 0.927
# [epoch: 9, i: 17324]  train_loss: 0.979  |  valid_loss: 0.852
# [epoch: 9, i: 17499]  train_loss: 0.934  |  valid_loss: 0.757
# --> [End of epoch 9] train_accuracy: 66.88%  |  valid_accuracy: 72.08%
# Finished Training.

# %%
plt.plot(avg_train_losses)
plt.plot(avg_valid_losses)
plt.title('Dense_max_1 + plateau scheduling + l2 regularization')
plt.xlabel('mini-batch index / {}'.format(iter_n_per_record))
plt.ylabel('avg. mini-batch loss')
plt.legend(['training loss', 'validation loss'])
plt.show()

# %%
def moving_average(data, window_size):
    """Compute the moving average of the data using a specified window size."""
    return np.convolve(data, np.ones(window_size)/window_size, mode='valid')

window_size = 20  # Adjust this based on your preference
train_losses_ma = moving_average(avg_train_losses, window_size)
valid_losses_ma = moving_average(avg_valid_losses, window_size)

# x_axis = np.arange(len(train_losses_ma))/100 
x_axis = np.arange(window_size - 1, len(train_losses_ma) + window_size - 1)

plt.plot(avg_train_losses)
plt.plot(avg_valid_losses)
plt.plot(x_axis, train_losses_ma, linewidth=2)
plt.plot(x_axis, valid_losses_ma, linewidth=2)
plt.title('DenseNet loss trend + exponential scheduling + l2 regularization')
plt.xlabel('mini-batch index / {}'.format(iter_n_per_record))
plt.ylabel('avg. mini-batch loss')
plt.legend(['training loss', 'validation loss', 'training loss (moving avg)', 'validation loss (moving avg)'])
plt.show()

# %%
plt.plot(train_accuracies)
plt.plot(valid_accuracies)
plt.title('DenseMax accuracy curve for plateau scheduling + l2 regularization')
plt.xlabel('epoch / {}'.format(iter_n_per_record))
plt.ylabel('accuracy')
plt.legend(['train accuracy', 'validation accuracy'])
plt.show()

# %%
# print average time per epoch to 2nd decimal place
print(f"Average time per epoch: {np.mean(time_per_epoch):.2f} seconds")
print("number of parameters:", count_parameters(model))
print(f'model size: {get_model_size(model):.3f}MB')
# Out:
# Average time per epoch: 540.34 seconds
# number of parameters: 136430
# model size: 0.522MB

# %%
# The function to show an image.
def imshow(img):
    img = img / 2 + 0.5     # Unnormalize.
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# %%
# Check several images.
dataiter = iter(validloader)
images, labels = next(dataiter)
imshow(torchvision.utils.make_grid(images))
print('GroundTruth: ', ' '.join('%5s' % classes[labels[j]] for j in range(4)))
outputs = model(images.to(device))

# max compare along the row, return the index of the max value, which is the predicted class
_, predicted = torch.max(outputs, 1)

print('Predicted: ', ' '.join('%5s' % classes[predicted[j]]
                              for j in range(4)))
# Out:
# GroundTruth:    cat  ship  ship plane
# Predicted:    cat  ship  ship   car

# %%
images, labels = next(iter(validloader))
print(len(images))
# Out:
# 4

# %%
inference_time_per_image = []


model.to(device)
model.eval()
# Get test accuracy.
correct = 0
total = 0
with torch.no_grad():
    for data in validloader:
        images, labels = data
        images, labels = images.to(device), labels.to(device)
        inference_start = time.time()
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        inference_end = time.time()
        inference_time_per_image.append((inference_end - inference_start) / len(images))
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print('Accuracy of the network on the 10000 test images: %.2f %%' % (
    100 * correct / total))

# print average inference time per image in ms
print(f"average inference time per image: {sum(inference_time_per_image) * 1000 / len(inference_time_per_image):.3f} ms")
# Out:
# Accuracy of the network on the 10000 test images: 72.78 %
# average inference time per image: 0.755 ms

# %%
model.to(device)
model.eval()

# Get test accuracy for each class.
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))
with torch.no_grad():
    for data in validloader:
        images, labels = data
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels).squeeze()
        for i in range(4):
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1

for i in range(10):
    print('Accuracy of %5s : %2d %%' % (
        classes[i], 100 * class_correct[i] / class_total[i]))
# Out:
# Accuracy of plane : 71 %
# Accuracy of   car : 86 %
# Accuracy of  bird : 62 %
# Accuracy of   cat : 51 %
# Accuracy of  deer : 68 %
# Accuracy of   dog : 69 %
# Accuracy of  frog : 73 %
# Accuracy of horse : 74 %
# Accuracy of  ship : 83 %
# Accuracy of truck : 89 %

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)

trainloader = torch.utils.data.DataLoader(trainset, batch_size=4,
                                          shuffle=True, num_workers=2)



validset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)
validloader = torch.utils.data.DataLoader(validset, batch_size=4,
                                         shuffle=False, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

print(len(trainloader))
print(len(validloader))

# If there are GPUs, choose the first one for computing. Otherwise use CPU.
device = torch.device("cuda:0" if torch.cuda.is_available() else ("mps" if torch.backends.mps.is_available() else "cpu"))
print(device)  
# If 'mps or cuda:0' is printed, it means GPU is available.
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# 12500
# 2500
# mps

# %%
class ShortConn2d(nn.Module):
    def __init__(self, in_channels, out_channels, stride=1):
        super().__init__()
        
        self.conv = nn.Conv2d(in_channels, out_channels,
                              kernel_size=1, stride=stride, padding=0)
            
        self.bn = nn.BatchNorm2d(out_channels)
    def forward(self, x):
        x = self.conv(x)
        x = self.bn(x)
        return x

# %%
class ResBlock(nn.Module):
    def __init__(self, in_channels, out_channels, stride=1):
        super(ResBlock, self).__init__()
    
        # 3x3
        self.conv1 = nn.Conv2d(in_channels, out_channels, 
                             kernel_size=3, stride=stride, padding=1)
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.act1 = nn.ReLU()
        
        # 3x3 
        self.conv2 = nn.Conv2d(out_channels, out_channels, 
                               kernel_size=3, stride=1, padding=1)
        self.bn2 = nn.BatchNorm2d(out_channels)
        
        # skip connect projection from in_channels to out_channels
        # depending on the stride and channels to do a projection
        # or just pass on the input
        if stride == 1 and in_channels == out_channels:
            self.shortcut = nn.Identity()
        else:
            self.shortcut = ShortConn2d(in_channels, out_channels, stride)

        
    def forward(self, x):
        # reserve this now for the skip connection
        shortcut = self.shortcut(x)
        x = self.conv1(x)
        x = self.bn1(x)
        x = self.act1(x)
        x = self.conv2(x)
        x = self.bn2(x)

        # not applying activation here for densenet implementation
        return x + shortcut

# %%
class DenseNet(nn.Module):
    def __init__(self):
        super(DenseNet, self).__init__()
        
        ### RES 1 ###
        
        # 3x32x32 to 10x32x32
        self.rb1 = ResBlock(3, 10, 1)
        self.act1 = nn.ReLU()

        ### RES 2 ###

        # 10x32x32 to 20x32x32
        self.rb2 = ResBlock(10, 20, 1)
        # RES 1 skip connection 3x32x32 to 20x32x32
        self.sc1 = ShortConn2d(3, 20, 1)  
        self.act2 = nn.ReLU()
        
        ### RES 3 ###
        
        # 20x32x32 to 20x16x16
        self.rb3 = ResBlock(20, 20, 2)
        # RES 1 skip connection for 3x32x32 to 20x16x16
        self.sc2 = ShortConn2d(3, 20, 2)
        # RES 2 skip connection 10x32x32 to 20x16x16
        self.sc3 = ShortConn2d(10, 20, 2)
        
        # apply dropout prior to last activation before fully connected layer
        self.dp = nn.Dropout(p=0.5)
        self.act3 = nn.ReLU()  
        
        # input image shape = 20x4x4
        # affine operation to hidden layer with 100 neurons
        self.fc1 = nn.Linear(20 * 16 * 16, 100)
        self.bn4 = nn.BatchNorm1d(100)
        
        self.act4 = nn.ReLU()
        
        # affine operation to output layer with 10 neurons
        self.fc2 = nn.Linear(100, 10)
        
    def forward(self, x):
       
        res1_sc1 = self.sc1(x)
        res1_sc2 = self.sc2(x)
        x = self.rb1(x)
        x = self.act1(x)
        
        res2_sc1 = self.sc3(x)
        x = self.rb2(x)
        x = self.act2(x + res1_sc1)
        
        x = self.rb3(x)
        x = self.dp(x + res1_sc2 + res2_sc1)
        x = self.act3(x)
        
        # flatten and pass through fully connected layers
        x = torch.flatten(x, 1)
        x = self.fc1(x)
        x = self.bn4(x)
        x = self.act4(x)
        x = self.fc2(x)
        return x

# %%
PATH = './cifar_dense_dropout_exp_adam.pth'

epochs = 5            # Total epochs.
iter_n = len(trainloader)  # number of iteration per epoch
record_freq = iter_n // 100  # Record frequency.
print_freq = iter_n // 100 # Print frequency, need to be multiple of record_freq.

# a number for computing running validation loss in each iteration.
train_per_valid = len(trainloader) / len(validloader)  

avg_train_losses, avg_valid_losses = [], []   # Avg. losses.
train_accuracies, valid_accuracies = [], []  # Train and test accuracies.

dense_net = DenseNet()     # Create the network instance.
dense_net.to(device)  # Move the network parameters to the specified device.

# We use cross-entropy as loss function.
loss_func = nn.CrossEntropyLoss()  

# We use Adam as optimizer.
opt = optim.Adam(dense_net.parameters(), lr=0.001, betas=(0.9, 0.999), eps=1e-08)

# add plateau scheduling
scheduler = optim.lr_scheduler.ExponentialLR(opt, gamma=0.8)

for epoch in range(epochs):  # Loop over the dataset multiple times.
    running_train_loss = 0.0       # Initialize running train_loss for training set.
    running_val_loss = 0.0     # Initialize running train_loss for validation set.
    
    # Initialize running total and correct for computing train accuracy.
    train_correct = 0 
    train_total = 0
    # Initialize running total and correct for computing test accuracy.
    valid_total = 0   
    valid_correct = 0
    
    print('--> [Start of epoch {}]'.format(epoch) +
          '  lr: {:.6f}'.format(scheduler.get_last_lr()[0]))
    
    
    validiter = iter(validloader)
    for i, data in enumerate(iterable=trainloader, start=0):
        
        # Set the model to training mode.
        dense_net.train()
        
        # Get the train_inputs.
        train_inputs, train_labels = data
        
        # Move the train_inputs to the specified device.
        train_inputs, train_labels = train_inputs.to(device), train_labels.to(device)
        
        # Zero the parameter gradients.
        opt.zero_grad()

        # Forward step
        train_output = dense_net(train_inputs)
        train_loss = loss_func(train_output, train_labels)
        
        # Backward step.
        train_loss.backward()
        
        # Optimization step (update the parameters).
        opt.step()
        
        dense_net.eval()
        # record statistics.
        running_train_loss += train_loss.item()
        
        # only iterate through validation set according to train_per_valid ratio
        if i % train_per_valid == train_per_valid - 1:
            # Set the model to evaluation mode.
            with torch.no_grad():
                valid_inputs, valid_labels = next(validiter)
                valid_inputs, valid_labels = valid_inputs.to(device), valid_labels.to(device)
                valid_output = dense_net(valid_inputs)
                valid_loss = loss_func(valid_output, valid_labels)
                running_val_loss += valid_loss.item()
                
                _, valid_predicted = torch.max(valid_output.data, 1)
                valid_total += valid_labels.size(0)
                valid_correct += (valid_predicted == valid_labels).sum().item()
        
        # record training accuracy in every mini-batch
        _, train_predicted = torch.max(train_output.data, 1)
        train_total += train_labels.size(0)
        train_correct += (train_predicted == train_labels).sum().item()
        
        # Record training/validation loss every several mini-batches.
        if i % record_freq == record_freq - 1: 
            avg_train_loss = running_train_loss / record_freq
            avg_train_losses.append(avg_train_loss)
            avg_valid_loss = train_per_valid * running_val_loss / record_freq
            avg_valid_losses.append(avg_valid_loss)
            running_train_loss, running_val_loss = 0.0, 0.0
            
            # only print traing training loss once in a while to avoid cluster output
            if i % print_freq == print_freq - 1:
                print('[epoch: {}, i: {:5d}]'.format(epoch, i) +
                      '  train_loss: {:.3f}'.format(avg_train_loss) + 
                      '  |  valid_loss: {:.3f}'.format(avg_valid_loss))

    # do exponential scheduling
    scheduler.step()
                   
    # calculating train accuracy
    train_accuracy = 100 * train_correct / train_total
    train_accuracies.append(train_accuracy)
    
    valid_accuracy = 100 * valid_correct / valid_total
    valid_accuracies.append(valid_accuracy)

    # Store the networks after each epochs.
    # in case we want to do simple average or weighted average
    torch.save({
            'epoch': epoch,
            'model_state_dict': dense_net.state_dict(),
            'optimizer_state_dict': opt.state_dict(),
            'train_loss': avg_train_losses[epoch],
            'train_accuracy': train_accuracies[epoch],
            'valid_accuracy': valid_accuracies[epoch],
            }, PATH)
    
    print('--> [End of epoch {}]'.format(epoch) +
                      ' train_accuracy: {:.2f}%'.format(train_accuracy) + 
                      '  |  valid_accuracy: {:.2f}%'.format(valid_accuracy))
              

print('Finished Training.')
# Out:
# --> [Start of epoch 3]  lr: 0.000410
# [epoch: 3, i:   124]  train_loss: 1.160  |  valid_loss: 0.793
# [epoch: 3, i:   249]  train_loss: 1.187  |  valid_loss: 0.838
# [epoch: 3, i:   374]  train_loss: 1.168  |  valid_loss: 0.831
# [epoch: 3, i:   499]  train_loss: 1.086  |  valid_loss: 0.947
# [epoch: 3, i:   624]  train_loss: 1.264  |  valid_loss: 0.851
# [epoch: 3, i:   749]  train_loss: 1.129  |  valid_loss: 0.696
# [epoch: 3, i:   874]  train_loss: 1.165  |  valid_loss: 0.860
# [epoch: 3, i:   999]  train_loss: 1.096  |  valid_loss: 0.898
# [epoch: 3, i:  1124]  train_loss: 1.165  |  valid_loss: 0.963
# [epoch: 3, i:  1249]  train_loss: 1.223  |  valid_loss: 0.753
# [epoch: 3, i:  1374]  train_loss: 1.209  |  valid_loss: 0.730
# [epoch: 3, i:  1499]  train_loss: 1.087  |  valid_loss: 0.858
# [epoch: 3, i:  1624]  train_loss: 1.145  |  valid_loss: 0.815
# [epoch: 3, i:  1749]  train_loss: 1.100  |  valid_loss: 0.885
# [epoch: 3, i:  1874]  train_loss: 1.158  |  valid_loss: 0.730
# [epoch: 3, i:  1999]  train_loss: 1.099  |  valid_loss: 0.919
# [epoch: 3, i:  2124]  train_loss: 1.088  |  valid_loss: 0.738
# [epoch: 3, i:  2249]  train_loss: 1.050  |  valid_loss: 0.864
# [epoch: 3, i:  2374]  train_loss: 1.115  |  valid_loss: 0.871
# [epoch: 3, i:  2499]  train_loss: 1.107  |  valid_loss: 1.040
# [epoch: 3, i:  2624]  train_loss: 1.120  |  valid_loss: 0.956
# [epoch: 3, i:  2749]  train_loss: 1.197  |  valid_loss: 0.847
# [epoch: 3, i:  2874]  train_loss: 1.114  |  valid_loss: 0.901
# [epoch: 3, i:  2999]  train_loss: 1.068  |  valid_loss: 0.889
# [epoch: 3, i:  3124]  train_loss: 1.139  |  valid_loss: 0.854
# [epoch: 3, i:  3249]  train_loss: 1.169  |  valid_loss: 1.108
# [epoch: 3, i:  3374]  train_loss: 1.184  |  valid_loss: 0.828
# [epoch: 3, i:  3499]  train_loss: 1.160  |  valid_loss: 0.919
# [epoch: 3, i:  3624]  train_loss: 1.128  |  valid_loss: 0.820
# [epoch: 3, i:  3749]  train_loss: 1.175  |  valid_loss: 0.822
# [epoch: 3, i:  3874]  train_loss: 1.095  |  valid_loss: 0.761
# [epoch: 3, i:  3999]  train_loss: 1.080  |  valid_loss: 0.771
# [epoch: 3, i:  4124]  train_loss: 1.075  |  valid_loss: 0.884
# [epoch: 3, i:  4249]  train_loss: 1.089  |  valid_loss: 0.980
# [epoch: 3, i:  4374]  train_loss: 1.125  |  valid_loss: 0.919
# [epoch: 3, i:  4499]  train_loss: 1.120  |  valid_loss: 0.853
# [epoch: 3, i:  4624]  train_loss: 1.082  |  valid_loss: 0.940
# [epoch: 3, i:  4749]  train_loss: 1.187  |  valid_loss: 0.941
# [epoch: 3, i:  4874]  train_loss: 1.132  |  valid_loss: 0.708
# [epoch: 3, i:  4999]  train_loss: 1.143  |  valid_loss: 0.701
# [epoch: 3, i:  5124]  train_loss: 1.090  |  valid_loss: 0.800
# [epoch: 3, i:  5249]  train_loss: 1.168  |  valid_loss: 0.810
# [epoch: 3, i:  5374]  train_loss: 1.124  |  valid_loss: 0.713
# [epoch: 3, i:  5499]  train_loss: 1.025  |  valid_loss: 0.807
# [epoch: 3, i:  5624]  train_loss: 1.022  |  valid_loss: 0.838
# [epoch: 3, i:  5749]  train_loss: 1.108  |  valid_loss: 0.866
# [epoch: 3, i:  5874]  train_loss: 1.052  |  valid_loss: 0.806
# [epoch: 3, i:  5999]  train_loss: 1.119  |  valid_loss: 0.892
# [epoch: 3, i:  6124]  train_loss: 1.142  |  valid_loss: 0.709
# [epoch: 3, i:  6249]  train_loss: 1.087  |  valid_loss: 0.873
# [epoch: 3, i:  6374]  train_loss: 1.103  |  valid_loss: 0.746
# [epoch: 3, i:  6499]  train_loss: 1.144  |  valid_loss: 0.856
# [epoch: 3, i:  6624]  train_loss: 1.014  |  valid_loss: 0.750
# [epoch: 3, i:  6749]  train_loss: 0.994  |  valid_loss: 0.919
# [epoch: 3, i:  6874]  train_loss: 1.072  |  valid_loss: 0.828
# [epoch: 3, i:  6999]  train_loss: 1.215  |  valid_loss: 0.948
# [epoch: 3, i:  7124]  train_loss: 1.138  |  valid_loss: 0.937
# [epoch: 3, i:  7249]  train_loss: 1.168  |  valid_loss: 0.660
# [epoch: 3, i:  7374]  train_loss: 1.210  |  valid_loss: 1.029
# [epoch: 3, i:  7499]  train_loss: 1.207  |  valid_loss: 0.829
# [epoch: 3, i:  7624]  train_loss: 1.147  |  valid_loss: 0.830
# [epoch: 3, i:  7749]  train_loss: 1.165  |  valid_loss: 0.784
# [epoch: 3, i:  7874]  train_loss: 1.059  |  valid_loss: 0.852
# [epoch: 3, i:  7999]  train_loss: 1.158  |  valid_loss: 0.780
# [epoch: 3, i:  8124]  train_loss: 1.090  |  valid_loss: 0.792
# [epoch: 3, i:  8249]  train_loss: 1.206  |  valid_loss: 0.817
# [epoch: 3, i:  8374]  train_loss: 1.063  |  valid_loss: 0.848
# [epoch: 3, i:  8499]  train_loss: 1.073  |  valid_loss: 0.857
# [epoch: 3, i:  8624]  train_loss: 1.150  |  valid_loss: 0.958
# [epoch: 3, i:  8749]  train_loss: 1.020  |  valid_loss: 0.921
# [epoch: 3, i:  8874]  train_loss: 1.225  |  valid_loss: 0.877
# [epoch: 3, i:  8999]  train_loss: 1.193  |  valid_loss: 0.916
# [epoch: 3, i:  9124]  train_loss: 1.138  |  valid_loss: 0.786
# [epoch: 3, i:  9249]  train_loss: 1.083  |  valid_loss: 0.644
# [epoch: 3, i:  9374]  train_loss: 1.104  |  valid_loss: 0.798
# [epoch: 3, i:  9499]  train_loss: 1.126  |  valid_loss: 0.770
# [epoch: 3, i:  9624]  train_loss: 1.197  |  valid_loss: 0.800
# [epoch: 3, i:  9749]  train_loss: 1.122  |  valid_loss: 0.758
# [epoch: 3, i:  9874]  train_loss: 1.058  |  valid_loss: 0.913
# [epoch: 3, i:  9999]  train_loss: 1.125  |  valid_loss: 0.860
# [epoch: 3, i: 10124]  train_loss: 1.108  |  valid_loss: 0.762
# [epoch: 3, i: 10249]  train_loss: 1.202  |  valid_loss: 0.756
# [epoch: 3, i: 10374]  train_loss: 1.159  |  valid_loss: 0.832
# [epoch: 3, i: 10499]  train_loss: 1.057  |  valid_loss: 0.829
# [epoch: 3, i: 10624]  train_loss: 1.089  |  valid_loss: 0.914
# [epoch: 3, i: 10749]  train_loss: 1.092  |  valid_loss: 0.838
# [epoch: 3, i: 10874]  train_loss: 1.011  |  valid_loss: 0.899
# [epoch: 3, i: 10999]  train_loss: 1.055  |  valid_loss: 0.901
# [epoch: 3, i: 11124]  train_loss: 1.080  |  valid_loss: 0.839
# [epoch: 3, i: 11249]  train_loss: 1.171  |  valid_loss: 0.822
# [epoch: 3, i: 11374]  train_loss: 1.089  |  valid_loss: 0.793
# [epoch: 3, i: 11499]  train_loss: 1.217  |  valid_loss: 0.750
# [epoch: 3, i: 11624]  train_loss: 1.099  |  valid_loss: 0.821
# [epoch: 3, i: 11749]  train_loss: 1.266  |  valid_loss: 0.804
# [epoch: 3, i: 11874]  train_loss: 1.074  |  valid_loss: 0.837
# [epoch: 3, i: 11999]  train_loss: 1.083  |  valid_loss: 0.812
# [epoch: 3, i: 12124]  train_loss: 1.127  |  valid_loss: 0.839
# [epoch: 3, i: 12249]  train_loss: 1.149  |  valid_loss: 0.965
# [epoch: 3, i: 12374]  train_loss: 1.136  |  valid_loss: 0.933
# [epoch: 3, i: 12499]  train_loss: 1.073  |  valid_loss: 0.728
# --> [End of epoch 3] train_accuracy: 61.65%  |  valid_accuracy: 71.07%
# --> [Start of epoch 4]  lr: 0.000328
# [epoch: 4, i:   124]  train_loss: 1.142  |  valid_loss: 0.741
# [epoch: 4, i:   249]  train_loss: 1.106  |  valid_loss: 0.807
# [epoch: 4, i:   374]  train_loss: 1.138  |  valid_loss: 0.762
# [epoch: 4, i:   499]  train_loss: 1.150  |  valid_loss: 0.930
# [epoch: 4, i:   624]  train_loss: 1.088  |  valid_loss: 0.815
# [epoch: 4, i:   749]  train_loss: 1.093  |  valid_loss: 0.616
# [epoch: 4, i:   874]  train_loss: 1.083  |  valid_loss: 0.739
# [epoch: 4, i:   999]  train_loss: 1.072  |  valid_loss: 0.855
# [epoch: 4, i:  1124]  train_loss: 1.077  |  valid_loss: 0.974
# [epoch: 4, i:  1249]  train_loss: 1.064  |  valid_loss: 0.751
# [epoch: 4, i:  1374]  train_loss: 1.069  |  valid_loss: 0.701
# [epoch: 4, i:  1499]  train_loss: 1.039  |  valid_loss: 0.814
# [epoch: 4, i:  1624]  train_loss: 1.016  |  valid_loss: 0.813
# [epoch: 4, i:  1749]  train_loss: 1.101  |  valid_loss: 0.813
# [epoch: 4, i:  1874]  train_loss: 1.162  |  valid_loss: 0.703
# [epoch: 4, i:  1999]  train_loss: 1.035  |  valid_loss: 0.834
# [epoch: 4, i:  2124]  train_loss: 1.043  |  valid_loss: 0.729
# [epoch: 4, i:  2249]  train_loss: 1.146  |  valid_loss: 0.768
# [epoch: 4, i:  2374]  train_loss: 1.081  |  valid_loss: 0.818
# [epoch: 4, i:  2499]  train_loss: 1.085  |  valid_loss: 1.099
# [epoch: 4, i:  2624]  train_loss: 0.992  |  valid_loss: 0.956
# [epoch: 4, i:  2749]  train_loss: 1.024  |  valid_loss: 0.868
# [epoch: 4, i:  2874]  train_loss: 1.136  |  valid_loss: 0.888
# [epoch: 4, i:  2999]  train_loss: 1.180  |  valid_loss: 0.888
# [epoch: 4, i:  3124]  train_loss: 1.086  |  valid_loss: 0.842
# [epoch: 4, i:  3249]  train_loss: 1.040  |  valid_loss: 1.126
# [epoch: 4, i:  3374]  train_loss: 1.025  |  valid_loss: 0.733
# [epoch: 4, i:  3499]  train_loss: 1.070  |  valid_loss: 0.871
# [epoch: 4, i:  3624]  train_loss: 1.104  |  valid_loss: 0.807
# [epoch: 4, i:  3749]  train_loss: 1.121  |  valid_loss: 0.752
# [epoch: 4, i:  3874]  train_loss: 1.030  |  valid_loss: 0.745
# [epoch: 4, i:  3999]  train_loss: 1.140  |  valid_loss: 0.790
# [epoch: 4, i:  4124]  train_loss: 1.063  |  valid_loss: 0.883
# [epoch: 4, i:  4249]  train_loss: 1.068  |  valid_loss: 0.870
# [epoch: 4, i:  4374]  train_loss: 1.158  |  valid_loss: 0.925
# [epoch: 4, i:  4499]  train_loss: 1.111  |  valid_loss: 0.812
# [epoch: 4, i:  4624]  train_loss: 1.153  |  valid_loss: 0.934
# [epoch: 4, i:  4749]  train_loss: 1.028  |  valid_loss: 0.882
# [epoch: 4, i:  4874]  train_loss: 1.073  |  valid_loss: 0.629
# [epoch: 4, i:  4999]  train_loss: 1.006  |  valid_loss: 0.702
# [epoch: 4, i:  5124]  train_loss: 1.036  |  valid_loss: 0.725
# [epoch: 4, i:  5249]  train_loss: 1.174  |  valid_loss: 0.766
# [epoch: 4, i:  5374]  train_loss: 1.120  |  valid_loss: 0.726
# [epoch: 4, i:  5499]  train_loss: 1.162  |  valid_loss: 0.790
# [epoch: 4, i:  5624]  train_loss: 1.011  |  valid_loss: 0.740
# [epoch: 4, i:  5749]  train_loss: 1.082  |  valid_loss: 0.918
# [epoch: 4, i:  5874]  train_loss: 1.118  |  valid_loss: 0.774
# [epoch: 4, i:  5999]  train_loss: 1.101  |  valid_loss: 0.817
# [epoch: 4, i:  6124]  train_loss: 1.084  |  valid_loss: 0.637
# [epoch: 4, i:  6249]  train_loss: 1.093  |  valid_loss: 0.872
# [epoch: 4, i:  6374]  train_loss: 1.066  |  valid_loss: 0.794
# [epoch: 4, i:  6499]  train_loss: 1.099  |  valid_loss: 0.828
# [epoch: 4, i:  6624]  train_loss: 1.047  |  valid_loss: 0.764
# [epoch: 4, i:  6749]  train_loss: 1.010  |  valid_loss: 0.938
# [epoch: 4, i:  6874]  train_loss: 1.076  |  valid_loss: 0.804
# [epoch: 4, i:  6999]  train_loss: 1.218  |  valid_loss: 0.900
# [epoch: 4, i:  7124]  train_loss: 1.105  |  valid_loss: 0.909
# [epoch: 4, i:  7249]  train_loss: 0.976  |  valid_loss: 0.612
# [epoch: 4, i:  7374]  train_loss: 1.098  |  valid_loss: 1.011
# [epoch: 4, i:  7499]  train_loss: 1.091  |  valid_loss: 0.763
# [epoch: 4, i:  7624]  train_loss: 1.135  |  valid_loss: 0.792
# [epoch: 4, i:  7749]  train_loss: 1.085  |  valid_loss: 0.768
# [epoch: 4, i:  7874]  train_loss: 1.034  |  valid_loss: 0.837
# [epoch: 4, i:  7999]  train_loss: 1.063  |  valid_loss: 0.700
# [epoch: 4, i:  8124]  train_loss: 1.158  |  valid_loss: 0.823
# [epoch: 4, i:  8249]  train_loss: 1.109  |  valid_loss: 0.816
# [epoch: 4, i:  8374]  train_loss: 0.995  |  valid_loss: 0.803
# [epoch: 4, i:  8499]  train_loss: 1.090  |  valid_loss: 0.845
# [epoch: 4, i:  8624]  train_loss: 1.137  |  valid_loss: 0.857
# [epoch: 4, i:  8749]  train_loss: 1.093  |  valid_loss: 0.847
# [epoch: 4, i:  8874]  train_loss: 1.077  |  valid_loss: 0.831
# [epoch: 4, i:  8999]  train_loss: 1.094  |  valid_loss: 0.807
# [epoch: 4, i:  9124]  train_loss: 1.031  |  valid_loss: 0.717
# [epoch: 4, i:  9249]  train_loss: 1.132  |  valid_loss: 0.687
# [epoch: 4, i:  9374]  train_loss: 0.970  |  valid_loss: 0.749
# [epoch: 4, i:  9499]  train_loss: 1.073  |  valid_loss: 0.747
# [epoch: 4, i:  9624]  train_loss: 0.987  |  valid_loss: 0.764
# [epoch: 4, i:  9749]  train_loss: 1.057  |  valid_loss: 0.730
# [epoch: 4, i:  9874]  train_loss: 1.081  |  valid_loss: 0.893
# [epoch: 4, i:  9999]  train_loss: 1.076  |  valid_loss: 0.862
# [epoch: 4, i: 10124]  train_loss: 0.990  |  valid_loss: 0.684
# [epoch: 4, i: 10249]  train_loss: 0.970  |  valid_loss: 0.733
# [epoch: 4, i: 10374]  train_loss: 1.097  |  valid_loss: 0.783
# [epoch: 4, i: 10499]  train_loss: 1.062  |  valid_loss: 0.812
# [epoch: 4, i: 10624]  train_loss: 1.065  |  valid_loss: 0.815
# [epoch: 4, i: 10749]  train_loss: 1.093  |  valid_loss: 0.791
# [epoch: 4, i: 10874]  train_loss: 1.190  |  valid_loss: 0.811
# [epoch: 4, i: 10999]  train_loss: 1.018  |  valid_loss: 0.738
# [epoch: 4, i: 11124]  train_loss: 1.009  |  valid_loss: 0.841
# [epoch: 4, i: 11249]  train_loss: 0.971  |  valid_loss: 0.799
# [epoch: 4, i: 11374]  train_loss: 1.048  |  valid_loss: 0.685
# [epoch: 4, i: 11499]  train_loss: 1.098  |  valid_loss: 0.719
# [epoch: 4, i: 11624]  train_loss: 1.062  |  valid_loss: 0.805
# [epoch: 4, i: 11749]  train_loss: 1.125  |  valid_loss: 0.716
# [epoch: 4, i: 11874]  train_loss: 1.038  |  valid_loss: 0.820
# [epoch: 4, i: 11999]  train_loss: 1.069  |  valid_loss: 0.782
# [epoch: 4, i: 12124]  train_loss: 1.183  |  valid_loss: 0.783
# [epoch: 4, i: 12249]  train_loss: 1.057  |  valid_loss: 1.003
# [epoch: 4, i: 12374]  train_loss: 1.040  |  valid_loss: 0.876
# [epoch: 4, i: 12499]  train_loss: 1.070  |  valid_loss: 0.711
# --> [End of epoch 4] train_accuracy: 63.30%  |  valid_accuracy: 72.33%
# --> [Start of epoch 5]  lr: 0.000262
# [epoch: 5, i:   124]  train_loss: 0.924  |  valid_loss: 0.735
# [epoch: 5, i:   249]  train_loss: 1.018  |  valid_loss: 0.769
# [epoch: 5, i:   374]  train_loss: 1.021  |  valid_loss: 0.802
# [epoch: 5, i:   499]  train_loss: 1.018  |  valid_loss: 0.869
# [epoch: 5, i:   624]  train_loss: 0.967  |  valid_loss: 0.804
# [epoch: 5, i:   749]  train_loss: 1.078  |  valid_loss: 0.559
# [epoch: 5, i:   874]  train_loss: 1.127  |  valid_loss: 0.767
# [epoch: 5, i:   999]  train_loss: 1.127  |  valid_loss: 0.811
# [epoch: 5, i:  1124]  train_loss: 1.144  |  valid_loss: 0.895
# [epoch: 5, i:  1249]  train_loss: 1.087  |  valid_loss: 0.723
# [epoch: 5, i:  1374]  train_loss: 0.922  |  valid_loss: 0.698
# [epoch: 5, i:  1499]  train_loss: 1.068  |  valid_loss: 0.867
# [epoch: 5, i:  1624]  train_loss: 1.168  |  valid_loss: 0.757
# [epoch: 5, i:  1749]  train_loss: 1.030  |  valid_loss: 0.834
# [epoch: 5, i:  1874]  train_loss: 1.055  |  valid_loss: 0.716
# [epoch: 5, i:  1999]  train_loss: 1.010  |  valid_loss: 0.859
# [epoch: 5, i:  2124]  train_loss: 1.046  |  valid_loss: 0.685
# [epoch: 5, i:  2249]  train_loss: 1.049  |  valid_loss: 0.780
# [epoch: 5, i:  2374]  train_loss: 1.034  |  valid_loss: 0.776
# [epoch: 5, i:  2499]  train_loss: 1.032  |  valid_loss: 1.059
# [epoch: 5, i:  2624]  train_loss: 1.076  |  valid_loss: 0.894
# [epoch: 5, i:  2749]  train_loss: 1.048  |  valid_loss: 0.764
# [epoch: 5, i:  2874]  train_loss: 1.132  |  valid_loss: 0.902
# [epoch: 5, i:  2999]  train_loss: 1.009  |  valid_loss: 0.849
# [epoch: 5, i:  3124]  train_loss: 1.026  |  valid_loss: 0.801
# [epoch: 5, i:  3249]  train_loss: 0.993  |  valid_loss: 1.117
# [epoch: 5, i:  3374]  train_loss: 1.068  |  valid_loss: 0.727
# [epoch: 5, i:  3499]  train_loss: 1.035  |  valid_loss: 0.842
# [epoch: 5, i:  3624]  train_loss: 1.094  |  valid_loss: 0.783
# [epoch: 5, i:  3749]  train_loss: 1.100  |  valid_loss: 0.787
# [epoch: 5, i:  3874]  train_loss: 1.032  |  valid_loss: 0.716
# [epoch: 5, i:  3999]  train_loss: 1.014  |  valid_loss: 0.735
# [epoch: 5, i:  4124]  train_loss: 1.025  |  valid_loss: 0.848
# [epoch: 5, i:  4249]  train_loss: 1.016  |  valid_loss: 0.861
# [epoch: 5, i:  4374]  train_loss: 1.059  |  valid_loss: 0.958
# [epoch: 5, i:  4499]  train_loss: 1.086  |  valid_loss: 0.821
# [epoch: 5, i:  4624]  train_loss: 1.088  |  valid_loss: 0.964
# [epoch: 5, i:  4749]  train_loss: 1.135  |  valid_loss: 0.929
# [epoch: 5, i:  4874]  train_loss: 0.994  |  valid_loss: 0.624
# [epoch: 5, i:  4999]  train_loss: 0.979  |  valid_loss: 0.630
# [epoch: 5, i:  5124]  train_loss: 1.043  |  valid_loss: 0.770
# [epoch: 5, i:  5249]  train_loss: 1.043  |  valid_loss: 0.799
# [epoch: 5, i:  5374]  train_loss: 0.990  |  valid_loss: 0.738
# [epoch: 5, i:  5499]  train_loss: 1.056  |  valid_loss: 0.772
# [epoch: 5, i:  5624]  train_loss: 1.041  |  valid_loss: 0.738
# [epoch: 5, i:  5749]  train_loss: 0.998  |  valid_loss: 0.861
# [epoch: 5, i:  5874]  train_loss: 1.100  |  valid_loss: 0.797
# [epoch: 5, i:  5999]  train_loss: 1.021  |  valid_loss: 0.774
# [epoch: 5, i:  6124]  train_loss: 1.046  |  valid_loss: 0.579
# [epoch: 5, i:  6249]  train_loss: 1.081  |  valid_loss: 0.853
# [epoch: 5, i:  6374]  train_loss: 1.025  |  valid_loss: 0.771
# [epoch: 5, i:  6499]  train_loss: 1.024  |  valid_loss: 0.835
# [epoch: 5, i:  6624]  train_loss: 1.134  |  valid_loss: 0.736
# [epoch: 5, i:  6749]  train_loss: 1.024  |  valid_loss: 0.874
# [epoch: 5, i:  6874]  train_loss: 1.035  |  valid_loss: 0.790
# [epoch: 5, i:  6999]  train_loss: 1.028  |  valid_loss: 0.852
# [epoch: 5, i:  7124]  train_loss: 1.128  |  valid_loss: 0.876
# [epoch: 5, i:  7249]  train_loss: 1.081  |  valid_loss: 0.621
# [epoch: 5, i:  7374]  train_loss: 1.109  |  valid_loss: 0.963
# [epoch: 5, i:  7499]  train_loss: 1.040  |  valid_loss: 0.763
# [epoch: 5, i:  7624]  train_loss: 1.092  |  valid_loss: 0.751
# [epoch: 5, i:  7749]  train_loss: 1.118  |  valid_loss: 0.736
# [epoch: 5, i:  7874]  train_loss: 1.025  |  valid_loss: 0.775
# [epoch: 5, i:  7999]  train_loss: 0.909  |  valid_loss: 0.711
# [epoch: 5, i:  8124]  train_loss: 1.115  |  valid_loss: 0.773
# [epoch: 5, i:  8249]  train_loss: 1.075  |  valid_loss: 0.776
# [epoch: 5, i:  8374]  train_loss: 1.040  |  valid_loss: 0.772
# [epoch: 5, i:  8499]  train_loss: 1.000  |  valid_loss: 0.803
# [epoch: 5, i:  8624]  train_loss: 1.005  |  valid_loss: 0.864
# [epoch: 5, i:  8749]  train_loss: 1.025  |  valid_loss: 0.859
# [epoch: 5, i:  8874]  train_loss: 1.147  |  valid_loss: 0.770
# [epoch: 5, i:  8999]  train_loss: 1.159  |  valid_loss: 0.759
# [epoch: 5, i:  9124]  train_loss: 1.143  |  valid_loss: 0.705
# [epoch: 5, i:  9249]  train_loss: 1.083  |  valid_loss: 0.652
# [epoch: 5, i:  9374]  train_loss: 1.088  |  valid_loss: 0.726
# [epoch: 5, i:  9499]  train_loss: 1.070  |  valid_loss: 0.770
# [epoch: 5, i:  9624]  train_loss: 1.007  |  valid_loss: 0.734
# [epoch: 5, i:  9749]  train_loss: 1.063  |  valid_loss: 0.750
# [epoch: 5, i:  9874]  train_loss: 1.086  |  valid_loss: 0.834
# [epoch: 5, i:  9999]  train_loss: 1.049  |  valid_loss: 0.847
# [epoch: 5, i: 10124]  train_loss: 1.104  |  valid_loss: 0.687
# [epoch: 5, i: 10249]  train_loss: 1.026  |  valid_loss: 0.743
# [epoch: 5, i: 10374]  train_loss: 1.022  |  valid_loss: 0.734
# [epoch: 5, i: 10499]  train_loss: 1.027  |  valid_loss: 0.840
# [epoch: 5, i: 10624]  train_loss: 1.064  |  valid_loss: 0.818
# [epoch: 5, i: 10749]  train_loss: 0.931  |  valid_loss: 0.767
# [epoch: 5, i: 10874]  train_loss: 1.079  |  valid_loss: 0.844
# [epoch: 5, i: 10999]  train_loss: 1.053  |  valid_loss: 0.768
# [epoch: 5, i: 11124]  train_loss: 0.979  |  valid_loss: 0.820
# [epoch: 5, i: 11249]  train_loss: 1.114  |  valid_loss: 0.803
# [epoch: 5, i: 11374]  train_loss: 1.105  |  valid_loss: 0.726
# [epoch: 5, i: 11499]  train_loss: 0.991  |  valid_loss: 0.689
# [epoch: 5, i: 11624]  train_loss: 1.096  |  valid_loss: 0.743
# [epoch: 5, i: 11749]  train_loss: 1.037  |  valid_loss: 0.722
# [epoch: 5, i: 11874]  train_loss: 1.015  |  valid_loss: 0.815
# [epoch: 5, i: 11999]  train_loss: 1.168  |  valid_loss: 0.740
# [epoch: 5, i: 12124]  train_loss: 1.013  |  valid_loss: 0.770
# [epoch: 5, i: 12249]  train_loss: 1.004  |  valid_loss: 1.012
# [epoch: 5, i: 12374]  train_loss: 1.024  |  valid_loss: 0.878
# [epoch: 5, i: 12499]  train_loss: 1.011  |  valid_loss: 0.738
# --> [End of epoch 5] train_accuracy: 64.36%  |  valid_accuracy: 72.76%
# Finished Training.

# %%
plt.plot(avg_train_losses)
plt.plot(avg_valid_losses)
plt.title('DenseNet loss curve + pleateau scheduling')
plt.xlabel('mini-batch index / {}'.format(record_freq))
plt.ylabel('avg. mini-batch loss')
plt.legend(['training loss', 'validation loss'])
plt.show()

# %%
plt.plot(train_accuracies)
plt.plot(valid_accuracies)
plt.title('Accuracy Curve for DenseNet + ReduceLROnPlateau + Adam')
plt.xlabel('epoch / {}'.format(record_freq))
plt.ylabel('accuracy')
plt.legend(['train accuracy', 'test accuracy'])
plt.show()

# %%
# The function to show an image.
def imshow(img):
    img = img / 2 + 0.5     # Unnormalize.
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# %%
# Check several images.
dataiter = iter(validloader)
images, labels = next(dataiter)
imshow(torchvision.utils.make_grid(images))
print('GroundTruth: ', ' '.join('%5s' % classes[labels[j]] for j in range(4)))
outputs = dense_net(images.to(device))

# max compare along the row, return the index of the max value, which is the predicted class
_, predicted = torch.max(outputs, 1)

print('Predicted: ', ' '.join('%5s' % classes[predicted[j]]
                              for j in range(4)))
# Out:
# GroundTruth:    cat  ship  ship plane
# Predicted:    cat  ship  ship plane

# %%
dense_net.eval()
# Get test accuracy.
correct = 0
total = 0
with torch.no_grad():
    for data in validloader:
        images, labels = data
        images, labels = images.to(device), labels.to(device)
        outputs = dense_net(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print('Accuracy of the network on the 10000 test images: %.2f %%' % (
    100 * correct / total))
# Out:
# Accuracy of the network on the 10000 test images: 73.13 %

# %%
# Get test accuracy for each class.
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))
with torch.no_grad():
    for data in validloader:
        images, labels = data
        images, labels = images.to(device), labels.to(device)
        outputs = dense_net(images)
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels).squeeze()
        for i in range(4):
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1

for i in range(10):
    print('Accuracy of %5s : %2d %%' % (
        classes[i], 100 * class_correct[i] / class_total[i]))
# Out:
# Accuracy of plane : 70 %
# Accuracy of   car : 84 %
# Accuracy of  bird : 59 %
# Accuracy of   cat : 48 %
# Accuracy of  deer : 69 %
# Accuracy of   dog : 65 %
# Accuracy of  frog : 84 %
# Accuracy of horse : 74 %
# Accuracy of  ship : 91 %
# Accuracy of truck : 83 %

# %%
dense_net = DenseNet()     # Create the network instance.
opt = optim.Adam(dense_net.parameters())

PATH = './models/cifar_dense_dropout_exp_adam.pth'
checkpoint = torch.load(PATH)
dense_net.load_state_dict(checkpoint['model_state_dict'])
# dense_net.load_state_dict(checkpoint['optimizer_state_dict'])

dense_net.to(device)

dense_net.eval()
# Get test accuracy.
correct = 0
total = 0
with torch.no_grad():
    for data in validloader:
        images, labels = data
        images, labels = images.to(device), labels.to(device)
        outputs = dense_net(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print('Accuracy of the network on the 10000 test images: %.2f %%' % (
    100 * correct / total))
# Out:
# Accuracy of the network on the 10000 test images: 72.87 %

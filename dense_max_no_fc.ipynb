# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

batch_size = 4

std_transforms = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

std_trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=std_transforms)
trainloader = torch.utils.data.DataLoader(std_trainset, batch_size=batch_size,
                                          shuffle=True, num_workers=2)

validset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=std_transforms)
validloader = torch.utils.data.DataLoader(validset, batch_size=batch_size,
                                         shuffle=False, num_workers=2)

# If there are GPUs, choose the first one for computing. Otherwise use CPU.
device = torch.device("cuda:0" if torch.cuda.is_available() else ("mps" if torch.backends.mps.is_available() else "cpu"))

# the order for cifar10 10 classes
classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

print(device)
print(len(std_trainset))
print(len(trainloader))  
# If 'mps or cuda:0' is printed, it means GPU is available.
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# mps
# 50000
# 12500

# %% [markdown]
# #### Optional: Apply data augmentation

# %%
from custom_nn.datasets import CustomCIFAR10

# Additional focused augmentations
focused_augmentations = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
])

# using custom dataset class to add focused augmentations capability
aug_trainset = CustomCIFAR10(
    root='./data',
    train=True,
    download=True,
    transform=std_transforms,
    focused_transform=focused_augmentations
)

# the class we want the augmentation for birds, cats, deer, and dogs
desired_classes = [1, 2, 3, 4]

# Filter the dataset
filtered_indices = [i for i, (_, label) in enumerate(aug_trainset) if label in desired_classes]

filtered_dataset = torch.utils.data.Subset(aug_trainset, filtered_indices)

# Combine the two datasets
combined_trainset = torch.utils.data.ConcatDataset([std_trainset, filtered_dataset])
trainloader = torch.utils.data.DataLoader(combined_trainset, batch_size=batch_size,
                                          shuffle=True, num_workers=2)
print(len(combined_trainset))
print(len(trainloader))
# Out:
# Files already downloaded and verified
# 70000
# 17500

# %%
from custom_nn.blocks import ResBlock, SkipConn2d, BottleneckResBlock

class DenseMaxNoFC(nn.Module):
    def __init__(self):
        super().__init__()
        
        ### RES 1
        
        # 3x32x32 to 10x32x32
        self.rb1 = ResBlock(3, 10, 1)
        self.act1 = nn.ReLU()
        # 10x32x32 to 10x16x16
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)

        ### RES 2

        # 10x16x16 to 20x16x16
        self.rb2 = ResBlock(10, 20, 1)
        sc_layers = [SkipConn2d(3, 20, 2)]
        self.sc2 = nn.ModuleList(sc_layers)
        self.act2 = nn.ReLU()
        # 20x16x16 to 20x8x18
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        
        ### RES 3
        # 20x8x8 to 30x8x8
        self.rb3 = ResBlock(20, 30, 1)
        sc_layers = [SkipConn2d(3, 30, 4),SkipConn2d(10, 30, 2)]
        self.sc3 = nn.ModuleList(sc_layers)
        self.act3 = nn.ReLU()
        
        ### RES 4
        # 30x8x8 to 40x8x8
        self.rb4 = ResBlock(30, 40, 1)
        sc_layers = [SkipConn2d(3, 40, 4),SkipConn2d(10, 40, 2), SkipConn2d(20, 40)]
        self.sc4 = nn.ModuleList(sc_layers)
        self.act4 = nn.ReLU()
        
        ### RES 5
        # 40x8x8 to 40x8x8
        self.rb5 = ResBlock(40, 40, 1)
        sc_layers = [SkipConn2d(3, 40, 4),SkipConn2d(10, 40, 2), SkipConn2d(20, 40), SkipConn2d(30,40)]
        self.sc5 = nn.ModuleList(sc_layers)
        self.act5 = nn.ReLU()
        
        ### RES 6
        # 40x8x8 to 50x8x8
        self.rb6 = ResBlock(40, 50, 1)
        sc_layers = [SkipConn2d(3, 50, 4),SkipConn2d(10, 50, 2), SkipConn2d(20, 50), SkipConn2d(30,50), SkipConn2d(40,50)]
        self.sc6 = nn.ModuleList(sc_layers)
        self.act6 = nn.ReLU()
        
        # we will do flatten height and width and then do global average pooling
        # affine operation from 20 neurons to output layer with 10 classes
        self.fc = nn.Linear(50, 10)
        
        # add all skip connections to a list
        self.sc_list = [self.sc2, self.sc3, self.sc4, self.sc5, self.sc6]
        
    def forward(self, x):

        sc1 = []
        for sc in self.sc_list:
            sc1.append(sc[0](x))
        x = self.rb1(x)
        x = self.act1(x)
        x = self.pool1(x)
        
        sc2 = []
        for sc in self.sc_list[1:]:
            sc2.append(sc[1](x))
        
        x = self.rb2(x)
        x = x + sc1[0]
        x = self.act2(x)
        x = self.pool2(x)
        
        sc3 = []
        for sc in self.sc_list[2:]:
            sc3.append(sc[2](x))
        x = self.rb3(x)
        x = x + sc1[1] + sc2[0]
        x = self.act3(x)
        
        sc4 = []
        for sc in self.sc_list[3:]:
            sc4.append(sc[3](x))
        x = self.rb4(x)
        x = x + sc1[2] + sc2[1] + sc3[0]
        x = self.act4(x)
        
        sc5 = []
        for sc in self.sc_list[4:]:
            sc5.append(sc[4](x))
        x = self.rb5(x)
        x = x + sc1[3] + sc2[2] + sc3[1] + sc4[0]
        x = self.act5(x)
        
        x = self.rb6(x)
        x = x + sc1[4] + sc2[3] + sc3[2] + sc4[1] + sc5[0]
        x = self.act6(x)
        
        # 4 (batch size) x 50 (channels) x 32 (height) x 32 (width)
        # change x from shape [batch_size, channels, height, width] 
        # to [batch_size, channels, height*width]
        x = x.view(x.shape[0], x.shape[1], -1)
        # global average pooling over the spatial dimensions in each feature map
        # becomes 4 x 50
        x = x.mean(dim=-1)
         
        x = self.fc(x)
        return x
    
test = DenseMaxNoFC()
test.to(device)
test(torch.randn(4, 3, 32, 32).to(device))
# Out:
# tensor([[-0.7640, -0.2569,  0.2636,  0.5117, -1.4477, -1.7202, -0.1469,  0.0664,
#          -0.3224, -0.7752],
#         [-0.3465, -0.1302,  0.4086,  0.4198, -1.4061, -1.4067, -0.1955, -0.1025,
#          -0.3143, -0.4780],
#         [-0.3083, -0.0268,  0.3632,  0.3235, -1.6100, -1.4681, -0.0813, -0.0384,
#          -0.2729, -0.5186],
#         [-0.3403, -0.1818,  0.4609,  0.4950, -1.3746, -1.5663, -0.2047, -0.1067,
#          -0.5224, -0.4971]], device='mps:0', grad_fn=<LinearBackward0>)

# %%
from pathlib import Path
import time
from custom_nn.utils.model_utils import count_parameters, get_model_size

epoch_start = 0     # Start from epoch 0 or last checkpoint epoch
iter_n = len(trainloader)  # number of iteration per epoch
record_freq = 100 # how many times to record the loss and accuracy per epoch
print_freq = 100 # how many times to print the loss and accuracy per epoch
iter_n_per_record = iter_n // record_freq  # Record frequency.
iter_n_per_print = iter_n // print_freq # Print frequency, need to be multiple of record_freq.

# a number for computing running validation loss in each iteration.
train_per_valid = len(trainloader) / len(validloader)  

avg_train_losses, avg_valid_losses = [], []   # Avg. losses.
train_accuracies, valid_accuracies = [], []  # Train and test accuracies.
time_per_epoch = []  # Time per epoch.

model = DenseMaxNoFC()     # Create the network instance.
# Move the network parameters to the specified device
# need to be done before passing to optimizer.
model.to(device)  

assert model(torch.randn(4, 3, 32, 32).to(device)).shape == torch.Size([4, 10])

# We use Adam as optimizer.
opt = optim.Adam(model.parameters(), lr=5e-4, betas=(0.9, 0.999), eps=1e-08, weight_decay=1e-4)
# We use cross-entropy as loss function.
loss_func = nn.CrossEntropyLoss() 

# add scheduling
# scheduler = optim.lr_scheduler.ExponentialLR(opt, gamma=0.8)
# scheduler = optim.lr_scheduler.StepLR(opt, step_size=5, gamma=0.8)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(opt, mode='max', factor=0.1, patience=4, threshold=1e-4)

# directory to save the model
directory_path = Path("./checkpoints/dense_max_no_fc" + "_batch" + str(batch_size))
# Make the directory if it doesn't exist
directory_path.mkdir(parents=True, exist_ok=True)

print("train_per_valid:", train_per_valid)

print("number of parameters:", count_parameters(model))
print('model size: {:.4f}MB'.format(get_model_size(model)))
# Out:
# train_per_valid: 7.0
# number of parameters: 131970
# model size: 0.5124MB

# %%
import re

# Pattern to match the files and extract epoch numbers
pattern = r'epoch_(\d+).pth'

# Use Path.glob to list all files matching the pattern
files = list(directory_path.glob('epoch_*.pth'))

# Extract epochs and files into a list of tuples
epoch_files = []
for file_path in files:
    match = re.search(pattern, file_path.name)
    if match:
        epoch_num = int(match.group(1))
        epoch_files.append((epoch_num, file_path))

# Sort the list by epoch number in descending order
epoch_files.sort(key=lambda x: x[0], reverse=False)

if epoch_files:
    # populating history for loss and accuracy for plotting
    for file in epoch_files:
        checkpoint = torch.load(file[1])
        avg_train_losses += checkpoint['avg_train_losses']
        avg_valid_losses += checkpoint['avg_valid_losses']
        train_accuracies.append(checkpoint['train_accuracy'])
        valid_accuracies.append(checkpoint['valid_accuracy'])
        time_per_epoch.append(checkpoint['time_per_epoch'])
    
    # load the model from the latest checkpoint file
    latest_file_path = epoch_files[-1][1]
    print(f"The latest checkpoint file is: {latest_file_path}")
    checkpoint = torch.load(latest_file_path)
    model.load_state_dict(checkpoint['model_state_dict'])
    opt.load_state_dict(checkpoint['optimizer_state_dict'])
    scheduler.load_state_dict(checkpoint['scheduler_state_dict'])
    
    # start training from the next epoch
    epoch_start = checkpoint['epoch'] + 1
else:
    print("No checkpoint files found.")
# Out:
# No checkpoint files found.

# %%
epochs = 10  # Total epochs.

for epoch in range(epoch_start, epoch_start + epochs):  # Loop over the dataset multiple times.
    running_train_loss = 0.0       # Initialize running train_loss for training set.
    running_val_loss = 0.0     # Initialize running train_loss for validation set.
    
    # Initialize running total and correct for computing train accuracy.
    train_correct = 0 
    train_total = 0
    # Initialize running total and correct for computing test accuracy.
    valid_total = 0   
    valid_correct = 0
    
    
    
    print('--> [Start of epoch {}]'.format(epoch) +
          '  lr: {:.6f}'.format(opt.param_groups[0]['lr']))
    
    # print('--> [Start of epoch {}]'.format(epoch))
    
    epoch_start_time = time.time()
    
    validiter = iter(validloader)
    for i, data in enumerate(iterable=trainloader, start=0):
        
        # Set the model to training mode.
        model.train()
        
        # Get the inputs.
        inputs, labels = data
        
        # Move the inputs to the specified device.
        inputs, labels = inputs.to(device), labels.to(device)
        
        # Zero the parameter gradients.
        opt.zero_grad()

        # Forward step
        train_output = model(inputs)
        train_loss = loss_func(train_output, labels)
        
        # Backward step.
        train_loss.backward()
        
        # Optimization step (update the parameters).
        opt.step()
        
        model.eval()
        
        # record statistics.
        running_train_loss += train_loss.item()
        
        # this is for recording training accuracy
        _, train_predicted = torch.max(train_output.data, 1)
        train_total += labels.size(0)
        train_correct += (train_predicted == labels).sum().item()
        
        # only iterate through validation set according to train_per_valid ratio
        if i % train_per_valid == train_per_valid - 1:
            # Set the model to evaluation mode.
            with torch.no_grad():
                valid_inputs, valid_labels = next(validiter)
                valid_inputs, valid_labels = valid_inputs.to(device), valid_labels.to(device)
                valid_output = model(valid_inputs)
                valid_loss = loss_func(valid_output, valid_labels)
                running_val_loss += valid_loss.item()
                
                _, valid_predicted = torch.max(valid_output.data, 1)
                valid_total += valid_labels.size(0)
                valid_correct += (valid_predicted == valid_labels).sum().item()
            
        # Record training/validation loss every several mini-batches.
        if i % iter_n_per_record == iter_n_per_record - 1: 
            avg_train_loss = running_train_loss / iter_n_per_record
            avg_train_losses.append(avg_train_loss)
            avg_valid_loss = train_per_valid * running_val_loss / iter_n_per_record
            avg_valid_losses.append(avg_valid_loss)
            running_train_loss, running_val_loss = 0.0, 0.0
            
            # only print traing training loss once in a while to avoid cluster output
            if i % iter_n_per_print == iter_n_per_print - 1:
                print('[epoch: {}, i: {:5d}]'.format(epoch, i) +
                      '  train_loss: {:.3f}'.format(avg_train_loss) + 
                      '  |  valid_loss: {:.3f}'.format(avg_valid_loss))
                            
    epoch_end_time = time.time()
    time_per_epoch.append(epoch_end_time - epoch_start_time)
    
    # calculating train accuracy
    train_accuracy = 100 * train_correct / train_total
    train_accuracies.append(train_accuracy)
    
    valid_accuracy = 100 * valid_correct / valid_total
    valid_accuracies.append(valid_accuracy)     
    
    # reduce on plateau scheduling
    scheduler.step(valid_accuracy)
    
    # Store the networks after each epochs.
    # in case we want to do simple average or weighted average
    file_name = f'epoch_{epoch:04d}.pth'
    save_path = directory_path / file_name
    
    torch.save({
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': opt.state_dict(),
            'scheduler_state_dict': scheduler.state_dict(),
            'avg_train_losses': avg_train_losses[epoch * iter_n_per_record : (epoch + 1) * iter_n_per_record],
            'avg_valid_losses': avg_valid_losses[epoch * iter_n_per_record : (epoch + 1) * iter_n_per_record],
            'train_accuracy': train_accuracies[epoch],
            'valid_accuracy': valid_accuracies[epoch],
            'time_per_epoch': time_per_epoch[epoch],
            }, save_path)
    
    print('--> [End of epoch {}]'.format(epoch) +
                      ' train_accuracy: {:.2f}%'.format(train_accuracy) + 
                      '  |  valid_accuracy: {:.2f}%'.format(valid_accuracy))

print('Finished Training.')
# Out:
# --> [Start of epoch 0]  lr: 0.000500
# [epoch: 0, i:   174]  train_loss: 2.100  |  valid_loss: 2.387
# [epoch: 0, i:   349]  train_loss: 1.955  |  valid_loss: 2.131
# [epoch: 0, i:   524]  train_loss: 1.878  |  valid_loss: 1.828
# [epoch: 0, i:   699]  train_loss: 1.854  |  valid_loss: 1.865
# [epoch: 0, i:   874]  train_loss: 1.754  |  valid_loss: 1.788
# [epoch: 0, i:  1049]  train_loss: 1.740  |  valid_loss: 1.777
# [epoch: 0, i:  1224]  train_loss: 1.766  |  valid_loss: 1.717
# [epoch: 0, i:  1399]  train_loss: 1.718  |  valid_loss: 1.790
# [epoch: 0, i:  1574]  train_loss: 1.655  |  valid_loss: 1.627
# [epoch: 0, i:  1749]  train_loss: 1.617  |  valid_loss: 1.507
# [epoch: 0, i:  1924]  train_loss: 1.634  |  valid_loss: 1.461
# [epoch: 0, i:  2099]  train_loss: 1.599  |  valid_loss: 1.527
# [epoch: 0, i:  2274]  train_loss: 1.613  |  valid_loss: 1.632
# [epoch: 0, i:  2449]  train_loss: 1.565  |  valid_loss: 1.496
# [epoch: 0, i:  2624]  train_loss: 1.525  |  valid_loss: 1.297
# [epoch: 0, i:  2799]  train_loss: 1.532  |  valid_loss: 1.544
# [epoch: 0, i:  2974]  train_loss: 1.460  |  valid_loss: 1.444
# [epoch: 0, i:  3149]  train_loss: 1.491  |  valid_loss: 1.332
# [epoch: 0, i:  3324]  train_loss: 1.389  |  valid_loss: 1.431
# [epoch: 0, i:  3499]  train_loss: 1.426  |  valid_loss: 1.429
# [epoch: 0, i:  3674]  train_loss: 1.416  |  valid_loss: 1.345
# [epoch: 0, i:  3849]  train_loss: 1.376  |  valid_loss: 1.222
# [epoch: 0, i:  4024]  train_loss: 1.408  |  valid_loss: 1.419
# [epoch: 0, i:  4199]  train_loss: 1.388  |  valid_loss: 1.355
# [epoch: 0, i:  4374]  train_loss: 1.366  |  valid_loss: 1.240
# [epoch: 0, i:  4549]  train_loss: 1.300  |  valid_loss: 1.477
# [epoch: 0, i:  4724]  train_loss: 1.345  |  valid_loss: 1.272
# [epoch: 0, i:  4899]  train_loss: 1.365  |  valid_loss: 1.334
# [epoch: 0, i:  5074]  train_loss: 1.343  |  valid_loss: 1.440
# [epoch: 0, i:  5249]  train_loss: 1.316  |  valid_loss: 1.222
# [epoch: 0, i:  5424]  train_loss: 1.289  |  valid_loss: 1.240
# [epoch: 0, i:  5599]  train_loss: 1.304  |  valid_loss: 1.219
# [epoch: 0, i:  5774]  train_loss: 1.297  |  valid_loss: 1.291
# [epoch: 0, i:  5949]  train_loss: 1.289  |  valid_loss: 1.380
# [epoch: 0, i:  6124]  train_loss: 1.314  |  valid_loss: 1.279
# [epoch: 0, i:  6299]  train_loss: 1.299  |  valid_loss: 1.172
# [epoch: 0, i:  6474]  train_loss: 1.255  |  valid_loss: 1.362
# [epoch: 0, i:  6649]  train_loss: 1.312  |  valid_loss: 1.439
# [epoch: 0, i:  6824]  train_loss: 1.241  |  valid_loss: 1.068
# [epoch: 0, i:  6999]  train_loss: 1.319  |  valid_loss: 1.098
# [epoch: 0, i:  7174]  train_loss: 1.267  |  valid_loss: 1.229
# [epoch: 0, i:  7349]  train_loss: 1.217  |  valid_loss: 1.072
# [epoch: 0, i:  7524]  train_loss: 1.228  |  valid_loss: 0.966
# [epoch: 0, i:  7699]  train_loss: 1.174  |  valid_loss: 1.153
# [epoch: 0, i:  7874]  train_loss: 1.213  |  valid_loss: 1.244
# [epoch: 0, i:  8049]  train_loss: 1.148  |  valid_loss: 1.185
# [epoch: 0, i:  8224]  train_loss: 1.242  |  valid_loss: 1.003
# [epoch: 0, i:  8399]  train_loss: 1.160  |  valid_loss: 1.219
# [epoch: 0, i:  8574]  train_loss: 1.147  |  valid_loss: 1.025
# [epoch: 0, i:  8749]  train_loss: 1.163  |  valid_loss: 1.183
# [epoch: 0, i:  8924]  train_loss: 1.131  |  valid_loss: 1.175
# [epoch: 0, i:  9099]  train_loss: 1.198  |  valid_loss: 1.097
# [epoch: 0, i:  9274]  train_loss: 1.159  |  valid_loss: 1.044
# [epoch: 0, i:  9449]  train_loss: 1.133  |  valid_loss: 1.254
# [epoch: 0, i:  9624]  train_loss: 1.090  |  valid_loss: 1.231
# [epoch: 0, i:  9799]  train_loss: 1.192  |  valid_loss: 1.365
# [epoch: 0, i:  9974]  train_loss: 1.157  |  valid_loss: 1.142
# [epoch: 0, i: 10149]  train_loss: 1.112  |  valid_loss: 0.942
# [epoch: 0, i: 10324]  train_loss: 1.172  |  valid_loss: 1.246
# [epoch: 0, i: 10499]  train_loss: 1.187  |  valid_loss: 1.070
# [epoch: 0, i: 10674]  train_loss: 1.227  |  valid_loss: 1.217
# [epoch: 0, i: 10849]  train_loss: 1.146  |  valid_loss: 1.077
# [epoch: 0, i: 11024]  train_loss: 1.165  |  valid_loss: 0.970
# [epoch: 0, i: 11199]  train_loss: 1.153  |  valid_loss: 1.162
# [epoch: 0, i: 11374]  train_loss: 1.127  |  valid_loss: 1.199
# [epoch: 0, i: 11549]  train_loss: 1.103  |  valid_loss: 1.028
# [epoch: 0, i: 11724]  train_loss: 1.137  |  valid_loss: 0.977
# [epoch: 0, i: 11899]  train_loss: 1.069  |  valid_loss: 1.048
# [epoch: 0, i: 12074]  train_loss: 1.044  |  valid_loss: 1.125
# [epoch: 0, i: 12249]  train_loss: 1.109  |  valid_loss: 1.276
# [epoch: 0, i: 12424]  train_loss: 1.052  |  valid_loss: 1.096
# [epoch: 0, i: 12599]  train_loss: 1.025  |  valid_loss: 0.997
# [epoch: 0, i: 12774]  train_loss: 1.027  |  valid_loss: 1.013
# [epoch: 0, i: 12949]  train_loss: 1.087  |  valid_loss: 0.826
# [epoch: 0, i: 13124]  train_loss: 1.034  |  valid_loss: 1.044
# [epoch: 0, i: 13299]  train_loss: 1.090  |  valid_loss: 1.005
# [epoch: 0, i: 13474]  train_loss: 1.062  |  valid_loss: 1.092
# [epoch: 0, i: 13649]  train_loss: 1.029  |  valid_loss: 1.068
# [epoch: 0, i: 13824]  train_loss: 0.957  |  valid_loss: 1.172
# [epoch: 0, i: 13999]  train_loss: 1.132  |  valid_loss: 1.190
# [epoch: 0, i: 14174]  train_loss: 1.076  |  valid_loss: 0.986
# [epoch: 0, i: 14349]  train_loss: 1.094  |  valid_loss: 0.970
# [epoch: 0, i: 14524]  train_loss: 0.997  |  valid_loss: 0.941
# [epoch: 0, i: 14699]  train_loss: 0.997  |  valid_loss: 1.111
# [epoch: 0, i: 14874]  train_loss: 1.038  |  valid_loss: 1.184
# [epoch: 0, i: 15049]  train_loss: 1.018  |  valid_loss: 0.892
# [epoch: 0, i: 15224]  train_loss: 1.047  |  valid_loss: 1.159
# [epoch: 0, i: 15399]  train_loss: 1.006  |  valid_loss: 0.999
# [epoch: 0, i: 15574]  train_loss: 1.049  |  valid_loss: 1.003
# [epoch: 0, i: 15749]  train_loss: 0.983  |  valid_loss: 0.924
# [epoch: 0, i: 15924]  train_loss: 1.036  |  valid_loss: 0.936
# [epoch: 0, i: 16099]  train_loss: 0.990  |  valid_loss: 0.791
# [epoch: 0, i: 16274]  train_loss: 0.986  |  valid_loss: 0.923
# [epoch: 0, i: 16449]  train_loss: 1.040  |  valid_loss: 1.027
# [epoch: 0, i: 16624]  train_loss: 1.009  |  valid_loss: 1.031
# [epoch: 0, i: 16799]  train_loss: 1.059  |  valid_loss: 0.902
# [epoch: 0, i: 16974]  train_loss: 1.014  |  valid_loss: 0.879
# [epoch: 0, i: 17149]  train_loss: 0.955  |  valid_loss: 1.049
# [epoch: 0, i: 17324]  train_loss: 0.962  |  valid_loss: 1.030
# [epoch: 0, i: 17499]  train_loss: 1.063  |  valid_loss: 1.006
# --> [End of epoch 0] train_accuracy: 54.80%  |  valid_accuracy: 55.46%
# --> [Start of epoch 1]  lr: 0.000500
# [epoch: 1, i:   174]  train_loss: 0.978  |  valid_loss: 0.919
# [epoch: 1, i:   349]  train_loss: 0.992  |  valid_loss: 0.884
# [epoch: 1, i:   524]  train_loss: 0.975  |  valid_loss: 1.068
# [epoch: 1, i:   699]  train_loss: 0.877  |  valid_loss: 0.899
# [epoch: 1, i:   874]  train_loss: 1.057  |  valid_loss: 1.088
# [epoch: 1, i:  1049]  train_loss: 0.955  |  valid_loss: 0.833
# [epoch: 1, i:  1224]  train_loss: 0.919  |  valid_loss: 1.020
# [epoch: 1, i:  1399]  train_loss: 0.952  |  valid_loss: 0.957
# [epoch: 1, i:  1574]  train_loss: 0.998  |  valid_loss: 1.004
# [epoch: 1, i:  1749]  train_loss: 0.924  |  valid_loss: 0.827
# [epoch: 1, i:  1924]  train_loss: 0.980  |  valid_loss: 0.886
# [epoch: 1, i:  2099]  train_loss: 0.973  |  valid_loss: 0.991
# [epoch: 1, i:  2274]  train_loss: 0.993  |  valid_loss: 0.813
# [epoch: 1, i:  2449]  train_loss: 0.940  |  valid_loss: 0.848
# [epoch: 1, i:  2624]  train_loss: 1.027  |  valid_loss: 0.912
# [epoch: 1, i:  2799]  train_loss: 0.934  |  valid_loss: 1.027
# [epoch: 1, i:  2974]  train_loss: 0.921  |  valid_loss: 0.940
# [epoch: 1, i:  3149]  train_loss: 0.922  |  valid_loss: 0.946
# [epoch: 1, i:  3324]  train_loss: 0.921  |  valid_loss: 0.918
# [epoch: 1, i:  3499]  train_loss: 0.988  |  valid_loss: 1.049
# [epoch: 1, i:  3674]  train_loss: 0.947  |  valid_loss: 0.939
# [epoch: 1, i:  3849]  train_loss: 0.821  |  valid_loss: 0.919
# [epoch: 1, i:  4024]  train_loss: 0.906  |  valid_loss: 0.954
# [epoch: 1, i:  4199]  train_loss: 0.928  |  valid_loss: 0.950
# [epoch: 1, i:  4374]  train_loss: 0.884  |  valid_loss: 0.796
# [epoch: 1, i:  4549]  train_loss: 0.900  |  valid_loss: 1.185
# [epoch: 1, i:  4724]  train_loss: 0.961  |  valid_loss: 0.807
# [epoch: 1, i:  4899]  train_loss: 0.924  |  valid_loss: 0.901
# [epoch: 1, i:  5074]  train_loss: 0.902  |  valid_loss: 0.924
# [epoch: 1, i:  5249]  train_loss: 0.889  |  valid_loss: 0.742
# [epoch: 1, i:  5424]  train_loss: 0.912  |  valid_loss: 0.880
# [epoch: 1, i:  5599]  train_loss: 0.890  |  valid_loss: 0.764
# [epoch: 1, i:  5774]  train_loss: 0.892  |  valid_loss: 0.841
# [epoch: 1, i:  5949]  train_loss: 0.890  |  valid_loss: 0.967
# [epoch: 1, i:  6124]  train_loss: 0.856  |  valid_loss: 1.048
# [epoch: 1, i:  6299]  train_loss: 0.890  |  valid_loss: 0.953
# [epoch: 1, i:  6474]  train_loss: 0.886  |  valid_loss: 1.042
# [epoch: 1, i:  6649]  train_loss: 0.908  |  valid_loss: 1.034
# [epoch: 1, i:  6824]  train_loss: 0.891  |  valid_loss: 0.775
# [epoch: 1, i:  6999]  train_loss: 0.880  |  valid_loss: 0.773
# [epoch: 1, i:  7174]  train_loss: 0.906  |  valid_loss: 0.866
# [epoch: 1, i:  7349]  train_loss: 0.840  |  valid_loss: 0.888
# [epoch: 1, i:  7524]  train_loss: 0.902  |  valid_loss: 0.646
# [epoch: 1, i:  7699]  train_loss: 0.920  |  valid_loss: 0.887
# [epoch: 1, i:  7874]  train_loss: 0.936  |  valid_loss: 0.984
# [epoch: 1, i:  8049]  train_loss: 0.889  |  valid_loss: 0.927
# [epoch: 1, i:  8224]  train_loss: 0.930  |  valid_loss: 0.787
# [epoch: 1, i:  8399]  train_loss: 0.951  |  valid_loss: 0.813
# [epoch: 1, i:  8574]  train_loss: 0.883  |  valid_loss: 0.696
# [epoch: 1, i:  8749]  train_loss: 0.836  |  valid_loss: 0.948
# [epoch: 1, i:  8924]  train_loss: 0.865  |  valid_loss: 0.870
# [epoch: 1, i:  9099]  train_loss: 0.930  |  valid_loss: 0.882
# [epoch: 1, i:  9274]  train_loss: 0.831  |  valid_loss: 0.752
# [epoch: 1, i:  9449]  train_loss: 0.866  |  valid_loss: 0.869
# [epoch: 1, i:  9624]  train_loss: 0.793  |  valid_loss: 0.907
# [epoch: 1, i:  9799]  train_loss: 0.897  |  valid_loss: 1.027
# [epoch: 1, i:  9974]  train_loss: 0.863  |  valid_loss: 0.938
# [epoch: 1, i: 10149]  train_loss: 0.886  |  valid_loss: 0.627
# [epoch: 1, i: 10324]  train_loss: 0.868  |  valid_loss: 0.998
# [epoch: 1, i: 10499]  train_loss: 0.821  |  valid_loss: 0.812
# [epoch: 1, i: 10674]  train_loss: 0.926  |  valid_loss: 0.917
# [epoch: 1, i: 10849]  train_loss: 0.853  |  valid_loss: 0.845
# [epoch: 1, i: 11024]  train_loss: 0.939  |  valid_loss: 0.782
# [epoch: 1, i: 11199]  train_loss: 0.848  |  valid_loss: 0.735
# [epoch: 1, i: 11374]  train_loss: 0.840  |  valid_loss: 0.823
# [epoch: 1, i: 11549]  train_loss: 0.857  |  valid_loss: 0.868
# [epoch: 1, i: 11724]  train_loss: 0.826  |  valid_loss: 0.828
# [epoch: 1, i: 11899]  train_loss: 0.857  |  valid_loss: 0.811
# [epoch: 1, i: 12074]  train_loss: 0.874  |  valid_loss: 0.929
# [epoch: 1, i: 12249]  train_loss: 0.886  |  valid_loss: 0.926
# [epoch: 1, i: 12424]  train_loss: 0.862  |  valid_loss: 0.875
# [epoch: 1, i: 12599]  train_loss: 0.799  |  valid_loss: 0.781
# [epoch: 1, i: 12774]  train_loss: 0.831  |  valid_loss: 0.811
# [epoch: 1, i: 12949]  train_loss: 0.827  |  valid_loss: 0.664
# [epoch: 1, i: 13124]  train_loss: 0.809  |  valid_loss: 0.850
# [epoch: 1, i: 13299]  train_loss: 0.907  |  valid_loss: 0.683
# [epoch: 1, i: 13474]  train_loss: 0.859  |  valid_loss: 0.911
# [epoch: 1, i: 13649]  train_loss: 0.870  |  valid_loss: 0.785
# [epoch: 1, i: 13824]  train_loss: 0.851  |  valid_loss: 1.016
# [epoch: 1, i: 13999]  train_loss: 0.760  |  valid_loss: 0.858
# [epoch: 1, i: 14174]  train_loss: 0.803  |  valid_loss: 0.717
# [epoch: 1, i: 14349]  train_loss: 0.838  |  valid_loss: 0.905
# [epoch: 1, i: 14524]  train_loss: 0.843  |  valid_loss: 0.799
# [epoch: 1, i: 14699]  train_loss: 0.847  |  valid_loss: 0.812
# [epoch: 1, i: 14874]  train_loss: 0.822  |  valid_loss: 0.952
# [epoch: 1, i: 15049]  train_loss: 0.823  |  valid_loss: 0.765
# [epoch: 1, i: 15224]  train_loss: 0.864  |  valid_loss: 0.948
# [epoch: 1, i: 15399]  train_loss: 0.793  |  valid_loss: 0.806
# [epoch: 1, i: 15574]  train_loss: 0.750  |  valid_loss: 0.774
# [epoch: 1, i: 15749]  train_loss: 0.814  |  valid_loss: 0.843
# [epoch: 1, i: 15924]  train_loss: 0.883  |  valid_loss: 0.742
# [epoch: 1, i: 16099]  train_loss: 0.800  |  valid_loss: 0.562
# [epoch: 1, i: 16274]  train_loss: 0.823  |  valid_loss: 0.694
# [epoch: 1, i: 16449]  train_loss: 0.786  |  valid_loss: 0.849
# [epoch: 1, i: 16624]  train_loss: 0.783  |  valid_loss: 0.789
# [epoch: 1, i: 16799]  train_loss: 0.831  |  valid_loss: 0.697
# [epoch: 1, i: 16974]  train_loss: 0.852  |  valid_loss: 0.797
# [epoch: 1, i: 17149]  train_loss: 0.804  |  valid_loss: 0.926
# [epoch: 1, i: 17324]  train_loss: 0.799  |  valid_loss: 0.949
# [epoch: 1, i: 17499]  train_loss: 0.811  |  valid_loss: 0.850
# --> [End of epoch 1] train_accuracy: 68.46%  |  valid_accuracy: 69.27%
# --> [Start of epoch 2]  lr: 0.000500
# [epoch: 2, i:   174]  train_loss: 0.761  |  valid_loss: 0.795
# [epoch: 2, i:   349]  train_loss: 0.782  |  valid_loss: 0.664
# [epoch: 2, i:   524]  train_loss: 0.785  |  valid_loss: 0.809
# [epoch: 2, i:   699]  train_loss: 0.789  |  valid_loss: 0.737
# [epoch: 2, i:   874]  train_loss: 0.759  |  valid_loss: 0.801
# [epoch: 2, i:  1049]  train_loss: 0.804  |  valid_loss: 0.563
# [epoch: 2, i:  1224]  train_loss: 0.729  |  valid_loss: 0.667
# [epoch: 2, i:  1399]  train_loss: 0.815  |  valid_loss: 0.929
# [epoch: 2, i:  1574]  train_loss: 0.799  |  valid_loss: 0.896
# [epoch: 2, i:  1749]  train_loss: 0.742  |  valid_loss: 0.744
# [epoch: 2, i:  1924]  train_loss: 0.716  |  valid_loss: 0.638
# [epoch: 2, i:  2099]  train_loss: 0.742  |  valid_loss: 0.812
# [epoch: 2, i:  2274]  train_loss: 0.754  |  valid_loss: 0.603
# [epoch: 2, i:  2449]  train_loss: 0.725  |  valid_loss: 0.708
# [epoch: 2, i:  2624]  train_loss: 0.745  |  valid_loss: 0.642
# [epoch: 2, i:  2799]  train_loss: 0.795  |  valid_loss: 0.926
# [epoch: 2, i:  2974]  train_loss: 0.749  |  valid_loss: 0.608
# [epoch: 2, i:  3149]  train_loss: 0.847  |  valid_loss: 0.755
# [epoch: 2, i:  3324]  train_loss: 0.765  |  valid_loss: 0.708
# [epoch: 2, i:  3499]  train_loss: 0.780  |  valid_loss: 0.968
# [epoch: 2, i:  3674]  train_loss: 0.715  |  valid_loss: 0.796
# [epoch: 2, i:  3849]  train_loss: 0.837  |  valid_loss: 0.806
# [epoch: 2, i:  4024]  train_loss: 0.730  |  valid_loss: 0.900
# [epoch: 2, i:  4199]  train_loss: 0.710  |  valid_loss: 0.794
# [epoch: 2, i:  4374]  train_loss: 0.811  |  valid_loss: 0.752
# [epoch: 2, i:  4549]  train_loss: 0.720  |  valid_loss: 0.941
# [epoch: 2, i:  4724]  train_loss: 0.714  |  valid_loss: 0.765
# [epoch: 2, i:  4899]  train_loss: 0.701  |  valid_loss: 0.944
# [epoch: 2, i:  5074]  train_loss: 0.800  |  valid_loss: 0.747
# [epoch: 2, i:  5249]  train_loss: 0.715  |  valid_loss: 0.654
# [epoch: 2, i:  5424]  train_loss: 0.682  |  valid_loss: 0.736
# [epoch: 2, i:  5599]  train_loss: 0.799  |  valid_loss: 0.806
# [epoch: 2, i:  5774]  train_loss: 0.695  |  valid_loss: 0.629
# [epoch: 2, i:  5949]  train_loss: 0.740  |  valid_loss: 0.866
# [epoch: 2, i:  6124]  train_loss: 0.784  |  valid_loss: 1.089
# [epoch: 2, i:  6299]  train_loss: 0.722  |  valid_loss: 0.788
# [epoch: 2, i:  6474]  train_loss: 0.764  |  valid_loss: 1.007
# [epoch: 2, i:  6649]  train_loss: 0.813  |  valid_loss: 0.839
# [epoch: 2, i:  6824]  train_loss: 0.677  |  valid_loss: 0.582
# [epoch: 2, i:  6999]  train_loss: 0.759  |  valid_loss: 0.758
# [epoch: 2, i:  7174]  train_loss: 0.758  |  valid_loss: 0.692
# [epoch: 2, i:  7349]  train_loss: 0.699  |  valid_loss: 0.769
# [epoch: 2, i:  7524]  train_loss: 0.693  |  valid_loss: 0.543
# [epoch: 2, i:  7699]  train_loss: 0.711  |  valid_loss: 0.851
# [epoch: 2, i:  7874]  train_loss: 0.796  |  valid_loss: 0.652
# [epoch: 2, i:  8049]  train_loss: 0.692  |  valid_loss: 0.694
# [epoch: 2, i:  8224]  train_loss: 0.733  |  valid_loss: 0.651
# [epoch: 2, i:  8399]  train_loss: 0.754  |  valid_loss: 0.686
# [epoch: 2, i:  8574]  train_loss: 0.685  |  valid_loss: 0.649
# [epoch: 2, i:  8749]  train_loss: 0.715  |  valid_loss: 0.780
# [epoch: 2, i:  8924]  train_loss: 0.668  |  valid_loss: 0.677
# [epoch: 2, i:  9099]  train_loss: 0.713  |  valid_loss: 0.804
# [epoch: 2, i:  9274]  train_loss: 0.759  |  valid_loss: 0.587
# [epoch: 2, i:  9449]  train_loss: 0.734  |  valid_loss: 0.696
# [epoch: 2, i:  9624]  train_loss: 0.759  |  valid_loss: 0.689
# [epoch: 2, i:  9799]  train_loss: 0.768  |  valid_loss: 0.915
# [epoch: 2, i:  9974]  train_loss: 0.691  |  valid_loss: 0.825
# [epoch: 2, i: 10149]  train_loss: 0.742  |  valid_loss: 0.552
# [epoch: 2, i: 10324]  train_loss: 0.684  |  valid_loss: 0.897
# [epoch: 2, i: 10499]  train_loss: 0.691  |  valid_loss: 0.755
# [epoch: 2, i: 10674]  train_loss: 0.799  |  valid_loss: 0.777
# [epoch: 2, i: 10849]  train_loss: 0.706  |  valid_loss: 0.665
# [epoch: 2, i: 11024]  train_loss: 0.738  |  valid_loss: 0.769
# [epoch: 2, i: 11199]  train_loss: 0.694  |  valid_loss: 0.622
# [epoch: 2, i: 11374]  train_loss: 0.749  |  valid_loss: 0.815
# [epoch: 2, i: 11549]  train_loss: 0.726  |  valid_loss: 0.750
# [epoch: 2, i: 11724]  train_loss: 0.705  |  valid_loss: 0.636
# [epoch: 2, i: 11899]  train_loss: 0.654  |  valid_loss: 0.723
# [epoch: 2, i: 12074]  train_loss: 0.739  |  valid_loss: 0.754
# [epoch: 2, i: 12249]  train_loss: 0.762  |  valid_loss: 0.887
# [epoch: 2, i: 12424]  train_loss: 0.726  |  valid_loss: 0.594
# [epoch: 2, i: 12599]  train_loss: 0.662  |  valid_loss: 0.683
# [epoch: 2, i: 12774]  train_loss: 0.715  |  valid_loss: 0.641
# [epoch: 2, i: 12949]  train_loss: 0.705  |  valid_loss: 0.648
# [epoch: 2, i: 13124]  train_loss: 0.693  |  valid_loss: 0.841
# [epoch: 2, i: 13299]  train_loss: 0.654  |  valid_loss: 0.671
# [epoch: 2, i: 13474]  train_loss: 0.660  |  valid_loss: 0.886
# [epoch: 2, i: 13649]  train_loss: 0.721  |  valid_loss: 0.657
# [epoch: 2, i: 13824]  train_loss: 0.701  |  valid_loss: 0.804
# [epoch: 2, i: 13999]  train_loss: 0.707  |  valid_loss: 0.792
# [epoch: 2, i: 14174]  train_loss: 0.723  |  valid_loss: 0.547
# [epoch: 2, i: 14349]  train_loss: 0.664  |  valid_loss: 0.675
# [epoch: 2, i: 14524]  train_loss: 0.761  |  valid_loss: 0.752
# [epoch: 2, i: 14699]  train_loss: 0.757  |  valid_loss: 0.668
# [epoch: 2, i: 14874]  train_loss: 0.668  |  valid_loss: 0.814
# [epoch: 2, i: 15049]  train_loss: 0.605  |  valid_loss: 0.720
# [epoch: 2, i: 15224]  train_loss: 0.718  |  valid_loss: 0.714
# [epoch: 2, i: 15399]  train_loss: 0.752  |  valid_loss: 0.741
# [epoch: 2, i: 15574]  train_loss: 0.755  |  valid_loss: 0.663
# [epoch: 2, i: 15749]  train_loss: 0.644  |  valid_loss: 0.720
# [epoch: 2, i: 15924]  train_loss: 0.731  |  valid_loss: 0.662
# [epoch: 2, i: 16099]  train_loss: 0.692  |  valid_loss: 0.564
# [epoch: 2, i: 16274]  train_loss: 0.644  |  valid_loss: 0.628
# [epoch: 2, i: 16449]  train_loss: 0.730  |  valid_loss: 0.714
# [epoch: 2, i: 16624]  train_loss: 0.657  |  valid_loss: 0.822
# [epoch: 2, i: 16799]  train_loss: 0.700  |  valid_loss: 0.670
# [epoch: 2, i: 16974]  train_loss: 0.635  |  valid_loss: 0.592
# [epoch: 2, i: 17149]  train_loss: 0.679  |  valid_loss: 0.936
# [epoch: 2, i: 17324]  train_loss: 0.713  |  valid_loss: 0.718
# [epoch: 2, i: 17499]  train_loss: 0.724  |  valid_loss: 0.810
# --> [End of epoch 2] train_accuracy: 74.41%  |  valid_accuracy: 73.87%
# --> [Start of epoch 3]  lr: 0.000500
# [epoch: 3, i:   174]  train_loss: 0.657  |  valid_loss: 0.643
# [epoch: 3, i:   349]  train_loss: 0.684  |  valid_loss: 0.550
# [epoch: 3, i:   524]  train_loss: 0.716  |  valid_loss: 0.801
# [epoch: 3, i:   699]  train_loss: 0.665  |  valid_loss: 0.632
# [epoch: 3, i:   874]  train_loss: 0.653  |  valid_loss: 0.772
# [epoch: 3, i:  1049]  train_loss: 0.595  |  valid_loss: 0.510
# [epoch: 3, i:  1224]  train_loss: 0.595  |  valid_loss: 0.615
# [epoch: 3, i:  1399]  train_loss: 0.656  |  valid_loss: 0.832
# [epoch: 3, i:  1574]  train_loss: 0.668  |  valid_loss: 1.009
# [epoch: 3, i:  1749]  train_loss: 0.706  |  valid_loss: 0.583
# [epoch: 3, i:  1924]  train_loss: 0.616  |  valid_loss: 0.633
# [epoch: 3, i:  2099]  train_loss: 0.578  |  valid_loss: 0.754
# [epoch: 3, i:  2274]  train_loss: 0.658  |  valid_loss: 0.620
# [epoch: 3, i:  2449]  train_loss: 0.640  |  valid_loss: 0.682
# [epoch: 3, i:  2624]  train_loss: 0.718  |  valid_loss: 0.534
# [epoch: 3, i:  2799]  train_loss: 0.578  |  valid_loss: 0.769
# [epoch: 3, i:  2974]  train_loss: 0.635  |  valid_loss: 0.592
# [epoch: 3, i:  3149]  train_loss: 0.618  |  valid_loss: 0.723
# [epoch: 3, i:  3324]  train_loss: 0.667  |  valid_loss: 0.807
# [epoch: 3, i:  3499]  train_loss: 0.689  |  valid_loss: 0.820
# [epoch: 3, i:  3674]  train_loss: 0.722  |  valid_loss: 0.672
# [epoch: 3, i:  3849]  train_loss: 0.685  |  valid_loss: 0.799
# [epoch: 3, i:  4024]  train_loss: 0.683  |  valid_loss: 0.775
# [epoch: 3, i:  4199]  train_loss: 0.642  |  valid_loss: 0.733
# [epoch: 3, i:  4374]  train_loss: 0.648  |  valid_loss: 0.707
# [epoch: 3, i:  4549]  train_loss: 0.640  |  valid_loss: 0.963
# [epoch: 3, i:  4724]  train_loss: 0.642  |  valid_loss: 0.562
# [epoch: 3, i:  4899]  train_loss: 0.669  |  valid_loss: 0.621
# [epoch: 3, i:  5074]  train_loss: 0.663  |  valid_loss: 0.670
# [epoch: 3, i:  5249]  train_loss: 0.638  |  valid_loss: 0.631
# [epoch: 3, i:  5424]  train_loss: 0.690  |  valid_loss: 0.751
# [epoch: 3, i:  5599]  train_loss: 0.614  |  valid_loss: 0.659
# [epoch: 3, i:  5774]  train_loss: 0.628  |  valid_loss: 0.606
# [epoch: 3, i:  5949]  train_loss: 0.755  |  valid_loss: 0.759
# [epoch: 3, i:  6124]  train_loss: 0.638  |  valid_loss: 1.064
# [epoch: 3, i:  6299]  train_loss: 0.612  |  valid_loss: 0.790
# [epoch: 3, i:  6474]  train_loss: 0.680  |  valid_loss: 0.875
# [epoch: 3, i:  6649]  train_loss: 0.705  |  valid_loss: 0.768
# [epoch: 3, i:  6824]  train_loss: 0.613  |  valid_loss: 0.544
# [epoch: 3, i:  6999]  train_loss: 0.660  |  valid_loss: 0.598
# [epoch: 3, i:  7174]  train_loss: 0.617  |  valid_loss: 0.680
# [epoch: 3, i:  7349]  train_loss: 0.636  |  valid_loss: 0.667
# [epoch: 3, i:  7524]  train_loss: 0.697  |  valid_loss: 0.548
# [epoch: 3, i:  7699]  train_loss: 0.553  |  valid_loss: 0.689
# [epoch: 3, i:  7874]  train_loss: 0.604  |  valid_loss: 0.695
# [epoch: 3, i:  8049]  train_loss: 0.647  |  valid_loss: 0.577
# [epoch: 3, i:  8224]  train_loss: 0.565  |  valid_loss: 0.716
# [epoch: 3, i:  8399]  train_loss: 0.656  |  valid_loss: 0.758
# [epoch: 3, i:  8574]  train_loss: 0.586  |  valid_loss: 0.681
# [epoch: 3, i:  8749]  train_loss: 0.625  |  valid_loss: 0.841
# [epoch: 3, i:  8924]  train_loss: 0.600  |  valid_loss: 0.520
# [epoch: 3, i:  9099]  train_loss: 0.681  |  valid_loss: 0.704
# [epoch: 3, i:  9274]  train_loss: 0.605  |  valid_loss: 0.639
# [epoch: 3, i:  9449]  train_loss: 0.644  |  valid_loss: 0.590
# [epoch: 3, i:  9624]  train_loss: 0.585  |  valid_loss: 0.711
# [epoch: 3, i:  9799]  train_loss: 0.636  |  valid_loss: 0.815
# [epoch: 3, i:  9974]  train_loss: 0.628  |  valid_loss: 0.658
# [epoch: 3, i: 10149]  train_loss: 0.635  |  valid_loss: 0.561
# [epoch: 3, i: 10324]  train_loss: 0.614  |  valid_loss: 0.735
# [epoch: 3, i: 10499]  train_loss: 0.647  |  valid_loss: 0.774
# [epoch: 3, i: 10674]  train_loss: 0.543  |  valid_loss: 0.682
# [epoch: 3, i: 10849]  train_loss: 0.634  |  valid_loss: 0.654
# [epoch: 3, i: 11024]  train_loss: 0.602  |  valid_loss: 0.619
# [epoch: 3, i: 11199]  train_loss: 0.655  |  valid_loss: 0.636
# [epoch: 3, i: 11374]  train_loss: 0.658  |  valid_loss: 0.849
# [epoch: 3, i: 11549]  train_loss: 0.626  |  valid_loss: 0.657
# [epoch: 3, i: 11724]  train_loss: 0.565  |  valid_loss: 0.517
# [epoch: 3, i: 11899]  train_loss: 0.649  |  valid_loss: 0.787
# [epoch: 3, i: 12074]  train_loss: 0.616  |  valid_loss: 0.703
# [epoch: 3, i: 12249]  train_loss: 0.585  |  valid_loss: 0.771
# [epoch: 3, i: 12424]  train_loss: 0.641  |  valid_loss: 0.682
# [epoch: 3, i: 12599]  train_loss: 0.636  |  valid_loss: 0.647
# [epoch: 3, i: 12774]  train_loss: 0.627  |  valid_loss: 0.587
# [epoch: 3, i: 12949]  train_loss: 0.653  |  valid_loss: 0.496
# [epoch: 3, i: 13124]  train_loss: 0.592  |  valid_loss: 0.785
# [epoch: 3, i: 13299]  train_loss: 0.650  |  valid_loss: 0.557
# [epoch: 3, i: 13474]  train_loss: 0.697  |  valid_loss: 0.787
# [epoch: 3, i: 13649]  train_loss: 0.618  |  valid_loss: 0.624
# [epoch: 3, i: 13824]  train_loss: 0.684  |  valid_loss: 0.830
# [epoch: 3, i: 13999]  train_loss: 0.636  |  valid_loss: 0.585
# [epoch: 3, i: 14174]  train_loss: 0.665  |  valid_loss: 0.585
# [epoch: 3, i: 14349]  train_loss: 0.620  |  valid_loss: 0.539
# [epoch: 3, i: 14524]  train_loss: 0.568  |  valid_loss: 0.605
# [epoch: 3, i: 14699]  train_loss: 0.637  |  valid_loss: 0.615
# [epoch: 3, i: 14874]  train_loss: 0.558  |  valid_loss: 0.810
# [epoch: 3, i: 15049]  train_loss: 0.607  |  valid_loss: 0.671
# [epoch: 3, i: 15224]  train_loss: 0.641  |  valid_loss: 0.643
# [epoch: 3, i: 15399]  train_loss: 0.593  |  valid_loss: 0.693
# [epoch: 3, i: 15574]  train_loss: 0.637  |  valid_loss: 0.755
# [epoch: 3, i: 15749]  train_loss: 0.595  |  valid_loss: 0.694
# [epoch: 3, i: 15924]  train_loss: 0.602  |  valid_loss: 0.500
# [epoch: 3, i: 16099]  train_loss: 0.669  |  valid_loss: 0.505
# [epoch: 3, i: 16274]  train_loss: 0.654  |  valid_loss: 0.743
# [epoch: 3, i: 16449]  train_loss: 0.605  |  valid_loss: 0.648
# [epoch: 3, i: 16624]  train_loss: 0.616  |  valid_loss: 0.610
# [epoch: 3, i: 16799]  train_loss: 0.644  |  valid_loss: 0.614
# [epoch: 3, i: 16974]  train_loss: 0.652  |  valid_loss: 0.564
# [epoch: 3, i: 17149]  train_loss: 0.632  |  valid_loss: 0.799
# [epoch: 3, i: 17324]  train_loss: 0.595  |  valid_loss: 0.803
# [epoch: 3, i: 17499]  train_loss: 0.625  |  valid_loss: 0.681
# --> [End of epoch 3] train_accuracy: 77.69%  |  valid_accuracy: 76.47%
# --> [Start of epoch 4]  lr: 0.000500
# [epoch: 4, i:   174]  train_loss: 0.592  |  valid_loss: 0.640
# [epoch: 4, i:   349]  train_loss: 0.610  |  valid_loss: 0.575
# [epoch: 4, i:   524]  train_loss: 0.589  |  valid_loss: 0.678
# [epoch: 4, i:   699]  train_loss: 0.597  |  valid_loss: 0.559
# [epoch: 4, i:   874]  train_loss: 0.590  |  valid_loss: 0.648
# [epoch: 4, i:  1049]  train_loss: 0.558  |  valid_loss: 0.464
# [epoch: 4, i:  1224]  train_loss: 0.540  |  valid_loss: 0.561
# [epoch: 4, i:  1399]  train_loss: 0.576  |  valid_loss: 0.809
# [epoch: 4, i:  1574]  train_loss: 0.579  |  valid_loss: 0.896
# [epoch: 4, i:  1749]  train_loss: 0.559  |  valid_loss: 0.626
# [epoch: 4, i:  1924]  train_loss: 0.594  |  valid_loss: 0.501
# [epoch: 4, i:  2099]  train_loss: 0.575  |  valid_loss: 0.621
# [epoch: 4, i:  2274]  train_loss: 0.598  |  valid_loss: 0.611
# [epoch: 4, i:  2449]  train_loss: 0.530  |  valid_loss: 0.518
# [epoch: 4, i:  2624]  train_loss: 0.654  |  valid_loss: 0.475
# [epoch: 4, i:  2799]  train_loss: 0.552  |  valid_loss: 0.694
# [epoch: 4, i:  2974]  train_loss: 0.575  |  valid_loss: 0.568
# [epoch: 4, i:  3149]  train_loss: 0.554  |  valid_loss: 0.689
# [epoch: 4, i:  3324]  train_loss: 0.527  |  valid_loss: 0.750
# [epoch: 4, i:  3499]  train_loss: 0.582  |  valid_loss: 0.785
# [epoch: 4, i:  3674]  train_loss: 0.651  |  valid_loss: 0.699
# [epoch: 4, i:  3849]  train_loss: 0.614  |  valid_loss: 0.570
# [epoch: 4, i:  4024]  train_loss: 0.544  |  valid_loss: 0.835
# [epoch: 4, i:  4199]  train_loss: 0.572  |  valid_loss: 0.667
# [epoch: 4, i:  4374]  train_loss: 0.604  |  valid_loss: 0.830
# [epoch: 4, i:  4549]  train_loss: 0.628  |  valid_loss: 0.883
# [epoch: 4, i:  4724]  train_loss: 0.590  |  valid_loss: 0.510
# [epoch: 4, i:  4899]  train_loss: 0.585  |  valid_loss: 0.690
# [epoch: 4, i:  5074]  train_loss: 0.525  |  valid_loss: 0.646
# [epoch: 4, i:  5249]  train_loss: 0.570  |  valid_loss: 0.574
# [epoch: 4, i:  5424]  train_loss: 0.581  |  valid_loss: 0.640
# [epoch: 4, i:  5599]  train_loss: 0.546  |  valid_loss: 0.629
# [epoch: 4, i:  5774]  train_loss: 0.583  |  valid_loss: 0.555
# [epoch: 4, i:  5949]  train_loss: 0.587  |  valid_loss: 0.848
# [epoch: 4, i:  6124]  train_loss: 0.617  |  valid_loss: 0.797
# [epoch: 4, i:  6299]  train_loss: 0.540  |  valid_loss: 0.665
# [epoch: 4, i:  6474]  train_loss: 0.593  |  valid_loss: 0.763
# [epoch: 4, i:  6649]  train_loss: 0.609  |  valid_loss: 0.678
# [epoch: 4, i:  6824]  train_loss: 0.586  |  valid_loss: 0.514
# [epoch: 4, i:  6999]  train_loss: 0.561  |  valid_loss: 0.538
# [epoch: 4, i:  7174]  train_loss: 0.551  |  valid_loss: 0.525
# [epoch: 4, i:  7349]  train_loss: 0.568  |  valid_loss: 0.676
# [epoch: 4, i:  7524]  train_loss: 0.600  |  valid_loss: 0.516
# [epoch: 4, i:  7699]  train_loss: 0.570  |  valid_loss: 0.708
# [epoch: 4, i:  7874]  train_loss: 0.604  |  valid_loss: 0.675
# [epoch: 4, i:  8049]  train_loss: 0.560  |  valid_loss: 0.619
# [epoch: 4, i:  8224]  train_loss: 0.619  |  valid_loss: 0.667
# [epoch: 4, i:  8399]  train_loss: 0.596  |  valid_loss: 0.730
# [epoch: 4, i:  8574]  train_loss: 0.664  |  valid_loss: 0.644
# [epoch: 4, i:  8749]  train_loss: 0.600  |  valid_loss: 0.838
# [epoch: 4, i:  8924]  train_loss: 0.581  |  valid_loss: 0.517
# [epoch: 4, i:  9099]  train_loss: 0.567  |  valid_loss: 0.748
# [epoch: 4, i:  9274]  train_loss: 0.569  |  valid_loss: 0.584
# [epoch: 4, i:  9449]  train_loss: 0.544  |  valid_loss: 0.572
# [epoch: 4, i:  9624]  train_loss: 0.538  |  valid_loss: 0.619
# [epoch: 4, i:  9799]  train_loss: 0.624  |  valid_loss: 0.820
# [epoch: 4, i:  9974]  train_loss: 0.571  |  valid_loss: 0.748
# [epoch: 4, i: 10149]  train_loss: 0.579  |  valid_loss: 0.590
# [epoch: 4, i: 10324]  train_loss: 0.517  |  valid_loss: 0.760
# [epoch: 4, i: 10499]  train_loss: 0.626  |  valid_loss: 0.738
# [epoch: 4, i: 10674]  train_loss: 0.562  |  valid_loss: 0.666
# [epoch: 4, i: 10849]  train_loss: 0.597  |  valid_loss: 0.678
# [epoch: 4, i: 11024]  train_loss: 0.564  |  valid_loss: 0.568
# [epoch: 4, i: 11199]  train_loss: 0.593  |  valid_loss: 0.500
# [epoch: 4, i: 11374]  train_loss: 0.632  |  valid_loss: 0.647
# [epoch: 4, i: 11549]  train_loss: 0.561  |  valid_loss: 0.696
# [epoch: 4, i: 11724]  train_loss: 0.609  |  valid_loss: 0.602
# [epoch: 4, i: 11899]  train_loss: 0.606  |  valid_loss: 0.661
# [epoch: 4, i: 12074]  train_loss: 0.522  |  valid_loss: 0.730
# [epoch: 4, i: 12249]  train_loss: 0.654  |  valid_loss: 0.712
# [epoch: 4, i: 12424]  train_loss: 0.552  |  valid_loss: 0.723
# [epoch: 4, i: 12599]  train_loss: 0.559  |  valid_loss: 0.601
# [epoch: 4, i: 12774]  train_loss: 0.609  |  valid_loss: 0.461
# [epoch: 4, i: 12949]  train_loss: 0.582  |  valid_loss: 0.503
# [epoch: 4, i: 13124]  train_loss: 0.641  |  valid_loss: 0.899
# [epoch: 4, i: 13299]  train_loss: 0.547  |  valid_loss: 0.562
# [epoch: 4, i: 13474]  train_loss: 0.572  |  valid_loss: 0.857
# [epoch: 4, i: 13649]  train_loss: 0.573  |  valid_loss: 0.647
# [epoch: 4, i: 13824]  train_loss: 0.523  |  valid_loss: 0.668
# [epoch: 4, i: 13999]  train_loss: 0.590  |  valid_loss: 0.643
# [epoch: 4, i: 14174]  train_loss: 0.624  |  valid_loss: 0.546
# [epoch: 4, i: 14349]  train_loss: 0.601  |  valid_loss: 0.584
# [epoch: 4, i: 14524]  train_loss: 0.572  |  valid_loss: 0.519
# [epoch: 4, i: 14699]  train_loss: 0.536  |  valid_loss: 0.618
# [epoch: 4, i: 14874]  train_loss: 0.545  |  valid_loss: 0.657
# [epoch: 4, i: 15049]  train_loss: 0.544  |  valid_loss: 0.721
# [epoch: 4, i: 15224]  train_loss: 0.568  |  valid_loss: 0.734
# [epoch: 4, i: 15399]  train_loss: 0.609  |  valid_loss: 0.642
# [epoch: 4, i: 15574]  train_loss: 0.582  |  valid_loss: 0.536
# [epoch: 4, i: 15749]  train_loss: 0.574  |  valid_loss: 0.702
# [epoch: 4, i: 15924]  train_loss: 0.562  |  valid_loss: 0.524
# [epoch: 4, i: 16099]  train_loss: 0.622  |  valid_loss: 0.439
# [epoch: 4, i: 16274]  train_loss: 0.559  |  valid_loss: 0.626
# [epoch: 4, i: 16449]  train_loss: 0.538  |  valid_loss: 0.772
# [epoch: 4, i: 16624]  train_loss: 0.627  |  valid_loss: 0.590
# [epoch: 4, i: 16799]  train_loss: 0.590  |  valid_loss: 0.528
# [epoch: 4, i: 16974]  train_loss: 0.506  |  valid_loss: 0.509
# [epoch: 4, i: 17149]  train_loss: 0.562  |  valid_loss: 0.686
# [epoch: 4, i: 17324]  train_loss: 0.582  |  valid_loss: 0.793
# [epoch: 4, i: 17499]  train_loss: 0.633  |  valid_loss: 0.682
# --> [End of epoch 4] train_accuracy: 79.65%  |  valid_accuracy: 77.28%
# --> [Start of epoch 5]  lr: 0.000500
# [epoch: 5, i:   174]  train_loss: 0.458  |  valid_loss: 0.583
# [epoch: 5, i:   349]  train_loss: 0.519  |  valid_loss: 0.529
# [epoch: 5, i:   524]  train_loss: 0.582  |  valid_loss: 0.640
# [epoch: 5, i:   699]  train_loss: 0.518  |  valid_loss: 0.525
# [epoch: 5, i:   874]  train_loss: 0.554  |  valid_loss: 0.580
# [epoch: 5, i:  1049]  train_loss: 0.482  |  valid_loss: 0.496
# [epoch: 5, i:  1224]  train_loss: 0.559  |  valid_loss: 0.547
# [epoch: 5, i:  1399]  train_loss: 0.560  |  valid_loss: 0.848
# [epoch: 5, i:  1574]  train_loss: 0.558  |  valid_loss: 0.874
# [epoch: 5, i:  1749]  train_loss: 0.570  |  valid_loss: 0.569
# [epoch: 5, i:  1924]  train_loss: 0.553  |  valid_loss: 0.564
# [epoch: 5, i:  2099]  train_loss: 0.519  |  valid_loss: 0.558
# [epoch: 5, i:  2274]  train_loss: 0.552  |  valid_loss: 0.475
# [epoch: 5, i:  2449]  train_loss: 0.525  |  valid_loss: 0.603
# [epoch: 5, i:  2624]  train_loss: 0.502  |  valid_loss: 0.424
# [epoch: 5, i:  2799]  train_loss: 0.540  |  valid_loss: 0.621
# [epoch: 5, i:  2974]  train_loss: 0.524  |  valid_loss: 0.481
# [epoch: 5, i:  3149]  train_loss: 0.553  |  valid_loss: 0.618
# [epoch: 5, i:  3324]  train_loss: 0.507  |  valid_loss: 0.650
# [epoch: 5, i:  3499]  train_loss: 0.627  |  valid_loss: 0.782
# [epoch: 5, i:  3674]  train_loss: 0.537  |  valid_loss: 0.617
# [epoch: 5, i:  3849]  train_loss: 0.532  |  valid_loss: 0.556
# [epoch: 5, i:  4024]  train_loss: 0.560  |  valid_loss: 0.675
# [epoch: 5, i:  4199]  train_loss: 0.472  |  valid_loss: 0.672
# [epoch: 5, i:  4374]  train_loss: 0.518  |  valid_loss: 0.782
# [epoch: 5, i:  4549]  train_loss: 0.515  |  valid_loss: 0.785
# [epoch: 5, i:  4724]  train_loss: 0.537  |  valid_loss: 0.398
# [epoch: 5, i:  4899]  train_loss: 0.532  |  valid_loss: 0.599
# [epoch: 5, i:  5074]  train_loss: 0.561  |  valid_loss: 0.634
# [epoch: 5, i:  5249]  train_loss: 0.491  |  valid_loss: 0.566
# [epoch: 5, i:  5424]  train_loss: 0.543  |  valid_loss: 0.647
# [epoch: 5, i:  5599]  train_loss: 0.498  |  valid_loss: 0.578
# [epoch: 5, i:  5774]  train_loss: 0.517  |  valid_loss: 0.591
# [epoch: 5, i:  5949]  train_loss: 0.540  |  valid_loss: 0.776
# [epoch: 5, i:  6124]  train_loss: 0.577  |  valid_loss: 0.930
# [epoch: 5, i:  6299]  train_loss: 0.557  |  valid_loss: 0.693
# [epoch: 5, i:  6474]  train_loss: 0.473  |  valid_loss: 0.788
# [epoch: 5, i:  6649]  train_loss: 0.515  |  valid_loss: 0.605
# [epoch: 5, i:  6824]  train_loss: 0.482  |  valid_loss: 0.477
# [epoch: 5, i:  6999]  train_loss: 0.554  |  valid_loss: 0.480
# [epoch: 5, i:  7174]  train_loss: 0.513  |  valid_loss: 0.440
# [epoch: 5, i:  7349]  train_loss: 0.572  |  valid_loss: 0.699
# [epoch: 5, i:  7524]  train_loss: 0.574  |  valid_loss: 0.479
# [epoch: 5, i:  7699]  train_loss: 0.521  |  valid_loss: 0.692
# [epoch: 5, i:  7874]  train_loss: 0.541  |  valid_loss: 0.637
# [epoch: 5, i:  8049]  train_loss: 0.574  |  valid_loss: 0.635
# [epoch: 5, i:  8224]  train_loss: 0.554  |  valid_loss: 0.638
# [epoch: 5, i:  8399]  train_loss: 0.506  |  valid_loss: 0.660
# [epoch: 5, i:  8574]  train_loss: 0.521  |  valid_loss: 0.508
# [epoch: 5, i:  8749]  train_loss: 0.572  |  valid_loss: 0.870
# [epoch: 5, i:  8924]  train_loss: 0.516  |  valid_loss: 0.523
# [epoch: 5, i:  9099]  train_loss: 0.541  |  valid_loss: 0.663
# [epoch: 5, i:  9274]  train_loss: 0.519  |  valid_loss: 0.635
# [epoch: 5, i:  9449]  train_loss: 0.520  |  valid_loss: 0.570
# [epoch: 5, i:  9624]  train_loss: 0.516  |  valid_loss: 0.628
# [epoch: 5, i:  9799]  train_loss: 0.484  |  valid_loss: 0.689
# [epoch: 5, i:  9974]  train_loss: 0.530  |  valid_loss: 0.655
# [epoch: 5, i: 10149]  train_loss: 0.554  |  valid_loss: 0.470
# [epoch: 5, i: 10324]  train_loss: 0.590  |  valid_loss: 0.714
# [epoch: 5, i: 10499]  train_loss: 0.521  |  valid_loss: 0.737
# [epoch: 5, i: 10674]  train_loss: 0.583  |  valid_loss: 0.631
# [epoch: 5, i: 10849]  train_loss: 0.492  |  valid_loss: 0.645
# [epoch: 5, i: 11024]  train_loss: 0.526  |  valid_loss: 0.519
# [epoch: 5, i: 11199]  train_loss: 0.537  |  valid_loss: 0.482
# [epoch: 5, i: 11374]  train_loss: 0.543  |  valid_loss: 0.643
# [epoch: 5, i: 11549]  train_loss: 0.552  |  valid_loss: 0.586
# [epoch: 5, i: 11724]  train_loss: 0.569  |  valid_loss: 0.523
# [epoch: 5, i: 11899]  train_loss: 0.591  |  valid_loss: 0.582
# [epoch: 5, i: 12074]  train_loss: 0.537  |  valid_loss: 0.633
# [epoch: 5, i: 12249]  train_loss: 0.535  |  valid_loss: 0.753
# [epoch: 5, i: 12424]  train_loss: 0.516  |  valid_loss: 0.618
# [epoch: 5, i: 12599]  train_loss: 0.564  |  valid_loss: 0.557
# [epoch: 5, i: 12774]  train_loss: 0.612  |  valid_loss: 0.598
# [epoch: 5, i: 12949]  train_loss: 0.536  |  valid_loss: 0.544
# [epoch: 5, i: 13124]  train_loss: 0.614  |  valid_loss: 0.763
# [epoch: 5, i: 13299]  train_loss: 0.480  |  valid_loss: 0.515
# [epoch: 5, i: 13474]  train_loss: 0.531  |  valid_loss: 0.832
# [epoch: 5, i: 13649]  train_loss: 0.529  |  valid_loss: 0.613
# [epoch: 5, i: 13824]  train_loss: 0.467  |  valid_loss: 0.717
# [epoch: 5, i: 13999]  train_loss: 0.502  |  valid_loss: 0.686
# [epoch: 5, i: 14174]  train_loss: 0.528  |  valid_loss: 0.452
# [epoch: 5, i: 14349]  train_loss: 0.516  |  valid_loss: 0.553
# [epoch: 5, i: 14524]  train_loss: 0.501  |  valid_loss: 0.625
# [epoch: 5, i: 14699]  train_loss: 0.519  |  valid_loss: 0.633
# [epoch: 5, i: 14874]  train_loss: 0.514  |  valid_loss: 0.671
# [epoch: 5, i: 15049]  train_loss: 0.501  |  valid_loss: 0.633
# [epoch: 5, i: 15224]  train_loss: 0.541  |  valid_loss: 0.654
# [epoch: 5, i: 15399]  train_loss: 0.510  |  valid_loss: 0.629
# [epoch: 5, i: 15574]  train_loss: 0.557  |  valid_loss: 0.647
# [epoch: 5, i: 15749]  train_loss: 0.527  |  valid_loss: 0.799
# [epoch: 5, i: 15924]  train_loss: 0.489  |  valid_loss: 0.497
# [epoch: 5, i: 16099]  train_loss: 0.581  |  valid_loss: 0.481
# [epoch: 5, i: 16274]  train_loss: 0.559  |  valid_loss: 0.651
# [epoch: 5, i: 16449]  train_loss: 0.517  |  valid_loss: 0.694
# [epoch: 5, i: 16624]  train_loss: 0.554  |  valid_loss: 0.625
# [epoch: 5, i: 16799]  train_loss: 0.546  |  valid_loss: 0.495
# [epoch: 5, i: 16974]  train_loss: 0.549  |  valid_loss: 0.518
# [epoch: 5, i: 17149]  train_loss: 0.605  |  valid_loss: 0.727
# [epoch: 5, i: 17324]  train_loss: 0.615  |  valid_loss: 0.789
# [epoch: 5, i: 17499]  train_loss: 0.501  |  valid_loss: 0.551
# --> [End of epoch 5] train_accuracy: 81.09%  |  valid_accuracy: 78.94%
# --> [Start of epoch 6]  lr: 0.000500
# [epoch: 6, i:   174]  train_loss: 0.435  |  valid_loss: 0.551
# [epoch: 6, i:   349]  train_loss: 0.496  |  valid_loss: 0.466
# [epoch: 6, i:   524]  train_loss: 0.453  |  valid_loss: 0.539
# [epoch: 6, i:   699]  train_loss: 0.447  |  valid_loss: 0.478
# [epoch: 6, i:   874]  train_loss: 0.505  |  valid_loss: 0.516
# [epoch: 6, i:  1049]  train_loss: 0.485  |  valid_loss: 0.409
# [epoch: 6, i:  1224]  train_loss: 0.557  |  valid_loss: 0.600
# [epoch: 6, i:  1399]  train_loss: 0.512  |  valid_loss: 0.709
# [epoch: 6, i:  1574]  train_loss: 0.501  |  valid_loss: 0.668
# [epoch: 6, i:  1749]  train_loss: 0.452  |  valid_loss: 0.467
# [epoch: 6, i:  1924]  train_loss: 0.467  |  valid_loss: 0.492
# [epoch: 6, i:  2099]  train_loss: 0.447  |  valid_loss: 0.545
# [epoch: 6, i:  2274]  train_loss: 0.542  |  valid_loss: 0.426
# [epoch: 6, i:  2449]  train_loss: 0.502  |  valid_loss: 0.551
# [epoch: 6, i:  2624]  train_loss: 0.563  |  valid_loss: 0.460
# [epoch: 6, i:  2799]  train_loss: 0.455  |  valid_loss: 0.577
# [epoch: 6, i:  2974]  train_loss: 0.452  |  valid_loss: 0.459
# [epoch: 6, i:  3149]  train_loss: 0.500  |  valid_loss: 0.673
# [epoch: 6, i:  3324]  train_loss: 0.435  |  valid_loss: 0.643
# [epoch: 6, i:  3499]  train_loss: 0.564  |  valid_loss: 0.675
# [epoch: 6, i:  3674]  train_loss: 0.467  |  valid_loss: 0.664
# [epoch: 6, i:  3849]  train_loss: 0.530  |  valid_loss: 0.635
# [epoch: 6, i:  4024]  train_loss: 0.467  |  valid_loss: 0.611
# [epoch: 6, i:  4199]  train_loss: 0.471  |  valid_loss: 0.650
# [epoch: 6, i:  4374]  train_loss: 0.514  |  valid_loss: 0.815
# [epoch: 6, i:  4549]  train_loss: 0.435  |  valid_loss: 0.844
# [epoch: 6, i:  4724]  train_loss: 0.493  |  valid_loss: 0.409
# [epoch: 6, i:  4899]  train_loss: 0.558  |  valid_loss: 0.645
# [epoch: 6, i:  5074]  train_loss: 0.466  |  valid_loss: 0.529
# [epoch: 6, i:  5249]  train_loss: 0.544  |  valid_loss: 0.696
# [epoch: 6, i:  5424]  train_loss: 0.562  |  valid_loss: 0.669
# [epoch: 6, i:  5599]  train_loss: 0.519  |  valid_loss: 0.576
# [epoch: 6, i:  5774]  train_loss: 0.511  |  valid_loss: 0.539
# [epoch: 6, i:  5949]  train_loss: 0.480  |  valid_loss: 0.570
# [epoch: 6, i:  6124]  train_loss: 0.496  |  valid_loss: 0.873
# [epoch: 6, i:  6299]  train_loss: 0.513  |  valid_loss: 0.704
# [epoch: 6, i:  6474]  train_loss: 0.475  |  valid_loss: 0.833
# [epoch: 6, i:  6649]  train_loss: 0.555  |  valid_loss: 0.591
# [epoch: 6, i:  6824]  train_loss: 0.471  |  valid_loss: 0.495
# [epoch: 6, i:  6999]  train_loss: 0.467  |  valid_loss: 0.532
# [epoch: 6, i:  7174]  train_loss: 0.532  |  valid_loss: 0.494
# [epoch: 6, i:  7349]  train_loss: 0.510  |  valid_loss: 0.694
# [epoch: 6, i:  7524]  train_loss: 0.518  |  valid_loss: 0.432
# [epoch: 6, i:  7699]  train_loss: 0.559  |  valid_loss: 0.687
# [epoch: 6, i:  7874]  train_loss: 0.451  |  valid_loss: 0.608
# [epoch: 6, i:  8049]  train_loss: 0.563  |  valid_loss: 0.441
# [epoch: 6, i:  8224]  train_loss: 0.485  |  valid_loss: 0.573
# [epoch: 6, i:  8399]  train_loss: 0.534  |  valid_loss: 0.654
# [epoch: 6, i:  8574]  train_loss: 0.462  |  valid_loss: 0.453
# [epoch: 6, i:  8749]  train_loss: 0.515  |  valid_loss: 0.693
# [epoch: 6, i:  8924]  train_loss: 0.461  |  valid_loss: 0.449
# [epoch: 6, i:  9099]  train_loss: 0.501  |  valid_loss: 0.659
# [epoch: 6, i:  9274]  train_loss: 0.585  |  valid_loss: 0.527
# [epoch: 6, i:  9449]  train_loss: 0.490  |  valid_loss: 0.585
# [epoch: 6, i:  9624]  train_loss: 0.485  |  valid_loss: 0.614
# [epoch: 6, i:  9799]  train_loss: 0.537  |  valid_loss: 0.699
# [epoch: 6, i:  9974]  train_loss: 0.540  |  valid_loss: 0.733
# [epoch: 6, i: 10149]  train_loss: 0.509  |  valid_loss: 0.370
# [epoch: 6, i: 10324]  train_loss: 0.455  |  valid_loss: 0.700
# [epoch: 6, i: 10499]  train_loss: 0.502  |  valid_loss: 0.818
# [epoch: 6, i: 10674]  train_loss: 0.536  |  valid_loss: 0.585
# [epoch: 6, i: 10849]  train_loss: 0.578  |  valid_loss: 0.640
# [epoch: 6, i: 11024]  train_loss: 0.502  |  valid_loss: 0.541
# [epoch: 6, i: 11199]  train_loss: 0.493  |  valid_loss: 0.424
# [epoch: 6, i: 11374]  train_loss: 0.463  |  valid_loss: 0.596
# [epoch: 6, i: 11549]  train_loss: 0.542  |  valid_loss: 0.500
# [epoch: 6, i: 11724]  train_loss: 0.536  |  valid_loss: 0.491
# [epoch: 6, i: 11899]  train_loss: 0.490  |  valid_loss: 0.751
# [epoch: 6, i: 12074]  train_loss: 0.524  |  valid_loss: 0.623
# [epoch: 6, i: 12249]  train_loss: 0.530  |  valid_loss: 0.756
# [epoch: 6, i: 12424]  train_loss: 0.449  |  valid_loss: 0.628
# [epoch: 6, i: 12599]  train_loss: 0.541  |  valid_loss: 0.562
# [epoch: 6, i: 12774]  train_loss: 0.521  |  valid_loss: 0.464
# [epoch: 6, i: 12949]  train_loss: 0.432  |  valid_loss: 0.455
# [epoch: 6, i: 13124]  train_loss: 0.511  |  valid_loss: 0.756
# [epoch: 6, i: 13299]  train_loss: 0.449  |  valid_loss: 0.588
# [epoch: 6, i: 13474]  train_loss: 0.501  |  valid_loss: 0.671
# [epoch: 6, i: 13649]  train_loss: 0.475  |  valid_loss: 0.510
# [epoch: 6, i: 13824]  train_loss: 0.491  |  valid_loss: 0.762
# [epoch: 6, i: 13999]  train_loss: 0.507  |  valid_loss: 0.576
# [epoch: 6, i: 14174]  train_loss: 0.481  |  valid_loss: 0.452
# [epoch: 6, i: 14349]  train_loss: 0.537  |  valid_loss: 0.497
# [epoch: 6, i: 14524]  train_loss: 0.542  |  valid_loss: 0.485
# [epoch: 6, i: 14699]  train_loss: 0.462  |  valid_loss: 0.555
# [epoch: 6, i: 14874]  train_loss: 0.542  |  valid_loss: 0.625
# [epoch: 6, i: 15049]  train_loss: 0.577  |  valid_loss: 0.620
# [epoch: 6, i: 15224]  train_loss: 0.497  |  valid_loss: 0.594
# [epoch: 6, i: 15399]  train_loss: 0.440  |  valid_loss: 0.567
# [epoch: 6, i: 15574]  train_loss: 0.503  |  valid_loss: 0.535
# [epoch: 6, i: 15749]  train_loss: 0.507  |  valid_loss: 0.776
# [epoch: 6, i: 15924]  train_loss: 0.534  |  valid_loss: 0.487
# [epoch: 6, i: 16099]  train_loss: 0.484  |  valid_loss: 0.449
# [epoch: 6, i: 16274]  train_loss: 0.525  |  valid_loss: 0.607
# [epoch: 6, i: 16449]  train_loss: 0.533  |  valid_loss: 0.664
# [epoch: 6, i: 16624]  train_loss: 0.515  |  valid_loss: 0.545
# [epoch: 6, i: 16799]  train_loss: 0.503  |  valid_loss: 0.542
# [epoch: 6, i: 16974]  train_loss: 0.524  |  valid_loss: 0.422
# [epoch: 6, i: 17149]  train_loss: 0.526  |  valid_loss: 0.713
# [epoch: 6, i: 17324]  train_loss: 0.450  |  valid_loss: 0.584
# [epoch: 6, i: 17499]  train_loss: 0.526  |  valid_loss: 0.614
# --> [End of epoch 6] train_accuracy: 82.54%  |  valid_accuracy: 79.85%
# --> [Start of epoch 7]  lr: 0.000500
# [epoch: 7, i:   174]  train_loss: 0.496  |  valid_loss: 0.571
# [epoch: 7, i:   349]  train_loss: 0.460  |  valid_loss: 0.448
# [epoch: 7, i:   524]  train_loss: 0.436  |  valid_loss: 0.536
# [epoch: 7, i:   699]  train_loss: 0.474  |  valid_loss: 0.625
# [epoch: 7, i:   874]  train_loss: 0.453  |  valid_loss: 0.514
# [epoch: 7, i:  1049]  train_loss: 0.439  |  valid_loss: 0.409
# [epoch: 7, i:  1224]  train_loss: 0.443  |  valid_loss: 0.492
# [epoch: 7, i:  1399]  train_loss: 0.502  |  valid_loss: 0.738
# [epoch: 7, i:  1574]  train_loss: 0.562  |  valid_loss: 0.899
# [epoch: 7, i:  1749]  train_loss: 0.406  |  valid_loss: 0.545
# [epoch: 7, i:  1924]  train_loss: 0.502  |  valid_loss: 0.628
# [epoch: 7, i:  2099]  train_loss: 0.448  |  valid_loss: 0.531
# [epoch: 7, i:  2274]  train_loss: 0.484  |  valid_loss: 0.370
# [epoch: 7, i:  2449]  train_loss: 0.447  |  valid_loss: 0.587
# [epoch: 7, i:  2624]  train_loss: 0.399  |  valid_loss: 0.451
# [epoch: 7, i:  2799]  train_loss: 0.459  |  valid_loss: 0.637
# [epoch: 7, i:  2974]  train_loss: 0.415  |  valid_loss: 0.501
# [epoch: 7, i:  3149]  train_loss: 0.425  |  valid_loss: 0.620
# [epoch: 7, i:  3324]  train_loss: 0.496  |  valid_loss: 0.618
# [epoch: 7, i:  3499]  train_loss: 0.478  |  valid_loss: 0.760
# [epoch: 7, i:  3674]  train_loss: 0.490  |  valid_loss: 0.573
# [epoch: 7, i:  3849]  train_loss: 0.461  |  valid_loss: 0.650
# [epoch: 7, i:  4024]  train_loss: 0.492  |  valid_loss: 0.569
# [epoch: 7, i:  4199]  train_loss: 0.481  |  valid_loss: 0.632
# [epoch: 7, i:  4374]  train_loss: 0.450  |  valid_loss: 0.804
# [epoch: 7, i:  4549]  train_loss: 0.447  |  valid_loss: 0.929
# [epoch: 7, i:  4724]  train_loss: 0.496  |  valid_loss: 0.440
# [epoch: 7, i:  4899]  train_loss: 0.491  |  valid_loss: 0.699
# [epoch: 7, i:  5074]  train_loss: 0.501  |  valid_loss: 0.574
# [epoch: 7, i:  5249]  train_loss: 0.506  |  valid_loss: 0.523
# [epoch: 7, i:  5424]  train_loss: 0.536  |  valid_loss: 0.637
# [epoch: 7, i:  5599]  train_loss: 0.460  |  valid_loss: 0.620
# [epoch: 7, i:  5774]  train_loss: 0.467  |  valid_loss: 0.401
# [epoch: 7, i:  5949]  train_loss: 0.499  |  valid_loss: 0.525
# [epoch: 7, i:  6124]  train_loss: 0.482  |  valid_loss: 0.853
# [epoch: 7, i:  6299]  train_loss: 0.506  |  valid_loss: 0.734
# [epoch: 7, i:  6474]  train_loss: 0.451  |  valid_loss: 0.836
# [epoch: 7, i:  6649]  train_loss: 0.471  |  valid_loss: 0.642
# [epoch: 7, i:  6824]  train_loss: 0.482  |  valid_loss: 0.408
# [epoch: 7, i:  6999]  train_loss: 0.486  |  valid_loss: 0.490
# [epoch: 7, i:  7174]  train_loss: 0.516  |  valid_loss: 0.562
# [epoch: 7, i:  7349]  train_loss: 0.468  |  valid_loss: 0.602
# [epoch: 7, i:  7524]  train_loss: 0.494  |  valid_loss: 0.416
# [epoch: 7, i:  7699]  train_loss: 0.530  |  valid_loss: 0.669
# [epoch: 7, i:  7874]  train_loss: 0.451  |  valid_loss: 0.527
# [epoch: 7, i:  8049]  train_loss: 0.481  |  valid_loss: 0.403
# [epoch: 7, i:  8224]  train_loss: 0.507  |  valid_loss: 0.543
# [epoch: 7, i:  8399]  train_loss: 0.452  |  valid_loss: 0.677
# [epoch: 7, i:  8574]  train_loss: 0.529  |  valid_loss: 0.474
# [epoch: 7, i:  8749]  train_loss: 0.445  |  valid_loss: 0.894
# [epoch: 7, i:  8924]  train_loss: 0.451  |  valid_loss: 0.556
# [epoch: 7, i:  9099]  train_loss: 0.476  |  valid_loss: 0.580
# [epoch: 7, i:  9274]  train_loss: 0.426  |  valid_loss: 0.567
# [epoch: 7, i:  9449]  train_loss: 0.442  |  valid_loss: 0.608
# [epoch: 7, i:  9624]  train_loss: 0.510  |  valid_loss: 0.542
# [epoch: 7, i:  9799]  train_loss: 0.457  |  valid_loss: 0.647
# [epoch: 7, i:  9974]  train_loss: 0.414  |  valid_loss: 0.656
# [epoch: 7, i: 10149]  train_loss: 0.464  |  valid_loss: 0.420
# [epoch: 7, i: 10324]  train_loss: 0.532  |  valid_loss: 0.638
# [epoch: 7, i: 10499]  train_loss: 0.486  |  valid_loss: 0.690
# [epoch: 7, i: 10674]  train_loss: 0.473  |  valid_loss: 0.576
# [epoch: 7, i: 10849]  train_loss: 0.477  |  valid_loss: 0.649
# [epoch: 7, i: 11024]  train_loss: 0.491  |  valid_loss: 0.490
# [epoch: 7, i: 11199]  train_loss: 0.484  |  valid_loss: 0.411
# [epoch: 7, i: 11374]  train_loss: 0.509  |  valid_loss: 0.565
# [epoch: 7, i: 11549]  train_loss: 0.503  |  valid_loss: 0.549
# [epoch: 7, i: 11724]  train_loss: 0.501  |  valid_loss: 0.527
# [epoch: 7, i: 11899]  train_loss: 0.522  |  valid_loss: 0.726
# [epoch: 7, i: 12074]  train_loss: 0.489  |  valid_loss: 0.478
# [epoch: 7, i: 12249]  train_loss: 0.491  |  valid_loss: 0.814
# [epoch: 7, i: 12424]  train_loss: 0.472  |  valid_loss: 0.664
# [epoch: 7, i: 12599]  train_loss: 0.438  |  valid_loss: 0.565
# [epoch: 7, i: 12774]  train_loss: 0.454  |  valid_loss: 0.581
# [epoch: 7, i: 12949]  train_loss: 0.435  |  valid_loss: 0.425
# [epoch: 7, i: 13124]  train_loss: 0.435  |  valid_loss: 0.697
# [epoch: 7, i: 13299]  train_loss: 0.502  |  valid_loss: 0.539
# [epoch: 7, i: 13474]  train_loss: 0.478  |  valid_loss: 0.719
# [epoch: 7, i: 13649]  train_loss: 0.488  |  valid_loss: 0.520
# [epoch: 7, i: 13824]  train_loss: 0.512  |  valid_loss: 0.672
# [epoch: 7, i: 13999]  train_loss: 0.458  |  valid_loss: 0.499
# [epoch: 7, i: 14174]  train_loss: 0.498  |  valid_loss: 0.509
# [epoch: 7, i: 14349]  train_loss: 0.491  |  valid_loss: 0.461
# [epoch: 7, i: 14524]  train_loss: 0.485  |  valid_loss: 0.536
# [epoch: 7, i: 14699]  train_loss: 0.438  |  valid_loss: 0.496
# [epoch: 7, i: 14874]  train_loss: 0.417  |  valid_loss: 0.518
# [epoch: 7, i: 15049]  train_loss: 0.483  |  valid_loss: 0.599
# [epoch: 7, i: 15224]  train_loss: 0.459  |  valid_loss: 0.587
# [epoch: 7, i: 15399]  train_loss: 0.518  |  valid_loss: 0.602
# [epoch: 7, i: 15574]  train_loss: 0.509  |  valid_loss: 0.570
# [epoch: 7, i: 15749]  train_loss: 0.477  |  valid_loss: 0.701
# [epoch: 7, i: 15924]  train_loss: 0.459  |  valid_loss: 0.422
# [epoch: 7, i: 16099]  train_loss: 0.528  |  valid_loss: 0.475
# [epoch: 7, i: 16274]  train_loss: 0.495  |  valid_loss: 0.632
# [epoch: 7, i: 16449]  train_loss: 0.479  |  valid_loss: 0.527
# [epoch: 7, i: 16624]  train_loss: 0.533  |  valid_loss: 0.582
# [epoch: 7, i: 16799]  train_loss: 0.402  |  valid_loss: 0.510
# [epoch: 7, i: 16974]  train_loss: 0.528  |  valid_loss: 0.416
# [epoch: 7, i: 17149]  train_loss: 0.528  |  valid_loss: 0.700
# [epoch: 7, i: 17324]  train_loss: 0.470  |  valid_loss: 0.657
# [epoch: 7, i: 17499]  train_loss: 0.466  |  valid_loss: 0.633
# --> [End of epoch 7] train_accuracy: 83.30%  |  valid_accuracy: 80.29%
# --> [Start of epoch 8]  lr: 0.000500
# [epoch: 8, i:   174]  train_loss: 0.479  |  valid_loss: 0.422
# [epoch: 8, i:   349]  train_loss: 0.412  |  valid_loss: 0.418
# [epoch: 8, i:   524]  train_loss: 0.405  |  valid_loss: 0.471
# [epoch: 8, i:   699]  train_loss: 0.432  |  valid_loss: 0.502
# [epoch: 8, i:   874]  train_loss: 0.440  |  valid_loss: 0.465
# [epoch: 8, i:  1049]  train_loss: 0.431  |  valid_loss: 0.475
# [epoch: 8, i:  1224]  train_loss: 0.451  |  valid_loss: 0.682
# [epoch: 8, i:  1399]  train_loss: 0.454  |  valid_loss: 0.747
# [epoch: 8, i:  1574]  train_loss: 0.434  |  valid_loss: 0.874
# [epoch: 8, i:  1749]  train_loss: 0.487  |  valid_loss: 0.540
# [epoch: 8, i:  1924]  train_loss: 0.466  |  valid_loss: 0.624
# [epoch: 8, i:  2099]  train_loss: 0.505  |  valid_loss: 0.618
# [epoch: 8, i:  2274]  train_loss: 0.424  |  valid_loss: 0.522
# [epoch: 8, i:  2449]  train_loss: 0.453  |  valid_loss: 0.660
# [epoch: 8, i:  2624]  train_loss: 0.417  |  valid_loss: 0.411
# [epoch: 8, i:  2799]  train_loss: 0.439  |  valid_loss: 0.555
# [epoch: 8, i:  2974]  train_loss: 0.499  |  valid_loss: 0.506
# [epoch: 8, i:  3149]  train_loss: 0.417  |  valid_loss: 0.563
# [epoch: 8, i:  3324]  train_loss: 0.431  |  valid_loss: 0.648
# [epoch: 8, i:  3499]  train_loss: 0.478  |  valid_loss: 0.742
# [epoch: 8, i:  3674]  train_loss: 0.455  |  valid_loss: 0.675
# [epoch: 8, i:  3849]  train_loss: 0.408  |  valid_loss: 0.665
# [epoch: 8, i:  4024]  train_loss: 0.467  |  valid_loss: 0.676
# [epoch: 8, i:  4199]  train_loss: 0.461  |  valid_loss: 0.572
# [epoch: 8, i:  4374]  train_loss: 0.426  |  valid_loss: 0.813
# [epoch: 8, i:  4549]  train_loss: 0.416  |  valid_loss: 0.947
# [epoch: 8, i:  4724]  train_loss: 0.460  |  valid_loss: 0.354
# [epoch: 8, i:  4899]  train_loss: 0.416  |  valid_loss: 0.587
# [epoch: 8, i:  5074]  train_loss: 0.434  |  valid_loss: 0.556
# [epoch: 8, i:  5249]  train_loss: 0.459  |  valid_loss: 0.562
# [epoch: 8, i:  5424]  train_loss: 0.467  |  valid_loss: 0.572
# [epoch: 8, i:  5599]  train_loss: 0.495  |  valid_loss: 0.544
# [epoch: 8, i:  5774]  train_loss: 0.459  |  valid_loss: 0.536
# [epoch: 8, i:  5949]  train_loss: 0.437  |  valid_loss: 0.641
# [epoch: 8, i:  6124]  train_loss: 0.403  |  valid_loss: 0.799
# [epoch: 8, i:  6299]  train_loss: 0.479  |  valid_loss: 0.739
# [epoch: 8, i:  6474]  train_loss: 0.444  |  valid_loss: 0.838
# [epoch: 8, i:  6649]  train_loss: 0.471  |  valid_loss: 0.550
# [epoch: 8, i:  6824]  train_loss: 0.463  |  valid_loss: 0.441
# [epoch: 8, i:  6999]  train_loss: 0.412  |  valid_loss: 0.433
# [epoch: 8, i:  7174]  train_loss: 0.484  |  valid_loss: 0.585
# [epoch: 8, i:  7349]  train_loss: 0.485  |  valid_loss: 0.541
# [epoch: 8, i:  7524]  train_loss: 0.382  |  valid_loss: 0.319
# [epoch: 8, i:  7699]  train_loss: 0.514  |  valid_loss: 0.612
# [epoch: 8, i:  7874]  train_loss: 0.478  |  valid_loss: 0.556
# [epoch: 8, i:  8049]  train_loss: 0.500  |  valid_loss: 0.425
# [epoch: 8, i:  8224]  train_loss: 0.484  |  valid_loss: 0.501
# [epoch: 8, i:  8399]  train_loss: 0.474  |  valid_loss: 0.635
# [epoch: 8, i:  8574]  train_loss: 0.470  |  valid_loss: 0.467
# [epoch: 8, i:  8749]  train_loss: 0.491  |  valid_loss: 0.749
# [epoch: 8, i:  8924]  train_loss: 0.469  |  valid_loss: 0.446
# [epoch: 8, i:  9099]  train_loss: 0.454  |  valid_loss: 0.584
# [epoch: 8, i:  9274]  train_loss: 0.451  |  valid_loss: 0.457
# [epoch: 8, i:  9449]  train_loss: 0.512  |  valid_loss: 0.549
# [epoch: 8, i:  9624]  train_loss: 0.477  |  valid_loss: 0.532
# [epoch: 8, i:  9799]  train_loss: 0.427  |  valid_loss: 0.608
# [epoch: 8, i:  9974]  train_loss: 0.460  |  valid_loss: 0.614
# [epoch: 8, i: 10149]  train_loss: 0.445  |  valid_loss: 0.428
# [epoch: 8, i: 10324]  train_loss: 0.456  |  valid_loss: 0.696
# [epoch: 8, i: 10499]  train_loss: 0.448  |  valid_loss: 0.596
# [epoch: 8, i: 10674]  train_loss: 0.466  |  valid_loss: 0.585
# [epoch: 8, i: 10849]  train_loss: 0.473  |  valid_loss: 0.516
# [epoch: 8, i: 11024]  train_loss: 0.458  |  valid_loss: 0.446
# [epoch: 8, i: 11199]  train_loss: 0.456  |  valid_loss: 0.538
# [epoch: 8, i: 11374]  train_loss: 0.450  |  valid_loss: 0.572
# [epoch: 8, i: 11549]  train_loss: 0.449  |  valid_loss: 0.603
# [epoch: 8, i: 11724]  train_loss: 0.416  |  valid_loss: 0.337
# [epoch: 8, i: 11899]  train_loss: 0.435  |  valid_loss: 0.620
# [epoch: 8, i: 12074]  train_loss: 0.508  |  valid_loss: 0.582
# [epoch: 8, i: 12249]  train_loss: 0.431  |  valid_loss: 0.681
# [epoch: 8, i: 12424]  train_loss: 0.483  |  valid_loss: 0.639
# [epoch: 8, i: 12599]  train_loss: 0.439  |  valid_loss: 0.558
# [epoch: 8, i: 12774]  train_loss: 0.451  |  valid_loss: 0.590
# [epoch: 8, i: 12949]  train_loss: 0.434  |  valid_loss: 0.384
# [epoch: 8, i: 13124]  train_loss: 0.467  |  valid_loss: 0.669
# [epoch: 8, i: 13299]  train_loss: 0.474  |  valid_loss: 0.544
# [epoch: 8, i: 13474]  train_loss: 0.439  |  valid_loss: 0.558
# [epoch: 8, i: 13649]  train_loss: 0.448  |  valid_loss: 0.545
# [epoch: 8, i: 13824]  train_loss: 0.473  |  valid_loss: 0.794
# [epoch: 8, i: 13999]  train_loss: 0.550  |  valid_loss: 0.557
# [epoch: 8, i: 14174]  train_loss: 0.483  |  valid_loss: 0.437
# [epoch: 8, i: 14349]  train_loss: 0.437  |  valid_loss: 0.464
# [epoch: 8, i: 14524]  train_loss: 0.421  |  valid_loss: 0.570
# [epoch: 8, i: 14699]  train_loss: 0.440  |  valid_loss: 0.409
# [epoch: 8, i: 14874]  train_loss: 0.476  |  valid_loss: 0.671
# [epoch: 8, i: 15049]  train_loss: 0.481  |  valid_loss: 0.596
# [epoch: 8, i: 15224]  train_loss: 0.515  |  valid_loss: 0.580
# [epoch: 8, i: 15399]  train_loss: 0.425  |  valid_loss: 0.586
# [epoch: 8, i: 15574]  train_loss: 0.418  |  valid_loss: 0.522
# [epoch: 8, i: 15749]  train_loss: 0.450  |  valid_loss: 0.582
# [epoch: 8, i: 15924]  train_loss: 0.436  |  valid_loss: 0.507
# [epoch: 8, i: 16099]  train_loss: 0.500  |  valid_loss: 0.444
# [epoch: 8, i: 16274]  train_loss: 0.462  |  valid_loss: 0.667
# [epoch: 8, i: 16449]  train_loss: 0.413  |  valid_loss: 0.573
# [epoch: 8, i: 16624]  train_loss: 0.413  |  valid_loss: 0.517
# [epoch: 8, i: 16799]  train_loss: 0.476  |  valid_loss: 0.494
# [epoch: 8, i: 16974]  train_loss: 0.442  |  valid_loss: 0.472
# [epoch: 8, i: 17149]  train_loss: 0.417  |  valid_loss: 0.660
# [epoch: 8, i: 17324]  train_loss: 0.467  |  valid_loss: 0.782
# [epoch: 8, i: 17499]  train_loss: 0.416  |  valid_loss: 0.607
# --> [End of epoch 8] train_accuracy: 84.07%  |  valid_accuracy: 80.71%
# --> [Start of epoch 9]  lr: 0.000500
# [epoch: 9, i:   174]  train_loss: 0.340  |  valid_loss: 0.436
# [epoch: 9, i:   349]  train_loss: 0.433  |  valid_loss: 0.468
# [epoch: 9, i:   524]  train_loss: 0.389  |  valid_loss: 0.583
# [epoch: 9, i:   699]  train_loss: 0.416  |  valid_loss: 0.450
# [epoch: 9, i:   874]  train_loss: 0.385  |  valid_loss: 0.393
# [epoch: 9, i:  1049]  train_loss: 0.418  |  valid_loss: 0.417
# [epoch: 9, i:  1224]  train_loss: 0.465  |  valid_loss: 0.500
# [epoch: 9, i:  1399]  train_loss: 0.441  |  valid_loss: 0.692
# [epoch: 9, i:  1574]  train_loss: 0.374  |  valid_loss: 0.790
# [epoch: 9, i:  1749]  train_loss: 0.456  |  valid_loss: 0.609
# [epoch: 9, i:  1924]  train_loss: 0.399  |  valid_loss: 0.474
# [epoch: 9, i:  2099]  train_loss: 0.454  |  valid_loss: 0.613
# [epoch: 9, i:  2274]  train_loss: 0.390  |  valid_loss: 0.462
# [epoch: 9, i:  2449]  train_loss: 0.432  |  valid_loss: 0.537
# [epoch: 9, i:  2624]  train_loss: 0.415  |  valid_loss: 0.418
# [epoch: 9, i:  2799]  train_loss: 0.425  |  valid_loss: 0.670
# [epoch: 9, i:  2974]  train_loss: 0.420  |  valid_loss: 0.483
# [epoch: 9, i:  3149]  train_loss: 0.438  |  valid_loss: 0.557
# [epoch: 9, i:  3324]  train_loss: 0.404  |  valid_loss: 0.587
# [epoch: 9, i:  3499]  train_loss: 0.405  |  valid_loss: 0.797
# [epoch: 9, i:  3674]  train_loss: 0.439  |  valid_loss: 0.675
# [epoch: 9, i:  3849]  train_loss: 0.484  |  valid_loss: 0.520
# [epoch: 9, i:  4024]  train_loss: 0.427  |  valid_loss: 0.731
# [epoch: 9, i:  4199]  train_loss: 0.460  |  valid_loss: 0.592
# [epoch: 9, i:  4374]  train_loss: 0.428  |  valid_loss: 0.659
# [epoch: 9, i:  4549]  train_loss: 0.531  |  valid_loss: 0.829
# [epoch: 9, i:  4724]  train_loss: 0.391  |  valid_loss: 0.428
# [epoch: 9, i:  4899]  train_loss: 0.421  |  valid_loss: 0.594
# [epoch: 9, i:  5074]  train_loss: 0.480  |  valid_loss: 0.626
# [epoch: 9, i:  5249]  train_loss: 0.526  |  valid_loss: 0.625
# [epoch: 9, i:  5424]  train_loss: 0.400  |  valid_loss: 0.582
# [epoch: 9, i:  5599]  train_loss: 0.486  |  valid_loss: 0.590
# [epoch: 9, i:  5774]  train_loss: 0.428  |  valid_loss: 0.547
# [epoch: 9, i:  5949]  train_loss: 0.440  |  valid_loss: 0.586
# [epoch: 9, i:  6124]  train_loss: 0.390  |  valid_loss: 0.720
# [epoch: 9, i:  6299]  train_loss: 0.414  |  valid_loss: 0.659
# [epoch: 9, i:  6474]  train_loss: 0.464  |  valid_loss: 0.710
# [epoch: 9, i:  6649]  train_loss: 0.385  |  valid_loss: 0.563
# [epoch: 9, i:  6824]  train_loss: 0.429  |  valid_loss: 0.452
# [epoch: 9, i:  6999]  train_loss: 0.429  |  valid_loss: 0.508
# [epoch: 9, i:  7174]  train_loss: 0.366  |  valid_loss: 0.488
# [epoch: 9, i:  7349]  train_loss: 0.456  |  valid_loss: 0.538
# [epoch: 9, i:  7524]  train_loss: 0.458  |  valid_loss: 0.440
# [epoch: 9, i:  7699]  train_loss: 0.450  |  valid_loss: 0.530
# [epoch: 9, i:  7874]  train_loss: 0.431  |  valid_loss: 0.463
# [epoch: 9, i:  8049]  train_loss: 0.394  |  valid_loss: 0.480
# [epoch: 9, i:  8224]  train_loss: 0.414  |  valid_loss: 0.552
# [epoch: 9, i:  8399]  train_loss: 0.448  |  valid_loss: 0.585
# [epoch: 9, i:  8574]  train_loss: 0.415  |  valid_loss: 0.416
# [epoch: 9, i:  8749]  train_loss: 0.398  |  valid_loss: 0.745
# [epoch: 9, i:  8924]  train_loss: 0.489  |  valid_loss: 0.457
# [epoch: 9, i:  9099]  train_loss: 0.515  |  valid_loss: 0.527
# [epoch: 9, i:  9274]  train_loss: 0.437  |  valid_loss: 0.503
# [epoch: 9, i:  9449]  train_loss: 0.389  |  valid_loss: 0.417
# [epoch: 9, i:  9624]  train_loss: 0.466  |  valid_loss: 0.630
# [epoch: 9, i:  9799]  train_loss: 0.413  |  valid_loss: 0.698
# [epoch: 9, i:  9974]  train_loss: 0.489  |  valid_loss: 0.646
# [epoch: 9, i: 10149]  train_loss: 0.476  |  valid_loss: 0.360
# [epoch: 9, i: 10324]  train_loss: 0.434  |  valid_loss: 0.572
# [epoch: 9, i: 10499]  train_loss: 0.472  |  valid_loss: 0.700
# [epoch: 9, i: 10674]  train_loss: 0.405  |  valid_loss: 0.538
# [epoch: 9, i: 10849]  train_loss: 0.439  |  valid_loss: 0.582
# [epoch: 9, i: 11024]  train_loss: 0.420  |  valid_loss: 0.499
# [epoch: 9, i: 11199]  train_loss: 0.411  |  valid_loss: 0.380
# [epoch: 9, i: 11374]  train_loss: 0.416  |  valid_loss: 0.625
# [epoch: 9, i: 11549]  train_loss: 0.447  |  valid_loss: 0.500
# [epoch: 9, i: 11724]  train_loss: 0.458  |  valid_loss: 0.539
# [epoch: 9, i: 11899]  train_loss: 0.382  |  valid_loss: 0.697
# [epoch: 9, i: 12074]  train_loss: 0.433  |  valid_loss: 0.607
# [epoch: 9, i: 12249]  train_loss: 0.514  |  valid_loss: 0.769
# [epoch: 9, i: 12424]  train_loss: 0.402  |  valid_loss: 0.662
# [epoch: 9, i: 12599]  train_loss: 0.415  |  valid_loss: 0.489
# [epoch: 9, i: 12774]  train_loss: 0.424  |  valid_loss: 0.454
# [epoch: 9, i: 12949]  train_loss: 0.448  |  valid_loss: 0.434
# [epoch: 9, i: 13124]  train_loss: 0.444  |  valid_loss: 0.770
# [epoch: 9, i: 13299]  train_loss: 0.462  |  valid_loss: 0.640
# [epoch: 9, i: 13474]  train_loss: 0.497  |  valid_loss: 0.664
# [epoch: 9, i: 13649]  train_loss: 0.447  |  valid_loss: 0.513
# [epoch: 9, i: 13824]  train_loss: 0.418  |  valid_loss: 0.666
# [epoch: 9, i: 13999]  train_loss: 0.397  |  valid_loss: 0.453
# [epoch: 9, i: 14174]  train_loss: 0.437  |  valid_loss: 0.468
# [epoch: 9, i: 14349]  train_loss: 0.469  |  valid_loss: 0.529
# [epoch: 9, i: 14524]  train_loss: 0.416  |  valid_loss: 0.479
# [epoch: 9, i: 14699]  train_loss: 0.496  |  valid_loss: 0.521
# [epoch: 9, i: 14874]  train_loss: 0.439  |  valid_loss: 0.623
# [epoch: 9, i: 15049]  train_loss: 0.443  |  valid_loss: 0.544
# [epoch: 9, i: 15224]  train_loss: 0.496  |  valid_loss: 0.489
# [epoch: 9, i: 15399]  train_loss: 0.369  |  valid_loss: 0.472
# [epoch: 9, i: 15574]  train_loss: 0.539  |  valid_loss: 0.500
# [epoch: 9, i: 15749]  train_loss: 0.432  |  valid_loss: 0.666
# [epoch: 9, i: 15924]  train_loss: 0.459  |  valid_loss: 0.420
# [epoch: 9, i: 16099]  train_loss: 0.419  |  valid_loss: 0.378
# [epoch: 9, i: 16274]  train_loss: 0.418  |  valid_loss: 0.673
# [epoch: 9, i: 16449]  train_loss: 0.407  |  valid_loss: 0.532
# [epoch: 9, i: 16624]  train_loss: 0.467  |  valid_loss: 0.452
# [epoch: 9, i: 16799]  train_loss: 0.501  |  valid_loss: 0.449
# [epoch: 9, i: 16974]  train_loss: 0.432  |  valid_loss: 0.456
# [epoch: 9, i: 17149]  train_loss: 0.443  |  valid_loss: 0.693
# [epoch: 9, i: 17324]  train_loss: 0.377  |  valid_loss: 0.603
# [epoch: 9, i: 17499]  train_loss: 0.413  |  valid_loss: 0.487
# --> [End of epoch 9] train_accuracy: 84.80%  |  valid_accuracy: 81.14%
# Finished Training.

# %%
plt.plot(avg_train_losses)
plt.plot(avg_valid_losses)
plt.title('rex_max_no_fc + plateau scheduling + l2 regularization')
plt.xlabel('mini-batch index / {}'.format(iter_n_per_record))
plt.ylabel('avg. mini-batch loss')
plt.legend(['training loss', 'validation loss'])
plt.show()

# %%
def moving_average(data, window_size):
    """Compute the moving average of the data using a specified window size."""
    return np.convolve(data, np.ones(window_size)/window_size, mode='valid')

window_size = 20  # Adjust this based on your preference
train_losses_ma = moving_average(avg_train_losses, window_size)
valid_losses_ma = moving_average(avg_valid_losses, window_size)

# x_axis = np.arange(len(train_losses_ma))/100 
x_axis = np.arange(window_size - 1, len(train_losses_ma) + window_size - 1)

plt.plot(avg_train_losses)
plt.plot(avg_valid_losses)
plt.plot(x_axis, train_losses_ma, linewidth=2)
plt.plot(x_axis, valid_losses_ma, linewidth=2)
plt.title('DenseNet loss trend + exponential scheduling + l2 regularization')
plt.xlabel('mini-batch index / {}'.format(iter_n_per_record))
plt.ylabel('avg. mini-batch loss')
plt.legend(['training loss', 'validation loss', 'training loss (moving avg)', 'validation loss (moving avg)'])
plt.show()

# %%
plt.plot(train_accuracies)
plt.plot(valid_accuracies)
plt.title('DenseMax accuracy curve for plateau scheduling + l2 regularization')
plt.xlabel('epoch / {}'.format(iter_n_per_record))
plt.ylabel('accuracy')
plt.legend(['train accuracy', 'validation accuracy'])
plt.show()

# %%
# print average time per epoch to 2nd decimal place
print(f"Average time per epoch: {np.mean(time_per_epoch):.2f} seconds")
print("number of parameters:", count_parameters(model))
print(f'model size: {get_model_size(model):.3f}MB')
# Out:
# Average time per epoch: 979.93 seconds
# number of parameters: 131970
# model size: 0.512MB

# %%
# The function to show an image.
def imshow(img):
    img = img / 2 + 0.5     # Unnormalize.
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# %%
# Check several images.
dataiter = iter(validloader)
images, labels = next(dataiter)
imshow(torchvision.utils.make_grid(images))
print('GroundTruth: ', ' '.join('%5s' % classes[labels[j]] for j in range(4)))
outputs = model(images.to(device))

# max compare along the row, return the index of the max value, which is the predicted class
_, predicted = torch.max(outputs, 1)

print('Predicted: ', ' '.join('%5s' % classes[predicted[j]]
                              for j in range(4)))
# Out:
# GroundTruth:    cat  ship  ship plane
# Predicted:    cat  ship  ship plane

# %%
images, labels = next(iter(validloader))
print(len(images))
# Out:
# 4

# %%
inference_time_per_image = []


model.to(device)
model.eval()
# Get test accuracy.
correct = 0
total = 0
with torch.no_grad():
    for data in validloader:
        images, labels = data
        images, labels = images.to(device), labels.to(device)
        inference_start = time.time()
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        inference_end = time.time()
        inference_time_per_image.append((inference_end - inference_start) / len(images))
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print('Accuracy of the network on the 10000 test images: %.2f %%' % (
    100 * correct / total))

# print average inference time per image in ms
print(f"average inference time per image: {sum(inference_time_per_image) * 1000 / len(inference_time_per_image):.3f} ms")
# Out:
# Accuracy of the network on the 10000 test images: 81.04 %
# average inference time per image: 1.400 ms

# %%
model.to(device)
model.eval()

# Get test accuracy for each class.
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))
with torch.no_grad():
    for data in validloader:
        images, labels = data
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels).squeeze()
        for i in range(4):
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1

for i in range(10):
    print('Accuracy of %5s : %2d %%' % (
        classes[i], 100 * class_correct[i] / class_total[i]))
# Out:
# Accuracy of plane : 83 %
# Accuracy of   car : 91 %
# Accuracy of  bird : 74 %
# Accuracy of   cat : 61 %
# Accuracy of  deer : 81 %
# Accuracy of   dog : 77 %
# Accuracy of  frog : 83 %
# Accuracy of horse : 80 %
# Accuracy of  ship : 85 %
# Accuracy of truck : 87 %
